# %%
###### With none-FE FDM coordinates match -- with 4 qs

import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import plotly.graph_objects as go

# q.grad.zero_()


# In[663]:


######################## explanation
## "The example model is based on a 5-nodes grid shell strcuture
##  which has a crossing projection in the x-y plane"
##  The FE part would be based on the Euler-bernoulli beam theory


# In[664]:


## Initial Geom
# Initial Coords:
node_coords = torch.tensor(
    [[0.0, 3.0, 0.0], [0.0, 6.0, 0.0], [3.0, 0.0, 0.0], [3.0, 3.0, 0.0], [3.0, 6.0, 0.0], [3.0, 9.0, 0.0],
     [6.0, 0.0, 0.0], [6.0, 3.0, 0.0], [6.0, 6.0, 0.0] ,[6.0, 9.0, 0.0], [9.0, 3.0 ,0.0], [9.0, 6.0, 0.0]],
    dtype=torch.float32, requires_grad=True, )
connectivity = [[1, 4], [2, 5], [3, 4], [5, 4], [6, 5], [4, 8], [7, 8], [9, 8],[11, 8],[10, 9],[12, 9],[5, 9]]
n_dof_per_node = 6  # Degrees of freedom per node
total_dof = n_dof_per_node * len(node_coords)
Fixed_nodes = [1, 2, 3, 6, 7, 10, 11, 12]
Free_nodes = []
n_elements = len(connectivity)
n_nodes = len(node_coords)
for i in range(1, n_nodes + 1):
    if i not in Fixed_nodes:
        Free_nodes.append(i)
idx_CF = [node - 1 for node in Fixed_nodes]
idx_CN = [i for i in range(n_nodes) if i not in idx_CF]

# In[665]:


## Force condition
####### Force condition -> need for modification
## +0 to x direction ; +1 to y direction ; +2 to Z direction
## +3 Bending around the z axis ; +4 bending around y axis ; +5 Twisting
# implement upwards loading of 50 kN at every free nodes
F = torch.zeros(total_dof, dtype=torch.float32)
f_n = Free_nodes
f_type = [2, 2, 2, 2]  # The force type
F_value = torch.tensor([50.0, 50.0, 50.0, 50.0]) * 1000  # The force value/direction
r = 1 / torch.max(F_value)
# print(r)
F_sign = torch.sign(F_value)
for idx, i in enumerate(f_n):
    F[6 * (i - 1) + f_type[idx]] = F_value[idx]  # unit: KN / KN*m

px = torch.zeros(len(f_n), 1, dtype=torch.float32)
py = torch.zeros(len(f_n), 1, dtype=torch.float32)
pz = torch.zeros(len(f_n), 1, dtype=torch.float32)

for i in range(len(f_n)):
    if f_type[idx] == 0:
        px[i] = F_value[i]
    elif f_type[idx] == 1:
        py[i] = F_value[i]
    elif f_type[idx] == 2:
        pz[i] = F_value[i]


## Obtaining Matrix D
# Assembly the nodal-branch matrix:
C = torch.zeros(n_elements, n_nodes, dtype=torch.float32)
for n, (i, j) in enumerate(connectivity):
    C[n, i - 1] = 1
    C[n, j - 1] = -1
CF = C[:, idx_CF]
CN = C[:, idx_CN]


# Assembly D
def FDM (Q,CN=CN, CF=CF, px=px, py=py, pz=pz,Fixed_nodes=Fixed_nodes, Free_nodes=Free_nodes,node_coords=node_coords) :
    Dn = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CN))
    DF = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CF))
    ## Coordinates solution
    # separate the coordinates:
    fixed_idces = [node - 1 for node in Fixed_nodes]
    xF = node_coords[fixed_idces, 0].unsqueeze(1)
    yF = node_coords[fixed_idces, 1].unsqueeze(1)
    zF = node_coords[fixed_idces, 2].unsqueeze(1)
    xN = torch.matmul(torch.inverse(Dn), (px - torch.matmul(DF, xF)))
    yN = torch.matmul(torch.inverse(Dn), (py - torch.matmul(DF, yF)))
    zN = torch.matmul(torch.inverse(Dn), (pz - torch.matmul(DF, zF)))
    ## Coordinates renewal: 
    new_node_coords = node_coords.clone()
    for idx, node in enumerate(Free_nodes):
        node_idx = node - 1
        new_node_coords[node_idx, 0] = xN[idx]
        new_node_coords[node_idx, 1] = yN[idx]
        new_node_coords[node_idx, 2] = zN[idx]

    return new_node_coords

# In[670]:

## Check point: FDM completed
# if q.grad is not None:
#     q.grad.zero_()
# loss = torch.sum(new_node_coords[:, 2])
# loss.backward()
# print("Gradient of q:")
# print(q.grad)



# Element creating
#################  input below:
############################################################################################################## input
# initial coordinates

####### BCs
fixed_dof = []
for node in Fixed_nodes:
    fixed_dof.extend([(node - 1) * 6 + i for i in range(6)])
# print(fixed_dof)
####### Gradient descent
step = 0.001
epochs = 800

####### Plotting
steps = 20  # steps for tracing deformation shape
###################################################################################################################################################
###################################################################################################################################################


### Defining the OBJ:
Obj_coords = torch.tensor([1.5, 1.5, 1.5, 1.5])
def Loss(Free_nodes, new_node_coords, Obj_coords):
    n_free_nodes = len(Free_nodes)
    Free_nodes = torch.tensor(Free_nodes)
    y_pred = new_node_coords[(Free_nodes - 1), 2]  
    y_true = Obj_coords 
    error = torch.abs(y_true - y_pred)
    loss = torch.mean(error)
    return loss

# In[679]:

# Optimized Variables
## initial variables
Idx_q1 = [3, 4, 5]
Idx_q2 = [1, 6, 11]
Idx_q3 = [8, 9, 10]
Idx_q4 = [2, 7, 12]
Idx_q1 = [i - 1 for i in Idx_q1] 
Idx_q2 = [i - 1 for i in Idx_q2]
Idx_q3 = [i - 1 for i in Idx_q3] 
Idx_q4 = [i - 1 for i in Idx_q4] 
q = torch.rand(4, requires_grad=True)
## Optimization
torch.autograd.set_detect_anomaly(True)

optimizer = optim.Adam([q], lr=step)
# Loop start
Loss_his = []
for iteration in range(epochs + 1):
#   print(iteration)
    # Forwards
    q_vec = torch.zeros(n_elements, requires_grad=True).clone()
    q_vec[Idx_q1] = q[0] 
    q_vec[Idx_q2] = q[1]
    q_vec[Idx_q3] = q[2] 
    q_vec[Idx_q4] = q[3] 
    Q = torch.diag(q_vec) * 1 / r  # scaling
    new_node_coords = FDM(Q)
    N_coords = new_node_coords.clone()
    # loss
    Loss_value = Loss(Free_nodes, new_node_coords, Obj_coords)
    Loss_his.append(Loss_value.item())
    # Backwards
    optimizer.zero_grad()
    # print(q.grad)
    Loss_value.backward(retain_graph=True)

    # Grad
    gradients = q.grad
    print(gradients)
    frob_norm = torch.norm(gradients)
    
    # Step
    optimizer.step()
#   print(gradients)
# #     mean_error = torch.mean(error)
#     for i in range(len(q)):
#         if error[i] > 2 * mean_error:
#             q[i].data -= 5 * step * q.grad[i] 
#         else:
#             q[i].data -= step * q.grad[i]
    print(new_node_coords)
    # print iteration
    if iteration % 5 == 0:
        print(f"Iteration {iteration}: Normalized Gradient = {frob_norm}, Adaptive learning rate = {step}")
print("Optimization completed.")
print(q)
# print("coordinates:",node_coords)

#############################################################################################################
x_orig = node_coords[:, 0].detach().numpy()
y_orig = node_coords[:, 1].detach().numpy()
z_orig = node_coords[:, 2].detach().numpy()

x_def = new_node_coords[:, 0].detach().numpy()
y_def = new_node_coords[:, 1].detach().numpy()
z_def = new_node_coords[:, 2].detach().numpy()

fig = go.Figure()

for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_orig[i-1], x_orig[j-1]],
        y=[y_orig[i-1], y_orig[j-1]],
        z=[z_orig[i-1], z_orig[j-1]],
        mode='lines',
        line=dict(color='blue', width=4),
        name='XY-projection(original)'
    ))

for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_def[i-1], x_def[j-1]],
        y=[y_def[i-1], y_def[j-1]],
        z=[z_def[i-1], z_def[j-1]],
        mode='lines',
        line=dict(color='red', width=4),
        name='FDM Solution'
    ))

for node in Free_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_def[node-1]],
        y=[y_def[node-1]],
        z=[z_def[node-1]],
        mode='markers+text',
        marker=dict(size=5, color='green'),
        text=[f'Node {node}'],
        textposition='top center',
        name=f'Free Node {node}'
    ))

fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        aspectmode='data'
    ),
    title='Deformation Comparison: Original vs. Deformed Geometry',
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()

##### Loss history
plt.figure()
plt.plot(range(epochs + 1), Loss_his, label='Loss History', color='blue', linewidth=2)
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Optimization Loss vs. Iterations')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# tensor([0.1438, 0.7541, 0.7108, 0.7108, 0.7108, 0.1438, 0.7541, 0.6798, 0.6798,
#         0.6798, 0.1438, 0.7541], grad_fn=<IndexPutBackward0>)
# tensor([0.4280, 0.4892, 0.3953, 0.3348])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9590, 2.9851, 0.9973],
#         [2.8023, 5.9866, 0.8303],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.4901, 2.8889, 0.7955],
#         [5.2704, 5.9621, 0.9599],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 0: Normalized Gradient = 0.831154465675354, Adaptive learning rate = 0.001
# tensor([0.1428, 0.7531, 0.7098, 0.7098, 0.7098, 0.1428, 0.7531, 0.6788, 0.6788,
#         0.6788, 0.1428, 0.7531], grad_fn=<IndexPutBackward0>)
# tensor([0.4297, 0.4912, 0.3967, 0.3359])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9586, 2.9851, 0.9994],
#         [2.8018, 5.9866, 0.8318],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.4909, 2.8887, 0.7968],
#         [5.2691, 5.9620, 0.9617],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1418, 0.7521, 0.7088, 0.7088, 0.7088, 0.1418, 0.7521, 0.6778, 0.6778,
#         0.6778, 0.1418, 0.7521], grad_fn=<IndexPutBackward0>)
# tensor([0.4314, 0.4932, 0.3982, 0.3370])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9582, 2.9851, 1.0015],
#         [2.8014, 5.9866, 0.8332],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.4916, 2.8885, 0.7980],
#         [5.2678, 5.9619, 0.9636],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1408, 0.7511, 0.7078, 0.7078, 0.7078, 0.1408, 0.7511, 0.6768, 0.6768,
#         0.6768, 0.1408, 0.7511], grad_fn=<IndexPutBackward0>)
# tensor([0.4331, 0.4953, 0.3996, 0.3381])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9578, 2.9851, 1.0036],
#         [2.8009, 5.9866, 0.8347],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.4924, 2.8883, 0.7992],
#         [5.2664, 5.9619, 0.9654],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1398, 0.7501, 0.7068, 0.7068, 0.7068, 0.1398, 0.7501, 0.6758, 0.6758,
#         0.6758, 0.1398, 0.7501], grad_fn=<IndexPutBackward0>)
# tensor([0.4348, 0.4973, 0.4010, 0.3393])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9574, 2.9852, 1.0057],
#         [2.8005, 5.9866, 0.8361],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.4932, 2.8881, 0.8005],
#         [5.2651, 5.9618, 0.9673],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1388, 0.7491, 0.7058, 0.7058, 0.7058, 0.1388, 0.7491, 0.6748, 0.6748,
#         0.6748, 0.1388, 0.7491], grad_fn=<IndexPutBackward0>)
# tensor([0.4366, 0.4994, 0.4025, 0.3404])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9570, 2.9852, 1.0079],
#         [2.8000, 5.9865, 0.8376],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.4940, 2.8879, 0.8017],
#         [5.2637, 5.9617, 0.9691],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 5: Normalized Gradient = 0.8472731113433838, Adaptive learning rate = 0.001
# tensor([0.1378, 0.7481, 0.7048, 0.7048, 0.7048, 0.1378, 0.7481, 0.6738, 0.6738,
#         0.6738, 0.1378, 0.7481], grad_fn=<IndexPutBackward0>)
# tensor([0.4383, 0.5015, 0.4040, 0.3416])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9566, 2.9852, 1.0100],
#         [2.7996, 5.9865, 0.8391],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.4948, 2.8877, 0.8030],
#         [5.2623, 5.9616, 0.9710],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1368, 0.7471, 0.7038, 0.7038, 0.7038, 0.1368, 0.7471, 0.6728, 0.6728,
#         0.6728, 0.1368, 0.7471], grad_fn=<IndexPutBackward0>)
# tensor([0.4401, 0.5036, 0.4054, 0.3427])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9562, 2.9852, 1.0122],
#         [2.7991, 5.9865, 0.8406],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.4956, 2.8875, 0.8042],
#         [5.2610, 5.9615, 0.9729],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1358, 0.7461, 0.7028, 0.7028, 0.7028, 0.1358, 0.7461, 0.6718, 0.6718,
#         0.6718, 0.1358, 0.7461], grad_fn=<IndexPutBackward0>)
# tensor([0.4419, 0.5057, 0.4069, 0.3439])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9558, 2.9852, 1.0143],
#         [2.7986, 5.9865, 0.8421],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.4964, 2.8873, 0.8055],
#         [5.2596, 5.9615, 0.9748],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1348, 0.7451, 0.7018, 0.7018, 0.7018, 0.1348, 0.7451, 0.6708, 0.6708,
#         0.6708, 0.1348, 0.7451], grad_fn=<IndexPutBackward0>)
# tensor([0.4437, 0.5078, 0.4084, 0.3450])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9554, 2.9852, 1.0165],
#         [2.7982, 5.9865, 0.8436],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.4972, 2.8871, 0.8067],
#         [5.2582, 5.9614, 0.9767],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1337, 0.7441, 0.7008, 0.7008, 0.7008, 0.1337, 0.7441, 0.6698, 0.6698,
#         0.6698, 0.1337, 0.7441], grad_fn=<IndexPutBackward0>)
# tensor([0.4455, 0.5099, 0.4099, 0.3462])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9550, 2.9853, 1.0187],
#         [2.7977, 5.9865, 0.8451],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.4980, 2.8869, 0.8080],
#         [5.2568, 5.9613, 0.9786],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 10: Normalized Gradient = 0.8639124035835266, Adaptive learning rate = 0.001
# tensor([0.1327, 0.7431, 0.6998, 0.6998, 0.6998, 0.1327, 0.7431, 0.6688, 0.6688,
#         0.6688, 0.1327, 0.7431], grad_fn=<IndexPutBackward0>)
# tensor([0.4473, 0.5121, 0.4114, 0.3474])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9546, 2.9853, 1.0209],
#         [2.7973, 5.9864, 0.8466],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.4989, 2.8867, 0.8093],
#         [5.2554, 5.9612, 0.9805],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1317, 0.7421, 0.6988, 0.6988, 0.6988, 0.1317, 0.7421, 0.6678, 0.6678,
#         0.6678, 0.1317, 0.7421], grad_fn=<IndexPutBackward0>)
# tensor([0.4491, 0.5142, 0.4129, 0.3486])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9541, 2.9853, 1.0231],
#         [2.7968, 5.9864, 0.8481],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.4997, 2.8865, 0.8105],
#         [5.2540, 5.9611, 0.9824],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1307, 0.7411, 0.6978, 0.6978, 0.6978, 0.1307, 0.7411, 0.6668, 0.6668,
#         0.6668, 0.1307, 0.7411], grad_fn=<IndexPutBackward0>)
# tensor([0.4510, 0.5164, 0.4144, 0.3498])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9537, 2.9853, 1.0253],
#         [2.7963, 5.9864, 0.8496],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5005, 2.8863, 0.8118],
#         [5.2526, 5.9611, 0.9844],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1297, 0.7401, 0.6968, 0.6968, 0.6968, 0.1297, 0.7401, 0.6658, 0.6658,
#         0.6658, 0.1297, 0.7401], grad_fn=<IndexPutBackward0>)
# tensor([0.4528, 0.5186, 0.4160, 0.3509])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9533, 2.9853, 1.0275],
#         [2.7958, 5.9864, 0.8511],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5013, 2.8861, 0.8131],
#         [5.2512, 5.9610, 0.9863],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1287, 0.7391, 0.6958, 0.6958, 0.6958, 0.1287, 0.7391, 0.6648, 0.6648,
#         0.6648, 0.1287, 0.7391], grad_fn=<IndexPutBackward0>)
# tensor([0.4547, 0.5209, 0.4175, 0.3522])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9528, 2.9853, 1.0298],
#         [2.7954, 5.9864, 0.8527],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5022, 2.8859, 0.8144],
#         [5.2498, 5.9609, 0.9882],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 15: Normalized Gradient = 0.8811231255531311, Adaptive learning rate = 0.001
# tensor([0.1277, 0.7381, 0.6948, 0.6948, 0.6948, 0.1277, 0.7381, 0.6638, 0.6638,
#         0.6638, 0.1277, 0.7381], grad_fn=<IndexPutBackward0>)
# tensor([0.4566, 0.5231, 0.4191, 0.3534])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9524, 2.9854, 1.0320],
#         [2.7949, 5.9864, 0.8542],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5030, 2.8857, 0.8157],
#         [5.2484, 5.9608, 0.9902],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1267, 0.7371, 0.6938, 0.6938, 0.6938, 0.1267, 0.7371, 0.6628, 0.6628,
#         0.6628, 0.1267, 0.7371], grad_fn=<IndexPutBackward0>)
# tensor([0.4585, 0.5253, 0.4206, 0.3546])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9520, 2.9854, 1.0343],
#         [2.7944, 5.9863, 0.8557],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5038, 2.8855, 0.8170],
#         [5.2469, 5.9607, 0.9922],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1257, 0.7361, 0.6928, 0.6928, 0.6928, 0.1257, 0.7361, 0.6618, 0.6618,
#         0.6618, 0.1257, 0.7361], grad_fn=<IndexPutBackward0>)
# tensor([0.4604, 0.5276, 0.4222, 0.3558])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9515, 2.9854, 1.0366],
#         [2.7939, 5.9863, 0.8573],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5047, 2.8853, 0.8183],
#         [5.2455, 5.9606, 0.9942],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1247, 0.7351, 0.6918, 0.6918, 0.6918, 0.1247, 0.7351, 0.6608, 0.6608,
#         0.6608, 0.1247, 0.7351], grad_fn=<IndexPutBackward0>)
# tensor([0.4623, 0.5299, 0.4238, 0.3571])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9511, 2.9854, 1.0389],
#         [2.7934, 5.9863, 0.8589],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5055, 2.8850, 0.8196],
#         [5.2440, 5.9606, 0.9962],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1237, 0.7340, 0.6907, 0.6907, 0.6907, 0.1237, 0.7340, 0.6598, 0.6598,
#         0.6598, 0.1237, 0.7340], grad_fn=<IndexPutBackward0>)
# tensor([0.4643, 0.5322, 0.4254, 0.3583])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9506, 2.9854, 1.0412],
#         [2.7929, 5.9863, 0.8604],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5064, 2.8848, 0.8209],
#         [5.2426, 5.9605, 0.9982],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 20: Normalized Gradient = 0.8989589214324951, Adaptive learning rate = 0.001
# tensor([0.1226, 0.7330, 0.6897, 0.6897, 0.6897, 0.1226, 0.7330, 0.6587, 0.6587,
#         0.6587, 0.1226, 0.7330], grad_fn=<IndexPutBackward0>)
# tensor([0.4662, 0.5345, 0.4270, 0.3596])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9502, 2.9855, 1.0435],
#         [2.7924, 5.9863, 0.8620],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5072, 2.8846, 0.8222],
#         [5.2411, 5.9604, 1.0002],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1216, 0.7320, 0.6887, 0.6887, 0.6887, 0.1216, 0.7320, 0.6577, 0.6577,
#         0.6577, 0.1216, 0.7320], grad_fn=<IndexPutBackward0>)
# tensor([0.4682, 0.5369, 0.4286, 0.3608])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9497, 2.9855, 1.0458],
#         [2.7919, 5.9863, 0.8636],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5081, 2.8844, 0.8236],
#         [5.2396, 5.9603, 1.0022],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1206, 0.7310, 0.6877, 0.6877, 0.6877, 0.1206, 0.7310, 0.6567, 0.6567,
#         0.6567, 0.1206, 0.7310], grad_fn=<IndexPutBackward0>)
# tensor([0.4702, 0.5392, 0.4303, 0.3621])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9492, 2.9855, 1.0482],
#         [2.7914, 5.9862, 0.8652],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5089, 2.8842, 0.8249],
#         [5.2382, 5.9602, 1.0042],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1196, 0.7300, 0.6867, 0.6867, 0.6867, 0.1196, 0.7300, 0.6557, 0.6557,
#         0.6557, 0.1196, 0.7300], grad_fn=<IndexPutBackward0>)
# tensor([0.4722, 0.5416, 0.4319, 0.3634])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9488, 2.9855, 1.0505],
#         [2.7909, 5.9862, 0.8668],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5098, 2.8840, 0.8262],
#         [5.2367, 5.9601, 1.0063],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1186, 0.7290, 0.6857, 0.6857, 0.6857, 0.1186, 0.7290, 0.6547, 0.6547,
#         0.6547, 0.1186, 0.7290], grad_fn=<IndexPutBackward0>)
# tensor([0.4742, 0.5440, 0.4336, 0.3646])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9483, 2.9855, 1.0529],
#         [2.7904, 5.9862, 0.8684],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5107, 2.8837, 0.8276],
#         [5.2352, 5.9601, 1.0083],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 25: Normalized Gradient = 0.9174753427505493, Adaptive learning rate = 0.001
# tensor([0.1176, 0.7280, 0.6846, 0.6846, 0.6846, 0.1176, 0.7280, 0.6537, 0.6537,
#         0.6537, 0.1176, 0.7280], grad_fn=<IndexPutBackward0>)
# tensor([0.4762, 0.5464, 0.4352, 0.3659])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9478, 2.9856, 1.0553],
#         [2.7899, 5.9862, 0.8700],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5115, 2.8835, 0.8289],
#         [5.2337, 5.9600, 1.0104],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1165, 0.7269, 0.6836, 0.6836, 0.6836, 0.1165, 0.7269, 0.6526, 0.6526,
#         0.6526, 0.1165, 0.7269], grad_fn=<IndexPutBackward0>)
# tensor([0.4783, 0.5489, 0.4369, 0.3672])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9473, 2.9856, 1.0577],
#         [2.7894, 5.9862, 0.8717],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5124, 2.8833, 0.8303],
#         [5.2322, 5.9599, 1.0125],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1155, 0.7259, 0.6826, 0.6826, 0.6826, 0.1155, 0.7259, 0.6516, 0.6516,
#         0.6516, 0.1155, 0.7259], grad_fn=<IndexPutBackward0>)
# tensor([0.4804, 0.5513, 0.4386, 0.3686])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9469, 2.9856, 1.0601],
#         [2.7889, 5.9862, 0.8733],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5133, 2.8831, 0.8316],
#         [5.2306, 5.9598, 1.0145],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1145, 0.7249, 0.6816, 0.6816, 0.6816, 0.1145, 0.7249, 0.6506, 0.6506,
#         0.6506, 0.1145, 0.7249], grad_fn=<IndexPutBackward0>)
# tensor([0.4824, 0.5538, 0.4403, 0.3699])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9464, 2.9856, 1.0626],
#         [2.7883, 5.9861, 0.8750],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5142, 2.8829, 0.8330],
#         [5.2291, 5.9597, 1.0166],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1135, 0.7239, 0.6805, 0.6805, 0.6805, 0.1135, 0.7239, 0.6496, 0.6496,
#         0.6496, 0.1135, 0.7239], grad_fn=<IndexPutBackward0>)
# tensor([0.4846, 0.5563, 0.4420, 0.3712])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9459, 2.9857, 1.0650],
#         [2.7878, 5.9861, 0.8766],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5151, 2.8826, 0.8344],
#         [5.2276, 5.9596, 1.0188],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 30: Normalized Gradient = 0.9367296695709229, Adaptive learning rate = 0.001
# tensor([0.1124, 0.7228, 0.6795, 0.6795, 0.6795, 0.1124, 0.7228, 0.6485, 0.6485,
#         0.6485, 0.1124, 0.7228], grad_fn=<IndexPutBackward0>)
# tensor([0.4867, 0.5589, 0.4437, 0.3725])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9454, 2.9857, 1.0675],
#         [2.7873, 5.9861, 0.8783],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5160, 2.8824, 0.8357],
#         [5.2260, 5.9595, 1.0209],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1114, 0.7218, 0.6785, 0.6785, 0.6785, 0.1114, 0.7218, 0.6475, 0.6475,
#         0.6475, 0.1114, 0.7218], grad_fn=<IndexPutBackward0>)
# tensor([0.4888, 0.5614, 0.4455, 0.3739])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9449, 2.9857, 1.0700],
#         [2.7868, 5.9861, 0.8800],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5169, 2.8822, 0.8371],
#         [5.2245, 5.9594, 1.0230],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1104, 0.7208, 0.6774, 0.6774, 0.6774, 0.1104, 0.7208, 0.6465, 0.6465,
#         0.6465, 0.1104, 0.7208], grad_fn=<IndexPutBackward0>)
# tensor([0.4910, 0.5640, 0.4472, 0.3752])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9443, 2.9857, 1.0725],
#         [2.7862, 5.9861, 0.8816],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5178, 2.8819, 0.8385],
#         [5.2229, 5.9593, 1.0252],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1093, 0.7198, 0.6764, 0.6764, 0.6764, 0.1093, 0.7198, 0.6455, 0.6455,
#         0.6455, 0.1093, 0.7198], grad_fn=<IndexPutBackward0>)
# tensor([0.4932, 0.5666, 0.4490, 0.3766])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9438, 2.9858, 1.0750],
#         [2.7857, 5.9860, 0.8833],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5187, 2.8817, 0.8399],
#         [5.2213, 5.9592, 1.0273],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1083, 0.7187, 0.6754, 0.6754, 0.6754, 0.1083, 0.7187, 0.6444, 0.6444,
#         0.6444, 0.1083, 0.7187], grad_fn=<IndexPutBackward0>)
# tensor([0.4954, 0.5692, 0.4508, 0.3780])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9433, 2.9858, 1.0775],
#         [2.7851, 5.9860, 0.8850],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5196, 2.8815, 0.8413],
#         [5.2197, 5.9592, 1.0295],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 35: Normalized Gradient = 0.9567819237709045, Adaptive learning rate = 0.001
# tensor([0.1072, 0.7177, 0.6743, 0.6743, 0.6743, 0.1072, 0.7177, 0.6434, 0.6434,
#         0.6434, 0.1072, 0.7177], grad_fn=<IndexPutBackward0>)
# tensor([0.4976, 0.5718, 0.4526, 0.3794])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9428, 2.9858, 1.0801],
#         [2.7846, 5.9860, 0.8868],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5206, 2.8812, 0.8427],
#         [5.2181, 5.9591, 1.0317],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1062, 0.7167, 0.6733, 0.6733, 0.6733, 0.1062, 0.7167, 0.6424, 0.6424,
#         0.6424, 0.1062, 0.7167], grad_fn=<IndexPutBackward0>)
# tensor([0.4998, 0.5745, 0.4544, 0.3808])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9423, 2.9858, 1.0827],
#         [2.7840, 5.9860, 0.8885],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5215, 2.8810, 0.8441],
#         [5.2165, 5.9590, 1.0339],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1052, 0.7156, 0.6722, 0.6722, 0.6722, 0.1052, 0.7156, 0.6413, 0.6413,
#         0.6413, 0.1052, 0.7156], grad_fn=<IndexPutBackward0>)
# tensor([0.5021, 0.5772, 0.4562, 0.3822])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9417, 2.9859, 1.0853],
#         [2.7835, 5.9860, 0.8902],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5224, 2.8808, 0.8456],
#         [5.2149, 5.9589, 1.0361],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1041, 0.7146, 0.6712, 0.6712, 0.6712, 0.1041, 0.7146, 0.6403, 0.6403,
#         0.6403, 0.1041, 0.7146], grad_fn=<IndexPutBackward0>)
# tensor([0.5044, 0.5799, 0.4580, 0.3836])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9412, 2.9859, 1.0879],
#         [2.7829, 5.9860, 0.8920],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5234, 2.8805, 0.8470],
#         [5.2133, 5.9588, 1.0383],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1031, 0.7136, 0.6702, 0.6702, 0.6702, 0.1031, 0.7136, 0.6392, 0.6392,
#         0.6392, 0.1031, 0.7136], grad_fn=<IndexPutBackward0>)
# tensor([0.5066, 0.5826, 0.4599, 0.3850])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9406, 2.9859, 1.0905],
#         [2.7824, 5.9859, 0.8937],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5243, 2.8803, 0.8484],
#         [5.2117, 5.9587, 1.0406],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 40: Normalized Gradient = 0.9776939749717712, Adaptive learning rate = 0.001
# tensor([0.1020, 0.7125, 0.6691, 0.6691, 0.6691, 0.1020, 0.7125, 0.6382, 0.6382,
#         0.6382, 0.1020, 0.7125], grad_fn=<IndexPutBackward0>)
# tensor([0.5090, 0.5854, 0.4617, 0.3865])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9401, 2.9860, 1.0931],
#         [2.7818, 5.9859, 0.8955],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5252, 2.8800, 0.8499],
#         [5.2100, 5.9586, 1.0428],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1010, 0.7115, 0.6681, 0.6681, 0.6681, 0.1010, 0.7115, 0.6371, 0.6371,
#         0.6371, 0.1010, 0.7115], grad_fn=<IndexPutBackward0>)
# tensor([0.5113, 0.5882, 0.4636, 0.3879])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9395, 2.9860, 1.0958],
#         [2.7812, 5.9859, 0.8973],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5262, 2.8798, 0.8513],
#         [5.2084, 5.9585, 1.0451],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0999, 0.7104, 0.6670, 0.6670, 0.6670, 0.0999, 0.7104, 0.6361, 0.6361,
#         0.6361, 0.0999, 0.7104], grad_fn=<IndexPutBackward0>)
# tensor([0.5137, 0.5910, 0.4655, 0.3894])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9389, 2.9860, 1.0985],
#         [2.7806, 5.9859, 0.8990],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5272, 2.8795, 0.8528],
#         [5.2067, 5.9584, 1.0474],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0989, 0.7094, 0.6660, 0.6660, 0.6660, 0.0989, 0.7094, 0.6351, 0.6351,
#         0.6351, 0.0989, 0.7094], grad_fn=<IndexPutBackward0>)
# tensor([0.5161, 0.5938, 0.4674, 0.3909])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9384, 2.9860, 1.1012],
#         [2.7801, 5.9859, 0.9008],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5281, 2.8793, 0.8543],
#         [5.2050, 5.9583, 1.0497],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0978, 0.7083, 0.6649, 0.6649, 0.6649, 0.0978, 0.7083, 0.6340, 0.6340,
#         0.6340, 0.0978, 0.7083], grad_fn=<IndexPutBackward0>)
# tensor([0.5185, 0.5967, 0.4694, 0.3923])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9378, 2.9861, 1.1039],
#         [2.7795, 5.9858, 0.9027],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5291, 2.8790, 0.8557],
#         [5.2033, 5.9582, 1.0520],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 45: Normalized Gradient = 0.9995309114456177, Adaptive learning rate = 0.001
# tensor([0.0967, 0.7073, 0.6638, 0.6638, 0.6638, 0.0967, 0.7073, 0.6329, 0.6329,
#         0.6329, 0.0967, 0.7073], grad_fn=<IndexPutBackward0>)
# tensor([0.5209, 0.5996, 0.4713, 0.3938])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9372, 2.9861, 1.1066],
#         [2.7789, 5.9858, 0.9045],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5301, 2.8788, 0.8572],
#         [5.2016, 5.9581, 1.0543],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0957, 0.7062, 0.6628, 0.6628, 0.6628, 0.0957, 0.7062, 0.6319, 0.6319,
#         0.6319, 0.0957, 0.7062], grad_fn=<IndexPutBackward0>)
# tensor([0.5233, 0.6025, 0.4732, 0.3953])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9366, 2.9861, 1.1094],
#         [2.7783, 5.9858, 0.9063],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5311, 2.8785, 0.8587],
#         [5.1999, 5.9580, 1.0566],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0946, 0.7052, 0.6617, 0.6617, 0.6617, 0.0946, 0.7052, 0.6308, 0.6308,
#         0.6308, 0.0946, 0.7052], grad_fn=<IndexPutBackward0>)
# tensor([0.5258, 0.6055, 0.4752, 0.3969])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9360, 2.9862, 1.1122],
#         [2.7777, 5.9858, 0.9081],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5321, 2.8783, 0.8602],
#         [5.1982, 5.9579, 1.0590],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0935, 0.7041, 0.6607, 0.6607, 0.6607, 0.0935, 0.7041, 0.6298, 0.6298,
#         0.6298, 0.0935, 0.7041], grad_fn=<IndexPutBackward0>)
# tensor([0.5283, 0.6084, 0.4772, 0.3984])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9354, 2.9862, 1.1150],
#         [2.7771, 5.9858, 0.9100],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5331, 2.8780, 0.8617],
#         [5.1965, 5.9578, 1.0613],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0925, 0.7031, 0.6596, 0.6596, 0.6596, 0.0925, 0.7031, 0.6287, 0.6287,
#         0.6287, 0.0925, 0.7031], grad_fn=<IndexPutBackward0>)
# tensor([0.5308, 0.6114, 0.4792, 0.3999])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9348, 2.9862, 1.1178],
#         [2.7765, 5.9858, 0.9119],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5341, 2.8778, 0.8632],
#         [5.1947, 5.9577, 1.0637],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 50: Normalized Gradient = 1.022363305091858, Adaptive learning rate = 0.001
# tensor([0.0914, 0.7020, 0.6585, 0.6585, 0.6585, 0.0914, 0.7020, 0.6277, 0.6277,
#         0.6277, 0.0914, 0.7020], grad_fn=<IndexPutBackward0>)
# tensor([0.5334, 0.6145, 0.4812, 0.4015])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9342, 2.9863, 1.1206],
#         [2.7759, 5.9857, 0.9137],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5351, 2.8775, 0.8647],
#         [5.1930, 5.9576, 1.0661],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0903, 0.7010, 0.6574, 0.6574, 0.6574, 0.0903, 0.7010, 0.6266, 0.6266,
#         0.6266, 0.0903, 0.7010], grad_fn=<IndexPutBackward0>)
# tensor([0.5360, 0.6175, 0.4833, 0.4030])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9336, 2.9863, 1.1235],
#         [2.7752, 5.9857, 0.9156],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5361, 2.8772, 0.8662],
#         [5.1912, 5.9575, 1.0685],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0893, 0.6999, 0.6564, 0.6564, 0.6564, 0.0893, 0.6999, 0.6255, 0.6255,
#         0.6255, 0.0893, 0.6999], grad_fn=<IndexPutBackward0>)
# tensor([0.5386, 0.6206, 0.4853, 0.4046])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9329, 2.9863, 1.1264],
#         [2.7746, 5.9857, 0.9175],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5371, 2.8770, 0.8678],
#         [5.1894, 5.9574, 1.0710],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0882, 0.6988, 0.6553, 0.6553, 0.6553, 0.0882, 0.6988, 0.6245, 0.6245,
#         0.6245, 0.0882, 0.6988], grad_fn=<IndexPutBackward0>)
# tensor([0.5412, 0.6238, 0.4874, 0.4062])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9323, 2.9864, 1.1293],
#         [2.7740, 5.9857, 0.9195],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5381, 2.8767, 0.8693],
#         [5.1876, 5.9573, 1.0734],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0871, 0.6978, 0.6542, 0.6542, 0.6542, 0.0871, 0.6978, 0.6234, 0.6234,
#         0.6234, 0.0871, 0.6978], grad_fn=<IndexPutBackward0>)
# tensor([0.5438, 0.6269, 0.4895, 0.4078])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9317, 2.9864, 1.1322],
#         [2.7734, 5.9857, 0.9214],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5392, 2.8764, 0.8709],
#         [5.1858, 5.9572, 1.0759],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 55: Normalized Gradient = 1.0462656021118164, Adaptive learning rate = 0.001
# tensor([0.0860, 0.6967, 0.6531, 0.6531, 0.6531, 0.0860, 0.6967, 0.6223, 0.6223,
#         0.6223, 0.0860, 0.6967], grad_fn=<IndexPutBackward0>)
# tensor([0.5465, 0.6301, 0.4916, 0.4094])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9310, 2.9864, 1.1352],
#         [2.7727, 5.9856, 0.9233],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5402, 2.8762, 0.8724],
#         [5.1840, 5.9570, 1.0784],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0849, 0.6957, 0.6521, 0.6521, 0.6521, 0.0849, 0.6957, 0.6212, 0.6212,
#         0.6212, 0.0849, 0.6957], grad_fn=<IndexPutBackward0>)
# tensor([0.5492, 0.6333, 0.4937, 0.4110])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9304, 2.9865, 1.1381],
#         [2.7721, 5.9856, 0.9253],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5413, 2.8759, 0.8740],
#         [5.1822, 5.9569, 1.0808],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0838, 0.6946, 0.6510, 0.6510, 0.6510, 0.0838, 0.6946, 0.6202, 0.6202,
#         0.6202, 0.0838, 0.6946], grad_fn=<IndexPutBackward0>)
# tensor([0.5519, 0.6366, 0.4959, 0.4127])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9297, 2.9865, 1.1411],
#         [2.7714, 5.9856, 0.9272],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5423, 2.8756, 0.8756],
#         [5.1804, 5.9568, 1.0834],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0827, 0.6935, 0.6499, 0.6499, 0.6499, 0.0827, 0.6935, 0.6191, 0.6191,
#         0.6191, 0.0827, 0.6935], grad_fn=<IndexPutBackward0>)
# tensor([0.5547, 0.6399, 0.4980, 0.4143])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9290, 2.9866, 1.1441],
#         [2.7708, 5.9856, 0.9292],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5434, 2.8753, 0.8771],
#         [5.1785, 5.9567, 1.0859],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0817, 0.6924, 0.6488, 0.6488, 0.6488, 0.0817, 0.6924, 0.6180, 0.6180,
#         0.6180, 0.0817, 0.6924], grad_fn=<IndexPutBackward0>)
# tensor([0.5575, 0.6432, 0.5002, 0.4160])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9283, 2.9866, 1.1472],
#         [2.7701, 5.9856, 0.9312],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5444, 2.8750, 0.8787],
#         [5.1766, 5.9566, 1.0884],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 60: Normalized Gradient = 1.0713186264038086, Adaptive learning rate = 0.001
# tensor([0.0806, 0.6914, 0.6477, 0.6477, 0.6477, 0.0806, 0.6914, 0.6169, 0.6169,
#         0.6169, 0.0806, 0.6914], grad_fn=<IndexPutBackward0>)
# tensor([0.5603, 0.6465, 0.5024, 0.4177])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9277, 2.9866, 1.1503],
#         [2.7695, 5.9855, 0.9332],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5455, 2.8748, 0.8803],
#         [5.1748, 5.9565, 1.0910],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0795, 0.6903, 0.6466, 0.6466, 0.6466, 0.0795, 0.6903, 0.6159, 0.6159,
#         0.6159, 0.0795, 0.6903], grad_fn=<IndexPutBackward0>)
# tensor([0.5631, 0.6499, 0.5046, 0.4194])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9270, 2.9867, 1.1533],
#         [2.7688, 5.9855, 0.9352],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5466, 2.8745, 0.8819],
#         [5.1729, 5.9564, 1.0936],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0784, 0.6892, 0.6455, 0.6455, 0.6455, 0.0784, 0.6892, 0.6148, 0.6148,
#         0.6148, 0.0784, 0.6892], grad_fn=<IndexPutBackward0>)
# tensor([0.5660, 0.6534, 0.5069, 0.4211])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9263, 2.9867, 1.1565],
#         [2.7681, 5.9855, 0.9373],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5477, 2.8742, 0.8835],
#         [5.1710, 5.9563, 1.0962],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0773, 0.6881, 0.6444, 0.6444, 0.6444, 0.0773, 0.6881, 0.6137, 0.6137,
#         0.6137, 0.0773, 0.6881], grad_fn=<IndexPutBackward0>)
# tensor([0.5689, 0.6568, 0.5091, 0.4228])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9255, 2.9868, 1.1596],
#         [2.7674, 5.9855, 0.9393],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5488, 2.8739, 0.8852],
#         [5.1691, 5.9562, 1.0988],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0762, 0.6870, 0.6433, 0.6433, 0.6433, 0.0762, 0.6870, 0.6126, 0.6126,
#         0.6126, 0.0762, 0.6870], grad_fn=<IndexPutBackward0>)
# tensor([0.5718, 0.6603, 0.5114, 0.4245])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9248, 2.9868, 1.1628],
#         [2.7668, 5.9855, 0.9414],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5499, 2.8736, 0.8868],
#         [5.1671, 5.9560, 1.1014],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 65: Normalized Gradient = 1.0976120233535767, Adaptive learning rate = 0.001
# tensor([0.0750, 0.6860, 0.6422, 0.6422, 0.6422, 0.0750, 0.6860, 0.6115, 0.6115,
#         0.6115, 0.0750, 0.6860], grad_fn=<IndexPutBackward0>)
# tensor([0.5748, 0.6639, 0.5137, 0.4263])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9241, 2.9869, 1.1660],
#         [2.7661, 5.9854, 0.9435],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5510, 2.8733, 0.8884],
#         [5.1652, 5.9559, 1.1041],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0739, 0.6849, 0.6411, 0.6411, 0.6411, 0.0739, 0.6849, 0.6104, 0.6104,
#         0.6104, 0.0739, 0.6849], grad_fn=<IndexPutBackward0>)
# tensor([0.5778, 0.6674, 0.5160, 0.4281])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9234, 2.9869, 1.1692],
#         [2.7654, 5.9854, 0.9455],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5521, 2.8730, 0.8901],
#         [5.1632, 5.9558, 1.1067],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0728, 0.6838, 0.6400, 0.6400, 0.6400, 0.0728, 0.6838, 0.6093, 0.6093,
#         0.6093, 0.0728, 0.6838], grad_fn=<IndexPutBackward0>)
# tensor([0.5808, 0.6710, 0.5183, 0.4298])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9226, 2.9869, 1.1724],
#         [2.7647, 5.9854, 0.9476],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5532, 2.8727, 0.8917],
#         [5.1613, 5.9557, 1.1094],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0717, 0.6827, 0.6389, 0.6389, 0.6389, 0.0717, 0.6827, 0.6082, 0.6082,
#         0.6082, 0.0717, 0.6827], grad_fn=<IndexPutBackward0>)
# tensor([0.5838, 0.6747, 0.5207, 0.4316])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9219, 2.9870, 1.1757],
#         [2.7640, 5.9854, 0.9498],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5544, 2.8724, 0.8934],
#         [5.1593, 5.9556, 1.1121],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0706, 0.6816, 0.6378, 0.6378, 0.6378, 0.0706, 0.6816, 0.6071, 0.6071,
#         0.6071, 0.0706, 0.6816], grad_fn=<IndexPutBackward0>)
# tensor([0.5869, 0.6784, 0.5231, 0.4335])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9211, 2.9870, 1.1790],
#         [2.7632, 5.9854, 0.9519],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5555, 2.8721, 0.8951],
#         [5.1573, 5.9554, 1.1148],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 70: Normalized Gradient = 1.1252415180206299, Adaptive learning rate = 0.001
# tensor([0.0695, 0.6805, 0.6366, 0.6366, 0.6366, 0.0695, 0.6805, 0.6060, 0.6060,
#         0.6060, 0.0695, 0.6805], grad_fn=<IndexPutBackward0>)
# tensor([0.5900, 0.6821, 0.5255, 0.4353])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9203, 2.9871, 1.1823],
#         [2.7625, 5.9853, 0.9540],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5567, 2.8718, 0.8968],
#         [5.1552, 5.9553, 1.1176],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0683, 0.6794, 0.6355, 0.6355, 0.6355, 0.0683, 0.6794, 0.6049, 0.6049,
#         0.6049, 0.0683, 0.6794], grad_fn=<IndexPutBackward0>)
# tensor([0.5932, 0.6859, 0.5279, 0.4371])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9195, 2.9871, 1.1857],
#         [2.7618, 5.9853, 0.9562],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5578, 2.8715, 0.8984],
#         [5.1532, 5.9552, 1.1204],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0672, 0.6783, 0.6344, 0.6344, 0.6344, 0.0672, 0.6783, 0.6038, 0.6038,
#         0.6038, 0.0672, 0.6783], grad_fn=<IndexPutBackward0>)
# tensor([0.5964, 0.6897, 0.5304, 0.4390])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9188, 2.9872, 1.1890],
#         [2.7611, 5.9853, 0.9584],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5590, 2.8712, 0.9001],
#         [5.1512, 5.9551, 1.1231],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0661, 0.6772, 0.6333, 0.6333, 0.6333, 0.0661, 0.6772, 0.6027, 0.6027,
#         0.6027, 0.0661, 0.6772], grad_fn=<IndexPutBackward0>)
# tensor([0.5996, 0.6935, 0.5328, 0.4409])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9180, 2.9872, 1.1925],
#         [2.7603, 5.9853, 0.9606],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5602, 2.8709, 0.9019],
#         [5.1491, 5.9550, 1.1259],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.0649, 0.6761, 0.6321, 0.6321, 0.6321, 0.0649, 0.6761, 0.6016, 0.6016,
#         0.6016, 0.0649, 0.6761], grad_fn=<IndexPutBackward0>)
# tensor([0.6029, 0.6974, 0.5353, 0.4427])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [2.9171, 2.9873, 1.1959],
#         [2.7596, 5.9853, 0.9628],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.5613, 2.8706, 0.9036],
#         [5.1470, 5.9548, 1.1288],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# ...
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1480, 3.1480, 1.5001],
#         [3.0977, 6.0977, 1.5000],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8572, 3.8570, 1.5002],
#         [6.3291, 6.3293, 1.5003],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1742, 0.1744, 0.4926, 0.4926, 0.4926, 0.1742, 0.1744, 0.4926, 0.4926,
#         0.4926, 0.1742, 0.1744], grad_fn=<IndexPutBackward0>)
# tensor([1.1243, 1.1244, 1.1242, 1.1241])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1480, 3.1480, 1.4996],
#         [3.0976, 6.0977, 1.4994],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8570, 3.8566, 1.4994],
#         [6.3288, 6.3291, 1.4996],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1741, 0.1743, 0.4925, 0.4925, 0.4925, 0.1741, 0.1743, 0.4926, 0.4926,
#         0.4926, 0.1741, 0.1743], grad_fn=<IndexPutBackward0>)
# tensor([1.1249, 1.1249, 1.1246, 1.1246])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1480, 3.1480, 1.5000],
#         [3.0976, 6.0977, 1.4998],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8572, 3.8568, 1.4996],
#         [6.3288, 6.3292, 1.4998],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1738, 0.1741, 0.4922, 0.4922, 0.4922, 0.1738, 0.1741, 0.4923, 0.4923,
#         0.4923, 0.1738, 0.1741], grad_fn=<IndexPutBackward0>)
# tensor([-1.1268, -1.1267, -1.1264, -1.1265])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1481, 3.1480, 1.5013],
#         [3.0977, 6.0977, 1.5011],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8580, 3.8576, 1.5009],
#         [6.3293, 6.3296, 1.5010],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 785: Normalized Gradient = 2.253232002258301, Adaptive learning rate = 0.001
# tensor([0.1738, 0.1740, 0.4921, 0.4921, 0.4921, 0.1738, 0.1740, 0.4923, 0.4923,
#         0.4923, 0.1738, 0.1740], grad_fn=<IndexPutBackward0>)
# tensor([-1.1271, -1.1270, -1.1266, -1.1267])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1481, 3.1481, 1.5015],
#         [3.0977, 6.0978, 1.5013],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8582, 3.8578, 1.5010],
#         [6.3293, 6.3297, 1.5012],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1739, 0.1742, 0.4922, 0.4922, 0.4922, 0.1739, 0.1742, 0.4926, 0.4926,
#         0.4926, 0.1739, 0.1742], grad_fn=<IndexPutBackward0>)
# tensor([-1.1260, -1.1258, -1.1253, -1.1255])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1481, 3.1480, 1.5008],
#         [3.0977, 6.0977, 1.5006],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8578, 3.8573, 1.5001],
#         [6.3289, 6.3295, 1.5003],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1742, 0.1747, 0.4925, 0.4925, 0.4925, 0.1742, 0.1747, 0.4930, 0.4930,
#         0.4930, 0.1742, 0.1747], grad_fn=<IndexPutBackward0>)
# tensor([1.1237, 1.1234, 1.1226, 1.1229])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1480, 3.1479, 1.4993],
#         [3.0976, 6.0977, 1.4990],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8570, 3.8562, 1.4983],
#         [6.3283, 6.3290, 1.4986],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1743, 0.1748, 0.4926, 0.4926, 0.4926, 0.1743, 0.1748, 0.4932, 0.4932,
#         0.4932, 0.1743, 0.1748], grad_fn=<IndexPutBackward0>)
# tensor([1.1230, 1.1226, 1.1217, 1.1221])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1480, 3.1479, 1.4988],
#         [3.0976, 6.0977, 1.4985],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8567, 3.8559, 1.4976],
#         [6.3281, 6.3289, 1.4980],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1742, 0.1747, 0.4925, 0.4925, 0.4925, 0.1742, 0.1747, 0.4931, 0.4931,
#         0.4931, 0.1742, 0.1747], grad_fn=<IndexPutBackward0>)
# tensor([1.1237, 1.1233, 1.1224, 1.1227])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1480, 3.1479, 1.4993],
#         [3.0976, 6.0977, 1.4989],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8570, 3.8562, 1.4981],
#         [6.3282, 6.3290, 1.4984],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 790: Normalized Gradient = 2.2460227012634277, Adaptive learning rate = 0.001
# tensor([0.1740, 0.1744, 0.4922, 0.4922, 0.4922, 0.1740, 0.1744, 0.4928, 0.4928,
#         0.4928, 0.1740, 0.1744], grad_fn=<IndexPutBackward0>)
# tensor([-7.3946e-01, -1.3055e-03,  7.3837e-01, -6.5294e-04])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1481, 3.1480, 1.5006],
#         [3.0977, 6.0977, 1.5003],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8578, 3.8571, 1.4994],
#         [6.3287, 6.3294, 1.4997],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1737, 0.1741, 0.4920, 0.4920, 0.4920, 0.1737, 0.1741, 0.4924, 0.4924,
#         0.4924, 0.1737, 0.1741], grad_fn=<IndexPutBackward0>)
# tensor([-1.1272, -1.1271, -1.1265, -1.1266])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1481, 3.1480, 1.5016],
#         [3.0977, 6.0977, 1.5013],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8583, 3.8576, 1.5009],
#         [6.3290, 6.3296, 1.5012],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1737, 0.1741, 0.4921, 0.4921, 0.4921, 0.1737, 0.1741, 0.4922, 0.4922,
#         0.4922, 0.1737, 0.1741], grad_fn=<IndexPutBackward0>)
# tensor([-1.1272, -1.1273, -1.1270, -1.1269])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1480, 3.1479, 1.5016],
#         [3.0976, 6.0977, 1.5013],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8582, 3.8575, 1.5012],
#         [6.3289, 6.3296, 1.5015],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1738, 0.1743, 0.4924, 0.4924, 0.4924, 0.1738, 0.1743, 0.4923, 0.4923,
#         0.4923, 0.1738, 0.1743], grad_fn=<IndexPutBackward0>)
# tensor([-1.1259, -1.1262, -1.1260, -1.1257])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1479, 3.1479, 1.5008],
#         [3.0976, 6.0976, 1.5004],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8576, 3.8568, 1.5005],
#         [6.3285, 6.3293, 1.5008],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1741, 0.1747, 0.4928, 0.4928, 0.4928, 0.1741, 0.1747, 0.4926, 0.4926,
#         0.4926, 0.1741, 0.1747], grad_fn=<IndexPutBackward0>)
# tensor([1.1233, 1.1238, 1.1236, 1.1232])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1478, 3.1477, 1.4991],
#         [3.0975, 6.0976, 1.4986],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8565, 3.8556, 1.4989],
#         [6.3278, 6.3287, 1.4993],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 795: Normalized Gradient = 2.2469308376312256, Adaptive learning rate = 0.001
# tensor([0.1742, 0.1748, 0.4930, 0.4930, 0.4930, 0.1742, 0.1748, 0.4927, 0.4927,
#         0.4927, 0.1742, 0.1748], grad_fn=<IndexPutBackward0>)
# tensor([1.1223, 1.1230, 1.1230, 1.1223])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1478, 3.1477, 1.4984],
#         [3.0974, 6.0975, 1.4980],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8561, 3.8551, 1.4984],
#         [6.3275, 6.3285, 1.4989],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1742, 0.1747, 0.4929, 0.4929, 0.4929, 0.1742, 0.1747, 0.4925, 0.4925,
#         0.4925, 0.1742, 0.1747], grad_fn=<IndexPutBackward0>)
# tensor([1.1228, 1.1236, 1.1238, 1.1230])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1478, 3.1477, 1.4988],
#         [3.0974, 6.0975, 1.4983],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8562, 3.8552, 1.4990],
#         [6.3276, 6.3285, 1.4994],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1739, 0.1744, 0.4927, 0.4927, 0.4927, 0.1739, 0.1744, 0.4921, 0.4921,
#         0.4921, 0.1739, 0.1744], grad_fn=<IndexPutBackward0>)
# tensor([ 7.3851e-01, -6.0675e-04, -7.3963e-01, -1.3986e-03])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1478, 3.1477, 1.4999],
#         [3.0974, 6.0975, 1.4995],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8568, 3.8559, 1.5004],
#         [6.3280, 6.3289, 1.5008],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1737, 0.1742, 0.4924, 0.4924, 0.4924, 0.1737, 0.1742, 0.4919, 0.4919,
#         0.4919, 0.1737, 0.1742], grad_fn=<IndexPutBackward0>)
# tensor([-1.1265, -1.1273, -1.1275, -1.1267])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1478, 3.1478, 1.5012],
#         [3.0975, 6.0976, 1.5008],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8576, 3.8568, 1.5015],
#         [6.3284, 6.3293, 1.5019],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# tensor([0.1736, 0.1741, 0.4923, 0.4923, 0.4923, 0.1736, 0.1741, 0.4920, 0.4920,
#         0.4920, 0.1736, 0.1741], grad_fn=<IndexPutBackward0>)
# tensor([-1.1268, -1.1275, -1.1276, -1.1269])
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1479, 3.1478, 1.5014],
#         [3.0975, 6.0976, 1.5010],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.8578, 3.8570, 1.5015],
#         [6.3285, 6.3294, 1.5019],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 800: Normalized Gradient = 2.2543587684631348, Adaptive learning rate = 0.001
# Optimization completed.
# tensor([0.4924, 0.1738, 0.4922, 0.1743], requires_grad=True)
# <div>                            <div id="3aa9d390-9bef-43e5-b6c2-89fbe22e9aed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3aa9d390-9bef-43e5-b6c2-89fbe22e9aed")) {                    Plotly.newPlot(                        "3aa9d390-9bef-43e5-b6c2-89fbe22e9aed",                        [{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[0.0,3.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[0.0,3.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,3.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,3.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,3.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[6.0,6.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[6.0,6.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[9.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[6.0,6.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[9.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[0.0,3.1478796005249023],"y":[3.0,3.147801160812378],"z":[0.0,1.5013822317123413],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[0.0,3.0975399017333984],"y":[6.0,6.097618579864502],"z":[0.0,1.5010093450546265],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.0,3.1478796005249023],"y":[0.0,3.147801160812378],"z":[0.0,1.5013822317123413],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.0975399017333984,3.1478796005249023],"y":[6.097618579864502,3.147801160812378],"z":[1.5010093450546265,1.5013822317123413],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.0,3.0975399017333984],"y":[9.0,6.097618579864502],"z":[0.0,1.5010093450546265],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.1478796005249023,6.857800483703613],"y":[3.147801160812378,3.856976270675659],"z":[1.5013822317123413,1.5015218257904053],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[6.0,6.857800483703613],"y":[0.0,3.856976270675659],"z":[0.0,1.5015218257904053],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[6.328534126281738,6.857800483703613],"y":[6.329357624053955,3.856976270675659],"z":[1.5018948316574097,1.5015218257904053],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[9.0,6.857800483703613],"y":[3.0,3.856976270675659],"z":[0.0,1.5015218257904053],"type":"scatter3d"},{"line":{ ...

# %%
### Deflected shape matching -- with 4 qs
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import plotly.graph_objects as go

# q.grad.zero_()


# In[663]:


######################## explanation
## "The example model is based on a 5-nodes grid shell strcuture
##  which has a crossing projection in the x-y plane"
##  The FE part would be based on the Euler-bernoulli beam theory


# In[664]:


## Initial Geom
# Initial Coords:
node_coords = torch.tensor(
    [[0.0, 3.0, 0.0], [0.0, 6.0, 0.0], [3.0, 0.0, 0.0], [3.0, 3.0, 0.0], [3.0, 6.0, 0.0], [3.0, 9.0, 0.0],
     [6.0, 0.0, 0.0], [6.0, 3.0, 0.0], [6.0, 6.0, 0.0] ,[6.0, 9.0, 0.0], [9.0, 3.0 ,0.0], [9.0, 6.0, 0.0]],
    dtype=torch.float32, requires_grad=True, )
connectivity = [[1, 4], [2, 5], [3, 4], [5, 4], [6, 5], [4, 8], [7, 8], [9, 8],[11, 8],[10, 9],[12, 9],[5, 9]]
n_dof_per_node = 6  # Degrees of freedom per node
total_dof = n_dof_per_node * len(node_coords)
Fixed_nodes = [1, 2, 3, 6, 7, 10, 11, 12]
Free_nodes = []
n_elements = len(connectivity)
n_nodes = len(node_coords)
for i in range(1, n_nodes + 1):
    if i not in Fixed_nodes:
        Free_nodes.append(i)
idx_CF = [node - 1 for node in Fixed_nodes]
idx_CN = [i for i in range(n_nodes) if i not in idx_CF]


## Force condition
####### Force condition -> need for modification
## +0 to x direction ; +1 to y direction ; +2 to Z direction
## +3 Bending around the z axis ; +4 bending around y axis ; +5 Twisting
# implement upwards loading of 50 kN at every free nodes
F = torch.zeros(total_dof, dtype=torch.float32)
f_n = Free_nodes
f_type = [2, 2, 2, 2]  # The force type
F_value = torch.tensor([50.0, 50.0, 50.0, 50.0]) * 1000  # The force value/direction
r = 1 / torch.max(F_value)
# print(r)
F_sign = torch.sign(F_value)
for idx, i in enumerate(f_n):
    F[6 * (i - 1) + f_type[idx]] = F_value[idx]  # unit: KN / KN*m

px = torch.zeros(len(f_n), 1, dtype=torch.float32)
py = torch.zeros(len(f_n), 1, dtype=torch.float32)
pz = torch.zeros(len(f_n), 1, dtype=torch.float32)

for i in range(len(f_n)):
    if f_type[idx] == 0:
        px[i] = F_value[i]
    elif f_type[idx] == 1:
        py[i] = F_value[i]
    elif f_type[idx] == 2:
        pz[i] = F_value[i]


## Obtaining Matrix D
# Assembly the nodal-branch matrix:
C = torch.zeros(n_elements, n_nodes, dtype=torch.float32)
for n, (i, j) in enumerate(connectivity):
    C[n, i - 1] = 1
    C[n, j - 1] = -1
CF = C[:, idx_CF]
CN = C[:, idx_CN]


# Assembly D
def FDM (Q,CN=CN, CF=CF, px=px, py=py, pz=pz,Fixed_nodes=Fixed_nodes, Free_nodes=Free_nodes,node_coords=node_coords) :
    Dn = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CN))
    DF = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CF))
    ## Coordinates solution
    # separate the coordinates:
    fixed_idces = [node - 1 for node in Fixed_nodes]
    xF = node_coords[fixed_idces, 0].unsqueeze(1)
    yF = node_coords[fixed_idces, 1].unsqueeze(1)
    zF = node_coords[fixed_idces, 2].unsqueeze(1)
    xN = torch.matmul(torch.inverse(Dn), (px - torch.matmul(DF, xF)))
    yN = torch.matmul(torch.inverse(Dn), (py - torch.matmul(DF, yF)))
    zN = torch.matmul(torch.inverse(Dn), (pz - torch.matmul(DF, zF)))
    ## Coordinates renewal: 
    new_node_coords = node_coords.clone()
    for idx, node in enumerate(Free_nodes):
        node_idx = node - 1
        new_node_coords[node_idx, 0] = xN[idx]
        new_node_coords[node_idx, 1] = yN[idx]
        new_node_coords[node_idx, 2] = zN[idx]

    return new_node_coords

# In[670]:


## Check point: FDM completed
# if q.grad is not None:
#     q.grad.zero_()
# loss = torch.sum(new_node_coords[:, 2])
# loss.backward()
# print("Gradient of q:")
# print(q.grad)


############ Now comes to FE part:
#### Default values (in meters, Pascals, etc.)
## For rectangular sections
# D_width = 0.1
# D_height = 0.2
# D_young_modulus = 210e9  # Young's modulus in Pascals
# D_shear_modulus = 81e9  # Shear modulus in Pascals
# D_poisson_ratio = 0.3
# cross_section_angle_a = 0  # Cross-section angle at node 1 (anti-clockwise)
# cross_section_angle_b = 0  # Cross-section angle at node 2 (anti-clockwise)
# a_small_number = 1e-10

D_radius = 0.05
D_young_modulus = 210e9  # Young's modulus in Pascals
D_shear_modulus = 81e9  # Shear modulus in Pascals
D_poisson_ratio = 0.3
cross_section_angle_a = 0  # Cross-section angle at node 1 (anti-clockwise)
cross_section_angle_b = 0  # Cross-section angle at node 2 (anti-clockwise)
a_small_number = 1e-10


# In[673]:


def rotation(v, k, theta):
    """Rotation of vector v around axis k by angle theta."""
    k = k / torch.norm(k)  # Normalize k
    cross_product = torch.cross(k, v)
    dot_product = torch.dot(k, v)

    # Ensure theta is a tensor
    theta = torch.tensor(theta, dtype=torch.float32) if not isinstance(theta, torch.Tensor) else theta

    v_rotated = v * torch.cos(theta) + cross_product * torch.sin(theta) + k * dot_product * (1 - torch.cos(theta))
    return v_rotated


# In[674]:


###### Element Creating (euler beam)
# For rectangular sections
# class Beam:
#     def __init__(self, node_coordinates, width=D_width, height=D_height, young_modulus=D_young_modulus,
#                  shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
#                  Beta_b=cross_section_angle_b):
#         self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

#         # Material and geometry
#         self.width = width
#         self.height = height
#         self.young_modulus = young_modulus
#         self.shear_modulus = shear_modulus
#         self.poisson_ratio = poisson_ratio

#         # Cross-sectional properties
#         self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
#         self.Iy = (self.width * self.height ** 3) / 12
#         self.Iz = (self.width ** 3 * self.height) / 12
#         self.A = self.width * self.height
#         self.J = (self.width * self.height ** 3) / 3

#         # Stiffness components
#         self.S_u = self.young_modulus * self.A / self.length
#         self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
#         self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
#         self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
#         self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
#         self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
#         self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
#         self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
#         self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
#         self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
#         self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
#         self.S_Tr = self.shear_modulus * self.J / self.length

#         # Section rotations at the two ends
#         self.Beta_a = Beta_a
#         self.Beta_b = Beta_b


# In[675]:


# For circular sections
class Beam:
    def __init__(self, node_coordinates, R=D_radius, young_modulus=D_young_modulus,
                 shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                 Beta_b=cross_section_angle_b):
        self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

        # Material and geometry
        self.radius = R
        self.young_modulus = young_modulus
        self.shear_modulus = shear_modulus
        self.poisson_ratio = poisson_ratio

        # Cross-sectional properties
        self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
        self.Iy = (torch.pi * self.radius ** 4) / 4 
        self.Iz = self.Iy
        self.A = torch.pi * self.radius ** 2
        self.J = (torch.pi * self.radius ** 4) / 2

        # Stiffness components
        self.S_u = self.young_modulus * self.A / self.length
        self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
        self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
        self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
        self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
        self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
        self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
        self.S_Tr = self.shear_modulus * self.J / self.length

        # Section rotations at the two ends
        self.Beta_a = Beta_a
        self.Beta_b = Beta_b

    def get_element_stiffness_matrix(self):
        """Element stiffness matrix."""
        K_element = torch.tensor([
            [self.S_u, 0, 0, 0, 0, 0, -self.S_u, 0, 0, 0, 0, 0],
            [0, self.S_v1a, 0, 0, 0, self.S_theta1a, 0, -self.S_v1a, 0, 0, 0, self.S_theta1a],
            [0, 0, self.S_v2a, 0, -self.S_theta2a, 0, 0, 0, -self.S_v2a, 0, -self.S_theta2a, 0],
            [0, 0, 0, self.S_Tr, 0, 0, 0, 0, 0, -self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2b, 0, 0, 0, self.S_v2b, 0, self.S_theta2c, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1b, 0, -self.S_v1b, 0, 0, 0, self.S_theta1c],
            [-self.S_u, 0, 0, 0, 0, 0, self.S_u, 0, 0, 0, 0, 0],
            [0, -self.S_v1a, 0, 0, 0, -self.S_theta1a, 0, self.S_v1a, 0, 0, 0, -self.S_theta1a],
            [0, 0, -self.S_v2a, 0, self.S_theta2a, 0, 0, 0, self.S_v2a, 0, self.S_theta2a, 0],
            [0, 0, 0, -self.S_Tr, 0, 0, 0, 0, 0, self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2c, 0, 0, 0, self.S_v2b, 0, self.S_theta2b, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1c, 0, -self.S_v1b, 0, 0, 0, self.S_theta1b],
        ], dtype=torch.float32)

        return K_element

    def System_Transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        # print(vector_x,vector_y,vector_z)
        # Calculate alpha and ceta using PyTorch
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)
        # print(alpha)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)

        # Z_axis_b = rotation(V_projection, X_axis, self.Beta_b)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        # Y_axis_b = rotation(Z_axis_b, X_axis, torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        # Z_axis_b = Z_axis_b / torch.norm(Z_axis_b)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)
        # Y_axis_b = Y_axis_b / torch.norm(Y_axis_b)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)
        matrix_T = torch.zeros((12, 12), dtype=torch.float32)
        for i in range(0, 12, 3):
            matrix_T[i:i + 3, i:i + 3] = lambda_matrix
        return matrix_T

    def nodal_transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        # Calculate alpha and ceta using PyTorch
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)

        # Z_axis_b = rotation(V_projection, X_axis, self.Beta_b)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        # Y_axis_b = rotation(Z_axis_b, X_axis, torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        # Z_axis_b = Z_axis_b / torch.norm(Z_axis_b)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)
        # Y_axis_b = Y_axis_b / torch.norm(Y_axis_b)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)

        return lambda_matrix


# In[676]:


def assemble_stiffness_matrix(beams, n_nodes, n_dof_per_node, connectivity):
    """Global stiffness matrix assembly."""
    total_dof = n_nodes * n_dof_per_node  # Total degrees of freedom
    K_global = torch.zeros((total_dof, total_dof), dtype=torch.float32)
    for idx, (i, j) in enumerate(connectivity):
        Matrix_T = beams[idx].System_Transform()  # Get transformation matrix

        K_element = torch.matmul(torch.transpose(Matrix_T, 0, 1),
                                 torch.matmul(beams[idx].get_element_stiffness_matrix(), Matrix_T))

        start_idx = (i - 1) * n_dof_per_node
        end_idx = (j - 1) * n_dof_per_node
        K_global[start_idx:start_idx + 6, start_idx:start_idx + 6] = K_global[start_idx:start_idx + 6,
                                                                     start_idx:start_idx + 6] + K_element[0:6, 0:6]
        K_global[end_idx:end_idx + 6, end_idx:end_idx + 6] = K_global[end_idx:end_idx + 6,
                                                             end_idx:end_idx + 6] + K_element[6:12, 6:12]
        K_global[start_idx:start_idx + 6, end_idx:end_idx + 6] = K_global[start_idx:start_idx + 6,
                                                                 end_idx:end_idx + 6] + K_element[0:6, 6:12]
        K_global[end_idx:end_idx + 6, start_idx:start_idx + 6] = K_global[end_idx:end_idx + 6,
                                                                 start_idx:start_idx + 6] + K_element[6:12, 0:6]

    return K_global


# In[677]:


def Strain_E(node_coords, connectivity, fixed_dof, F):
    # node_coords[:, 2] = 0.0
    # Element Assembly
    beams = []
    for connection in connectivity:
        node_1_coords = node_coords[connection[0] - 1]
        node_2_coords = node_coords[connection[1] - 1]
        beam = Beam(node_coordinates=torch.stack([node_1_coords, node_2_coords]),
                    R=D_radius, young_modulus=D_young_modulus,
                    shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                    Beta_b=cross_section_angle_b)
        beams.append(beam)
    # Stiffness renewal
    K_global = assemble_stiffness_matrix(beams, n_nodes=len(node_coords), n_dof_per_node=6, connectivity=connectivity)
    K_global[fixed_dof, :] = K_global[fixed_dof, :] - K_global[fixed_dof, :]
    K_global[:, fixed_dof] = K_global[:, fixed_dof] - K_global[:, fixed_dof]
    K_global[fixed_dof, fixed_dof] = 1e5
    rank_K = torch.linalg.matrix_rank(K_global)

    if rank_K < K_global.shape[0]:
        print("Warning: The stiffness matrix is not of full rank")
    else:
        displacements = torch.linalg.solve(K_global, F)

    # Compute strain energy
    strain_energy_list = []
    Local_d = torch.zeros(len(connectivity), 12, dtype=torch.float32)
    for n, (i, j) in enumerate(connectivity):
        matrix_T = beams[n].System_Transform()
        Tep_displacements = torch.cat(
            [displacements[6 * (i - 1):6 * (i - 1) + 6], displacements[6 * (j - 1):6 * (j - 1) + 6]], dim=0)
        Local_d_n = torch.matmul(Tep_displacements, matrix_T.T)
        Local_d[n, :] = Local_d_n.clone()
        K_g = torch.matmul(torch.transpose(matrix_T, 0, 1),
                           torch.matmul(beams[n].get_element_stiffness_matrix(), matrix_T))

        strain_energy_list.append(torch.matmul(Local_d_n, torch.matmul(K_g, Local_d_n.reshape(-1, 1))))

    Strain_energy = torch.stack(strain_energy_list)

    return Strain_energy, Local_d, displacements, beams

def Average_height(Free_nodes, new_node_coords):
    n_free_nodes = len(Free_nodes)
    Free_nodes = torch.tensor(Free_nodes)
    AH = torch.sum(new_node_coords[(Free_nodes - 1), 2])/ n_free_nodes
    return AH

# In[678]:


# Element creating
#################  input below:
############################################################################################################## input
# initial coordinates

####### BCs
fixed_dof = []
for node in Fixed_nodes:
    fixed_dof.extend([(node - 1) * 6 + i for i in range(6)])
# print(fixed_dof)
####### Gradient descent
step = 0.005
epochs = 1000
Obj_coords = 1.5
####### Plotting
steps = 20  # steps for tracing deformation shape
###################################################################################################################################################
###################################################################################################################################################


# In[679]:

# Optimized Variables
## initial variables
Idx_q1 = [3, 4, 5]
Idx_q2 = [1, 6, 11]
Idx_q3 = [8, 9, 10]
Idx_q4 = [2, 7, 12]
Idx_q1 = [i - 1 for i in Idx_q1] 
Idx_q2 = [i - 1 for i in Idx_q2]
Idx_q3 = [i - 1 for i in Idx_q3] 
Idx_q4 = [i - 1 for i in Idx_q4] 
q = torch.rand(4, requires_grad=True)
## Optimization
torch.autograd.set_detect_anomaly(True)
# Optimizer setting
optimizer = optim.Adam([q], lr=step)
# Initilizing
# New_Coordinates = torch.zeros(n_nodes * 3, dtype=torch.float32)
Loss_his = []
Disp_his = []
# Loop start
for iteration in range(epochs + 1):
    print('ite',iteration)
    # Forwards
    q_vec = torch.zeros(n_elements, requires_grad=True).clone()
    q_vec[Idx_q1] = q[0] 
    q_vec[Idx_q2] = q[1]
    q_vec[Idx_q3] = q[2] 
    q_vec[Idx_q4] = q[3] 
    Q = torch.diag(q_vec) * 1 / r  # scaling
    new_node_coords = FDM(Q)
    N_coords = new_node_coords.clone()
    Strain_energy, _, displacements, _ = Strain_E(N_coords, connectivity, fixed_dof, F)
    idx = 6 * torch.arange(n_nodes) + 2
    Ave_Disp = abs(torch.sum(displacements[idx] / len(Free_nodes)))
    Disp_his.append(Ave_Disp.item())
    N_coords = N_coords.reshape(-1)
    New_Coordinates = torch.zeros(n_nodes * 3, dtype=torch.float32)
    for n in range(n_nodes):
        New_Coordinates[3*n : 3*n+3] = N_coords[3*n : 3*n+3] + displacements[6*n : 6*n+3]
    New_Coordinates = New_Coordinates.view(n_nodes, 3).clone()
    AVE = Average_height(Free_nodes, New_Coordinates)
    print("Average height",AVE)
    # loss
    Loss = torch.norm(AVE - Obj_coords)
    Loss_his.append(Loss.item())
    # Backwards
    optimizer.zero_grad()
    # print(q.grad)
    Loss.backward(retain_graph=True)

    # Grad
    gradients = q.grad
    print('Grad',gradients)
    frob_norm = torch.norm(gradients)
    optimizer.step()
    
    # print iteration
    if iteration % 5 == 0:
        print(f"Iteration {iteration}: Normalized Gradient = {frob_norm}, Adaptive learning rate = {step}")
print("Optimization completed.")
print(q)
# print("coordinates:",node_coords)

#############################################################################################################
## Visualization
# print(Coordinates)
# displacements = Strain_E(node_coords, connectivity, fixed_dof, F)[2]
# print("displacements:", displacements)
print("Deformed:", New_Coordinates)

x_orig = node_coords[:, 0].detach().numpy()
y_orig = node_coords[:, 1].detach().numpy()
z_orig = node_coords[:, 2].detach().numpy()

x_def = New_Coordinates[:, 0].detach().numpy()
y_def = New_Coordinates[:, 1].detach().numpy()
z_def = New_Coordinates[:, 2].detach().numpy()


fig = go.Figure()


for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_orig[i-1], x_orig[j-1]],
        y=[y_orig[i-1], y_orig[j-1]],
        z=[z_orig[i-1], z_orig[j-1]],
        mode='lines',
        line=dict(color='blue', width=4),
        name='Original Geometry'
    ))


for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_def[i-1], x_def[j-1]],
        y=[y_def[i-1], y_def[j-1]],
        z=[z_def[i-1], z_def[j-1]],
        mode='lines',
        line=dict(color='red', width=4),
        name='Deformed Geometry'
    ))


for node in Free_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_def[node-1]],
        y=[y_def[node-1]],
        z=[z_def[node-1]],
        mode='markers+text',
        marker=dict(size=5, color='green'),
        text=[f'Node {node}'],
        textposition='top center',
        name=f'Free Node {node}'
    ))


fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        aspectmode='data'
    ),
    title='Deformation Comparison: Original vs. Deformed Geometry (FE Analysis)',
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()

########################################################################################################################

### Plot the optimization history
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'blue'
ax1.set_xlabel('Iterations')
ax1.set_ylabel('Loss', color=color)
ax1.plot(range(epochs + 1), Loss_his, label='Loss History', color=color, linewidth=2)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True)

ax2 = ax1.twinx()
color = 'red'
ax2.set_ylabel('Average Displacement', color=color)
ax2.plot(range(epochs + 1), Disp_his, label='Average Displacement', color=color, linewidth=2, linestyle='--')
ax2.tick_params(axis='y', labelcolor=color)

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

plt.title('Loss & Average Displacement vs. Iterations')

plt.tight_layout()
plt.show()
# Out:
# ite 0
# Average height tensor(0.9305, grad_fn=<DivBackward0>)
# Grad tensor([0.4311, 0.5179, 0.4529, 0.3662])
# Iteration 0: Normalized Gradient = 0.8906715512275696, Adaptive learning rate = 0.005
# ite 1
# Average height tensor(0.9394, grad_fn=<DivBackward0>)
# Grad tensor([0.4397, 0.5289, 0.4618, 0.3728])
# ite 2
# Average height tensor(0.9485, grad_fn=<DivBackward0>)
# Grad tensor([0.4486, 0.5402, 0.4710, 0.3795])
# ite 3
# Average height tensor(0.9578, grad_fn=<DivBackward0>)
# Grad tensor([0.4578, 0.5520, 0.4804, 0.3864])
# ite 4
# Average height tensor(0.9673, grad_fn=<DivBackward0>)
# Grad tensor([0.4673, 0.5641, 0.4902, 0.3935])
# ite 5
# Average height tensor(0.9770, grad_fn=<DivBackward0>)
# Grad tensor([0.4771, 0.5767, 0.5003, 0.4008])
# Iteration 5: Normalized Gradient = 0.985479474067688, Adaptive learning rate = 0.005
# ite 6
# Average height tensor(0.9870, grad_fn=<DivBackward0>)
# Grad tensor([0.4873, 0.5897, 0.5107, 0.4084])
# ite 7
# Average height tensor(0.9971, grad_fn=<DivBackward0>)
# Grad tensor([0.4978, 0.6032, 0.5215, 0.4162])
# ite 8
# Average height tensor(1.0076, grad_fn=<DivBackward0>)
# Grad tensor([0.5087, 0.6172, 0.5326, 0.4242])
# ite 9
# Average height tensor(1.0182, grad_fn=<DivBackward0>)
# Grad tensor([0.5200, 0.6318, 0.5442, 0.4325])
# ite 10
# Average height tensor(1.0291, grad_fn=<DivBackward0>)
# Grad tensor([0.5317, 0.6470, 0.5561, 0.4410])
# Iteration 10: Normalized Gradient = 1.097779393196106, Adaptive learning rate = 0.005
# ite 11
# Average height tensor(1.0404, grad_fn=<DivBackward0>)
# Grad tensor([0.5440, 0.6627, 0.5686, 0.4499])
# ite 12
# Average height tensor(1.0519, grad_fn=<DivBackward0>)
# Grad tensor([0.5566, 0.6791, 0.5814, 0.4590])
# ite 13
# Average height tensor(1.0637, grad_fn=<DivBackward0>)
# Grad tensor([0.5699, 0.6962, 0.5948, 0.4685])
# ite 14
# Average height tensor(1.0758, grad_fn=<DivBackward0>)
# Grad tensor([0.5836, 0.7141, 0.6088, 0.4783])
# ite 15
# Average height tensor(1.0883, grad_fn=<DivBackward0>)
# Grad tensor([0.5980, 0.7328, 0.6232, 0.4885])
# Iteration 15: Normalized Gradient = 1.233553409576416, Adaptive learning rate = 0.005
# ite 16
# Average height tensor(1.1012, grad_fn=<DivBackward0>)
# Grad tensor([0.6130, 0.7523, 0.6383, 0.4991])
# ite 17
# Average height tensor(1.1145, grad_fn=<DivBackward0>)
# Grad tensor([0.6287, 0.7727, 0.6541, 0.5100])
# ite 18
# Average height tensor(1.1281, grad_fn=<DivBackward0>)
# Grad tensor([0.6452, 0.7942, 0.6705, 0.5214])
# ite 19
# Average height tensor(1.1423, grad_fn=<DivBackward0>)
# Grad tensor([0.6624, 0.8167, 0.6876, 0.5333])
# ite 20
# Average height tensor(1.1568, grad_fn=<DivBackward0>)
# Grad tensor([0.6805, 0.8403, 0.7056, 0.5457])
# Iteration 20: Normalized Gradient = 1.4016919136047363, Adaptive learning rate = 0.005
# ite 21
# Average height tensor(1.1719, grad_fn=<DivBackward0>)
# Grad tensor([0.6995, 0.8652, 0.7244, 0.5585])
# ite 22
# Average height tensor(1.1874, grad_fn=<DivBackward0>)
# Grad tensor([0.7194, 0.8914, 0.7441, 0.5720])
# ite 23
# Average height tensor(1.2036, grad_fn=<DivBackward0>)
# Grad tensor([0.7405, 0.9191, 0.7647, 0.5860])
# ite 24
# Average height tensor(1.2203, grad_fn=<DivBackward0>)
# Grad tensor([0.7627, 0.9483, 0.7864, 0.6006])
# ite 25
# Average height tensor(1.2376, grad_fn=<DivBackward0>)
# Grad tensor([0.7862, 0.9792, 0.8092, 0.6160])
# Iteration 25: Normalized Gradient = 1.6159350872039795, Adaptive learning rate = 0.005
# ite 26
# Average height tensor(1.2556, grad_fn=<DivBackward0>)
# Grad tensor([0.8110, 1.0120, 0.8333, 0.6321])
# ite 27
# Average height tensor(1.2743, grad_fn=<DivBackward0>)
# Grad tensor([0.8374, 1.0468, 0.8586, 0.6489])
# ite 28
# Average height tensor(1.2938, grad_fn=<DivBackward0>)
# Grad tensor([0.8654, 1.0838, 0.8854, 0.6666])
# ite 29
# Average height tensor(1.3141, grad_fn=<DivBackward0>)
# Grad tensor([0.8952, 1.1233, 0.9137, 0.6852])
# ite 30
# Average height tensor(1.3352, grad_fn=<DivBackward0>)
# Grad tensor([0.9270, 1.1655, 0.9437, 0.7048])
# Iteration 30: Normalized Gradient = 1.8986502885818481, Adaptive learning rate = 0.005
# ite 31
# Average height tensor(1.3573, grad_fn=<DivBackward0>)
# Grad tensor([0.9609, 1.2106, 0.9755, 0.7254])
# ite 32
# Average height tensor(1.3804, grad_fn=<DivBackward0>)
# Grad tensor([0.9973, 1.2590, 1.0093, 0.7471])
# ite 33
# Average height tensor(1.4046, grad_fn=<DivBackward0>)
# Grad tensor([1.0363, 1.3110, 1.0453, 0.7701])
# ite 34
# Average height tensor(1.4300, grad_fn=<DivBackward0>)
# Grad tensor([1.0784, 1.3671, 1.0837, 0.7944])
# ite 35
# Average height tensor(1.4566, grad_fn=<DivBackward0>)
# Grad tensor([1.1237, 1.4277, 1.1247, 0.8202])
# Iteration 35: Normalized Gradient = 2.288857936859131, Adaptive learning rate = 0.005
# ite 36
# Average height tensor(1.4846, grad_fn=<DivBackward0>)
# Grad tensor([1.1729, 1.4934, 1.1686, 0.8476])
# ite 37
# Average height tensor(1.5141, grad_fn=<DivBackward0>)
# Grad tensor([-1.2262, -1.5649, -1.2157, -0.8766])
# ite 38
# Average height tensor(1.5369, grad_fn=<DivBackward0>)
# Grad tensor([-1.2684, -1.6215, -1.2528, -0.8993])
# ite 39
# Average height tensor(1.5533, grad_fn=<DivBackward0>)
# Grad tensor([-1.2991, -1.6628, -1.2798, -0.9158])
# ite 40
# Average height tensor(1.5636, grad_fn=<DivBackward0>)
# Grad tensor([-1.3186, -1.6891, -1.2970, -0.9263])
# Iteration 40: Normalized Gradient = 2.67057204246521, Adaptive learning rate = 0.005
# ite 41
# Average height tensor(1.5684, grad_fn=<DivBackward0>)
# Grad tensor([-1.3276, -1.7013, -1.3053, -0.9313])
# ite 42
# Average height tensor(1.5685, grad_fn=<DivBackward0>)
# Grad tensor([-1.3272, -1.7009, -1.3056, -0.9316])
# ite 43
# Average height tensor(1.5643, grad_fn=<DivBackward0>)
# Grad tensor([-1.3187, -1.6897, -1.2989, -0.9276])
# ite 44
# Average height tensor(1.5566, grad_fn=<DivBackward0>)
# Grad tensor([-1.3036, -1.6694, -1.2864, -0.9202])
# ite 45
# Average height tensor(1.5461, grad_fn=<DivBackward0>)
# Grad tensor([-1.2830, -1.6419, -1.2692, -0.9097])
# Iteration 45: Normalized Gradient = 2.60392165184021, Adaptive learning rate = 0.005
# ite 46
# Average height tensor(1.5331, grad_fn=<DivBackward0>)
# Grad tensor([-1.2583, -1.6089, -1.2481, -0.8970])
# ite 47
# Average height tensor(1.5183, grad_fn=<DivBackward0>)
# Grad tensor([-1.2305, -1.5717, -1.2241, -0.8824])
# ite 48
# Average height tensor(1.5020, grad_fn=<DivBackward0>)
# Grad tensor([-1.2006, -1.5317, -1.1981, -0.8664])
# ite 49
# Average height tensor(1.4846, grad_fn=<DivBackward0>)
# Grad tensor([1.1694, 1.4899, 1.1706, 0.8494])
# ite 50
# Average height tensor(1.4725, grad_fn=<DivBackward0>)
# Grad tensor([1.1478, 1.4610, 1.1515, 0.8376])
# Iteration 50: Normalized Gradient = 2.3408076763153076, Adaptive learning rate = 0.005
# ite 51
# Average height tensor(1.4647, grad_fn=<DivBackward0>)
# Grad tensor([1.1340, 1.4426, 1.1393, 0.8300])
# ite 52
# Average height tensor(1.4605, grad_fn=<DivBackward0>)
# Grad tensor([1.1266, 1.4329, 1.1329, 0.8260])
# ite 53
# Average height tensor(1.4596, grad_fn=<DivBackward0>)
# Grad tensor([1.1249, 1.4306, 1.1316, 0.8253])
# ite 54
# Average height tensor(1.4616, grad_fn=<DivBackward0>)
# Grad tensor([1.1281, 1.4349, 1.1347, 0.8272])
# ite 55
# Average height tensor(1.4661, grad_fn=<DivBackward0>)
# Grad tensor([1.1357, 1.4452, 1.1419, 0.8317])
# Iteration 55: Normalized Gradient = 2.3181824684143066, Adaptive learning rate = 0.005
# ite 56
# Average height tensor(1.4729, grad_fn=<DivBackward0>)
# Grad tensor([1.1474, 1.4610, 1.1528, 0.8386])
# ite 57
# Average height tensor(1.4820, grad_fn=<DivBackward0>)
# Grad tensor([1.1631, 1.4821, 1.1672, 0.8476])
# ite 58
# Average height tensor(1.4931, grad_fn=<DivBackward0>)
# Grad tensor([1.1827, 1.5084, 1.1850, 0.8586])
# ite 59
# Average height tensor(1.5062, grad_fn=<DivBackward0>)
# Grad tensor([-1.2060, -1.5398, -1.2061, -0.8717])
# ite 60
# Average height tensor(1.5151, grad_fn=<DivBackward0>)
# Grad tensor([-1.2219, -1.5612, -1.2205, -0.8806])
# Iteration 60: Normalized Gradient = 2.489107847213745, Adaptive learning rate = 0.005
# ite 61
# Average height tensor(1.5200, grad_fn=<DivBackward0>)
# Grad tensor([-1.2307, -1.5730, -1.2285, -0.8856])
# ite 62
# Average height tensor(1.5212, grad_fn=<DivBackward0>)
# Grad tensor([-1.2329, -1.5760, -1.2306, -0.8869])
# ite 63
# Average height tensor(1.5192, grad_fn=<DivBackward0>)
# Grad tensor([-1.2291, -1.5709, -1.2274, -0.8849])
# ite 64
# Average height tensor(1.5143, grad_fn=<DivBackward0>)
# Grad tensor([-1.2201, -1.5589, -1.2196, -0.8801])
# ite 65
# Average height tensor(1.5070, grad_fn=<DivBackward0>)
# Grad tensor([-1.2067, -1.5409, -1.2077, -0.8728])
# Iteration 65: Normalized Gradient = 2.4598262310028076, Adaptive learning rate = 0.005
# ite 66
# Average height tensor(1.4975, grad_fn=<DivBackward0>)
# Grad tensor([1.1896, 1.5180, 1.1925, 0.8634])
# ite 67
# Average height tensor(1.4920, grad_fn=<DivBackward0>)
# Grad tensor([1.1797, 1.5047, 1.1837, 0.8580])
# ite 68
# Average height tensor(1.4899, grad_fn=<DivBackward0>)
# Grad tensor([1.1759, 1.4996, 1.1803, 0.8559])
# ite 69
# Average height tensor(1.4908, grad_fn=<DivBackward0>)
# Grad tensor([1.1774, 1.5017, 1.1818, 0.8568])
# ite 70
# Average height tensor(1.4944, grad_fn=<DivBackward0>)
# Grad tensor([1.1838, 1.5102, 1.1877, 0.8605])
# Iteration 70: Normalized Gradient = 2.4151694774627686, Adaptive learning rate = 0.005
# ite 71
# Average height tensor(1.5005, grad_fn=<DivBackward0>)
# Grad tensor([-1.1946, -1.5248, -1.1975, -0.8666])
# ite 72
# Average height tensor(1.5031, grad_fn=<DivBackward0>)
# Grad tensor([-1.1992, -1.5310, -1.2018, -0.8692])
# ite 73
# Average height tensor(1.5026, grad_fn=<DivBackward0>)
# Grad tensor([-1.1983, -1.5298, -1.2010, -0.8688])
# ite 74
# Average height tensor(1.4993, grad_fn=<DivBackward0>)
# Grad tensor([1.1924, 1.5218, 1.1957, 0.8655])
# ite 75
# Average height tensor(1.4992, grad_fn=<DivBackward0>)
# Grad tensor([1.1921, 1.5215, 1.1955, 0.8654])
# Iteration 75: Normalized Gradient = 2.431924819946289, Adaptive learning rate = 0.005
# ite 76
# Average height tensor(1.5019, grad_fn=<DivBackward0>)
# Grad tensor([-1.1969, -1.5280, -1.1999, -0.8681])
# ite 77
# Average height tensor(1.5015, grad_fn=<DivBackward0>)
# Grad tensor([-1.1961, -1.5270, -1.1993, -0.8677])
# ite 78
# Average height tensor(1.4984, grad_fn=<DivBackward0>)
# Grad tensor([1.1905, 1.5194, 1.1942, 0.8646])
# ite 79
# Average height tensor(1.4983, grad_fn=<DivBackward0>)
# Grad tensor([1.1903, 1.5192, 1.1942, 0.8646])
# ite 80
# Average height tensor(1.5010, grad_fn=<DivBackward0>)
# Grad tensor([-1.1952, -1.5257, -1.1986, -0.8673])
# Iteration 80: Normalized Gradient = 2.4382777214050293, Adaptive learning rate = 0.005
# ite 81
# Average height tensor(1.5007, grad_fn=<DivBackward0>)
# Grad tensor([-1.1946, -1.5249, -1.1981, -0.8670])
# ite 82
# Average height tensor(1.4976, grad_fn=<DivBackward0>)
# Grad tensor([1.1891, 1.5176, 1.1931, 0.8639])
# ite 83
# Average height tensor(1.4976, grad_fn=<DivBackward0>)
# Grad tensor([1.1891, 1.5175, 1.1931, 0.8640])
# ite 84
# Average height tensor(1.5004, grad_fn=<DivBackward0>)
# Grad tensor([-1.1940, -1.5241, -1.1976, -0.8667])
# ite 85
# Average height tensor(1.5001, grad_fn=<DivBackward0>)
# Grad tensor([-1.1934, -1.5234, -1.1971, -0.8664])
# Iteration 85: Normalized Gradient = 2.4349255561828613, Adaptive learning rate = 0.005
# ite 86
# Average height tensor(1.4971, grad_fn=<DivBackward0>)
# Grad tensor([1.1881, 1.5162, 1.1923, 0.8634])
# ite 87
# Average height tensor(1.4971, grad_fn=<DivBackward0>)
# Grad tensor([1.1881, 1.5163, 1.1924, 0.8635])
# ite 88
# Average height tensor(1.4999, grad_fn=<DivBackward0>)
# Grad tensor([1.1930, 1.5228, 1.1968, 0.8662])
# ite 89
# Average height tensor(1.5051, grad_fn=<DivBackward0>)
# Grad tensor([-1.2024, -1.5354, -1.2053, -0.8715])
# ite 90
# Average height tensor(1.5071, grad_fn=<DivBackward0>)
# Grad tensor([-1.2058, -1.5401, -1.2084, -0.8734])
# Iteration 90: Normalized Gradient = 2.4594972133636475, Adaptive learning rate = 0.005
# ite 91
# Average height tensor(1.5061, grad_fn=<DivBackward0>)
# Grad tensor([-1.2040, -1.5376, -1.2068, -0.8724])
# ite 92
# Average height tensor(1.5024, grad_fn=<DivBackward0>)
# Grad tensor([-1.1974, -1.5287, -1.2008, -0.8687])
# ite 93
# Average height tensor(1.4964, grad_fn=<DivBackward0>)
# Grad tensor([1.1867, 1.5143, 1.1912, 0.8628])
# ite 94
# Average height tensor(1.4937, grad_fn=<DivBackward0>)
# Grad tensor([1.1819, 1.5079, 1.1869, 0.8601])
# ite 95
# Average height tensor(1.4939, grad_fn=<DivBackward0>)
# Grad tensor([1.1823, 1.5085, 1.1873, 0.8603])
# Iteration 95: Normalized Gradient = 2.413147211074829, Adaptive learning rate = 0.005
# ite 96
# Average height tensor(1.4968, grad_fn=<DivBackward0>)
# Grad tensor([1.1874, 1.5154, 1.1919, 0.8632])
# ite 97
# Average height tensor(1.5021, grad_fn=<DivBackward0>)
# Grad tensor([-1.1969, -1.5281, -1.2005, -0.8685])
# ite 98
# Average height tensor(1.5042, grad_fn=<DivBackward0>)
# Grad tensor([-1.2005, -1.5330, -1.2038, -0.8706])
# ite 99
# Average height tensor(1.5033, grad_fn=<DivBackward0>)
# Grad tensor([-1.1990, -1.5309, -1.2024, -0.8697])
# ite 100
# Average height tensor(1.4999, grad_fn=<DivBackward0>)
# Grad tensor([1.1928, 1.5226, 1.1968, 0.8663])
# Iteration 100: Normalized Gradient = 2.4338831901550293, Adaptive learning rate = 0.005
# ite 101
# Average height tensor(1.4994, grad_fn=<DivBackward0>)
# Grad tensor([1.1920, 1.5215, 1.1961, 0.8658])
# ite 102
# Average height tensor(1.5017, grad_fn=<DivBackward0>)
# Grad tensor([-1.1961, -1.5270, -1.1998, -0.8681])
# ite 103
# Average height tensor(1.5011, grad_fn=<DivBackward0>)
# Grad tensor([-1.1949, -1.5255, -1.1988, -0.8675])
# ite 104
# Average height tensor(1.4978, grad_fn=<DivBackward0>)
# Grad tensor([1.1891, 1.5177, 1.1936, 0.8643])
# ite 105
# Average height tensor(1.4976, grad_fn=<DivBackward0>)
# Grad tensor([1.1887, 1.5171, 1.1932, 0.8640])
# Iteration 105: Normalized Gradient = 2.4258835315704346, Adaptive learning rate = 0.005
# ite 106
# Average height tensor(1.5000, grad_fn=<DivBackward0>)
# Grad tensor([-1.1930, -1.5229, -1.1971, -0.8665])
# ite 107
# Average height tensor(1.4995, grad_fn=<DivBackward0>)
# Grad tensor([1.1921, 1.5218, 1.1964, 0.8660])
# ite 108
# Average height tensor(1.5018, grad_fn=<DivBackward0>)
# Grad tensor([-1.1961, -1.5271, -1.2000, -0.8682])
# ite 109
# Average height tensor(1.5011, grad_fn=<DivBackward0>)
# Grad tensor([-1.1949, -1.5255, -1.1989, -0.8676])
# ite 110
# Average height tensor(1.4979, grad_fn=<DivBackward0>)
# Grad tensor([1.1891, 1.5177, 1.1937, 0.8643])
# Iteration 110: Normalized Gradient = 2.426801919937134, Adaptive learning rate = 0.005
# ite 111
# Average height tensor(1.4976, grad_fn=<DivBackward0>)
# Grad tensor([1.1886, 1.5170, 1.1932, 0.8641])
# ite 112
# Average height tensor(1.5000, grad_fn=<DivBackward0>)
# Grad tensor([1.1929, 1.5227, 1.1971, 0.8664])
# ite 113
# Average height tensor(1.5048, grad_fn=<DivBackward0>)
# Grad tensor([-1.2014, -1.5343, -1.2048, -0.8712])
# ite 114
# Average height tensor(1.5064, grad_fn=<DivBackward0>)
# Grad tensor([-1.2044, -1.5383, -1.2075, -0.8729])
# ite 115
# Average height tensor(1.5052, grad_fn=<DivBackward0>)
# Grad tensor([-1.2023, -1.5354, -1.2056, -0.8717])
# Iteration 115: Normalized Gradient = 2.4527840614318848, Adaptive learning rate = 0.005
# ite 116
# Average height tensor(1.5015, grad_fn=<DivBackward0>)
# Grad tensor([-1.1956, -1.5264, -1.1996, -0.8680])
# ite 117
# Average height tensor(1.4955, grad_fn=<DivBackward0>)
# Grad tensor([1.1849, 1.5121, 1.1899, 0.8620])
# ite 118
# Average height tensor(1.4928, grad_fn=<DivBackward0>)
# Grad tensor([1.1801, 1.5056, 1.1855, 0.8593])
# ite 119
# Average height tensor(1.4929, grad_fn=<DivBackward0>)
# Grad tensor([1.1803, 1.5058, 1.1857, 0.8594])
# ite 120
# Average height tensor(1.4956, grad_fn=<DivBackward0>)
# Grad tensor([1.1850, 1.5122, 1.1900, 0.8621])
# Iteration 120: Normalized Gradient = 2.418754816055298, Adaptive learning rate = 0.005
# ite 121
# Average height tensor(1.5006, grad_fn=<DivBackward0>)
# Grad tensor([-1.1939, -1.5242, -1.1981, -0.8671])
# ite 122
# Average height tensor(1.5025, grad_fn=<DivBackward0>)
# Grad tensor([-1.1973, -1.5288, -1.2012, -0.8690])
# ite 123
# Average height tensor(1.5016, grad_fn=<DivBackward0>)
# Grad tensor([-1.1957, -1.5266, -1.1998, -0.8681])
# ite 124
# Average height tensor(1.4982, grad_fn=<DivBackward0>)
# Grad tensor([1.1895, 1.5183, 1.1942, 0.8647])
# ite 125
# Average height tensor(1.4977, grad_fn=<DivBackward0>)
# Grad tensor([1.1887, 1.5171, 1.1934, 0.8642])
# Iteration 125: Normalized Gradient = 2.426043748855591, Adaptive learning rate = 0.005
# ite 126
# Average height tensor(1.4998, grad_fn=<DivBackward0>)
# Grad tensor([1.1925, 1.5223, 1.1969, 0.8664])
# ite 127
# Average height tensor(1.5044, grad_fn=<DivBackward0>)
# Grad tensor([-1.2006, -1.5332, -1.2043, -0.8709])
# ite 128
# Average height tensor(1.5059, grad_fn=<DivBackward0>)
# Grad tensor([-1.2033, -1.5368, -1.2067, -0.8724])
# ite 129
# Average height tensor(1.5046, grad_fn=<DivBackward0>)
# Grad tensor([-1.2009, -1.5336, -1.2046, -0.8711])
# ite 130
# Average height tensor(1.5008, grad_fn=<DivBackward0>)
# Grad tensor([-1.1941, -1.5245, -1.1984, -0.8673])
# Iteration 130: Normalized Gradient = 2.436880588531494, Adaptive learning rate = 0.005
# ite 131
# Average height tensor(1.4948, grad_fn=<DivBackward0>)
# Grad tensor([1.1834, 1.5101, 1.1888, 0.8613])
# ite 132
# Average height tensor(1.4919, grad_fn=<DivBackward0>)
# Grad tensor([1.1785, 1.5035, 1.1843, 0.8585])
# ite 133
# Average height tensor(1.4920, grad_fn=<DivBackward0>)
# Grad tensor([1.1785, 1.5035, 1.1843, 0.8586])
# ite 134
# Average height tensor(1.4945, grad_fn=<DivBackward0>)
# Grad tensor([1.1830, 1.5096, 1.1884, 0.8611])
# ite 135
# Average height tensor(1.4994, grad_fn=<DivBackward0>)
# Grad tensor([1.1917, 1.5212, 1.1963, 0.8660])
# Iteration 135: Normalized Gradient = 2.4321506023406982, Adaptive learning rate = 0.005
# ite 136
# Average height tensor(1.5065, grad_fn=<DivBackward0>)
# Grad tensor([-1.2042, -1.5381, -1.2077, -0.8730])
# ite 137
# Average height tensor(1.5102, grad_fn=<DivBackward0>)
# Grad tensor([-1.2109, -1.5471, -1.2137, -0.8768])
# ite 138
# Average height tensor(1.5109, grad_fn=<DivBackward0>)
# Grad tensor([-1.2121, -1.5488, -1.2149, -0.8775])
# ite 139
# Average height tensor(1.5088, grad_fn=<DivBackward0>)
# Grad tensor([-1.2084, -1.5438, -1.2116, -0.8754])
# ite 140
# Average height tensor(1.5044, grad_fn=<DivBackward0>)
# Grad tensor([-1.2004, -1.5330, -1.2043, -0.8710])
# Iteration 140: Normalized Gradient = 2.4495084285736084, Adaptive learning rate = 0.005
# ite 141
# Average height tensor(1.4978, grad_fn=<DivBackward0>)
# Grad tensor([1.1886, 1.5172, 1.1937, 0.8644])
# ite 142
# Average height tensor(1.4944, grad_fn=<DivBackward0>)
# Grad tensor([1.1827, 1.5092, 1.1883, 0.8611])
# ite 143
# Average height tensor(1.4940, grad_fn=<DivBackward0>)
# Grad tensor([1.1819, 1.5082, 1.1876, 0.8607])
# ite 144
# Average height tensor(1.4961, grad_fn=<DivBackward0>)
# Grad tensor([1.1857, 1.5132, 1.1911, 0.8628])
# ite 145
# Average height tensor(1.5006, grad_fn=<DivBackward0>)
# Grad tensor([-1.1937, -1.5239, -1.1983, -0.8673])
# Iteration 145: Normalized Gradient = 2.436262845993042, Adaptive learning rate = 0.005
# ite 146
# Average height tensor(1.5021, grad_fn=<DivBackward0>)
# Grad tensor([-1.1963, -1.5275, -1.2007, -0.8688])
# ite 147
# Average height tensor(1.5008, grad_fn=<DivBackward0>)
# Grad tensor([-1.1940, -1.5244, -1.1987, -0.8675])
# ite 148
# Average height tensor(1.4971, grad_fn=<DivBackward0>)
# Grad tensor([1.1874, 1.5155, 1.1927, 0.8638])
# ite 149
# Average height tensor(1.4963, grad_fn=<DivBackward0>)
# Grad tensor([1.1860, 1.5137, 1.1915, 0.8630])
# ite 150
# Average height tensor(1.4982, grad_fn=<DivBackward0>)
# Grad tensor([1.1893, 1.5181, 1.1945, 0.8649])
# Iteration 150: Normalized Gradient = 2.4277169704437256, Adaptive learning rate = 0.005
# ite 151
# Average height tensor(1.5024, grad_fn=<DivBackward0>)
# Grad tensor([-1.1968, -1.5282, -1.2013, -0.8691])
# ite 152
# Average height tensor(1.5037, grad_fn=<DivBackward0>)
# Grad tensor([-1.1990, -1.5312, -1.2033, -0.8704])
# ite 153
# Average height tensor(1.5022, grad_fn=<DivBackward0>)
# Grad tensor([-1.1964, -1.5276, -1.2009, -0.8689])
# ite 154
# Average height tensor(1.4983, grad_fn=<DivBackward0>)
# Grad tensor([1.1894, 1.5183, 1.1946, 0.8650])
# ite 155
# Average height tensor(1.4974, grad_fn=<DivBackward0>)
# Grad tensor([1.1877, 1.5160, 1.1931, 0.8641])
# Iteration 155: Normalized Gradient = 2.4247169494628906, Adaptive learning rate = 0.005
# ite 156
# Average height tensor(1.4991, grad_fn=<DivBackward0>)
# Grad tensor([1.1907, 1.5201, 1.1959, 0.8658])
# ite 157
# Average height tensor(1.5031, grad_fn=<DivBackward0>)
# Grad tensor([-1.1980, -1.5299, -1.2025, -0.8699])
# ite 158
# Average height tensor(1.5043, grad_fn=<DivBackward0>)
# Grad tensor([-1.2000, -1.5325, -1.2043, -0.8710])
# ite 159
# Average height tensor(1.5027, grad_fn=<DivBackward0>)
# Grad tensor([-1.1972, -1.5287, -1.2017, -0.8694])
# ite 160
# Average height tensor(1.4987, grad_fn=<DivBackward0>)
# Grad tensor([1.1900, 1.5191, 1.1953, 0.8654])
# Iteration 160: Normalized Gradient = 2.4293298721313477, Adaptive learning rate = 0.005
# ite 161
# Average height tensor(1.4976, grad_fn=<DivBackward0>)
# Grad tensor([1.1882, 1.5167, 1.1936, 0.8644])
# ite 162
# Average height tensor(1.4993, grad_fn=<DivBackward0>)
# Grad tensor([1.1911, 1.5205, 1.1962, 0.8660])
# ite 163
# Average height tensor(1.5033, grad_fn=<DivBackward0>)
# Grad tensor([-1.1982, -1.5301, -1.2027, -0.8700])
# ite 164
# Average height tensor(1.5043, grad_fn=<DivBackward0>)
# Grad tensor([-1.2000, -1.5326, -1.2044, -0.8711])
# ite 165
# Average height tensor(1.5027, grad_fn=<DivBackward0>)
# Grad tensor([-1.1971, -1.5286, -1.2017, -0.8694])
# Iteration 165: Normalized Gradient = 2.443330764770508, Adaptive learning rate = 0.005
# ite 166
# Average height tensor(1.4986, grad_fn=<DivBackward0>)
# Grad tensor([1.1899, 1.5190, 1.1952, 0.8654])
# ite 167
# Average height tensor(1.4976, grad_fn=<DivBackward0>)
# Grad tensor([1.1880, 1.5164, 1.1935, 0.8643])
# ite 168
# Average height tensor(1.4991, grad_fn=<DivBackward0>)
# Grad tensor([1.1908, 1.5201, 1.1960, 0.8659])
# ite 169
# Average height tensor(1.5031, grad_fn=<DivBackward0>)
# Grad tensor([-1.1978, -1.5296, -1.2024, -0.8699])
# ite 170
# Average height tensor(1.5041, grad_fn=<DivBackward0>)
# Grad tensor([-1.1996, -1.5320, -1.2040, -0.8709])
# Iteration 170: Normalized Gradient = 2.4482898712158203, Adaptive learning rate = 0.005
# ite 171
# Average height tensor(1.5024, grad_fn=<DivBackward0>)
# Grad tensor([-1.1966, -1.5280, -1.2013, -0.8692])
# ite 172
# Average height tensor(1.4984, grad_fn=<DivBackward0>)
# Grad tensor([1.1894, 1.5183, 1.1948, 0.8652])
# ite 173
# Average height tensor(1.4973, grad_fn=<DivBackward0>)
# Grad tensor([1.1874, 1.5157, 1.1931, 0.8641])
# ite 174
# Average height tensor(1.4988, grad_fn=<DivBackward0>)
# Grad tensor([1.1902, 1.5193, 1.1955, 0.8656])
# ite 175
# Average height tensor(1.5027, grad_fn=<DivBackward0>)
# Grad tensor([-1.1971, -1.5287, -1.2019, -0.8695])
# Iteration 175: Normalized Gradient = 2.4434797763824463, Adaptive learning rate = 0.005
# ite 176
# Average height tensor(1.5037, grad_fn=<DivBackward0>)
# Grad tensor([-1.1989, -1.5311, -1.2035, -0.8705])
# ite 177
# Average height tensor(1.5020, grad_fn=<DivBackward0>)
# Grad tensor([-1.1959, -1.5270, -1.2007, -0.8688])
# ite 178
# Average height tensor(1.4980, grad_fn=<DivBackward0>)
# Grad tensor([1.1887, 1.5173, 1.1942, 0.8648])
# ite 179
# Average height tensor(1.4969, grad_fn=<DivBackward0>)
# Grad tensor([1.1867, 1.5147, 1.1924, 0.8637])
# ite 180
# Average height tensor(1.4984, grad_fn=<DivBackward0>)
# Grad tensor([1.1894, 1.5183, 1.1949, 0.8652])
# Iteration 180: Normalized Gradient = 2.4282028675079346, Adaptive learning rate = 0.005
# ite 181
# Average height tensor(1.5023, grad_fn=<DivBackward0>)
# Grad tensor([-1.1963, -1.5276, -1.2012, -0.8691])
# ite 182
# Average height tensor(1.5033, grad_fn=<DivBackward0>)
# Grad tensor([-1.1980, -1.5299, -1.2028, -0.8701])
# ite 183
# Average height tensor(1.5016, grad_fn=<DivBackward0>)
# Grad tensor([-1.1950, -1.5259, -1.2000, -0.8684])
# ite 184
# Average height tensor(1.4975, grad_fn=<DivBackward0>)
# Grad tensor([1.1878, 1.5162, 1.1935, 0.8644])
# ite 185
# Average height tensor(1.4964, grad_fn=<DivBackward0>)
# Grad tensor([1.1859, 1.5136, 1.1917, 0.8633])
# Iteration 185: Normalized Gradient = 2.4212844371795654, Adaptive learning rate = 0.005
# ite 186
# Average height tensor(1.4979, grad_fn=<DivBackward0>)
# Grad tensor([1.1885, 1.5171, 1.1942, 0.8648])
# ite 187
# Average height tensor(1.5018, grad_fn=<DivBackward0>)
# Grad tensor([-1.1954, -1.5264, -1.2004, -0.8687])
# ite 188
# Average height tensor(1.5028, grad_fn=<DivBackward0>)
# Grad tensor([-1.1971, -1.5287, -1.2020, -0.8696])
# ite 189
# Average height tensor(1.5011, grad_fn=<DivBackward0>)
# Grad tensor([-1.1941, -1.5247, -1.1993, -0.8679])
# ite 190
# Average height tensor(1.4971, grad_fn=<DivBackward0>)
# Grad tensor([1.1869, 1.5150, 1.1928, 0.8639])
# Iteration 190: Normalized Gradient = 2.423488140106201, Adaptive learning rate = 0.005
# ite 191
# Average height tensor(1.4959, grad_fn=<DivBackward0>)
# Grad tensor([1.1850, 1.5124, 1.1910, 0.8628])
# ite 192
# Average height tensor(1.4974, grad_fn=<DivBackward0>)
# Grad tensor([1.1876, 1.5160, 1.1934, 0.8643])
# ite 193
# Average height tensor(1.5013, grad_fn=<DivBackward0>)
# Grad tensor([-1.1945, -1.5252, -1.1996, -0.8682])
# ite 194
# Average height tensor(1.5023, grad_fn=<DivBackward0>)
# Grad tensor([-1.1962, -1.5275, -1.2012, -0.8691])
# ite 195
# Average height tensor(1.5006, grad_fn=<DivBackward0>)
# Grad tensor([-1.1932, -1.5234, -1.1985, -0.8675])
# Iteration 195: Normalized Gradient = 2.435853958129883, Adaptive learning rate = 0.005
# ite 196
# Average height tensor(1.4966, grad_fn=<DivBackward0>)
# Grad tensor([1.1860, 1.5138, 1.1920, 0.8634])
# ite 197
# Average height tensor(1.4955, grad_fn=<DivBackward0>)
# Grad tensor([1.1841, 1.5112, 1.1902, 0.8623])
# ite 198
# Average height tensor(1.4969, grad_fn=<DivBackward0>)
# Grad tensor([1.1867, 1.5147, 1.1926, 0.8638])
# ite 199
# Average height tensor(1.5008, grad_fn=<DivBackward0>)
# Grad tensor([-1.1935, -1.5239, -1.1988, -0.8677])
# ite 200
# Average height tensor(1.5017, grad_fn=<DivBackward0>)
# Grad tensor([-1.1952, -1.5262, -1.2004, -0.8686])
# Iteration 200: Normalized Gradient = 2.4399187564849854, Adaptive learning rate = 0.005
# ite 201
# Average height tensor(1.5001, grad_fn=<DivBackward0>)
# Grad tensor([-1.1922, -1.5222, -1.1977, -0.8670])
# ite 202
# Average height tensor(1.4961, grad_fn=<DivBackward0>)
# Grad tensor([1.1851, 1.5126, 1.1912, 0.8630])
# ite 203
# Average height tensor(1.4950, grad_fn=<DivBackward0>)
# Grad tensor([1.1831, 1.5100, 1.1895, 0.8619])
# ite 204
# Average height tensor(1.4964, grad_fn=<DivBackward0>)
# Grad tensor([1.1858, 1.5135, 1.1919, 0.8634])
# ite 205
# Average height tensor(1.5003, grad_fn=<DivBackward0>)
# Grad tensor([-1.1926, -1.5226, -1.1980, -0.8672])
# Iteration 205: Normalized Gradient = 2.4347448348999023, Adaptive learning rate = 0.005
# ite 206
# Average height tensor(1.5012, grad_fn=<DivBackward0>)
# Grad tensor([-1.1942, -1.5249, -1.1996, -0.8681])
# ite 207
# Average height tensor(1.4996, grad_fn=<DivBackward0>)
# Grad tensor([1.1913, 1.5209, 1.1969, 0.8665])
# ite 208
# Average height tensor(1.5006, grad_fn=<DivBackward0>)
# Grad tensor([-1.1931, -1.5233, -1.1985, -0.8675])
# ite 209
# Average height tensor(1.4990, grad_fn=<DivBackward0>)
# Grad tensor([1.1902, 1.5195, 1.1959, 0.8659])
# ite 210
# Average height tensor(1.5000, grad_fn=<DivBackward0>)
# Grad tensor([-1.1921, -1.5220, -1.1977, -0.8670])
# Iteration 210: Normalized Gradient = 2.4338555335998535, Adaptive learning rate = 0.005
# ite 211
# Average height tensor(1.4985, grad_fn=<DivBackward0>)
# Grad tensor([1.1893, 1.5183, 1.1952, 0.8654])
# ite 212
# Average height tensor(1.4996, grad_fn=<DivBackward0>)
# Grad tensor([1.1913, 1.5209, 1.1969, 0.8665])
# ite 213
# Average height tensor(1.5031, grad_fn=<DivBackward0>)
# Grad tensor([-1.1975, -1.5293, -1.2026, -0.8700])
# ite 214
# Average height tensor(1.5037, grad_fn=<DivBackward0>)
# Grad tensor([-1.1987, -1.5309, -1.2036, -0.8707])
# ite 215
# Average height tensor(1.5018, grad_fn=<DivBackward0>)
# Grad tensor([-1.1952, -1.5262, -1.2005, -0.8687])
# Iteration 215: Normalized Gradient = 2.439970016479492, Adaptive learning rate = 0.005
# ite 216
# Average height tensor(1.4975, grad_fn=<DivBackward0>)
# Grad tensor([1.1876, 1.5160, 1.1936, 0.8645])
# ite 217
# Average height tensor(1.4962, grad_fn=<DivBackward0>)
# Grad tensor([1.1852, 1.5128, 1.1915, 0.8631])
# ite 218
# Average height tensor(1.4975, grad_fn=<DivBackward0>)
# Grad tensor([1.1875, 1.5158, 1.1935, 0.8644])
# ite 219
# Average height tensor(1.5011, grad_fn=<DivBackward0>)
# Grad tensor([-1.1939, -1.5245, -1.1994, -0.8680])
# ite 220
# Average height tensor(1.5019, grad_fn=<DivBackward0>)
# Grad tensor([-1.1953, -1.5264, -1.2007, -0.8688])
# Iteration 220: Normalized Gradient = 2.4402966499328613, Adaptive learning rate = 0.005
# ite 221
# Average height tensor(1.5001, grad_fn=<DivBackward0>)
# Grad tensor([-1.1921, -1.5220, -1.1977, -0.8670])
# ite 222
# Average height tensor(1.4959, grad_fn=<DivBackward0>)
# Grad tensor([1.1848, 1.5122, 1.1911, 0.8629])
# ite 223
# Average height tensor(1.4947, grad_fn=<DivBackward0>)
# Grad tensor([1.1826, 1.5093, 1.1891, 0.8617])
# ite 224
# Average height tensor(1.4961, grad_fn=<DivBackward0>)
# Grad tensor([1.1850, 1.5125, 1.1913, 0.8631])
# ite 225
# Average height tensor(1.4998, grad_fn=<DivBackward0>)
# Grad tensor([1.1916, 1.5214, 1.1973, 0.8668])
# Iteration 225: Normalized Gradient = 2.4329674243927, Adaptive learning rate = 0.005
# ite 226
# Average height tensor(1.5057, grad_fn=<DivBackward0>)
# Grad tensor([-1.2021, -1.5354, -1.2068, -0.8726])
# ite 227
# Average height tensor(1.5084, grad_fn=<DivBackward0>)
# Grad tensor([-1.2070, -1.5421, -1.2113, -0.8754])
# ite 228
# Average height tensor(1.5084, grad_fn=<DivBackward0>)
# Grad tensor([-1.2069, -1.5420, -1.2112, -0.8754])
# ite 229
# Average height tensor(1.5058, grad_fn=<DivBackward0>)
# Grad tensor([-1.2022, -1.5357, -1.2070, -0.8728])
# ite 230
# Average height tensor(1.5009, grad_fn=<DivBackward0>)
# Grad tensor([-1.1935, -1.5240, -1.1991, -0.8679])
# Iteration 230: Normalized Gradient = 2.4368531703948975, Adaptive learning rate = 0.005
# ite 231
# Average height tensor(1.4941, grad_fn=<DivBackward0>)
# Grad tensor([1.1814, 1.5077, 1.1881, 0.8611])
# ite 232
# Average height tensor(1.4904, grad_fn=<DivBackward0>)
# Grad tensor([1.1750, 1.4990, 1.1823, 0.8574])
# ite 233
# Average height tensor(1.4896, grad_fn=<DivBackward0>)
# Grad tensor([1.1735, 1.4970, 1.1809, 0.8566])
# ite 234
# Average height tensor(1.4912, grad_fn=<DivBackward0>)
# Grad tensor([1.1764, 1.5009, 1.1836, 0.8583])
# ite 235
# Average height tensor(1.4952, grad_fn=<DivBackward0>)
# Grad tensor([1.1833, 1.5103, 1.1899, 0.8622])
# Iteration 235: Normalized Gradient = 2.416700601577759, Adaptive learning rate = 0.005
# ite 236
# Average height tensor(1.5012, grad_fn=<DivBackward0>)
# Grad tensor([-1.1940, -1.5247, -1.1997, -0.8683])
# ite 237
# Average height tensor(1.5042, grad_fn=<DivBackward0>)
# Grad tensor([-1.1993, -1.5317, -1.2045, -0.8712])
# ite 238
# Average height tensor(1.5043, grad_fn=<DivBackward0>)
# Grad tensor([-1.1995, -1.5321, -1.2047, -0.8714])
# ite 239
# Average height tensor(1.5020, grad_fn=<DivBackward0>)
# Grad tensor([-1.1953, -1.5264, -1.2009, -0.8690])
# ite 240
# Average height tensor(1.4973, grad_fn=<DivBackward0>)
# Grad tensor([1.1870, 1.5153, 1.1934, 0.8644])
# Iteration 240: Normalized Gradient = 2.4241437911987305, Adaptive learning rate = 0.005
# ite 241
# Average height tensor(1.4956, grad_fn=<DivBackward0>)
# Grad tensor([1.1840, 1.5113, 1.1907, 0.8627])
# ite 242
# Average height tensor(1.4966, grad_fn=<DivBackward0>)
# Grad tensor([1.1857, 1.5135, 1.1923, 0.8637])
# ite 243
# Average height tensor(1.4999, grad_fn=<DivBackward0>)
# Grad tensor([1.1916, 1.5214, 1.1976, 0.8670])
# ite 244
# Average height tensor(1.5054, grad_fn=<DivBackward0>)
# Grad tensor([-1.2014, -1.5347, -1.2065, -0.8725])
# ite 245
# Average height tensor(1.5079, grad_fn=<DivBackward0>)
# Grad tensor([-1.2058, -1.5406, -1.2105, -0.8750])
# Iteration 245: Normalized Gradient = 2.461355209350586, Adaptive learning rate = 0.005
# ite 246
# Average height tensor(1.5076, grad_fn=<DivBackward0>)
# Grad tensor([-1.2052, -1.5398, -1.2100, -0.8747])
# ite 247
# Average height tensor(1.5047, grad_fn=<DivBackward0>)
# Grad tensor([-1.2001, -1.5329, -1.2054, -0.8718])
# ite 248
# Average height tensor(1.4997, grad_fn=<DivBackward0>)
# Grad tensor([1.1911, 1.5208, 1.1973, 0.8668])
# ite 249
# Average height tensor(1.4976, grad_fn=<DivBackward0>)
# Grad tensor([1.1875, 1.5159, 1.1940, 0.8648])
# ite 250
# Average height tensor(1.4983, grad_fn=<DivBackward0>)
# Grad tensor([1.1886, 1.5175, 1.1950, 0.8654])
# Iteration 250: Normalized Gradient = 2.427452325820923, Adaptive learning rate = 0.005
# ite 251
# Average height tensor(1.5013, grad_fn=<DivBackward0>)
# Grad tensor([-1.1940, -1.5248, -1.2000, -0.8685])
# ite 252
# Average height tensor(1.5016, grad_fn=<DivBackward0>)
# Grad tensor([-1.1945, -1.5254, -1.2004, -0.8687])
# ite 253
# Average height tensor(1.4993, grad_fn=<DivBackward0>)
# Grad tensor([1.1905, 1.5200, 1.1968, 0.8665])
# ite 254
# Average height tensor(1.4998, grad_fn=<DivBackward0>)
# Grad tensor([1.1913, 1.5210, 1.1975, 0.8669])
# ite 255
# Average height tensor(1.5027, grad_fn=<DivBackward0>)
# Grad tensor([-1.1964, -1.5280, -1.2022, -0.8698])
# Iteration 255: Normalized Gradient = 2.442918062210083, Adaptive learning rate = 0.005
# ite 256
# Average height tensor(1.5028, grad_fn=<DivBackward0>)
# Grad tensor([-1.1966, -1.5282, -1.2024, -0.8699])
# ite 257
# Average height tensor(1.5004, grad_fn=<DivBackward0>)
# Grad tensor([-1.1923, -1.5224, -1.1985, -0.8675])
# ite 258
# Average height tensor(1.4958, grad_fn=<DivBackward0>)
# Grad tensor([1.1841, 1.5114, 1.1910, 0.8629])
# ite 259
# Average height tensor(1.4941, grad_fn=<DivBackward0>)
# Grad tensor([1.1811, 1.5074, 1.1883, 0.8612])
# ite 260
# Average height tensor(1.4950, grad_fn=<DivBackward0>)
# Grad tensor([1.1827, 1.5095, 1.1898, 0.8622])
# Iteration 260: Normalized Gradient = 2.4158565998077393, Adaptive learning rate = 0.005
# ite 261
# Average height tensor(1.4983, grad_fn=<DivBackward0>)
# Grad tensor([1.1885, 1.5173, 1.1951, 0.8654])
# ite 262
# Average height tensor(1.5037, grad_fn=<DivBackward0>)
# Grad tensor([-1.1982, -1.5304, -1.2039, -0.8709])
# ite 263
# Average height tensor(1.5061, grad_fn=<DivBackward0>)
# Grad tensor([-1.2025, -1.5362, -1.2078, -0.8733])
# ite 264
# Average height tensor(1.5058, grad_fn=<DivBackward0>)
# Grad tensor([-1.2019, -1.5353, -1.2072, -0.8730])
# ite 265
# Average height tensor(1.5030, grad_fn=<DivBackward0>)
# Grad tensor([-1.1968, -1.5285, -1.2027, -0.8702])
# Iteration 265: Normalized Gradient = 2.443840503692627, Adaptive learning rate = 0.005
# ite 266
# Average height tensor(1.4980, grad_fn=<DivBackward0>)
# Grad tensor([1.1879, 1.5165, 1.1946, 0.8651])
# ite 267
# Average height tensor(1.4959, grad_fn=<DivBackward0>)
# Grad tensor([1.1843, 1.5117, 1.1913, 0.8631])
# ite 268
# Average height tensor(1.4965, grad_fn=<DivBackward0>)
# Grad tensor([1.1854, 1.5132, 1.1923, 0.8637])
# ite 269
# Average height tensor(1.4996, grad_fn=<DivBackward0>)
# Grad tensor([1.1907, 1.5203, 1.1972, 0.8668])
# ite 270
# Average height tensor(1.5048, grad_fn=<DivBackward0>)
# Grad tensor([-1.2000, -1.5328, -1.2056, -0.8720])
# Iteration 270: Normalized Gradient = 2.4502041339874268, Adaptive learning rate = 0.005
# ite 271
# Average height tensor(1.5070, grad_fn=<DivBackward0>)
# Grad tensor([-1.2039, -1.5381, -1.2092, -0.8742])
# ite 272
# Average height tensor(1.5065, grad_fn=<DivBackward0>)
# Grad tensor([-1.2030, -1.5368, -1.2083, -0.8737])
# ite 273
# Average height tensor(1.5035, grad_fn=<DivBackward0>)
# Grad tensor([-1.1976, -1.5296, -1.2035, -0.8707])
# ite 274
# Average height tensor(1.4983, grad_fn=<DivBackward0>)
# Grad tensor([1.1884, 1.5172, 1.1951, 0.8655])
# ite 275
# Average height tensor(1.4961, grad_fn=<DivBackward0>)
# Grad tensor([1.1845, 1.5120, 1.1916, 0.8633])
# Iteration 275: Normalized Gradient = 2.419661045074463, Adaptive learning rate = 0.005
# ite 276
# Average height tensor(1.4966, grad_fn=<DivBackward0>)
# Grad tensor([1.1854, 1.5132, 1.1925, 0.8638])
# ite 277
# Average height tensor(1.4995, grad_fn=<DivBackward0>)
# Grad tensor([1.1905, 1.5201, 1.1971, 0.8668])
# ite 278
# Average height tensor(1.5046, grad_fn=<DivBackward0>)
# Grad tensor([-1.1996, -1.5323, -1.2054, -0.8719])
# ite 279
# Average height tensor(1.5067, grad_fn=<DivBackward0>)
# Grad tensor([-1.2034, -1.5374, -1.2088, -0.8740])
# ite 280
# Average height tensor(1.5061, grad_fn=<DivBackward0>)
# Grad tensor([-1.2022, -1.5359, -1.2078, -0.8734])
# Iteration 280: Normalized Gradient = 2.454789400100708, Adaptive learning rate = 0.005
# ite 281
# Average height tensor(1.5030, grad_fn=<DivBackward0>)
# Grad tensor([-1.1968, -1.5285, -1.2029, -0.8703])
# ite 282
# Average height tensor(1.4978, grad_fn=<DivBackward0>)
# Grad tensor([1.1875, 1.5160, 1.1944, 0.8651])
# ite 283
# Average height tensor(1.4956, grad_fn=<DivBackward0>)
# Grad tensor([1.1835, 1.5107, 1.1908, 0.8629])
# ite 284
# Average height tensor(1.4960, grad_fn=<DivBackward0>)
# Grad tensor([1.1843, 1.5117, 1.1916, 0.8633])
# ite 285
# Average height tensor(1.4989, grad_fn=<DivBackward0>)
# Grad tensor([1.1893, 1.5185, 1.1962, 0.8662])
# Iteration 285: Normalized Gradient = 2.4292685985565186, Adaptive learning rate = 0.005
# ite 286
# Average height tensor(1.5039, grad_fn=<DivBackward0>)
# Grad tensor([-1.1983, -1.5306, -1.2043, -0.8712])
# ite 287
# Average height tensor(1.5060, grad_fn=<DivBackward0>)
# Grad tensor([-1.2019, -1.5355, -1.2077, -0.8733])
# ite 288
# Average height tensor(1.5053, grad_fn=<DivBackward0>)
# Grad tensor([-1.2008, -1.5339, -1.2066, -0.8726])
# ite 289
# Average height tensor(1.5022, grad_fn=<DivBackward0>)
# Grad tensor([-1.1953, -1.5265, -1.2016, -0.8695])
# ite 290
# Average height tensor(1.4970, grad_fn=<DivBackward0>)
# Grad tensor([1.1859, 1.5140, 1.1932, 0.8643])
# Iteration 290: Normalized Gradient = 2.4226748943328857, Adaptive learning rate = 0.005
# ite 291
# Average height tensor(1.4948, grad_fn=<DivBackward0>)
# Grad tensor([1.1820, 1.5087, 1.1896, 0.8621])
# ite 292
# Average height tensor(1.4952, grad_fn=<DivBackward0>)
# Grad tensor([1.1827, 1.5096, 1.1902, 0.8625])
# ite 293
# Average height tensor(1.4980, grad_fn=<DivBackward0>)
# Grad tensor([1.1877, 1.5163, 1.1948, 0.8653])
# ite 294
# Average height tensor(1.5030, grad_fn=<DivBackward0>)
# Grad tensor([-1.1965, -1.5283, -1.2029, -0.8703])
# ite 295
# Average height tensor(1.5050, grad_fn=<DivBackward0>)
# Grad tensor([-1.2002, -1.5332, -1.2062, -0.8724])
# Iteration 295: Normalized Gradient = 2.450892210006714, Adaptive learning rate = 0.005
# ite 296
# Average height tensor(1.5044, grad_fn=<DivBackward0>)
# Grad tensor([-1.1990, -1.5315, -1.2051, -0.8717])
# ite 297
# Average height tensor(1.5013, grad_fn=<DivBackward0>)
# Grad tensor([-1.1935, -1.5241, -1.2001, -0.8686])
# ite 298
# Average height tensor(1.4960, grad_fn=<DivBackward0>)
# Grad tensor([1.1842, 1.5117, 1.1917, 0.8634])
# ite 299
# Average height tensor(1.4938, grad_fn=<DivBackward0>)
# Grad tensor([1.1802, 1.5063, 1.1881, 0.8612])
# ite 300
# Average height tensor(1.4942, grad_fn=<DivBackward0>)
# Grad tensor([1.1809, 1.5073, 1.1887, 0.8616])
# Iteration 300: Normalized Gradient = 2.4128198623657227, Adaptive learning rate = 0.005
# ite 301
# Average height tensor(1.4970, grad_fn=<DivBackward0>)
# Grad tensor([1.1858, 1.5139, 1.1932, 0.8644])
# ite 302
# Average height tensor(1.5020, grad_fn=<DivBackward0>)
# Grad tensor([-1.1947, -1.5258, -1.2013, -0.8694])
# ite 303
# Average height tensor(1.5040, grad_fn=<DivBackward0>)
# Grad tensor([-1.1982, -1.5306, -1.2046, -0.8714])
# ite 304
# Average height tensor(1.5033, grad_fn=<DivBackward0>)
# Grad tensor([-1.1970, -1.5290, -1.2035, -0.8707])
# ite 305
# Average height tensor(1.5003, grad_fn=<DivBackward0>)
# Grad tensor([-1.1916, -1.5216, -1.1985, -0.8676])
# Iteration 305: Normalized Gradient = 2.433980703353882, Adaptive learning rate = 0.005
# ite 306
# Average height tensor(1.4950, grad_fn=<DivBackward0>)
# Grad tensor([1.1823, 1.5092, 1.1901, 0.8624])
# ite 307
# Average height tensor(1.4928, grad_fn=<DivBackward0>)
# Grad tensor([1.1783, 1.5038, 1.1865, 0.8602])
# ite 308
# Average height tensor(1.4932, grad_fn=<DivBackward0>)
# Grad tensor([1.1790, 1.5048, 1.1871, 0.8606])
# ite 309
# Average height tensor(1.4960, grad_fn=<DivBackward0>)
# Grad tensor([1.1839, 1.5114, 1.1916, 0.8634])
# ite 310
# Average height tensor(1.5009, grad_fn=<DivBackward0>)
# Grad tensor([-1.1927, -1.5232, -1.1996, -0.8684])
# Iteration 310: Normalized Gradient = 2.43634033203125, Adaptive learning rate = 0.005
# ite 311
# Average height tensor(1.5029, grad_fn=<DivBackward0>)
# Grad tensor([-1.1963, -1.5280, -1.2029, -0.8704])
# ite 312
# Average height tensor(1.5023, grad_fn=<DivBackward0>)
# Grad tensor([-1.1951, -1.5264, -1.2018, -0.8697])
# ite 313
# Average height tensor(1.4992, grad_fn=<DivBackward0>)
# Grad tensor([1.1896, 1.5190, 1.1968, 0.8666])
# ite 314
# Average height tensor(1.4989, grad_fn=<DivBackward0>)
# Grad tensor([1.1891, 1.5183, 1.1964, 0.8663])
# ite 315
# Average height tensor(1.5011, grad_fn=<DivBackward0>)
# Grad tensor([-1.1929, -1.5235, -1.1999, -0.8685])
# Iteration 315: Normalized Gradient = 2.4368395805358887, Adaptive learning rate = 0.005
# ite 316
# Average height tensor(1.5006, grad_fn=<DivBackward0>)
# Grad tensor([-1.1920, -1.5223, -1.1991, -0.8680])
# ite 317
# Average height tensor(1.4977, grad_fn=<DivBackward0>)
# Grad tensor([1.1869, 1.5153, 1.1944, 0.8651])
# ite 318
# Average height tensor(1.4975, grad_fn=<DivBackward0>)
# Grad tensor([1.1866, 1.5149, 1.1941, 0.8650])
# ite 319
# Average height tensor(1.4998, grad_fn=<DivBackward0>)
# Grad tensor([1.1906, 1.5204, 1.1978, 0.8673])
# ite 320
# Average height tensor(1.5043, grad_fn=<DivBackward0>)
# Grad tensor([-1.1987, -1.5313, -1.2052, -0.8718])
# Iteration 320: Normalized Gradient = 2.448305130004883, Adaptive learning rate = 0.005
# ite 321
# Average height tensor(1.5060, grad_fn=<DivBackward0>)
# Grad tensor([-1.2016, -1.5351, -1.2078, -0.8734])
# ite 322
# Average height tensor(1.5049, grad_fn=<DivBackward0>)
# Grad tensor([-1.1997, -1.5326, -1.2061, -0.8724])
# ite 323
# Average height tensor(1.5015, grad_fn=<DivBackward0>)
# Grad tensor([-1.1936, -1.5244, -1.2006, -0.8690])
# ite 324
# Average height tensor(1.4960, grad_fn=<DivBackward0>)
# Grad tensor([1.1838, 1.5112, 1.1917, 0.8634])
# ite 325
# Average height tensor(1.4934, grad_fn=<DivBackward0>)
# Grad tensor([1.1793, 1.5052, 1.1876, 0.8609])
# Iteration 325: Normalized Gradient = 2.4100115299224854, Adaptive learning rate = 0.005
# ite 326
# Average height tensor(1.4936, grad_fn=<DivBackward0>)
# Grad tensor([1.1796, 1.5056, 1.1879, 0.8611])
# ite 327
# Average height tensor(1.4961, grad_fn=<DivBackward0>)
# Grad tensor([1.1841, 1.5116, 1.1920, 0.8636])
# ite 328
# Average height tensor(1.5009, grad_fn=<DivBackward0>)
# Grad tensor([-1.1925, -1.5229, -1.1997, -0.8684])
# ite 329
# Average height tensor(1.5027, grad_fn=<DivBackward0>)
# Grad tensor([-1.1957, -1.5273, -1.2026, -0.8702])
# ite 330
# Average height tensor(1.5019, grad_fn=<DivBackward0>)
# Grad tensor([-1.1943, -1.5253, -1.2013, -0.8694])
# Iteration 330: Normalized Gradient = 2.4396328926086426, Adaptive learning rate = 0.005
# ite 331
# Average height tensor(1.4987, grad_fn=<DivBackward0>)
# Grad tensor([1.1886, 1.5176, 1.1961, 0.8662])
# ite 332
# Average height tensor(1.4983, grad_fn=<DivBackward0>)
# Grad tensor([1.1878, 1.5166, 1.1954, 0.8658])
# ite 333
# Average height tensor(1.5003, grad_fn=<DivBackward0>)
# Grad tensor([-1.1914, -1.5215, -1.1987, -0.8678])
# ite 334
# Average height tensor(1.4997, grad_fn=<DivBackward0>)
# Grad tensor([1.1903, 1.5201, 1.1978, 0.8672])
# ite 335
# Average height tensor(1.5016, grad_fn=<DivBackward0>)
# Grad tensor([-1.1937, -1.5246, -1.2009, -0.8692])
# Iteration 335: Normalized Gradient = 2.4386487007141113, Adaptive learning rate = 0.005
# ite 336
# Average height tensor(1.5009, grad_fn=<DivBackward0>)
# Grad tensor([-1.1924, -1.5228, -1.1997, -0.8684])
# ite 337
# Average height tensor(1.4978, grad_fn=<DivBackward0>)
# Grad tensor([1.1869, 1.5154, 1.1946, 0.8653])
# ite 338
# Average height tensor(1.4974, grad_fn=<DivBackward0>)
# Grad tensor([1.1862, 1.5145, 1.1940, 0.8649])
# ite 339
# Average height tensor(1.4995, grad_fn=<DivBackward0>)
# Grad tensor([1.1900, 1.5196, 1.1975, 0.8671])
# ite 340
# Average height tensor(1.5039, grad_fn=<DivBackward0>)
# Grad tensor([-1.1977, -1.5300, -1.2045, -0.8714])
# Iteration 340: Normalized Gradient = 2.4465668201446533, Adaptive learning rate = 0.005
# ite 341
# Average height tensor(1.5054, grad_fn=<DivBackward0>)
# Grad tensor([-1.2003, -1.5335, -1.2069, -0.8729])
# ite 342
# Average height tensor(1.5042, grad_fn=<DivBackward0>)
# Grad tensor([-1.1982, -1.5307, -1.2050, -0.8717])
# ite 343
# Average height tensor(1.5006, grad_fn=<DivBackward0>)
# Grad tensor([-1.1919, -1.5222, -1.1993, -0.8682])
# ite 344
# Average height tensor(1.4950, grad_fn=<DivBackward0>)
# Grad tensor([1.1820, 1.5089, 1.1903, 0.8626])
# ite 345
# Average height tensor(1.4924, grad_fn=<DivBackward0>)
# Grad tensor([1.1774, 1.5027, 1.1861, 0.8600])
# Iteration 345: Normalized Gradient = 2.4064319133758545, Adaptive learning rate = 0.005
# ite 346
# Average height tensor(1.4925, grad_fn=<DivBackward0>)
# Grad tensor([1.1775, 1.5029, 1.1862, 0.8601])
# ite 347
# Average height tensor(1.4950, grad_fn=<DivBackward0>)
# Grad tensor([1.1819, 1.5087, 1.1902, 0.8625])
# ite 348
# Average height tensor(1.4996, grad_fn=<DivBackward0>)
# Grad tensor([1.1901, 1.5198, 1.1977, 0.8672])
# ite 349
# Average height tensor(1.5063, grad_fn=<DivBackward0>)
# Grad tensor([-1.2020, -1.5358, -1.2085, -0.8739])
# ite 350
# Average height tensor(1.5099, grad_fn=<DivBackward0>)
# Grad tensor([-1.2083, -1.5443, -1.2143, -0.8775])
# Iteration 350: Normalized Gradient = 2.467710494995117, Adaptive learning rate = 0.005
# ite 351
# Average height tensor(1.5106, grad_fn=<DivBackward0>)
# Grad tensor([-1.2096, -1.5460, -1.2154, -0.8782])
# ite 352
# Average height tensor(1.5087, grad_fn=<DivBackward0>)
# Grad tensor([-1.2061, -1.5414, -1.2123, -0.8763])
# ite 353
# Average height tensor(1.5045, grad_fn=<DivBackward0>)
# Grad tensor([-1.1986, -1.5312, -1.2055, -0.8721])
# ite 354
# Average height tensor(1.4982, grad_fn=<DivBackward0>)
# Grad tensor([1.1875, 1.5163, 1.1955, 0.8658])
# ite 355
# Average height tensor(1.4951, grad_fn=<DivBackward0>)
# Grad tensor([1.1820, 1.5089, 1.1904, 0.8627])
# Iteration 355: Normalized Gradient = 2.415574312210083, Adaptive learning rate = 0.005
# ite 356
# Average height tensor(1.4947, grad_fn=<DivBackward0>)
# Grad tensor([1.1812, 1.5079, 1.1898, 0.8623])
# ite 357
# Average height tensor(1.4967, grad_fn=<DivBackward0>)
# Grad tensor([1.1849, 1.5128, 1.1931, 0.8644])
# ite 358
# Average height tensor(1.5010, grad_fn=<DivBackward0>)
# Grad tensor([-1.1925, -1.5230, -1.2000, -0.8687])
# ite 359
# Average height tensor(1.5025, grad_fn=<DivBackward0>)
# Grad tensor([-1.1950, -1.5264, -1.2023, -0.8701])
# ite 360
# Average height tensor(1.5013, grad_fn=<DivBackward0>)
# Grad tensor([-1.1928, -1.5235, -1.2004, -0.8689])
# Iteration 360: Normalized Gradient = 2.437206268310547, Adaptive learning rate = 0.005
# ite 361
# Average height tensor(1.4977, grad_fn=<DivBackward0>)
# Grad tensor([1.1866, 1.5151, 1.1947, 0.8654])
# ite 362
# Average height tensor(1.4970, grad_fn=<DivBackward0>)
# Grad tensor([1.1853, 1.5134, 1.1936, 0.8647])
# ite 363
# Average height tensor(1.4988, grad_fn=<DivBackward0>)
# Grad tensor([1.1885, 1.5176, 1.1965, 0.8665])
# ite 364
# Average height tensor(1.5029, grad_fn=<DivBackward0>)
# Grad tensor([-1.1956, -1.5273, -1.2030, -0.8705])
# ite 365
# Average height tensor(1.5041, grad_fn=<DivBackward0>)
# Grad tensor([-1.1978, -1.5301, -1.2050, -0.8717])
# Iteration 365: Normalized Gradient = 2.44700026512146, Adaptive learning rate = 0.005
# ite 366
# Average height tensor(1.5027, grad_fn=<DivBackward0>)
# Grad tensor([-1.1953, -1.5268, -1.2027, -0.8703])
# ite 367
# Average height tensor(1.4989, grad_fn=<DivBackward0>)
# Grad tensor([1.1887, 1.5179, 1.1967, 0.8666])
# ite 368
# Average height tensor(1.4980, grad_fn=<DivBackward0>)
# Grad tensor([1.1871, 1.5158, 1.1953, 0.8657])
# ite 369
# Average height tensor(1.4997, grad_fn=<DivBackward0>)
# Grad tensor([1.1899, 1.5196, 1.1979, 0.8674])
# ite 370
# Average height tensor(1.5036, grad_fn=<DivBackward0>)
# Grad tensor([-1.1969, -1.5290, -1.2042, -0.8713])
# Iteration 370: Normalized Gradient = 2.445380926132202, Adaptive learning rate = 0.005
# ite 371
# Average height tensor(1.5047, grad_fn=<DivBackward0>)
# Grad tensor([-1.1988, -1.5316, -1.2060, -0.8724])
# ite 372
# Average height tensor(1.5032, grad_fn=<DivBackward0>)
# Grad tensor([-1.1961, -1.5279, -1.2035, -0.8709])
# ite 373
# Average height tensor(1.4993, grad_fn=<DivBackward0>)
# Grad tensor([1.1893, 1.5188, 1.1974, 0.8671])
# ite 374
# Average height tensor(1.4984, grad_fn=<DivBackward0>)
# Grad tensor([1.1876, 1.5165, 1.1958, 0.8661])
# ite 375
# Average height tensor(1.4999, grad_fn=<DivBackward0>)
# Grad tensor([1.1903, 1.5202, 1.1983, 0.8676])
# Iteration 375: Normalized Gradient = 2.4323678016662598, Adaptive learning rate = 0.005
# ite 376
# Average height tensor(1.5038, grad_fn=<DivBackward0>)
# Grad tensor([-1.1972, -1.5294, -1.2045, -0.8715])
# ite 377
# Average height tensor(1.5048, grad_fn=<DivBackward0>)
# ...
# ite 706
# Average height tensor(1.5019, grad_fn=<DivBackward0>)
# Grad tensor([-1.1916, -1.5226, -1.2026, -0.8707])
# ite 707
# Average height tensor(1.5003, grad_fn=<DivBackward0>)
# Grad tensor([-1.1888, -1.5188, -1.2000, -0.8691])
# ite 708
# Average height tensor(1.4964, grad_fn=<DivBackward0>)
# Grad tensor([1.1820, 1.5097, 1.1938, 0.8652])
# ite 709
# Average height tensor(1.4954, grad_fn=<DivBackward0>)
# Grad tensor([1.1801, 1.5072, 1.1921, 0.8642])
# ite 710
# Average height tensor(1.4968, grad_fn=<DivBackward0>)
# Grad tensor([1.1826, 1.5105, 1.1944, 0.8656])
# Iteration 710: Normalized Gradient = 2.4199764728546143, Adaptive learning rate = 0.005
# ite 711
# Average height tensor(1.5005, grad_fn=<DivBackward0>)
# Grad tensor([-1.1891, -1.5193, -1.2004, -0.8693])
# ite 712
# Average height tensor(1.5014, grad_fn=<DivBackward0>)
# Grad tensor([-1.1907, -1.5215, -1.2019, -0.8702])
# ite 713
# Average height tensor(1.4998, grad_fn=<DivBackward0>)
# Grad tensor([1.1879, 1.5177, 1.1993, 0.8686])
# ite 714
# Average height tensor(1.5008, grad_fn=<DivBackward0>)
# Grad tensor([-1.1896, -1.5200, -1.2009, -0.8696])
# ite 715
# Average height tensor(1.4992, grad_fn=<DivBackward0>)
# Grad tensor([1.1869, 1.5163, 1.1984, 0.8681])
# Iteration 715: Normalized Gradient = 2.4284932613372803, Adaptive learning rate = 0.005
# ite 716
# Average height tensor(1.5003, grad_fn=<DivBackward0>)
# Grad tensor([-1.1887, -1.5187, -1.2000, -0.8691])
# ite 717
# Average height tensor(1.4988, grad_fn=<DivBackward0>)
# Grad tensor([1.1861, 1.5152, 1.1976, 0.8676])
# ite 718
# Average height tensor(1.4998, grad_fn=<DivBackward0>)
# Grad tensor([1.1879, 1.5177, 1.1994, 0.8687])
# ite 719
# Average height tensor(1.5032, grad_fn=<DivBackward0>)
# Grad tensor([-1.1939, -1.5258, -1.2048, -0.8721])
# ite 720
# Average height tensor(1.5038, grad_fn=<DivBackward0>)
# Grad tensor([-1.1950, -1.5272, -1.2058, -0.8727])
# Iteration 720: Normalized Gradient = 2.4446053504943848, Adaptive learning rate = 0.005
# ite 721
# Average height tensor(1.5019, grad_fn=<DivBackward0>)
# Grad tensor([-1.1917, -1.5227, -1.2028, -0.8708])
# ite 722
# Average height tensor(1.4978, grad_fn=<DivBackward0>)
# Grad tensor([1.1844, 1.5130, 1.1961, 0.8667])
# ite 723
# Average height tensor(1.4966, grad_fn=<DivBackward0>)
# Grad tensor([1.1821, 1.5099, 1.1941, 0.8654])
# ite 724
# Average height tensor(1.4978, grad_fn=<DivBackward0>)
# Grad tensor([1.1843, 1.5128, 1.1961, 0.8667])
# ite 725
# Average height tensor(1.5013, grad_fn=<DivBackward0>)
# Grad tensor([-1.1905, -1.5212, -1.2018, -0.8702])
# Iteration 725: Normalized Gradient = 2.43572735786438, Adaptive learning rate = 0.005
# ite 726
# Average height tensor(1.5021, grad_fn=<DivBackward0>)
# Grad tensor([-1.1918, -1.5230, -1.2030, -0.8710])
# ite 727
# Average height tensor(1.5003, grad_fn=<DivBackward0>)
# Grad tensor([-1.1887, -1.5188, -1.2002, -0.8692])
# ite 728
# Average height tensor(1.4963, grad_fn=<DivBackward0>)
# Grad tensor([1.1817, 1.5094, 1.1937, 0.8652])
# ite 729
# Average height tensor(1.4952, grad_fn=<DivBackward0>)
# Grad tensor([1.1797, 1.5066, 1.1918, 0.8640])
# ite 730
# Average height tensor(1.4965, grad_fn=<DivBackward0>)
# Grad tensor([1.1820, 1.5097, 1.1940, 0.8654])
# Iteration 730: Normalized Gradient = 2.4188337326049805, Adaptive learning rate = 0.005
# ite 731
# Average height tensor(1.5001, grad_fn=<DivBackward0>)
# Grad tensor([-1.1883, -1.5182, -1.1998, -0.8690])
# ite 732
# Average height tensor(1.5009, grad_fn=<DivBackward0>)
# Grad tensor([-1.1897, -1.5202, -1.2011, -0.8698])
# ite 733
# Average height tensor(1.4992, grad_fn=<DivBackward0>)
# Grad tensor([1.1868, 1.5162, 1.1984, 0.8681])
# ite 734
# Average height tensor(1.5001, grad_fn=<DivBackward0>)
# Grad tensor([-1.1884, -1.5183, -1.1999, -0.8690])
# ite 735
# Average height tensor(1.4985, grad_fn=<DivBackward0>)
# Grad tensor([1.1856, 1.5145, 1.1973, 0.8674])
# Iteration 735: Normalized Gradient = 2.425968885421753, Adaptive learning rate = 0.005
# ite 736
# Average height tensor(1.4995, grad_fn=<DivBackward0>)
# Grad tensor([1.1873, 1.5168, 1.1989, 0.8684])
# ite 737
# Average height tensor(1.5028, grad_fn=<DivBackward0>)
# Grad tensor([-1.1931, -1.5246, -1.2042, -0.8717])
# ite 738
# Average height tensor(1.5033, grad_fn=<DivBackward0>)
# Grad tensor([-1.1940, -1.5259, -1.2051, -0.8722])
# ite 739
# Average height tensor(1.5014, grad_fn=<DivBackward0>)
# Grad tensor([-1.1905, -1.5213, -1.2019, -0.8703])
# ite 740
# Average height tensor(1.4972, grad_fn=<DivBackward0>)
# Grad tensor([1.1832, 1.5114, 1.1952, 0.8661])
# Iteration 740: Normalized Gradient = 2.4213168621063232, Adaptive learning rate = 0.005
# ite 741
# Average height tensor(1.4959, grad_fn=<DivBackward0>)
# Grad tensor([1.1808, 1.5082, 1.1930, 0.8648])
# ite 742
# Average height tensor(1.4970, grad_fn=<DivBackward0>)
# Grad tensor([1.1829, 1.5110, 1.1949, 0.8660])
# ite 743
# Average height tensor(1.5005, grad_fn=<DivBackward0>)
# Grad tensor([-1.1890, -1.5192, -1.2005, -0.8694])
# ite 744
# Average height tensor(1.5012, grad_fn=<DivBackward0>)
# Grad tensor([-1.1902, -1.5209, -1.2017, -0.8701])
# ite 745
# Average height tensor(1.4994, grad_fn=<DivBackward0>)
# Grad tensor([1.1871, 1.5166, 1.1988, 0.8684])
# Iteration 745: Normalized Gradient = 2.429093360900879, Adaptive learning rate = 0.005
# ite 746
# Average height tensor(1.5002, grad_fn=<DivBackward0>)
# Grad tensor([-1.1885, -1.5185, -1.2001, -0.8692])
# ite 747
# Average height tensor(1.4986, grad_fn=<DivBackward0>)
# Grad tensor([1.1855, 1.5145, 1.1974, 0.8675])
# ite 748
# Average height tensor(1.4995, grad_fn=<DivBackward0>)
# Grad tensor([1.1871, 1.5166, 1.1988, 0.8684])
# ite 749
# Average height tensor(1.5027, grad_fn=<DivBackward0>)
# Grad tensor([-1.1928, -1.5243, -1.2040, -0.8716])
# ite 750
# Average height tensor(1.5031, grad_fn=<DivBackward0>)
# Grad tensor([-1.1936, -1.5254, -1.2048, -0.8721])
# Iteration 750: Normalized Gradient = 2.4420580863952637, Adaptive learning rate = 0.005
# ite 751
# Average height tensor(1.5011, grad_fn=<DivBackward0>)
# Grad tensor([-1.1901, -1.5206, -1.2015, -0.8701])
# ite 752
# Average height tensor(1.4969, grad_fn=<DivBackward0>)
# Grad tensor([1.1826, 1.5106, 1.1947, 0.8659])
# ite 753
# Average height tensor(1.4955, grad_fn=<DivBackward0>)
# Grad tensor([1.1802, 1.5074, 1.1925, 0.8645])
# ite 754
# Average height tensor(1.4967, grad_fn=<DivBackward0>)
# Grad tensor([1.1822, 1.5100, 1.1943, 0.8656])
# ite 755
# Average height tensor(1.5001, grad_fn=<DivBackward0>)
# Grad tensor([-1.1882, -1.5181, -1.1999, -0.8690])
# Iteration 755: Normalized Gradient = 2.4313671588897705, Adaptive learning rate = 0.005
# ite 756
# Average height tensor(1.5008, grad_fn=<DivBackward0>)
# Grad tensor([-1.1894, -1.5197, -1.2010, -0.8697])
# ite 757
# Average height tensor(1.4990, grad_fn=<DivBackward0>)
# Grad tensor([1.1862, 1.5154, 1.1980, 0.8679])
# ite 758
# Average height tensor(1.4997, grad_fn=<DivBackward0>)
# Grad tensor([1.1876, 1.5173, 1.1993, 0.8687])
# ite 759
# Average height tensor(1.5029, grad_fn=<DivBackward0>)
# Grad tensor([-1.1931, -1.5247, -1.2044, -0.8718])
# ite 760
# Average height tensor(1.5032, grad_fn=<DivBackward0>)
# Grad tensor([-1.1937, -1.5256, -1.2050, -0.8722])
# Iteration 760: Normalized Gradient = 2.4423985481262207, Adaptive learning rate = 0.005
# ite 761
# Average height tensor(1.5012, grad_fn=<DivBackward0>)
# Grad tensor([-1.1901, -1.5206, -1.2016, -0.8701])
# ite 762
# Average height tensor(1.4969, grad_fn=<DivBackward0>)
# Grad tensor([1.1825, 1.5105, 1.1947, 0.8658])
# ite 763
# Average height tensor(1.4954, grad_fn=<DivBackward0>)
# Grad tensor([1.1800, 1.5070, 1.1924, 0.8644])
# ite 764
# Average height tensor(1.4965, grad_fn=<DivBackward0>)
# Grad tensor([1.1818, 1.5096, 1.1941, 0.8655])
# ite 765
# Average height tensor(1.4999, grad_fn=<DivBackward0>)
# Grad tensor([1.1878, 1.5176, 1.1995, 0.8689])
# Iteration 765: Normalized Gradient = 2.4305548667907715, Adaptive learning rate = 0.005
# ite 766
# Average height tensor(1.5053, grad_fn=<DivBackward0>)
# Grad tensor([-1.1974, -1.5306, -1.2084, -0.8743])
# ite 767
# Average height tensor(1.5078, grad_fn=<DivBackward0>)
# Grad tensor([-1.2019, -1.5366, -1.2125, -0.8769])
# ite 768
# Average height tensor(1.5076, grad_fn=<DivBackward0>)
# Grad tensor([-1.2015, -1.5360, -1.2121, -0.8767])
# ite 769
# Average height tensor(1.5050, grad_fn=<DivBackward0>)
# Grad tensor([-1.1968, -1.5297, -1.2078, -0.8740])
# ite 770
# Average height tensor(1.5002, grad_fn=<DivBackward0>)
# Grad tensor([-1.1882, -1.5182, -1.2000, -0.8692])
# Iteration 770: Normalized Gradient = 2.4315476417541504, Adaptive learning rate = 0.005
# ite 771
# Average height tensor(1.4935, grad_fn=<DivBackward0>)
# Grad tensor([1.1765, 1.5024, 1.1892, 0.8625])
# ite 772
# Average height tensor(1.4899, grad_fn=<DivBackward0>)
# Grad tensor([1.1701, 1.4938, 1.1834, 0.8588])
# ite 773
# Average height tensor(1.4889, grad_fn=<DivBackward0>)
# Grad tensor([1.1685, 1.4917, 1.1820, 0.8579])
# ite 774
# Average height tensor(1.4905, grad_fn=<DivBackward0>)
# Grad tensor([1.1712, 1.4953, 1.1844, 0.8595])
# ite 775
# Average height tensor(1.4942, grad_fn=<DivBackward0>)
# Grad tensor([1.1777, 1.5040, 1.1904, 0.8632])
# Iteration 775: Normalized Gradient = 2.4106523990631104, Adaptive learning rate = 0.005
# ite 776
# Average height tensor(1.5000, grad_fn=<DivBackward0>)
# Grad tensor([1.1878, 1.5176, 1.1997, 0.8690])
# ite 777
# Average height tensor(1.5076, grad_fn=<DivBackward0>)
# Grad tensor([-1.2013, -1.5359, -1.2121, -0.8767])
# ite 778
# Average height tensor(1.5121, grad_fn=<DivBackward0>)
# Grad tensor([-1.2093, -1.5466, -1.2194, -0.8812])
# ite 779
# Average height tensor(1.5136, grad_fn=<DivBackward0>)
# Grad tensor([-1.2120, -1.5503, -1.2220, -0.8828])
# ite 780
# Average height tensor(1.5125, grad_fn=<DivBackward0>)
# Grad tensor([-1.2100, -1.5476, -1.2202, -0.8817])
# Iteration 780: Normalized Gradient = 2.474994659423828, Adaptive learning rate = 0.005
# ite 781
# Average height tensor(1.5090, grad_fn=<DivBackward0>)
# Grad tensor([-1.2038, -1.5393, -1.2145, -0.8782])
# ite 782
# Average height tensor(1.5035, grad_fn=<DivBackward0>)
# Grad tensor([-1.1939, -1.5259, -1.2055, -0.8726])
# ite 783
# Average height tensor(1.4961, grad_fn=<DivBackward0>)
# Grad tensor([1.1809, 1.5083, 1.1935, 0.8652])
# ite 784
# Average height tensor(1.4918, grad_fn=<DivBackward0>)
# Grad tensor([1.1734, 1.4983, 1.1867, 0.8609])
# ite 785
# Average height tensor(1.4904, grad_fn=<DivBackward0>)
# Grad tensor([1.1709, 1.4949, 1.1844, 0.8595])
# Iteration 785: Normalized Gradient = 2.3973934650421143, Adaptive learning rate = 0.005
# ite 786
# Average height tensor(1.4915, grad_fn=<DivBackward0>)
# Grad tensor([1.1727, 1.4974, 1.1861, 0.8606])
# ite 787
# Average height tensor(1.4948, grad_fn=<DivBackward0>)
# Grad tensor([1.1785, 1.5052, 1.1915, 0.8639])
# ite 788
# Average height tensor(1.5002, grad_fn=<DivBackward0>)
# Grad tensor([-1.1880, -1.5179, -1.2002, -0.8693])
# ite 789
# Average height tensor(1.5026, grad_fn=<DivBackward0>)
# Grad tensor([-1.1923, -1.5238, -1.2042, -0.8718])
# ite 790
# Average height tensor(1.5024, grad_fn=<DivBackward0>)
# Grad tensor([-1.1919, -1.5232, -1.2038, -0.8716])
# Iteration 790: Normalized Gradient = 2.439180612564087, Adaptive learning rate = 0.005
# ite 791
# Average height tensor(1.4998, grad_fn=<DivBackward0>)
# Grad tensor([1.1873, 1.5170, 1.1996, 0.8690])
# ite 792
# Average height tensor(1.4998, grad_fn=<DivBackward0>)
# Grad tensor([1.1873, 1.5171, 1.1997, 0.8690])
# ite 793
# Average height tensor(1.5023, grad_fn=<DivBackward0>)
# Grad tensor([-1.1917, -1.5230, -1.2037, -0.8715])
# ite 794
# Average height tensor(1.5021, grad_fn=<DivBackward0>)
# Grad tensor([-1.1913, -1.5225, -1.2034, -0.8713])
# ite 795
# Average height tensor(1.4995, grad_fn=<DivBackward0>)
# Grad tensor([1.1867, 1.5163, 1.1992, 0.8687])
# Iteration 795: Normalized Gradient = 2.429020404815674, Adaptive learning rate = 0.005
# ite 796
# Average height tensor(1.4996, grad_fn=<DivBackward0>)
# Grad tensor([1.1868, 1.5165, 1.1993, 0.8688])
# ite 797
# Average height tensor(1.5021, grad_fn=<DivBackward0>)
# Grad tensor([-1.1912, -1.5223, -1.2033, -0.8713])
# ite 798
# Average height tensor(1.5019, grad_fn=<DivBackward0>)
# Grad tensor([-1.1908, -1.5219, -1.2030, -0.8711])
# ite 799
# Average height tensor(1.4993, grad_fn=<DivBackward0>)
# Grad tensor([1.1863, 1.5157, 1.1988, 0.8685])
# ite 800
# Average height tensor(1.4994, grad_fn=<DivBackward0>)
# Grad tensor([1.1864, 1.5159, 1.1989, 0.8686])
# Iteration 800: Normalized Gradient = 2.4284238815307617, Adaptive learning rate = 0.005
# ite 801
# Average height tensor(1.5018, grad_fn=<DivBackward0>)
# Grad tensor([-1.1908, -1.5218, -1.2030, -0.8711])
# ite 802
# Average height tensor(1.5016, grad_fn=<DivBackward0>)
# Grad tensor([-1.1904, -1.5213, -1.2027, -0.8709])
# ite 803
# Average height tensor(1.4991, grad_fn=<DivBackward0>)
# Grad tensor([1.1859, 1.5152, 1.1985, 0.8683])
# ite 804
# Average height tensor(1.4991, grad_fn=<DivBackward0>)
# Grad tensor([1.1860, 1.5153, 1.1986, 0.8684])
# ite 805
# Average height tensor(1.5016, grad_fn=<DivBackward0>)
# Grad tensor([-1.1904, -1.5212, -1.2026, -0.8709])
# Iteration 805: Normalized Gradient = 2.436349391937256, Adaptive learning rate = 0.005
# ite 806
# Average height tensor(1.5014, grad_fn=<DivBackward0>)
# Grad tensor([-1.1900, -1.5208, -1.2023, -0.8707])
# ite 807
# Average height tensor(1.4989, grad_fn=<DivBackward0>)
# Grad tensor([1.1855, 1.5147, 1.1982, 0.8681])
# ite 808
# Average height tensor(1.4989, grad_fn=<DivBackward0>)
# Grad tensor([1.1856, 1.5149, 1.1983, 0.8682])
# ite 809
# Average height tensor(1.5014, grad_fn=<DivBackward0>)
# Grad tensor([-1.1900, -1.5207, -1.2023, -0.8707])
# ite 810
# Average height tensor(1.5012, grad_fn=<DivBackward0>)
# Grad tensor([-1.1897, -1.5203, -1.2020, -0.8705])
# Iteration 810: Normalized Gradient = 2.435007333755493, Adaptive learning rate = 0.005
# ite 811
# Average height tensor(1.4987, grad_fn=<DivBackward0>)
# Grad tensor([1.1851, 1.5142, 1.1979, 0.8679])
# ite 812
# Average height tensor(1.4988, grad_fn=<DivBackward0>)
# Grad tensor([1.1853, 1.5144, 1.1980, 0.8680])
# ite 813
# Average height tensor(1.5012, grad_fn=<DivBackward0>)
# Grad tensor([-1.1896, -1.5203, -1.2020, -0.8705])
# ite 814
# Average height tensor(1.5011, grad_fn=<DivBackward0>)
# Grad tensor([-1.1893, -1.5198, -1.2017, -0.8703])
# ite 815
# Average height tensor(1.4985, grad_fn=<DivBackward0>)
# Grad tensor([1.1848, 1.5137, 1.1976, 0.8677])
# Iteration 815: Normalized Gradient = 2.4253323078155518, Adaptive learning rate = 0.005
# ite 816
# Average height tensor(1.4986, grad_fn=<DivBackward0>)
# Grad tensor([1.1849, 1.5139, 1.1977, 0.8678])
# ite 817
# Average height tensor(1.5010, grad_fn=<DivBackward0>)
# Grad tensor([-1.1893, -1.5198, -1.2017, -0.8703])
# ite 818
# Average height tensor(1.5009, grad_fn=<DivBackward0>)
# Grad tensor([-1.1890, -1.5194, -1.2014, -0.8701])
# ite 819
# Average height tensor(1.4983, grad_fn=<DivBackward0>)
# Grad tensor([1.1845, 1.5133, 1.1973, 0.8676])
# ite 820
# Average height tensor(1.4984, grad_fn=<DivBackward0>)
# Grad tensor([1.1846, 1.5135, 1.1974, 0.8676])
# Iteration 820: Normalized Gradient = 2.4249985218048096, Adaptive learning rate = 0.005
# ite 821
# Average height tensor(1.5009, grad_fn=<DivBackward0>)
# Grad tensor([-1.1890, -1.5194, -1.2015, -0.8701])
# ite 822
# Average height tensor(1.5007, grad_fn=<DivBackward0>)
# Grad tensor([-1.1887, -1.5190, -1.2012, -0.8700])
# ite 823
# Average height tensor(1.4981, grad_fn=<DivBackward0>)
# Grad tensor([1.1841, 1.5129, 1.1970, 0.8674])
# ite 824
# Average height tensor(1.4982, grad_fn=<DivBackward0>)
# Grad tensor([1.1843, 1.5131, 1.1972, 0.8675])
# ite 825
# Average height tensor(1.5007, grad_fn=<DivBackward0>)
# Grad tensor([-1.1886, -1.5189, -1.2012, -0.8700])
# Iteration 825: Normalized Gradient = 2.4330475330352783, Adaptive learning rate = 0.005
# ite 826
# Average height tensor(1.5005, grad_fn=<DivBackward0>)
# Grad tensor([-1.1883, -1.5185, -1.2009, -0.8698])
# ite 827
# Average height tensor(1.4980, grad_fn=<DivBackward0>)
# Grad tensor([1.1838, 1.5124, 1.1967, 0.8672])
# ite 828
# Average height tensor(1.4980, grad_fn=<DivBackward0>)
# Grad tensor([1.1840, 1.5126, 1.1969, 0.8673])
# ite 829
# Average height tensor(1.5005, grad_fn=<DivBackward0>)
# Grad tensor([-1.1883, -1.5185, -1.2009, -0.8698])
# ite 830
# Average height tensor(1.5003, grad_fn=<DivBackward0>)
# Grad tensor([-1.1880, -1.5181, -1.2006, -0.8696])
# Iteration 830: Normalized Gradient = 2.4318020343780518, Adaptive learning rate = 0.005
# ite 831

# %%
### Displacement Controll -- with 4 qs
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import plotly.graph_objects as go

# q.grad.zero_()


# In[663]:


######################## explanation
## "The example model is based on a 5-nodes grid shell strcuture
##  which has a crossing projection in the x-y plane"
##  The FE part would be based on the Euler-bernoulli beam theory


# In[664]:


## Initial Geom
# Initial Coords:
node_coords = torch.tensor(
    [[0.0, 3.0, 0.0], [0.0, 6.0, 0.0], [3.0, 0.0, 0.0], [3.0, 3.0, 0.0], [3.0, 6.0, 0.0], [3.0, 9.0, 0.0],
     [6.0, 0.0, 0.0], [6.0, 3.0, 0.0], [6.0, 6.0, 0.0] ,[6.0, 9.0, 0.0], [9.0, 3.0 ,0.0], [9.0, 6.0, 0.0]],
    dtype=torch.float32, requires_grad=True, )
connectivity = [[1, 4], [2, 5], [3, 4], [5, 4], [6, 5], [4, 8], [7, 8], [9, 8],[11, 8],[10, 9],[12, 9],[5, 9]]
n_dof_per_node = 6  # Degrees of freedom per node
total_dof = n_dof_per_node * len(node_coords)
Fixed_nodes = [1, 2, 3, 6, 7, 10, 11, 12]
Free_nodes = []
n_elements = len(connectivity)
n_nodes = len(node_coords)
for i in range(1, n_nodes + 1):
    if i not in Fixed_nodes:
        Free_nodes.append(i)
idx_CF = [node - 1 for node in Fixed_nodes]
idx_CN = [i for i in range(n_nodes) if i not in idx_CF]


## Force condition
####### Force condition -> need for modification
## +0 to x direction ; +1 to y direction ; +2 to Z direction
## +3 Bending around the z axis ; +4 bending around y axis ; +5 Twisting
# implement upwards loading of 50 kN at every free nodes
F = torch.zeros(total_dof, dtype=torch.float32)
f_n = Free_nodes
f_type = [2, 2, 2, 2]  # The force type
F_value = torch.tensor([50.0, 50.0, 50.0, 50.0]) * 1000  # The force value/direction
r = 1 / torch.max(F_value)
# print(r)
F_sign = torch.sign(F_value)
for idx, i in enumerate(f_n):
    F[6 * (i - 1) + f_type[idx]] = F_value[idx]  # unit: KN / KN*m

px = torch.zeros(len(f_n), 1, dtype=torch.float32)
py = torch.zeros(len(f_n), 1, dtype=torch.float32)
pz = torch.zeros(len(f_n), 1, dtype=torch.float32)

for i in range(len(f_n)):
    if f_type[idx] == 0:
        px[i] = F_value[i]
    elif f_type[idx] == 1:
        py[i] = F_value[i]
    elif f_type[idx] == 2:
        pz[i] = F_value[i]


## Obtaining Matrix D
# Assembly the nodal-branch matrix:
C = torch.zeros(n_elements, n_nodes, dtype=torch.float32)
for n, (i, j) in enumerate(connectivity):
    C[n, i - 1] = 1
    C[n, j - 1] = -1
CF = C[:, idx_CF]
CN = C[:, idx_CN]


# Assembly D
def FDM (Q,CN=CN, CF=CF, px=px, py=py, pz=pz,Fixed_nodes=Fixed_nodes, Free_nodes=Free_nodes,node_coords=node_coords) :
    Dn = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CN))
    DF = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CF))
    ## Coordinates solution
    # separate the coordinates:
    fixed_idces = [node - 1 for node in Fixed_nodes]
    xF = node_coords[fixed_idces, 0].unsqueeze(1)
    yF = node_coords[fixed_idces, 1].unsqueeze(1)
    zF = node_coords[fixed_idces, 2].unsqueeze(1)
    xN = torch.matmul(torch.inverse(Dn), (px - torch.matmul(DF, xF)))
    yN = torch.matmul(torch.inverse(Dn), (py - torch.matmul(DF, yF)))
    zN = torch.matmul(torch.inverse(Dn), (pz - torch.matmul(DF, zF)))
    ## Coordinates renewal: 
    new_node_coords = node_coords.clone()
    for idx, node in enumerate(Free_nodes):
        node_idx = node - 1
        new_node_coords[node_idx, 0] = xN[idx]
        new_node_coords[node_idx, 1] = yN[idx]
        new_node_coords[node_idx, 2] = zN[idx]

    return new_node_coords

# In[670]:


## Check point: FDM completed
# if q.grad is not None:
#     q.grad.zero_()
# loss = torch.sum(new_node_coords[:, 2])
# loss.backward()
# print("Gradient of q:")
# print(q.grad)


############ Now comes to FE part:
#### Default values (in meters, Pascals, etc.)
## For rectangular sections
# D_width = 0.1
# D_height = 0.2
# D_young_modulus = 210e9  # Young's modulus in Pascals
# D_shear_modulus = 81e9  # Shear modulus in Pascals
# D_poisson_ratio = 0.3
# cross_section_angle_a = 0  # Cross-section angle at node 1 (anti-clockwise)
# cross_section_angle_b = 0  # Cross-section angle at node 2 (anti-clockwise)
# a_small_number = 1e-10

D_radius = 0.05
D_young_modulus = 210e9  # Young's modulus in Pascals
D_shear_modulus = 81e9  # Shear modulus in Pascals
D_poisson_ratio = 0.3
cross_section_angle_a = 0  # Cross-section angle at node 1 (anti-clockwise)
cross_section_angle_b = 0  # Cross-section angle at node 2 (anti-clockwise)
a_small_number = 1e-10


# In[673]:


def rotation(v, k, theta):
    """Rotation of vector v around axis k by angle theta."""
    k = k / torch.norm(k)  # Normalize k
    cross_product = torch.cross(k, v)
    dot_product = torch.dot(k, v)

    # Ensure theta is a tensor
    theta = torch.tensor(theta, dtype=torch.float32) if not isinstance(theta, torch.Tensor) else theta

    v_rotated = v * torch.cos(theta) + cross_product * torch.sin(theta) + k * dot_product * (1 - torch.cos(theta))
    return v_rotated


# In[674]:


###### Element Creating (euler beam)
# For rectangular sections
# class Beam:
#     def __init__(self, node_coordinates, width=D_width, height=D_height, young_modulus=D_young_modulus,
#                  shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
#                  Beta_b=cross_section_angle_b):
#         self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

#         # Material and geometry
#         self.width = width
#         self.height = height
#         self.young_modulus = young_modulus
#         self.shear_modulus = shear_modulus
#         self.poisson_ratio = poisson_ratio

#         # Cross-sectional properties
#         self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
#         self.Iy = (self.width * self.height ** 3) / 12
#         self.Iz = (self.width ** 3 * self.height) / 12
#         self.A = self.width * self.height
#         self.J = (self.width * self.height ** 3) / 3

#         # Stiffness components
#         self.S_u = self.young_modulus * self.A / self.length
#         self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
#         self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
#         self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
#         self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
#         self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
#         self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
#         self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
#         self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
#         self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
#         self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
#         self.S_Tr = self.shear_modulus * self.J / self.length

#         # Section rotations at the two ends
#         self.Beta_a = Beta_a
#         self.Beta_b = Beta_b


# In[675]:


# For circular sections
class Beam:
    def __init__(self, node_coordinates, R=D_radius, young_modulus=D_young_modulus,
                 shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                 Beta_b=cross_section_angle_b):
        self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

        # Material and geometry
        self.radius = R
        self.young_modulus = young_modulus
        self.shear_modulus = shear_modulus
        self.poisson_ratio = poisson_ratio

        # Cross-sectional properties
        self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
        self.Iy = (torch.pi * self.radius ** 4) / 4 
        self.Iz = self.Iy
        self.A = torch.pi * self.radius ** 2
        self.J = (torch.pi * self.radius ** 4) / 2

        # Stiffness components
        self.S_u = self.young_modulus * self.A / self.length
        self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
        self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
        self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
        self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
        self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
        self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
        self.S_Tr = self.shear_modulus * self.J / self.length

        # Section rotations at the two ends
        self.Beta_a = Beta_a
        self.Beta_b = Beta_b

    def get_element_stiffness_matrix(self):
        """Element stiffness matrix."""
        K_element = torch.tensor([
            [self.S_u, 0, 0, 0, 0, 0, -self.S_u, 0, 0, 0, 0, 0],
            [0, self.S_v1a, 0, 0, 0, self.S_theta1a, 0, -self.S_v1a, 0, 0, 0, self.S_theta1a],
            [0, 0, self.S_v2a, 0, -self.S_theta2a, 0, 0, 0, -self.S_v2a, 0, -self.S_theta2a, 0],
            [0, 0, 0, self.S_Tr, 0, 0, 0, 0, 0, -self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2b, 0, 0, 0, self.S_v2b, 0, self.S_theta2c, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1b, 0, -self.S_v1b, 0, 0, 0, self.S_theta1c],
            [-self.S_u, 0, 0, 0, 0, 0, self.S_u, 0, 0, 0, 0, 0],
            [0, -self.S_v1a, 0, 0, 0, -self.S_theta1a, 0, self.S_v1a, 0, 0, 0, -self.S_theta1a],
            [0, 0, -self.S_v2a, 0, self.S_theta2a, 0, 0, 0, self.S_v2a, 0, self.S_theta2a, 0],
            [0, 0, 0, -self.S_Tr, 0, 0, 0, 0, 0, self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2c, 0, 0, 0, self.S_v2b, 0, self.S_theta2b, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1c, 0, -self.S_v1b, 0, 0, 0, self.S_theta1b],
        ], dtype=torch.float32)

        return K_element

    def System_Transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        # print(vector_x,vector_y,vector_z)
        # Calculate alpha and ceta using PyTorch
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)
        # print(alpha)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)

        # Z_axis_b = rotation(V_projection, X_axis, self.Beta_b)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        # Y_axis_b = rotation(Z_axis_b, X_axis, torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        # Z_axis_b = Z_axis_b / torch.norm(Z_axis_b)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)
        # Y_axis_b = Y_axis_b / torch.norm(Y_axis_b)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)
        matrix_T = torch.zeros((12, 12), dtype=torch.float32)
        for i in range(0, 12, 3):
            matrix_T[i:i + 3, i:i + 3] = lambda_matrix
        return matrix_T

    def nodal_transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        # Calculate alpha and ceta using PyTorch
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)

        # Z_axis_b = rotation(V_projection, X_axis, self.Beta_b)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        # Y_axis_b = rotation(Z_axis_b, X_axis, torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        # Z_axis_b = Z_axis_b / torch.norm(Z_axis_b)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)
        # Y_axis_b = Y_axis_b / torch.norm(Y_axis_b)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)

        return lambda_matrix


# In[676]:


def assemble_stiffness_matrix(beams, n_nodes, n_dof_per_node, connectivity):
    """Global stiffness matrix assembly."""
    total_dof = n_nodes * n_dof_per_node  # Total degrees of freedom
    K_global = torch.zeros((total_dof, total_dof), dtype=torch.float32)
    for idx, (i, j) in enumerate(connectivity):
        Matrix_T = beams[idx].System_Transform()  # Get transformation matrix

        K_element = torch.matmul(torch.transpose(Matrix_T, 0, 1),
                                 torch.matmul(beams[idx].get_element_stiffness_matrix(), Matrix_T))

        start_idx = (i - 1) * n_dof_per_node
        end_idx = (j - 1) * n_dof_per_node
        K_global[start_idx:start_idx + 6, start_idx:start_idx + 6] = K_global[start_idx:start_idx + 6,
                                                                     start_idx:start_idx + 6] + K_element[0:6, 0:6]
        K_global[end_idx:end_idx + 6, end_idx:end_idx + 6] = K_global[end_idx:end_idx + 6,
                                                             end_idx:end_idx + 6] + K_element[6:12, 6:12]
        K_global[start_idx:start_idx + 6, end_idx:end_idx + 6] = K_global[start_idx:start_idx + 6,
                                                                 end_idx:end_idx + 6] + K_element[0:6, 6:12]
        K_global[end_idx:end_idx + 6, start_idx:start_idx + 6] = K_global[end_idx:end_idx + 6,
                                                                 start_idx:start_idx + 6] + K_element[6:12, 0:6]

    return K_global


# In[677]:


def Strain_E(node_coords, connectivity, fixed_dof, F):
    # node_coords[:, 2] = 0.0
    # Element Assembly
    beams = []
    for connection in connectivity:
        node_1_coords = node_coords[connection[0] - 1]
        node_2_coords = node_coords[connection[1] - 1]
        beam = Beam(node_coordinates=torch.stack([node_1_coords, node_2_coords]),
                    R=D_radius, young_modulus=D_young_modulus,
                    shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                    Beta_b=cross_section_angle_b)
        beams.append(beam)
    # Stiffness renewal
    K_global = assemble_stiffness_matrix(beams, n_nodes=len(node_coords), n_dof_per_node=6, connectivity=connectivity)
    K_global[fixed_dof, :] = K_global[fixed_dof, :] - K_global[fixed_dof, :]
    K_global[:, fixed_dof] = K_global[:, fixed_dof] - K_global[:, fixed_dof]
    K_global[fixed_dof, fixed_dof] = 1e5
    rank_K = torch.linalg.matrix_rank(K_global)

    if rank_K < K_global.shape[0]:
        print("Warning: The stiffness matrix is not of full rank")
    else:
        displacements = torch.linalg.solve(K_global, F)

    # Compute strain energy
    strain_energy_list = []
    Local_d = torch.zeros(len(connectivity), 12, dtype=torch.float32)
    for n, (i, j) in enumerate(connectivity):
        matrix_T = beams[n].System_Transform()
        Tep_displacements = torch.cat(
            [displacements[6 * (i - 1):6 * (i - 1) + 6], displacements[6 * (j - 1):6 * (j - 1) + 6]], dim=0)
        Local_d_n = torch.matmul(Tep_displacements, matrix_T.T)
        Local_d[n, :] = Local_d_n.clone()
        K_g = torch.matmul(torch.transpose(matrix_T, 0, 1),
                           torch.matmul(beams[n].get_element_stiffness_matrix(), matrix_T))

        strain_energy_list.append(torch.matmul(Local_d_n, torch.matmul(K_g, Local_d_n.reshape(-1, 1))))

    Strain_energy = torch.stack(strain_energy_list)

    return Strain_energy, Local_d, displacements, beams

def Average_height(Free_nodes, new_node_coords):
    n_free_nodes = len(Free_nodes)
    Free_nodes = torch.tensor(Free_nodes)
    AH = torch.sum(new_node_coords[(Free_nodes - 1), 2])/ n_free_nodes
    return AH

# In[678]:


# Element creating
#################  input below:
############################################################################################################## input
# initial coordinates

####### BCs
fixed_dof = []
for node in Fixed_nodes:
    fixed_dof.extend([(node - 1) * 6 + i for i in range(6)])
# print(fixed_dof)
####### Gradient descent
step = 0.005
epochs = 1000
####### Plotting
steps = 20  # steps for tracing deformation shape
###################################################################################################################################################
###################################################################################################################################################


# In[679]:

# Optimized Variables
## initial variables
Idx_q1 = [3, 4, 5]
Idx_q2 = [1, 6, 11]
Idx_q3 = [8, 9, 10]
Idx_q4 = [2, 7, 12]
Idx_q1 = [i - 1 for i in Idx_q1] 
Idx_q2 = [i - 1 for i in Idx_q2]
Idx_q3 = [i - 1 for i in Idx_q3] 
Idx_q4 = [i - 1 for i in Idx_q4] 
q = torch.rand(4, requires_grad=True)
## Optimization
torch.autograd.set_detect_anomaly(True)
# Optimizer setting
optimizer = optim.Adam([q], lr=step)
# Initilizing
# New_Coordinates = torch.zeros(n_nodes * 3, dtype=torch.float32)
# Loss_his = []
Disp_his = []
patience = 5
count = 0

# Loop start
for iteration in range(epochs + 1):
    print('ite',iteration)
    # Forwards
    q_vec = torch.zeros(n_elements, requires_grad=True).clone()
    q_vec[Idx_q1] = q[0] 
    q_vec[Idx_q2] = q[1]
    q_vec[Idx_q3] = q[2] 
    q_vec[Idx_q4] = q[3] 
    Q = torch.diag(q_vec) * 1 / r  # scaling
    new_node_coords = FDM(Q)
    if iteration == 0:
        print(new_node_coords)
    N_coords = new_node_coords.clone()
    Strain_energy, _, displacements, _ = Strain_E(N_coords, connectivity, fixed_dof, F)
    idx = 6 * torch.arange(n_nodes) + 2
    Ave_Disp = abs(torch.sum(displacements[idx] / len(Free_nodes)))
    Disp_his.append(Ave_Disp.item())
    if iteration > 0:  
        previous_Ave_Disp = Disp_his[iteration - 1]  
        change = abs(Ave_Disp - previous_Ave_Disp) / previous_Ave_Disp  
        if change < 1/1000:
            count += 1
        else:
            count = 0 
        if count >= patience:
            print(f"Early stopping at iteration {iteration}: Ave_Disp change < 1% for {patience} consecutive iterations.")
            break 
    N_coords = N_coords.reshape(-1)
    New_Coordinates = torch.zeros(n_nodes * 3, dtype=torch.float32)
    for n in range(n_nodes):
        New_Coordinates[3*n : 3*n+3] = N_coords[3*n : 3*n+3] + displacements[6*n : 6*n+3]
    New_Coordinates = New_Coordinates.view(n_nodes, 3).clone()
#     AVE = Average_height(Free_nodes, New_Coordinates)
#     print("Average height",AVE)
#     # loss
#     Loss = torch.norm(AVE - Obj_coords)
#     Loss_his.append(Loss.item())
    # Backwards
    optimizer.zero_grad()
    # print(q.grad)
    Ave_Disp.backward(retain_graph=True)

    # Grad
    gradients = q.grad
    print('Grad',gradients)
    frob_norm = torch.norm(gradients)
    optimizer.step()
    
    # print iteration
    if iteration % 5 == 0:
        print(f"Iteration {iteration}: Normalized Gradient = {frob_norm}, Adaptive learning rate = {step}")
print("Optimization completed.")
print(q)
# print("coordinates:",node_coords)

#############################################################################################################
## Visualization
# print(Coordinates)
# displacements = Strain_E(node_coords, connectivity, fixed_dof, F)[2]
# print("displacements:", displacements)
print("Deformed:", New_Coordinates)

x_orig = node_coords[:, 0].detach().numpy()
y_orig = node_coords[:, 1].detach().numpy()
z_orig = node_coords[:, 2].detach().numpy()

x_def = New_Coordinates[:, 0].detach().numpy()
y_def = New_Coordinates[:, 1].detach().numpy()
z_def = New_Coordinates[:, 2].detach().numpy()


fig = go.Figure()


for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_orig[i-1], x_orig[j-1]],
        y=[y_orig[i-1], y_orig[j-1]],
        z=[z_orig[i-1], z_orig[j-1]],
        mode='lines',
        line=dict(color='blue', width=4),
        name='Original Geometry'
    ))


for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_def[i-1], x_def[j-1]],
        y=[y_def[i-1], y_def[j-1]],
        z=[z_def[i-1], z_def[j-1]],
        mode='lines',
        line=dict(color='red', width=4),
        name='Deformed Geometry'
    ))


for node in Free_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_def[node-1]],
        y=[y_def[node-1]],
        z=[z_def[node-1]],
        mode='markers+text',
        marker=dict(size=5, color='green'),
        text=[f'Node {node}'],
        textposition='top center',
        name=f'Free Node {node}'
    ))


fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        aspectmode='data'
    ),
    title='Deformation Comparison: Original vs. Deformed Geometry (FE Analysis)',
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()

########################################################################################################################

### Plot the optimization history
fig, ax1 = plt.subplots(figsize=(10, 6))

ax1 = ax1.twinx()
color = 'red'
ax1.set_ylabel('Average Displacement', color=color)
ax1.plot(range(len(Disp_his)), Disp_his, label='Average Displacement', color=color, linewidth=2, linestyle='--')
ax1.tick_params(axis='y', labelcolor=color)

lines1, labels1 = ax1.get_legend_handles_labels()
ax1.legend(lines1 , labels1, loc='upper right')

plt.title('Loss & Average Displacement vs. Iterations')

plt.tight_layout()
plt.show()
