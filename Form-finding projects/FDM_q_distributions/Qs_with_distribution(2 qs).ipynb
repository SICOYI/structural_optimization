# %%
###### With none-FE FDM coordinates match -- with 2 qs

import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import plotly.graph_objects as go

# q.grad.zero_()


# In[663]:


######################## explanation
## "The example model is based on a 5-nodes grid shell strcuture
##  which has a crossing projection in the x-y plane"
##  The FE part would be based on the Euler-bernoulli beam theory


# In[664]:


## Initial Geom
# Initial Coords:
node_coords = torch.tensor(
    [[0.0, 3.0, 0.0], [0.0, 6.0, 0.0], [3.0, 0.0, 0.0], [3.0, 3.0, 0.0], [3.0, 6.0, 0.0], [3.0, 9.0, 0.0],
     [6.0, 0.0, 0.0], [6.0, 3.0, 0.0], [6.0, 6.0, 0.0] ,[6.0, 9.0, 0.0], [9.0, 3.0 ,0.0], [9.0, 6.0, 0.0]],
    dtype=torch.float32, requires_grad=True, )
connectivity = [[1, 4], [2, 5], [3, 4], [5, 4], [6, 5], [4, 8],[5, 9], [7, 8], [9, 8],[10, 9],[12, 9],[11, 8]]
n_dof_per_node = 6  # Degrees of freedom per node
total_dof = n_dof_per_node * len(node_coords)
Fixed_nodes = [1, 2, 3, 6, 7, 10, 11, 12]
Free_nodes = []
n_elements = len(connectivity)
n_nodes = len(node_coords)
for i in range(1, n_nodes + 1):
    if i not in Fixed_nodes:
        Free_nodes.append(i)
idx_CF = [node - 1 for node in Fixed_nodes]
idx_CN = [i for i in range(n_nodes) if i not in idx_CF]

# In[665]:


## Force condition
####### Force condition -> need for modification
## +0 to x direction ; +1 to y direction ; +2 to Z direction
## +3 Bending around the z axis ; +4 bending around y axis ; +5 Twisting
# implement upwards loading of 50 kN at every free nodes
F = torch.zeros(total_dof, dtype=torch.float32)
f_n = Free_nodes
f_type = [2, 2, 2, 2]  # The force type
F_value = torch.tensor([50.0, 50.0, 50.0, 50.0]) * 1000  # The force value/direction
r = 1 / torch.max(F_value)
# print(r)
F_sign = torch.sign(F_value)
for idx, i in enumerate(f_n):
    F[6 * (i - 1) + f_type[idx]] = F_value[idx]  # unit: KN / KN*m

px = torch.zeros(len(f_n), 1, dtype=torch.float32)
py = torch.zeros(len(f_n), 1, dtype=torch.float32)
pz = torch.zeros(len(f_n), 1, dtype=torch.float32)

for i in range(len(f_n)):
    if f_type[idx] == 0:
        px[i] = F_value[i]
    elif f_type[idx] == 1:
        py[i] = F_value[i]
    elif f_type[idx] == 2:
        pz[i] = F_value[i]


## Obtaining Matrix D
# Assembly the nodal-branch matrix:
C = torch.zeros(n_elements, n_nodes, dtype=torch.float32)
for n, (i, j) in enumerate(connectivity):
    C[n, i - 1] = 1
    C[n, j - 1] = -1
CF = C[:, idx_CF]
CN = C[:, idx_CN]


# Assembly D
def FDM (Q,CN=CN, CF=CF, px=px, py=py, pz=pz,Fixed_nodes=Fixed_nodes, Free_nodes=Free_nodes,node_coords=node_coords) :
    Dn = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CN))
    DF = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CF))
    ## Coordinates solution
    # separate the coordinates:
    fixed_idces = [node - 1 for node in Fixed_nodes]
    xF = node_coords[fixed_idces, 0].unsqueeze(1)
    yF = node_coords[fixed_idces, 1].unsqueeze(1)
    zF = node_coords[fixed_idces, 2].unsqueeze(1)
    xN = torch.matmul(torch.inverse(Dn), (px - torch.matmul(DF, xF)))
    yN = torch.matmul(torch.inverse(Dn), (py - torch.matmul(DF, yF)))
    zN = torch.matmul(torch.inverse(Dn), (pz - torch.matmul(DF, zF)))
    ## Coordinates renewal: 
    new_node_coords = node_coords.clone()
    for idx, node in enumerate(Free_nodes):
        node_idx = node - 1
        new_node_coords[node_idx, 0] = xN[idx]
        new_node_coords[node_idx, 1] = yN[idx]
        new_node_coords[node_idx, 2] = zN[idx]

    return new_node_coords

# In[670]:

## Check point: FDM completed
# if q.grad is not None:
#     q.grad.zero_()
# loss = torch.sum(new_node_coords[:, 2])
# loss.backward()
# print("Gradient of q:")
# print(q.grad)



# Element creating
#################  input below:
############################################################################################################## input
# initial coordinates

####### BCs
fixed_dof = []
for node in Fixed_nodes:
    fixed_dof.extend([(node - 1) * 6 + i for i in range(6)])
# print(fixed_dof)
####### Gradient descent
step = 0.001
epochs = 500

####### Plotting
steps = 20  # steps for tracing deformation shape
###################################################################################################################################################
###################################################################################################################################################


### Defining the OBJ:
Obj_coords = torch.tensor([1.5, 1.5, 1.5, 1.5])
def Loss(Free_nodes, new_node_coords, Obj_coords):
    n_free_nodes = len(Free_nodes)
    Free_nodes = torch.tensor(Free_nodes)
    y_pred = new_node_coords[(Free_nodes - 1), 2]  
    y_true = Obj_coords 
    error = torch.abs(y_true - y_pred)
    loss = torch.mean(error)
    return loss

# In[679]:

# Optimized Variables
## initial variables
Idx_q1 = [3, 4, 5, 8, 9, 10]
Idx_q2 = [1, 6, 11, 2, 7, 12]
Idx_q1 = [i - 1 for i in Idx_q1] 
Idx_q2 = [i - 1 for i in Idx_q2] 
q = torch.rand(2, requires_grad=True)
## Optimization
torch.autograd.set_detect_anomaly(True)
# Optimizer setting
optimizer = optim.Adam([q], lr=step)
# Loop start
Loss_his = []
for iteration in range(epochs + 1):
    print(iteration)
    # Forwards
    q_vec = torch.zeros(n_elements, requires_grad=True).clone()
    q_vec[Idx_q1] = q[0] 
    q_vec[Idx_q2] = q[1]
    Q = torch.diag(q_vec) * 1 / r  # scaling
    new_node_coords = FDM(Q)
    # loss
    Loss_value = Loss(Free_nodes, new_node_coords, Obj_coords)
    Loss_his.append(Loss_value.item())
    # Backwards
    optimizer.zero_grad()
    # print(q.grad)
    Loss_value.backward(retain_graph=True)

    # Grad
    gradients = q.grad
    frob_norm = torch.norm(gradients)
#     print(gradients)
    optimizer.step()
    print(new_node_coords)
    # print iteration
    if iteration % 5 == 0:
        print(f"Iteration {iteration}: Normalized Gradient = {frob_norm}, Adaptive learning rate = {step}")
print("Optimization completed.")
print(q)
# print("coordinates:",node_coords)

#############################################################################################################
# Coordinates assembly:
x_orig = node_coords[:, 0].detach().numpy()
y_orig = node_coords[:, 1].detach().numpy()
z_orig = node_coords[:, 2].detach().numpy()

x_def = new_node_coords[:, 0].detach().numpy()
y_def = new_node_coords[:, 1].detach().numpy()
z_def = new_node_coords[:, 2].detach().numpy()

fig = go.Figure()

for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_orig[i-1], x_orig[j-1]],
        y=[y_orig[i-1], y_orig[j-1]],
        z=[z_orig[i-1], z_orig[j-1]],
        mode='lines',
        line=dict(color='blue', width=4),
        name='XY-projection(original)'
    ))

for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_def[i-1], x_def[j-1]],
        y=[y_def[i-1], y_def[j-1]],
        z=[z_def[i-1], z_def[j-1]],
        mode='lines',
        line=dict(color='red', width=4),
        name='FDM Solution'
    ))

for node in Free_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_def[node-1]],
        y=[y_def[node-1]],
        z=[z_def[node-1]],
        mode='markers+text',
        marker=dict(size=5, color='green'),
        text=[f'Node {node}'],
        textposition='top center',
        name=f'Free Node {node}'
    ))

fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        aspectmode='data'
    ),
    title='Deformation Comparison: Original vs. Deformed Geometry',
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()

##### Loss history
plt.figure()
plt.plot(range(epochs + 1), Loss_his, label='Loss History', color='blue', linewidth=2)
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Optimization Loss vs. Iterations')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 0
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0198],
#         [3.0000, 6.0000, 1.0198],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0198],
#         [6.0000, 6.0000, 1.0198],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 0: Normalized Gradient = 1.470801591873169, Adaptive learning rate = 0.001
# 1
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0219],
#         [3.0000, 6.0000, 1.0219],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0219],
#         [6.0000, 6.0000, 1.0219],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 2
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0240],
#         [3.0000, 6.0000, 1.0240],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0240],
#         [6.0000, 6.0000, 1.0240],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 3
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0261],
#         [3.0000, 6.0000, 1.0261],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0261],
#         [6.0000, 6.0000, 1.0261],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 4
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0282],
#         [3.0000, 6.0000, 1.0282],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0282],
#         [6.0000, 6.0000, 1.0282],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 5
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0303],
#         [3.0000, 6.0000, 1.0303],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0303],
#         [6.0000, 6.0000, 1.0303],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 5: Normalized Gradient = 1.5012762546539307, Adaptive learning rate = 0.001
# 6
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0325],
#         [3.0000, 6.0000, 1.0325],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0325],
#         [6.0000, 6.0000, 1.0325],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 7
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0346],
#         [3.0000, 6.0000, 1.0346],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0346],
#         [6.0000, 6.0000, 1.0346],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 8
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0367],
#         [3.0000, 6.0000, 1.0367],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0367],
#         [6.0000, 6.0000, 1.0367],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 9
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0389],
#         [3.0000, 6.0000, 1.0389],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0389],
#         [6.0000, 6.0000, 1.0389],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 10
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0411],
#         [3.0000, 6.0000, 1.0411],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0411],
#         [6.0000, 6.0000, 1.0411],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 10: Normalized Gradient = 1.532768726348877, Adaptive learning rate = 0.001
# 11
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0433],
#         [3.0000, 6.0000, 1.0433],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0433],
#         [6.0000, 6.0000, 1.0433],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 12
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0454],
#         [3.0000, 6.0000, 1.0454],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0454],
#         [6.0000, 6.0000, 1.0454],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 13
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0476],
#         [3.0000, 6.0000, 1.0476],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0476],
#         [6.0000, 6.0000, 1.0476],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 14
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0499],
#         [3.0000, 6.0000, 1.0499],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0499],
#         [6.0000, 6.0000, 1.0499],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 15
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0521],
#         [3.0000, 6.0000, 1.0521],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0521],
#         [6.0000, 6.0000, 1.0521],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 15: Normalized Gradient = 1.5653804540634155, Adaptive learning rate = 0.001
# 16
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0543],
#         [3.0000, 6.0000, 1.0543],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0543],
#         [6.0000, 6.0000, 1.0543],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 17
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0566],
#         [3.0000, 6.0000, 1.0566],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0566],
#         [6.0000, 6.0000, 1.0566],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 18
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0588],
#         [3.0000, 6.0000, 1.0588],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0588],
#         [6.0000, 6.0000, 1.0588],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 19
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0611],
#         [3.0000, 6.0000, 1.0611],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0611],
#         [6.0000, 6.0000, 1.0611],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 20
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0634],
#         [3.0000, 6.0000, 1.0634],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0634],
#         [6.0000, 6.0000, 1.0634],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 20: Normalized Gradient = 1.5992164611816406, Adaptive learning rate = 0.001
# 21
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1253],
#         [3.0000, 6.0000, 1.1253],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1253],
#         [6.0000, 6.0000, 1.1253],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 45: Normalized Gradient = 1.7907860279083252, Adaptive learning rate = 0.001
# 46
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1280],
#         [3.0000, 6.0000, 1.1280],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1280],
#         [6.0000, 6.0000, 1.1280],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 47
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1307],
#         [3.0000, 6.0000, 1.1307],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1307],
#         [6.0000, 6.0000, 1.1307],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 48
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1334],
#         [3.0000, 6.0000, 1.1334],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1334],
#         [6.0000, 6.0000, 1.1334],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 49
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1362],
#         [3.0000, 6.0000, 1.1362],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1362],
#         [6.0000, 6.0000, 1.1362],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 50
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1389],
#         [3.0000, 6.0000, 1.1389],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1389],
#         [6.0000, 6.0000, 1.1389],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 50: Normalized Gradient = 1.8344470262527466, Adaptive learning rate = 0.001
# 51
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1417],
#         [3.0000, 6.0000, 1.1417],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1417],
#         [6.0000, 6.0000, 1.1417],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 52
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1445],
#         [3.0000, 6.0000, 1.1445],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1445],
#         [6.0000, 6.0000, 1.1445],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 53
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1473],
#         [3.0000, 6.0000, 1.1473],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1473],
#         [6.0000, 6.0000, 1.1473],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 54
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1502],
#         [3.0000, 6.0000, 1.1502],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1502],
#         [6.0000, 6.0000, 1.1502],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 55
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1530],
#         [3.0000, 6.0000, 1.1530],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1530],
#         [6.0000, 6.0000, 1.1530],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 55: Normalized Gradient = 1.880215048789978, Adaptive learning rate = 0.001
# 56
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1559],
#         [3.0000, 6.0000, 1.1559],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1559],
#         [6.0000, 6.0000, 1.1559],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 57
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1588],
#         [3.0000, 6.0000, 1.1588],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1588],
#         [6.0000, 6.0000, 1.1588],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 58
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1618],
#         [3.0000, 6.0000, 1.1618],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1618],
#         [6.0000, 6.0000, 1.1618],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 59
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1647],
#         [3.0000, 6.0000, 1.1647],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1647],
#         [6.0000, 6.0000, 1.1647],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 60
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1677],
#         [3.0000, 6.0000, 1.1677],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1677],
#         [6.0000, 6.0000, 1.1677],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 60: Normalized Gradient = 1.9282478094100952, Adaptive learning rate = 0.001
# 61
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1707],
#         [3.0000, 6.0000, 1.1707],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1707],
#         [6.0000, 6.0000, 1.1707],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 62
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1737],
#         [3.0000, 6.0000, 1.1737],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1737],
#         [6.0000, 6.0000, 1.1737],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 63
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1767],
#         [3.0000, 6.0000, 1.1767],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1767],
#         [6.0000, 6.0000, 1.1767],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 64
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1798],
#         [3.0000, 6.0000, 1.1798],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1798],
#         [6.0000, 6.0000, 1.1798],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 65
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1829],
#         [3.0000, 6.0000, 1.1829],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1829],
#         [6.0000, 6.0000, 1.1829],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 65: Normalized Gradient = 1.9787200689315796, Adaptive learning rate = 0.001
# 66
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1860],
#         [3.0000, 6.0000, 1.1860],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1860],
#         [6.0000, 6.0000, 1.1860],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 67
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.1891],
#         [3.0000, 6.0000, 1.1891],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.1891],
#         [6.0000, 6.0000, 1.1891],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 68
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.2646],
#         [3.0000, 6.0000, 1.2646],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.2646],
#         [6.0000, 6.0000, 1.2646],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 90
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.2683],
#         [3.0000, 6.0000, 1.2683],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.2683],
#         [6.0000, 6.0000, 1.2683],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 90: Normalized Gradient = 2.2750136852264404, Adaptive learning rate = 0.001
# 91
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.2721],
#         [3.0000, 6.0000, 1.2721],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.2721],
#         [6.0000, 6.0000, 1.2721],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 92
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.2760],
#         [3.0000, 6.0000, 1.2760],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.2760],
#         [6.0000, 6.0000, 1.2760],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 93
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.2798],
#         [3.0000, 6.0000, 1.2798],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.2798],
#         [6.0000, 6.0000, 1.2798],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 94
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.2837],
#         [3.0000, 6.0000, 1.2837],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.2837],
#         [6.0000, 6.0000, 1.2837],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 95
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.2877],
#         [3.0000, 6.0000, 1.2877],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.2877],
#         [6.0000, 6.0000, 1.2877],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 95: Normalized Gradient = 2.3448591232299805, Adaptive learning rate = 0.001
# 96
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.2916],
#         [3.0000, 6.0000, 1.2916],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.2916],
#         [6.0000, 6.0000, 1.2916],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 97
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.2956],
#         [3.0000, 6.0000, 1.2956],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.2956],
#         [6.0000, 6.0000, 1.2956],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 98
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.2997],
#         [3.0000, 6.0000, 1.2997],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.2997],
#         [6.0000, 6.0000, 1.2997],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 99
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3037],
#         [3.0000, 6.0000, 1.3037],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3037],
#         [6.0000, 6.0000, 1.3037],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 100
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3078],
#         [3.0000, 6.0000, 1.3078],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3078],
#         [6.0000, 6.0000, 1.3078],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 100: Normalized Gradient = 2.418971300125122, Adaptive learning rate = 0.001
# 101
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3120],
#         [3.0000, 6.0000, 1.3120],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3120],
#         [6.0000, 6.0000, 1.3120],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 102
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3162],
#         [3.0000, 6.0000, 1.3162],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3162],
#         [6.0000, 6.0000, 1.3162],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 103
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3204],
#         [3.0000, 6.0000, 1.3204],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3204],
#         [6.0000, 6.0000, 1.3204],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 104
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3247],
#         [3.0000, 6.0000, 1.3247],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3247],
#         [6.0000, 6.0000, 1.3247],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 105
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3290],
#         [3.0000, 6.0000, 1.3290],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3290],
#         [6.0000, 6.0000, 1.3290],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 105: Normalized Gradient = 2.497744560241699, Adaptive learning rate = 0.001
# 106
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3333],
#         [3.0000, 6.0000, 1.3333],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3333],
#         [6.0000, 6.0000, 1.3333],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 107
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3377],
#         [3.0000, 6.0000, 1.3377],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3377],
#         [6.0000, 6.0000, 1.3377],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 108
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3421],
#         [3.0000, 6.0000, 1.3421],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3421],
#         [6.0000, 6.0000, 1.3421],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 109
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3466],
#         [3.0000, 6.0000, 1.3466],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3466],
#         [6.0000, 6.0000, 1.3466],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 110
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3511],
#         [3.0000, 6.0000, 1.3511],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3511],
#         [6.0000, 6.0000, 1.3511],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 110: Normalized Gradient = 2.581623077392578, Adaptive learning rate = 0.001
# 111
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3557],
#         [3.0000, 6.0000, 1.3557],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3557],
#         [6.0000, 6.0000, 1.3557],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 112
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3603],
#         [3.0000, 6.0000, 1.3603],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3603],
#         [6.0000, 6.0000, 1.3603],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 113
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3649],
#         [3.0000, 6.0000, 1.3649],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3649],
#         [6.0000, 6.0000, 1.3649],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 114
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3696],
#         [3.0000, 6.0000, 1.3696],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3696],
#         [6.0000, 6.0000, 1.3696],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 115
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3743],
#         [3.0000, 6.0000, 1.3743],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3743],
#         [6.0000, 6.0000, 1.3743],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 115: Normalized Gradient = 2.6711037158966064, Adaptive learning rate = 0.001
# 116
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3791],
#         [3.0000, 6.0000, 1.3791],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3791],
#         [6.0000, 6.0000, 1.3791],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 117
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3839],
#         [3.0000, 6.0000, 1.3839],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3839],
#         [6.0000, 6.0000, 1.3839],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 118
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3888],
#         [3.0000, 6.0000, 1.3888],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3888],
#         [6.0000, 6.0000, 1.3888],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 119
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3937],
#         [3.0000, 6.0000, 1.3937],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3937],
#         [6.0000, 6.0000, 1.3937],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 120
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.3987],
#         [3.0000, 6.0000, 1.3987],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.3987],
#         [6.0000, 6.0000, 1.3987],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 120: Normalized Gradient = 2.7667510509490967, Adaptive learning rate = 0.001
# 121
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4037],
#         [3.0000, 6.0000, 1.4037],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4037],
#         [6.0000, 6.0000, 1.4037],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 122
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4088],
#         [3.0000, 6.0000, 1.4088],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4088],
#         [6.0000, 6.0000, 1.4088],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 123
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4139],
#         [3.0000, 6.0000, 1.4139],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4139],
#         [6.0000, 6.0000, 1.4139],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 124
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4191],
#         [3.0000, 6.0000, 1.4191],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4191],
#         [6.0000, 6.0000, 1.4191],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 125
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4244],
#         [3.0000, 6.0000, 1.4244],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4244],
#         [6.0000, 6.0000, 1.4244],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 125: Normalized Gradient = 2.8692095279693604, Adaptive learning rate = 0.001
# 126
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4297],
#         [3.0000, 6.0000, 1.4297],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4297],
#         [6.0000, 6.0000, 1.4297],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 127
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4350],
#         [3.0000, 6.0000, 1.4350],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4350],
#         [6.0000, 6.0000, 1.4350],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 128
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4404],
#         [3.0000, 6.0000, 1.4404],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4404],
#         [6.0000, 6.0000, 1.4404],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 129
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4459],
#         [3.0000, 6.0000, 1.4459],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4459],
#         [6.0000, 6.0000, 1.4459],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 130
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4514],
#         [3.0000, 6.0000, 1.4514],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4514],
#         [6.0000, 6.0000, 1.4514],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 130: Normalized Gradient = 2.9792089462280273, Adaptive learning rate = 0.001
# 131
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4570],
#         [3.0000, 6.0000, 1.4570],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4570],
#         [6.0000, 6.0000, 1.4570],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 132
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4627],
#         [3.0000, 6.0000, 1.4627],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4627],
#         [6.0000, 6.0000, 1.4627],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 133
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4684],
#         [3.0000, 6.0000, 1.4684],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4684],
#         [6.0000, 6.0000, 1.4684],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 134
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4741],
#         [3.0000, 6.0000, 1.4741],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4741],
#         [6.0000, 6.0000, 1.4741],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 135
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4800],
#         [3.0000, 6.0000, 1.4800],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4800],
#         [6.0000, 6.0000, 1.4800],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 135: Normalized Gradient = 3.0975887775421143, Adaptive learning rate = 0.001
# 136
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4859],
#         [3.0000, 6.0000, 1.4859],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4859],
#         [6.0000, 6.0000, 1.4859],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 137
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4919],
#         [3.0000, 6.0000, 1.4919],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4919],
#         [6.0000, 6.0000, 1.4919],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 138
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4979],
#         [3.0000, 6.0000, 1.4979],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4979],
#         [6.0000, 6.0000, 1.4979],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 139
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5040],
#         [3.0000, 6.0000, 1.5040],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5040],
#         [6.0000, 6.0000, 1.5040],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 140
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5089],
#         [3.0000, 6.0000, 1.5089],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5089],
#         [6.0000, 6.0000, 1.5089],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 140: Normalized Gradient = 3.219656467437744, Adaptive learning rate = 0.001
# 141
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5126],
#         [3.0000, 6.0000, 1.5126],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5126],
#         [6.0000, 6.0000, 1.5126],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 142
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5152],
#         [3.0000, 6.0000, 1.5152],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5152],
#         [6.0000, 6.0000, 1.5152],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 143
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5170],
#         [3.0000, 6.0000, 1.5170],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5170],
#         [6.0000, 6.0000, 1.5170],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 144
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5178],
#         [3.0000, 6.0000, 1.5178],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5178],
#         [6.0000, 6.0000, 1.5178],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 145
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5180],
#         [3.0000, 6.0000, 1.5180],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5180],
#         [6.0000, 6.0000, 1.5180],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 145: Normalized Gradient = 3.2586865425109863, Adaptive learning rate = 0.001
# 146
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5174],
#         [3.0000, 6.0000, 1.5174],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5174],
#         [6.0000, 6.0000, 1.5174],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 147
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5163],
#         [3.0000, 6.0000, 1.5163],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5163],
#         [6.0000, 6.0000, 1.5163],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 148
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5146],
#         [3.0000, 6.0000, 1.5146],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5146],
#         [6.0000, 6.0000, 1.5146],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 149
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5124],
#         [3.0000, 6.0000, 1.5124],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5124],
#         [6.0000, 6.0000, 1.5124],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 150
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5098],
#         [3.0000, 6.0000, 1.5098],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5098],
#         [6.0000, 6.0000, 1.5098],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# ...
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 475
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4997],
#         [3.0000, 6.0000, 1.4997],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4997],
#         [6.0000, 6.0000, 1.4997],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 475: Normalized Gradient = 3.180677652359009, Adaptive learning rate = 0.001
# 476
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4995],
#         [3.0000, 6.0000, 1.4995],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4995],
#         [6.0000, 6.0000, 1.4995],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 477
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4998],
#         [3.0000, 6.0000, 1.4998],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4998],
#         [6.0000, 6.0000, 1.4998],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 478
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5005],
#         [3.0000, 6.0000, 1.5005],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5005],
#         [6.0000, 6.0000, 1.5005],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 479
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5007],
#         [3.0000, 6.0000, 1.5007],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5007],
#         [6.0000, 6.0000, 1.5007],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 480
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5004],
#         [3.0000, 6.0000, 1.5004],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5004],
#         [6.0000, 6.0000, 1.5004],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 480: Normalized Gradient = 3.1838178634643555, Adaptive learning rate = 0.001
# 481
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4997],
#         [3.0000, 6.0000, 1.4997],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4997],
#         [6.0000, 6.0000, 1.4997],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 482
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4995],
#         [3.0000, 6.0000, 1.4995],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4995],
#         [6.0000, 6.0000, 1.4995],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 483
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4998],
#         [3.0000, 6.0000, 1.4998],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4998],
#         [6.0000, 6.0000, 1.4998],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 484
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5005],
#         [3.0000, 6.0000, 1.5005],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5005],
#         [6.0000, 6.0000, 1.5005],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 485
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5007],
#         [3.0000, 6.0000, 1.5007],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5007],
#         [6.0000, 6.0000, 1.5007],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 485: Normalized Gradient = 3.185042142868042, Adaptive learning rate = 0.001
# 486
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5004],
#         [3.0000, 6.0000, 1.5004],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5004],
#         [6.0000, 6.0000, 1.5004],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 487
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4997],
#         [3.0000, 6.0000, 1.4997],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4997],
#         [6.0000, 6.0000, 1.4997],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 488
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4995],
#         [3.0000, 6.0000, 1.4995],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4995],
#         [6.0000, 6.0000, 1.4995],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 489
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4998],
#         [3.0000, 6.0000, 1.4998],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4998],
#         [6.0000, 6.0000, 1.4998],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 490
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5005],
#         [3.0000, 6.0000, 1.5005],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5005],
#         [6.0000, 6.0000, 1.5005],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 490: Normalized Gradient = 3.184136390686035, Adaptive learning rate = 0.001
# 491
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5007],
#         [3.0000, 6.0000, 1.5007],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5007],
#         [6.0000, 6.0000, 1.5007],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 492
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5004],
#         [3.0000, 6.0000, 1.5004],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5004],
#         [6.0000, 6.0000, 1.5004],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 493
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4996],
#         [3.0000, 6.0000, 1.4996],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4996],
#         [6.0000, 6.0000, 1.4996],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 494
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4994],
#         [3.0000, 6.0000, 1.4994],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4994],
#         [6.0000, 6.0000, 1.4994],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 495
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4997],
#         [3.0000, 6.0000, 1.4997],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4997],
#         [6.0000, 6.0000, 1.4997],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 495: Normalized Gradient = 3.1808791160583496, Adaptive learning rate = 0.001
# 496
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5005],
#         [3.0000, 6.0000, 1.5005],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5005],
#         [6.0000, 6.0000, 1.5005],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 497
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5007],
#         [3.0000, 6.0000, 1.5007],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5007],
#         [6.0000, 6.0000, 1.5007],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 498
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5004],
#         [3.0000, 6.0000, 1.5004],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5004],
#         [6.0000, 6.0000, 1.5004],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 499
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4996],
#         [3.0000, 6.0000, 1.4996],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4996],
#         [6.0000, 6.0000, 1.4996],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 500
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4994],
#         [3.0000, 6.0000, 1.4994],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4994],
#         [6.0000, 6.0000, 1.4994],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 500: Normalized Gradient = 3.1795361042022705, Adaptive learning rate = 0.001
# Optimization completed.
# tensor([0.2796, 0.3872], requires_grad=True)
# <div>                            <div id="36ae96b3-1185-449e-9f90-f1e2ddd2b92c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36ae96b3-1185-449e-9f90-f1e2ddd2b92c")) {                    Plotly.newPlot(                        "36ae96b3-1185-449e-9f90-f1e2ddd2b92c",                        [{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[0.0,3.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[0.0,3.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,3.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,3.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,3.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[6.0,6.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[6.0,6.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[6.0,6.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[9.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[9.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[0.0,3.0],"y":[3.0,2.999999761581421],"z":[0.0,1.499423861503601],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[0.0,2.999999761581421],"y":[6.0,6.0],"z":[0.0,1.4994237422943115],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.0,3.0],"y":[0.0,2.999999761581421],"z":[0.0,1.499423861503601],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[2.999999761581421,3.0],"y":[6.0,2.999999761581421],"z":[1.4994237422943115,1.499423861503601],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.0,2.999999761581421],"y":[9.0,6.0],"z":[0.0,1.4994237422943115],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.0,6.0],"y":[2.999999761581421,3.0],"z":[1.499423861503601,1.499423861503601],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[2.999999761581421,5.999999523162842],"y":[6.0,6.0],"z":[1.4994237422943115,1.4994237422943115],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[6.0,6.0],"y":[0.0,3.0],"z":[0.0,1.499423861503601],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[5.999999523162842,6.0],"y":[6.0,3.0],"z":[1.4994237422943115,1.499423861503601],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[6.0,5.999999523162842],"y":[9.0,6.0],"z":[0.0,1.4994237422943115],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":" ...

# %%
### Deflected shape matching -- with 2 qs
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import plotly.graph_objects as go

# q.grad.zero_()


# In[663]:


######################## explanation
## "The example model is based on a 5-nodes grid shell strcuture
##  which has a crossing projection in the x-y plane"
##  The FE part would be based on the Euler-bernoulli beam theory


# In[664]:


## Initial Geom
# Initial Coords:
node_coords = torch.tensor(
    [[0.0, 3.0, 0.0], [0.0, 6.0, 0.0], [3.0, 0.0, 0.0], [3.0, 3.0, 0.0], [3.0, 6.0, 0.0], [3.0, 9.0, 0.0],
     [6.0, 0.0, 0.0], [6.0, 3.0, 0.0], [6.0, 6.0, 0.0] ,[6.0, 9.0, 0.0], [9.0, 3.0 ,0.0], [9.0, 6.0, 0.0]],
    dtype=torch.float32, requires_grad=True, )
connectivity = [[1, 4], [2, 5], [3, 4], [5, 4], [6, 5], [4, 8],[5, 9], [7, 8], [9, 8],[10, 9],[12, 9],[11, 8]]
n_dof_per_node = 6  # Degrees of freedom per node
total_dof = n_dof_per_node * len(node_coords)
Fixed_nodes = [1, 2, 3, 6, 7, 10, 11, 12]
Free_nodes = []
n_elements = len(connectivity)
n_nodes = len(node_coords)
for i in range(1, n_nodes + 1):
    if i not in Fixed_nodes:
        Free_nodes.append(i)
idx_CF = [node - 1 for node in Fixed_nodes]
idx_CN = [i for i in range(n_nodes) if i not in idx_CF]


## Force condition
####### Force condition -> need for modification
## +0 to x direction ; +1 to y direction ; +2 to Z direction
## +3 Bending around the z axis ; +4 bending around y axis ; +5 Twisting
# implement upwards loading of 50 kN at every free nodes
F = torch.zeros(total_dof, dtype=torch.float32)
f_n = Free_nodes
f_type = [2, 2, 2, 2]  # The force type
F_value = torch.tensor([50.0, 50.0, 50.0, 50.0]) * 1000  # The force value/direction
r = 1 / torch.max(F_value)
# print(r)
F_sign = torch.sign(F_value)
for idx, i in enumerate(f_n):
    F[6 * (i - 1) + f_type[idx]] = F_value[idx]  # unit: KN / KN*m

px = torch.zeros(len(f_n), 1, dtype=torch.float32)
py = torch.zeros(len(f_n), 1, dtype=torch.float32)
pz = torch.zeros(len(f_n), 1, dtype=torch.float32)

for i in range(len(f_n)):
    if f_type[idx] == 0:
        px[i] = F_value[i]
    elif f_type[idx] == 1:
        py[i] = F_value[i]
    elif f_type[idx] == 2:
        pz[i] = F_value[i]


## Obtaining Matrix D
# Assembly the nodal-branch matrix:
C = torch.zeros(n_elements, n_nodes, dtype=torch.float32)
for n, (i, j) in enumerate(connectivity):
    C[n, i - 1] = 1
    C[n, j - 1] = -1
CF = C[:, idx_CF]
CN = C[:, idx_CN]


# Assembly D
def FDM (Q,CN=CN, CF=CF, px=px, py=py, pz=pz,Fixed_nodes=Fixed_nodes, Free_nodes=Free_nodes,node_coords=node_coords) :
    Dn = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CN))
    DF = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CF))
    ## Coordinates solution
    # separate the coordinates:
    fixed_idces = [node - 1 for node in Fixed_nodes]
    xF = node_coords[fixed_idces, 0].unsqueeze(1)
    yF = node_coords[fixed_idces, 1].unsqueeze(1)
    zF = node_coords[fixed_idces, 2].unsqueeze(1)
    xN = torch.matmul(torch.inverse(Dn), (px - torch.matmul(DF, xF)))
    yN = torch.matmul(torch.inverse(Dn), (py - torch.matmul(DF, yF)))
    zN = torch.matmul(torch.inverse(Dn), (pz - torch.matmul(DF, zF)))
    ## Coordinates renewal: 
    new_node_coords = node_coords.clone()
    for idx, node in enumerate(Free_nodes):
        node_idx = node - 1
        new_node_coords[node_idx, 0] = xN[idx]
        new_node_coords[node_idx, 1] = yN[idx]
        new_node_coords[node_idx, 2] = zN[idx]

    return new_node_coords

# In[670]:


## Check point: FDM completed
# if q.grad is not None:
#     q.grad.zero_()
# loss = torch.sum(new_node_coords[:, 2])
# loss.backward()
# print("Gradient of q:")
# print(q.grad)


############ Now comes to FE part:
#### Default values (in meters, Pascals, etc.)
## For rectangular sections
# D_width = 0.1
# D_height = 0.2
# D_young_modulus = 210e9  # Young's modulus in Pascals
# D_shear_modulus = 81e9  # Shear modulus in Pascals
# D_poisson_ratio = 0.3
# cross_section_angle_a = 0  # Cross-section angle at node 1 (anti-clockwise)
# cross_section_angle_b = 0  # Cross-section angle at node 2 (anti-clockwise)
# a_small_number = 1e-10

D_radius = 0.05
D_young_modulus = 210e9  # Young's modulus in Pascals
D_shear_modulus = 81e9  # Shear modulus in Pascals
D_poisson_ratio = 0.3
cross_section_angle_a = 0  # Cross-section angle at node 1 (anti-clockwise)
cross_section_angle_b = 0  # Cross-section angle at node 2 (anti-clockwise)
a_small_number = 1e-10


# In[673]:


def rotation(v, k, theta):
    """Rotation of vector v around axis k by angle theta."""
    k = k / torch.norm(k)  # Normalize k
    cross_product = torch.cross(k, v)
    dot_product = torch.dot(k, v)

    # Ensure theta is a tensor
    theta = torch.tensor(theta, dtype=torch.float32) if not isinstance(theta, torch.Tensor) else theta

    v_rotated = v * torch.cos(theta) + cross_product * torch.sin(theta) + k * dot_product * (1 - torch.cos(theta))
    return v_rotated


# In[674]:


###### Element Creating (euler beam)
# For rectangular sections
# class Beam:
#     def __init__(self, node_coordinates, width=D_width, height=D_height, young_modulus=D_young_modulus,
#                  shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
#                  Beta_b=cross_section_angle_b):
#         self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

#         # Material and geometry
#         self.width = width
#         self.height = height
#         self.young_modulus = young_modulus
#         self.shear_modulus = shear_modulus
#         self.poisson_ratio = poisson_ratio

#         # Cross-sectional properties
#         self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
#         self.Iy = (self.width * self.height ** 3) / 12
#         self.Iz = (self.width ** 3 * self.height) / 12
#         self.A = self.width * self.height
#         self.J = (self.width * self.height ** 3) / 3

#         # Stiffness components
#         self.S_u = self.young_modulus * self.A / self.length
#         self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
#         self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
#         self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
#         self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
#         self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
#         self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
#         self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
#         self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
#         self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
#         self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
#         self.S_Tr = self.shear_modulus * self.J / self.length

#         # Section rotations at the two ends
#         self.Beta_a = Beta_a
#         self.Beta_b = Beta_b


# In[675]:


# For circular sections
class Beam:
    def __init__(self, node_coordinates, R=D_radius, young_modulus=D_young_modulus,
                 shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                 Beta_b=cross_section_angle_b):
        self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

        # Material and geometry
        self.radius = R
        self.young_modulus = young_modulus
        self.shear_modulus = shear_modulus
        self.poisson_ratio = poisson_ratio

        # Cross-sectional properties
        self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
        self.Iy = (torch.pi * self.radius ** 4) / 4 
        self.Iz = self.Iy
        self.A = torch.pi * self.radius ** 2
        self.J = (torch.pi * self.radius ** 4) / 2

        # Stiffness components
        self.S_u = self.young_modulus * self.A / self.length
        self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
        self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
        self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
        self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
        self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
        self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
        self.S_Tr = self.shear_modulus * self.J / self.length

        # Section rotations at the two ends
        self.Beta_a = Beta_a
        self.Beta_b = Beta_b

    def get_element_stiffness_matrix(self):
        """Element stiffness matrix."""
        K_element = torch.tensor([
            [self.S_u, 0, 0, 0, 0, 0, -self.S_u, 0, 0, 0, 0, 0],
            [0, self.S_v1a, 0, 0, 0, self.S_theta1a, 0, -self.S_v1a, 0, 0, 0, self.S_theta1a],
            [0, 0, self.S_v2a, 0, -self.S_theta2a, 0, 0, 0, -self.S_v2a, 0, -self.S_theta2a, 0],
            [0, 0, 0, self.S_Tr, 0, 0, 0, 0, 0, -self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2b, 0, 0, 0, self.S_v2b, 0, self.S_theta2c, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1b, 0, -self.S_v1b, 0, 0, 0, self.S_theta1c],
            [-self.S_u, 0, 0, 0, 0, 0, self.S_u, 0, 0, 0, 0, 0],
            [0, -self.S_v1a, 0, 0, 0, -self.S_theta1a, 0, self.S_v1a, 0, 0, 0, -self.S_theta1a],
            [0, 0, -self.S_v2a, 0, self.S_theta2a, 0, 0, 0, self.S_v2a, 0, self.S_theta2a, 0],
            [0, 0, 0, -self.S_Tr, 0, 0, 0, 0, 0, self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2c, 0, 0, 0, self.S_v2b, 0, self.S_theta2b, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1c, 0, -self.S_v1b, 0, 0, 0, self.S_theta1b],
        ], dtype=torch.float32)

        return K_element

    def System_Transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        # print(vector_x,vector_y,vector_z)
        # Calculate alpha and ceta using PyTorch
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)
        # print(alpha)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)

        # Z_axis_b = rotation(V_projection, X_axis, self.Beta_b)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        # Y_axis_b = rotation(Z_axis_b, X_axis, torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        # Z_axis_b = Z_axis_b / torch.norm(Z_axis_b)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)
        # Y_axis_b = Y_axis_b / torch.norm(Y_axis_b)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)
        matrix_T = torch.zeros((12, 12), dtype=torch.float32)
        for i in range(0, 12, 3):
            matrix_T[i:i + 3, i:i + 3] = lambda_matrix
        return matrix_T

    def nodal_transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        # Calculate alpha and ceta using PyTorch
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)

        # Z_axis_b = rotation(V_projection, X_axis, self.Beta_b)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        # Y_axis_b = rotation(Z_axis_b, X_axis, torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        # Z_axis_b = Z_axis_b / torch.norm(Z_axis_b)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)
        # Y_axis_b = Y_axis_b / torch.norm(Y_axis_b)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)

        return lambda_matrix


# In[676]:


def assemble_stiffness_matrix(beams, n_nodes, n_dof_per_node, connectivity):
    """Global stiffness matrix assembly."""
    total_dof = n_nodes * n_dof_per_node  # Total degrees of freedom
    K_global = torch.zeros((total_dof, total_dof), dtype=torch.float32)
    for idx, (i, j) in enumerate(connectivity):
        Matrix_T = beams[idx].System_Transform()  # Get transformation matrix

        K_element = torch.matmul(torch.transpose(Matrix_T, 0, 1),
                                 torch.matmul(beams[idx].get_element_stiffness_matrix(), Matrix_T))

        start_idx = (i - 1) * n_dof_per_node
        end_idx = (j - 1) * n_dof_per_node
        K_global[start_idx:start_idx + 6, start_idx:start_idx + 6] = K_global[start_idx:start_idx + 6,
                                                                     start_idx:start_idx + 6] + K_element[0:6, 0:6]
        K_global[end_idx:end_idx + 6, end_idx:end_idx + 6] = K_global[end_idx:end_idx + 6,
                                                             end_idx:end_idx + 6] + K_element[6:12, 6:12]
        K_global[start_idx:start_idx + 6, end_idx:end_idx + 6] = K_global[start_idx:start_idx + 6,
                                                                 end_idx:end_idx + 6] + K_element[0:6, 6:12]
        K_global[end_idx:end_idx + 6, start_idx:start_idx + 6] = K_global[end_idx:end_idx + 6,
                                                                 start_idx:start_idx + 6] + K_element[6:12, 0:6]

    return K_global


# In[677]:


def Strain_E(node_coords, connectivity, fixed_dof, F):
    # node_coords[:, 2] = 0.0
    # Element Assembly
    beams = []
    for connection in connectivity:
        node_1_coords = node_coords[connection[0] - 1]
        node_2_coords = node_coords[connection[1] - 1]
        beam = Beam(node_coordinates=torch.stack([node_1_coords, node_2_coords]),
                    R=D_radius, young_modulus=D_young_modulus,
                    shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                    Beta_b=cross_section_angle_b)
        beams.append(beam)
    # Stiffness renewal
    K_global = assemble_stiffness_matrix(beams, n_nodes=len(node_coords), n_dof_per_node=6, connectivity=connectivity)
    K_global[fixed_dof, :] = K_global[fixed_dof, :] - K_global[fixed_dof, :]
    K_global[:, fixed_dof] = K_global[:, fixed_dof] - K_global[:, fixed_dof]
    K_global[fixed_dof, fixed_dof] = 1e5
    rank_K = torch.linalg.matrix_rank(K_global)

    if rank_K < K_global.shape[0]:
        print("Warning: The stiffness matrix is not of full rank")
    else:
        displacements = torch.linalg.solve(K_global, F)

    # Compute strain energy
    strain_energy_list = []
    Local_d = torch.zeros(len(connectivity), 12, dtype=torch.float32)
    for n, (i, j) in enumerate(connectivity):
        matrix_T = beams[n].System_Transform()
        Tep_displacements = torch.cat(
            [displacements[6 * (i - 1):6 * (i - 1) + 6], displacements[6 * (j - 1):6 * (j - 1) + 6]], dim=0)
        Local_d_n = torch.matmul(Tep_displacements, matrix_T.T)
        Local_d[n, :] = Local_d_n.clone()
        K_g = torch.matmul(torch.transpose(matrix_T, 0, 1),
                           torch.matmul(beams[n].get_element_stiffness_matrix(), matrix_T))

        strain_energy_list.append(torch.matmul(Local_d_n, torch.matmul(K_g, Local_d_n.reshape(-1, 1))))

    Strain_energy = torch.stack(strain_energy_list)

    return Strain_energy, Local_d, displacements, beams

# In[678]:


# Element creating
#################  input below:
############################################################################################################## input
# initial coordinates

####### BCs
fixed_dof = []
for node in Fixed_nodes:
    fixed_dof.extend([(node - 1) * 6 + i for i in range(6)])
# print(fixed_dof)
####### Gradient descent
step = 0.001
epochs = 1000
Obj_coords = 1.5
####### Plotting
steps = 20  # steps for tracing deformation shape
###################################################################################################################################################
###################################################################################################################################################


# In[679]:

# Optimized Variables
## initial variables
Idx_q1 = [3, 4, 5, 8, 9, 10]
Idx_q2 = [1, 6, 11, 2, 7, 12]
Idx_q1 = [i - 1 for i in Idx_q1] 
Idx_q2 = [i - 1 for i in Idx_q2] 
q = torch.rand(2, requires_grad=True)
## Optimization
torch.autograd.set_detect_anomaly(True)
# Optimizer setting
optimizer = optim.Adam([q], lr=step)
Obj_coords = torch.tensor([1.5, 1.5, 1.5, 1.5])
def Loss(Free_nodes, new_node_coords, Obj_coords):
    n_free_nodes = len(Free_nodes)
    Free_nodes = torch.tensor(Free_nodes)
    y_pred = new_node_coords[(Free_nodes - 1), 2]  
    y_true = Obj_coords 
    error = torch.abs(y_true - y_pred)
    loss = torch.mean(error)
    return loss

# Initilizing
# New_Coordinates = torch.zeros(n_nodes * 3, dtype=torch.float32)
Loss_his = []
Disp_his = []
# Loop start
for iteration in range(epochs + 1):
    print('ite',iteration)
    # Forwards
    q_vec = torch.zeros(n_elements, requires_grad=True).clone()
    q_vec[Idx_q1] = q[0] 
    q_vec[Idx_q2] = q[1]
    Q = torch.diag(q_vec) * 1 / r  # scaling
    new_node_coords = FDM(Q)
    N_coords = new_node_coords.clone()
    Strain_energy, _, displacements, _ = Strain_E(N_coords, connectivity, fixed_dof, F)
    idx = 6 * torch.arange(n_nodes) + 2
    Ave_Disp = abs(torch.sum(displacements[idx] / len(Free_nodes)))
    Disp_his.append(Ave_Disp.item())
    N_coords = N_coords.reshape(-1)
    New_Coordinates = torch.zeros(n_nodes * 3, dtype=torch.float32)
    for n in range(n_nodes):
        New_Coordinates[3*n : 3*n+3] = N_coords[3*n : 3*n+3] + displacements[6*n : 6*n+3]
    New_Coordinates = New_Coordinates.view(n_nodes, 3).clone()
    # loss
    Loss_value = Loss(Free_nodes, New_Coordinates, Obj_coords)
    Loss_his.append(Loss_value.item())
    # Backwards
    optimizer.zero_grad()
    # print(q.grad)
    Loss_value.backward(retain_graph=True)

    # Grad
    gradients = q.grad
    frob_norm = torch.norm(gradients)
    optimizer.step()
    
    # print iteration
    if iteration % 5 == 0:
        print(f"Iteration {iteration}: Normalized Gradient = {frob_norm}, Adaptive learning rate = {step}")
print("Optimization completed.")
print(q)
# print("coordinates:",node_coords)

#############################################################################################################
## Visualization
# print(Coordinates)
# displacements = Strain_E(node_coords, connectivity, fixed_dof, F)[2]
# print("displacements:", displacements)
print("Deformed:", New_Coordinates)

x_orig = node_coords[:, 0].detach().numpy()
y_orig = node_coords[:, 1].detach().numpy()
z_orig = node_coords[:, 2].detach().numpy()

x_def = New_Coordinates[:, 0].detach().numpy()
y_def = New_Coordinates[:, 1].detach().numpy()
z_def = New_Coordinates[:, 2].detach().numpy()


fig = go.Figure()


for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_orig[i-1], x_orig[j-1]],
        y=[y_orig[i-1], y_orig[j-1]],
        z=[z_orig[i-1], z_orig[j-1]],
        mode='lines',
        line=dict(color='blue', width=4),
        name='Original Geometry'
    ))


for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_def[i-1], x_def[j-1]],
        y=[y_def[i-1], y_def[j-1]],
        z=[z_def[i-1], z_def[j-1]],
        mode='lines',
        line=dict(color='red', width=4),
        name='Deformed Geometry'
    ))


for node in Free_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_def[node-1]],
        y=[y_def[node-1]],
        z=[z_def[node-1]],
        mode='markers+text',
        marker=dict(size=5, color='green'),
        text=[f'Node {node}'],
        textposition='top center',
        name=f'Free Node {node}'
    ))


fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        aspectmode='data'
    ),
    title='Deformation Comparison: Original vs. Deformed Geometry (FE Analysis)',
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()

########################################################################################################################

### Plot the optimization history
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'blue'
ax1.set_xlabel('Iterations')
ax1.set_ylabel('Loss', color=color)
ax1.plot(range(epochs + 1), Loss_his, label='Loss History', color=color, linewidth=2)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True)

ax2 = ax1.twinx()
color = 'red'
ax2.set_ylabel('Average Displacement', color=color)
ax2.plot(range(epochs + 1), Disp_his, label='Average Displacement', color=color, linewidth=2, linestyle='--')
ax2.tick_params(axis='y', labelcolor=color)

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

plt.title('Loss & Average Displacement vs. Iterations')

plt.tight_layout()
plt.show()
# Out:
# ite 0
# Iteration 0: Normalized Gradient = 0.7636841535568237, Adaptive learning rate = 0.001
# ite 1
# ite 2
# ite 3
# ite 4
# ite 5
# Iteration 5: Normalized Gradient = 0.775104284286499, Adaptive learning rate = 0.001
# ite 6
# ite 7
# ite 8
# ite 9
# ite 10
# Iteration 10: Normalized Gradient = 0.7867975234985352, Adaptive learning rate = 0.001
# ite 11
# ite 12
# ite 13
# ite 14
# ite 15
# Iteration 15: Normalized Gradient = 0.7987871170043945, Adaptive learning rate = 0.001
# ite 16
# ite 17
# ite 18
# ite 19
# ite 20
# Iteration 20: Normalized Gradient = 0.8110963106155396, Adaptive learning rate = 0.001
# ite 21
# ite 22
# ite 23
# ite 24
# ite 25
# Iteration 25: Normalized Gradient = 0.8237494230270386, Adaptive learning rate = 0.001
# ite 26
# ite 27
# ite 28
# ite 29
# ite 30
# Iteration 30: Normalized Gradient = 0.8367698788642883, Adaptive learning rate = 0.001
# ite 31
# ite 32
# ite 33
# ite 34
# ite 35
# Iteration 35: Normalized Gradient = 0.8501812815666199, Adaptive learning rate = 0.001
# ite 36
# ite 37
# ite 38
# ite 39
# ite 40
# Iteration 40: Normalized Gradient = 0.8640064597129822, Adaptive learning rate = 0.001
# ite 41
# ite 42
# ite 43
# ite 44
# ite 45
# Iteration 45: Normalized Gradient = 0.878269374370575, Adaptive learning rate = 0.001
# ite 46
# ite 47
# ite 48
# ite 49
# ite 50
# Iteration 50: Normalized Gradient = 0.8929934501647949, Adaptive learning rate = 0.001
# ite 51
# ite 52
# ite 53
# ite 54
# ite 55
# Iteration 55: Normalized Gradient = 0.9082033038139343, Adaptive learning rate = 0.001
# ite 56
# ite 57
# ite 58
# ite 59
# ite 60
# Iteration 60: Normalized Gradient = 0.9239246249198914, Adaptive learning rate = 0.001
# ite 61
# ite 62
# ite 63
# ite 64
# ite 65
# Iteration 65: Normalized Gradient = 0.9401841759681702, Adaptive learning rate = 0.001
# ite 66
# ite 67
# ite 68
# ite 69
# ite 70
# Iteration 70: Normalized Gradient = 0.9570099115371704, Adaptive learning rate = 0.001
# ite 71
# ite 72
# ite 73
# ite 74
# ite 75
# Iteration 75: Normalized Gradient = 0.9744323492050171, Adaptive learning rate = 0.001
# ite 76
# ite 77
# ite 78
# ite 79
# ite 80
# Iteration 80: Normalized Gradient = 0.9924833178520203, Adaptive learning rate = 0.001
# ite 81
# ite 82
# ite 83
# ite 84
# ite 85
# Iteration 85: Normalized Gradient = 1.011197566986084, Adaptive learning rate = 0.001
# ite 86
# ite 87
# ite 88
# ite 89
# ite 90
# Iteration 90: Normalized Gradient = 1.0306106805801392, Adaptive learning rate = 0.001
# ite 91
# ite 92
# ite 93
# ite 94
# ite 95
# Iteration 95: Normalized Gradient = 1.0507619380950928, Adaptive learning rate = 0.001
# ite 96
# ite 97
# ite 98
# ite 99
# ite 100
# Iteration 100: Normalized Gradient = 1.0716941356658936, Adaptive learning rate = 0.001
# ite 101
# ite 102
# ite 103
# ite 104
# ite 105
# Iteration 105: Normalized Gradient = 1.0934520959854126, Adaptive learning rate = 0.001
# ite 106
# ite 107
# ite 108
# ite 109
# ite 110
# Iteration 110: Normalized Gradient = 1.116085171699524, Adaptive learning rate = 0.001
# ite 111
# ite 112
# ite 113
# ite 114
# ite 115
# Iteration 115: Normalized Gradient = 1.1396454572677612, Adaptive learning rate = 0.001
# ite 116
# ite 117
# ite 118
# ite 119
# ite 120
# Iteration 120: Normalized Gradient = 1.1641898155212402, Adaptive learning rate = 0.001
# ite 121
# ite 122
# ite 123
# ite 124
# ite 125
# Iteration 125: Normalized Gradient = 1.189780354499817, Adaptive learning rate = 0.001
# ite 126
# ite 127
# ite 128
# ite 129
# ite 130
# Iteration 130: Normalized Gradient = 1.2164838314056396, Adaptive learning rate = 0.001
# ite 131
# ite 132
# ite 133
# ite 134
# ite 135
# Iteration 135: Normalized Gradient = 1.244372010231018, Adaptive learning rate = 0.001
# ite 136
# ite 137
# ite 138
# ite 139
# ite 140
# Iteration 140: Normalized Gradient = 1.273524284362793, Adaptive learning rate = 0.001
# ite 141
# ite 142
# ite 143
# ite 144
# ite 145
# Iteration 145: Normalized Gradient = 1.3040260076522827, Adaptive learning rate = 0.001
# ite 146
# ite 147
# ite 148
# ite 149
# ite 150
# Iteration 150: Normalized Gradient = 1.335971474647522, Adaptive learning rate = 0.001
# ite 151
# ite 152
# ite 153
# ite 154
# ite 155
# Iteration 155: Normalized Gradient = 1.3694627285003662, Adaptive learning rate = 0.001
# ite 156
# ite 157
# ite 158
# ite 159
# ite 160
# Iteration 160: Normalized Gradient = 1.4046120643615723, Adaptive learning rate = 0.001
# ite 161
# ite 162
# ite 163
# ite 164
# ite 165
# Iteration 165: Normalized Gradient = 1.4415428638458252, Adaptive learning rate = 0.001
# ite 166
# ite 167
# ite 168
# ite 169
# ite 170
# Iteration 170: Normalized Gradient = 1.4803894758224487, Adaptive learning rate = 0.001
# ite 171
# ite 172
# ite 173
# ite 174
# ite 175
# Iteration 175: Normalized Gradient = 1.521302342414856, Adaptive learning rate = 0.001
# ite 176
# ite 177
# ite 178
# ite 179
# ite 180
# Iteration 180: Normalized Gradient = 1.5644451379776, Adaptive learning rate = 0.001
# ite 181
# ite 182
# ite 183
# ite 184
# ite 185
# Iteration 185: Normalized Gradient = 1.610001802444458, Adaptive learning rate = 0.001
# ite 186
# ite 187
# ite 188
# ite 189
# ite 190
# Iteration 190: Normalized Gradient = 1.6581746339797974, Adaptive learning rate = 0.001
# ite 191
# ite 192
# ite 193
# ite 194
# ite 195
# Iteration 195: Normalized Gradient = 1.7091885805130005, Adaptive learning rate = 0.001
# ite 196
# ite 197
# ite 198
# ite 199
# ite 200
# Iteration 200: Normalized Gradient = 1.763296365737915, Adaptive learning rate = 0.001
# ite 201
# ite 202
# ite 203
# ite 204
# ite 205
# Iteration 205: Normalized Gradient = 1.82077956199646, Adaptive learning rate = 0.001
# ite 206
# ite 207
# ite 208
# ite 209
# ite 210
# Iteration 210: Normalized Gradient = 1.8819544315338135, Adaptive learning rate = 0.001
# ite 211
# ite 212
# ite 213
# ite 214
# ite 215
# Iteration 215: Normalized Gradient = 1.9471781253814697, Adaptive learning rate = 0.001
# ite 216
# ite 217
# ite 218
# ite 219
# ite 220
# Iteration 220: Normalized Gradient = 2.0168542861938477, Adaptive learning rate = 0.001
# ite 221
# ite 222
# ite 223
# ite 224
# ite 225
# Iteration 225: Normalized Gradient = 2.0914418697357178, Adaptive learning rate = 0.001
# ite 226
# ite 227
# ite 228
# ite 229
# ite 230
# Iteration 230: Normalized Gradient = 2.1714582443237305, Adaptive learning rate = 0.001
# ite 231
# ite 232
# ite 233
# ite 234
# ite 235
# Iteration 235: Normalized Gradient = 2.257503032684326, Adaptive learning rate = 0.001
# ite 236
# ite 237
# ite 238
# ite 239
# ite 240
# Iteration 240: Normalized Gradient = 2.35025954246521, Adaptive learning rate = 0.001
# ite 241
# ite 242
# ite 243
# ite 244
# ite 245
# Iteration 245: Normalized Gradient = 2.4505178928375244, Adaptive learning rate = 0.001
# ite 246
# ite 247
# ite 248
# ite 249
# ite 250
# Iteration 250: Normalized Gradient = 2.559194326400757, Adaptive learning rate = 0.001
# ite 251
# ite 252
# ite 253
# ite 254
# ite 255
# Iteration 255: Normalized Gradient = 2.677358627319336, Adaptive learning rate = 0.001
# ite 256
# ite 257
# ite 258
# ite 259
# ite 260
# Iteration 260: Normalized Gradient = 2.806260585784912, Adaptive learning rate = 0.001
# ite 261
# ite 262
# ite 263
# ite 264
# ite 265
# Iteration 265: Normalized Gradient = 2.947378396987915, Adaptive learning rate = 0.001
# ite 266
# ite 267
# ite 268
# ite 269
# ite 270
# Iteration 270: Normalized Gradient = 3.102466344833374, Adaptive learning rate = 0.001
# ite 271
# ite 272
# ite 273
# ite 274
# ite 275
# Iteration 275: Normalized Gradient = 3.2511403560638428, Adaptive learning rate = 0.001
# ite 276
# ite 277
# ite 278
# ite 279
# ite 280
# Iteration 280: Normalized Gradient = 3.2767491340637207, Adaptive learning rate = 0.001
# ite 281
# ite 282
# ite 283
# ite 284
# ite 285
# Iteration 285: Normalized Gradient = 3.2149055004119873, Adaptive learning rate = 0.001
# ite 286
# ite 287
# ite 288
# ite 289
# ite 290
# Iteration 290: Normalized Gradient = 3.1474459171295166, Adaptive learning rate = 0.001
# ite 291
# ite 292
# ite 293
# ite 294
# ite 295
# Iteration 295: Normalized Gradient = 3.1721131801605225, Adaptive learning rate = 0.001
# ite 296
# ite 297
# ite 298
# ite 299
# ite 300
# Iteration 300: Normalized Gradient = 3.194303512573242, Adaptive learning rate = 0.001
# ite 301
# ite 302
# ite 303
# ite 304
# ite 305
# Iteration 305: Normalized Gradient = 3.1593189239501953, Adaptive learning rate = 0.001
# ite 306
# ite 307
# ite 308
# ite 309
# ite 310
# Iteration 310: Normalized Gradient = 3.1843643188476562, Adaptive learning rate = 0.001
# ite 311
# ite 312
# ite 313
# ite 314
# ite 315
# Iteration 315: Normalized Gradient = 3.1794583797454834, Adaptive learning rate = 0.001
# ite 316
# ite 317
# ite 318
# ite 319
# ite 320
# Iteration 320: Normalized Gradient = 3.1790010929107666, Adaptive learning rate = 0.001
# ite 321
# ite 322
# ite 323
# ite 324
# ite 325
# Iteration 325: Normalized Gradient = 3.1763288974761963, Adaptive learning rate = 0.001
# ite 326
# Iteration 650: Normalized Gradient = 3.177935838699341, Adaptive learning rate = 0.001
# ite 651
# ite 652
# ite 653
# ite 654
# ite 655
# Iteration 655: Normalized Gradient = 3.1749186515808105, Adaptive learning rate = 0.001
# ite 656
# ite 657
# ite 658
# ite 659
# ite 660
# Iteration 660: Normalized Gradient = 3.179232358932495, Adaptive learning rate = 0.001
# ite 661
# ite 662
# ite 663
# ite 664
# ite 665
# Iteration 665: Normalized Gradient = 3.1756417751312256, Adaptive learning rate = 0.001
# ite 666
# ite 667
# ite 668
# ite 669
# ite 670
# Iteration 670: Normalized Gradient = 3.1795992851257324, Adaptive learning rate = 0.001
# ite 671
# ite 672
# ite 673
# ite 674
# ite 675
# Iteration 675: Normalized Gradient = 3.180438280105591, Adaptive learning rate = 0.001
# ite 676
# ite 677
# ite 678
# ite 679
# ite 680
# Iteration 680: Normalized Gradient = 3.180251359939575, Adaptive learning rate = 0.001
# ite 681
# ite 682
# ite 683
# ite 684
# ite 685
# Iteration 685: Normalized Gradient = 3.181601047515869, Adaptive learning rate = 0.001
# ite 686
# ite 687
# ite 688
# ite 689
# ite 690
# Iteration 690: Normalized Gradient = 3.1763007640838623, Adaptive learning rate = 0.001
# ite 691
# ite 692
# ite 693
# ite 694
# ite 695
# Iteration 695: Normalized Gradient = 3.1820695400238037, Adaptive learning rate = 0.001
# ite 696
# ite 697
# ite 698
# ite 699
# ite 700
# Iteration 700: Normalized Gradient = 3.17653751373291, Adaptive learning rate = 0.001
# ite 701
# ite 702
# ite 703
# ite 704
# ite 705
# Iteration 705: Normalized Gradient = 3.177802085876465, Adaptive learning rate = 0.001
# ite 706
# ite 707
# ite 708
# ite 709
# ite 710
# Iteration 710: Normalized Gradient = 3.176330327987671, Adaptive learning rate = 0.001
# ite 711
# ite 712
# ite 713
# ite 714
# ite 715
# Iteration 715: Normalized Gradient = 3.1865315437316895, Adaptive learning rate = 0.001
# ite 716
# ite 717
# ite 718
# ite 719
# ite 720
# Iteration 720: Normalized Gradient = 3.1708502769470215, Adaptive learning rate = 0.001
# ite 721
# ite 722
# ite 723
# ite 724
# ite 725
# Iteration 725: Normalized Gradient = 3.1831018924713135, Adaptive learning rate = 0.001
# ite 726
# ite 727
# ite 728
# ite 729
# ite 730
# Iteration 730: Normalized Gradient = 3.1769063472747803, Adaptive learning rate = 0.001
# ite 731
# ite 732
# ite 733
# ite 734
# ite 735
# Iteration 735: Normalized Gradient = 3.1777443885803223, Adaptive learning rate = 0.001
# ite 736
# ite 737
# ite 738
# ite 739
# ite 740
# Iteration 740: Normalized Gradient = 3.176041603088379, Adaptive learning rate = 0.001
# ite 741
# ite 742
# ite 743
# ite 744
# ite 745
# Iteration 745: Normalized Gradient = 3.186012029647827, Adaptive learning rate = 0.001
# ite 746
# ite 747
# ite 748
# ite 749
# ite 750
# Iteration 750: Normalized Gradient = 3.1703758239746094, Adaptive learning rate = 0.001
# ite 751
# ite 752
# ite 753
# ite 754
# ite 755
# Iteration 755: Normalized Gradient = 3.1824777126312256, Adaptive learning rate = 0.001
# ite 756
# ite 757
# ite 758
# ite 759
# ite 760
# Iteration 760: Normalized Gradient = 3.1763038635253906, Adaptive learning rate = 0.001
# ite 761
# ite 762
# ite 763
# ite 764
# ite 765
# Iteration 765: Normalized Gradient = 3.1836838722229004, Adaptive learning rate = 0.001
# ite 766
# ite 767
# ite 768
# ite 769
# ite 770
# Iteration 770: Normalized Gradient = 3.1710104942321777, Adaptive learning rate = 0.001
# ite 771
# ite 772
# ite 773
# ite 774
# ite 775
# Iteration 775: Normalized Gradient = 3.180380344390869, Adaptive learning rate = 0.001
# ite 776
# ite 777
# ite 778
# ite 779
# ite 780
# Iteration 780: Normalized Gradient = 3.1836087703704834, Adaptive learning rate = 0.001
# ite 781
# ite 782
# ite 783
# ite 784
# ite 785
# Iteration 785: Normalized Gradient = 3.1773457527160645, Adaptive learning rate = 0.001
# ite 786
# ite 787
# ite 788
# ite 789
# ite 790
# Iteration 790: Normalized Gradient = 3.179539442062378, Adaptive learning rate = 0.001
# ite 791
# ite 792
# ite 793
# ite 794
# ite 795
# Iteration 795: Normalized Gradient = 3.1793856620788574, Adaptive learning rate = 0.001
# ite 796
# ite 797
# ite 798
# ite 799
# ite 800
# Iteration 800: Normalized Gradient = 3.1828770637512207, Adaptive learning rate = 0.001
# ite 801
# ite 802
# ite 803
# ite 804
# ite 805
# Iteration 805: Normalized Gradient = 3.1768078804016113, Adaptive learning rate = 0.001
# ite 806
# ite 807
# ite 808
# ite 809
# ite 810
# Iteration 810: Normalized Gradient = 3.179089307785034, Adaptive learning rate = 0.001
# ite 811
# ite 812
# ite 813
# ite 814
# ite 815
# Iteration 815: Normalized Gradient = 3.1745405197143555, Adaptive learning rate = 0.001
# ite 816
# ite 817
# ite 818
# ite 819
# ite 820
# Iteration 820: Normalized Gradient = 3.184912919998169, Adaptive learning rate = 0.001
# ite 821
# ite 822
# ite 823
# ite 824
# ite 825
# Iteration 825: Normalized Gradient = 3.180055856704712, Adaptive learning rate = 0.001
# ite 826
# ite 827
# ite 828
# ite 829
# ite 830
# Iteration 830: Normalized Gradient = 3.1815967559814453, Adaptive learning rate = 0.001
# ite 831
# ite 832
# ite 833
# ite 834
# ite 835
# Iteration 835: Normalized Gradient = 3.1780612468719482, Adaptive learning rate = 0.001
# ite 836
# ite 837
# ite 838
# ite 839
# ite 840
# Iteration 840: Normalized Gradient = 3.178173303604126, Adaptive learning rate = 0.001
# ite 841
# ite 842
# ite 843
# ite 844
# ite 845
# Iteration 845: Normalized Gradient = 3.1782281398773193, Adaptive learning rate = 0.001
# ite 846
# ite 847
# ite 848
# ite 849
# ite 850
# Iteration 850: Normalized Gradient = 3.1754701137542725, Adaptive learning rate = 0.001
# ite 851
# ite 852
# ite 853
# ite 854
# ite 855
# Iteration 855: Normalized Gradient = 3.184553623199463, Adaptive learning rate = 0.001
# ite 856
# ite 857
# ite 858
# ite 859
# ite 860
# Iteration 860: Normalized Gradient = 3.1768529415130615, Adaptive learning rate = 0.001
# ite 861
# ite 862
# ite 863
# ite 864
# ite 865
# Iteration 865: Normalized Gradient = 3.1808671951293945, Adaptive learning rate = 0.001
# ite 866
# ite 867
# ite 868
# ite 869
# ite 870
# Iteration 870: Normalized Gradient = 3.1780433654785156, Adaptive learning rate = 0.001
# ite 871
# ite 872
# ite 873
# ite 874
# ite 875
# Iteration 875: Normalized Gradient = 3.18153715133667, Adaptive learning rate = 0.001
# ite 876
# ite 877
# ite 878
# ite 879
# ite 880
# Iteration 880: Normalized Gradient = 3.1750245094299316, Adaptive learning rate = 0.001
# ite 881
# ite 882
# ite 883
# ite 884
# ite 885
# Iteration 885: Normalized Gradient = 3.1819310188293457, Adaptive learning rate = 0.001
# ite 886
# ite 887
# ite 888
# ite 889
# ite 890
# Iteration 890: Normalized Gradient = 3.179567575454712, Adaptive learning rate = 0.001
# ite 891
# ite 892
# ite 893
# ite 894
# ite 895
# Iteration 895: Normalized Gradient = 3.178776264190674, Adaptive learning rate = 0.001
# ite 896
# ite 897
# ite 898
# ite 899
# ite 900
# Iteration 900: Normalized Gradient = 3.1755402088165283, Adaptive learning rate = 0.001
# ite 901
# ite 902
# ite 903
# ite 904
# ite 905
# Iteration 905: Normalized Gradient = 3.1842501163482666, Adaptive learning rate = 0.001
# ite 906
# ite 907
# ite 908
# ite 909
# ite 910
# Iteration 910: Normalized Gradient = 3.176443576812744, Adaptive learning rate = 0.001
# ite 911
# ite 912
# ite 913
# ite 914
# ite 915
# Iteration 915: Normalized Gradient = 3.1825475692749023, Adaptive learning rate = 0.001
# ite 916
# ite 917
# ite 918
# ite 919
# ite 920
# Iteration 920: Normalized Gradient = 3.179738998413086, Adaptive learning rate = 0.001
# ite 921
# ite 922
# ite 923
# ite 924
# ite 925
# Iteration 925: Normalized Gradient = 3.1786813735961914, Adaptive learning rate = 0.001
# ite 926
# ite 927
# ite 928
# ite 929
# ite 930
# Iteration 930: Normalized Gradient = 3.179441213607788, Adaptive learning rate = 0.001
# ite 931
# ite 932
# ite 933
# ite 934
# ite 935
# Iteration 935: Normalized Gradient = 3.1784777641296387, Adaptive learning rate = 0.001
# ite 936
# ite 937
# ite 938
# ite 939
# ite 940
# Iteration 940: Normalized Gradient = 3.1792919635772705, Adaptive learning rate = 0.001
# ite 941
# ite 942
# ite 943
# ite 944
# ite 945
# Iteration 945: Normalized Gradient = 3.17836332321167, Adaptive learning rate = 0.001
# ite 946
# ite 947
# ite 948
# ite 949
# ite 950
# Iteration 950: Normalized Gradient = 3.1791956424713135, Adaptive learning rate = 0.001
# ite 951
# ite 952
# ite 953
# ite 954
# ite 955
# Iteration 955: Normalized Gradient = 3.1739320755004883, Adaptive learning rate = 0.001
# ite 956
# ite 957
# ite 958
# ite 959
# ite 960
# Iteration 960: Normalized Gradient = 3.1835734844207764, Adaptive learning rate = 0.001
# ite 961
# ite 962
# ite 963
# ite 964
# ite 965
# Iteration 965: Normalized Gradient = 3.178548574447632, Adaptive learning rate = 0.001
# ite 966
# ite 967
# ite 968
# ite 969
# ite 970
# Iteration 970: Normalized Gradient = 3.177741289138794, Adaptive learning rate = 0.001
# ite 971
# <div>                            <div id="a83bcec7-8310-40cc-8c08-48e064f1c3de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a83bcec7-8310-40cc-8c08-48e064f1c3de")) {                    Plotly.newPlot(                        "a83bcec7-8310-40cc-8c08-48e064f1c3de",                        [{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[0.0,3.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[0.0,3.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,3.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,3.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,3.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[6.0,6.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[6.0,6.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[6.0,6.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[9.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[9.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[0.0,2.999953269958496],"y":[3.0,2.999953031539917],"z":[0.0,1.5012167692184448],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[0.0,2.9999561309814453],"y":[6.0,6.0000433921813965],"z":[0.0,1.5012108087539673],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[3.0,2.999953269958496],"y":[0.0,2.999953031539917],"z":[0.0,1.5012167692184448],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[2.9999561309814453,2.999953269958496],"y":[6.0000433921813965,2.999953031539917],"z":[1.5012108087539673,1.5012167692184448],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[3.0,2.9999561309814453],"y":[9.0,6.0000433921813965],"z":[0.0,1.5012108087539673],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[2.999953269958496,6.0000433921813965],"y":[2.999953031539917,2.999955654144287],"z":[1.5012167692184448,1.501211166381836],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[2.9999561309814453,6.000046730041504],"y":[6.0000433921813965,6.000046730041504],"z":[1.5012108087539673,1.5012164115905762],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[6.0,6.0000433921813965],"y":[0.0,2.999955654144287],"z":[0.0,1.501211166381836],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[6.000046730041504,6.0000433921813965],"y":[6.000046730041504,2.999955654144287],"z":[1.5012164115905762,1.501211166381836],"type":"scat ...

# %%
# ### Plot the optimization history
# fig, ax1 = plt.subplots(figsize=(10, 6))

# color = 'blue'
# ax1.set_xlabel('Iterations')
# ax1.set_ylabel('Loss', color=color)
# ax1.plot(range(epochs + 1), Loss_his, label='Loss History', color=color, linewidth=2)
# ax1.tick_params(axis='y', labelcolor=color)
# ax1.grid(True)

# ax2 = ax1.twinx()
# color = 'red'
# ax2.set_ylabel('Average Displacement', color=color)
# ax2.plot(range(epochs + 1), Disp_his, label='Average Displacement', color=color, linewidth=2, linestyle='--')
# ax2.tick_params(axis='y', labelcolor=color)

# lines1, labels1 = ax1.get_legend_handles_labels()
# lines2, labels2 = ax2.get_legend_handles_labels()
# ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

# plt.title('Loss & Average Displacement vs. Iterations')

# plt.tight_layout()
# plt.show()

# %%
### Displacement Controll -- with 2 qs
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import plotly.graph_objects as go

# q.grad.zero_()


# In[663]:


######################## explanation
## "The example model is based on a 5-nodes grid shell strcuture
##  which has a crossing projection in the x-y plane"
##  The FE part would be based on the Euler-bernoulli beam theory


# In[664]:


## Initial Geom
# Initial Coords:
node_coords = torch.tensor(
    [[0.0, 3.0, 0.0], [0.0, 6.0, 0.0], [3.0, 0.0, 0.0], [3.0, 3.0, 0.0], [3.0, 6.0, 0.0], [3.0, 9.0, 0.0],
     [6.0, 0.0, 0.0], [6.0, 3.0, 0.0], [6.0, 6.0, 0.0] ,[6.0, 9.0, 0.0], [9.0, 3.0 ,0.0], [9.0, 6.0, 0.0]],
    dtype=torch.float32, requires_grad=True, )
connectivity = [[1, 4], [2, 5], [3, 4], [5, 4], [6, 5], [4, 8],[5, 9], [7, 8], [9, 8],[10, 9],[12, 9],[11, 8]]
n_dof_per_node = 6  # Degrees of freedom per node
total_dof = n_dof_per_node * len(node_coords)
Fixed_nodes = [1, 2, 3, 6, 7, 10, 11, 12]
Free_nodes = []
n_elements = len(connectivity)
n_nodes = len(node_coords)
for i in range(1, n_nodes + 1):
    if i not in Fixed_nodes:
        Free_nodes.append(i)
idx_CF = [node - 1 for node in Fixed_nodes]
idx_CN = [i for i in range(n_nodes) if i not in idx_CF]


## Force condition
####### Force condition -> need for modification
## +0 to x direction ; +1 to y direction ; +2 to Z direction
## +3 Bending around the z axis ; +4 bending around y axis ; +5 Twisting
# implement upwards loading of 50 kN at every free nodes
F = torch.zeros(total_dof, dtype=torch.float32)
f_n = Free_nodes
f_type = [2, 2, 2, 2]  # The force type
F_value = torch.tensor([50.0, 50.0, 50.0, 50.0]) * 1000  # The force value/direction
r = 1 / torch.max(F_value)
# print(r)
F_sign = torch.sign(F_value)
for idx, i in enumerate(f_n):
    F[6 * (i - 1) + f_type[idx]] = F_value[idx]  # unit: KN / KN*m

px = torch.zeros(len(f_n), 1, dtype=torch.float32)
py = torch.zeros(len(f_n), 1, dtype=torch.float32)
pz = torch.zeros(len(f_n), 1, dtype=torch.float32)

for i in range(len(f_n)):
    if f_type[idx] == 0:
        px[i] = F_value[i]
    elif f_type[idx] == 1:
        py[i] = F_value[i]
    elif f_type[idx] == 2:
        pz[i] = F_value[i]


## Obtaining Matrix D
# Assembly the nodal-branch matrix:
C = torch.zeros(n_elements, n_nodes, dtype=torch.float32)
for n, (i, j) in enumerate(connectivity):
    C[n, i - 1] = 1
    C[n, j - 1] = -1
CF = C[:, idx_CF]
CN = C[:, idx_CN]


# Assembly D
def FDM (Q,CN=CN, CF=CF, px=px, py=py, pz=pz,Fixed_nodes=Fixed_nodes, Free_nodes=Free_nodes,node_coords=node_coords) :
    Dn = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CN))
    DF = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CF))
    ## Coordinates solution
    # separate the coordinates:
    fixed_idces = [node - 1 for node in Fixed_nodes]
    xF = node_coords[fixed_idces, 0].unsqueeze(1)
    yF = node_coords[fixed_idces, 1].unsqueeze(1)
    zF = node_coords[fixed_idces, 2].unsqueeze(1)
    xN = torch.matmul(torch.inverse(Dn), (px - torch.matmul(DF, xF)))
    yN = torch.matmul(torch.inverse(Dn), (py - torch.matmul(DF, yF)))
    zN = torch.matmul(torch.inverse(Dn), (pz - torch.matmul(DF, zF)))
    ## Coordinates renewal: 
    new_node_coords = node_coords.clone()
    for idx, node in enumerate(Free_nodes):
        node_idx = node - 1
        new_node_coords[node_idx, 0] = xN[idx]
        new_node_coords[node_idx, 1] = yN[idx]
        new_node_coords[node_idx, 2] = zN[idx]

    return new_node_coords

# In[670]:


## Check point: FDM completed
# if q.grad is not None:
#     q.grad.zero_()
# loss = torch.sum(new_node_coords[:, 2])
# loss.backward()
# print("Gradient of q:")
# print(q.grad)


############ Now comes to FE part:
#### Default values (in meters, Pascals, etc.)
## For rectangular sections
# D_width = 0.1
# D_height = 0.2
# D_young_modulus = 210e9  # Young's modulus in Pascals
# D_shear_modulus = 81e9  # Shear modulus in Pascals
# D_poisson_ratio = 0.3
# cross_section_angle_a = 0  # Cross-section angle at node 1 (anti-clockwise)
# cross_section_angle_b = 0  # Cross-section angle at node 2 (anti-clockwise)
# a_small_number = 1e-10

D_radius = 0.05
D_young_modulus = 210e9  # Young's modulus in Pascals
D_shear_modulus = 81e9  # Shear modulus in Pascals
D_poisson_ratio = 0.3
cross_section_angle_a = 0  # Cross-section angle at node 1 (anti-clockwise)
cross_section_angle_b = 0  # Cross-section angle at node 2 (anti-clockwise)
a_small_number = 1e-10


# In[673]:


def rotation(v, k, theta):
    """Rotation of vector v around axis k by angle theta."""
    k = k / torch.norm(k)  # Normalize k
    cross_product = torch.cross(k, v)
    dot_product = torch.dot(k, v)

    # Ensure theta is a tensor
    theta = torch.tensor(theta, dtype=torch.float32) if not isinstance(theta, torch.Tensor) else theta

    v_rotated = v * torch.cos(theta) + cross_product * torch.sin(theta) + k * dot_product * (1 - torch.cos(theta))
    return v_rotated


# In[674]:


###### Element Creating (euler beam)
# For rectangular sections
# class Beam:
#     def __init__(self, node_coordinates, width=D_width, height=D_height, young_modulus=D_young_modulus,
#                  shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
#                  Beta_b=cross_section_angle_b):
#         self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

#         # Material and geometry
#         self.width = width
#         self.height = height
#         self.young_modulus = young_modulus
#         self.shear_modulus = shear_modulus
#         self.poisson_ratio = poisson_ratio

#         # Cross-sectional properties
#         self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
#         self.Iy = (self.width * self.height ** 3) / 12
#         self.Iz = (self.width ** 3 * self.height) / 12
#         self.A = self.width * self.height
#         self.J = (self.width * self.height ** 3) / 3

#         # Stiffness components
#         self.S_u = self.young_modulus * self.A / self.length
#         self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
#         self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
#         self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
#         self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
#         self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
#         self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
#         self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
#         self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
#         self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
#         self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
#         self.S_Tr = self.shear_modulus * self.J / self.length

#         # Section rotations at the two ends
#         self.Beta_a = Beta_a
#         self.Beta_b = Beta_b


# In[675]:


# For circular sections
class Beam:
    def __init__(self, node_coordinates, R=D_radius, young_modulus=D_young_modulus,
                 shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                 Beta_b=cross_section_angle_b):
        self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

        # Material and geometry
        self.radius = R
        self.young_modulus = young_modulus
        self.shear_modulus = shear_modulus
        self.poisson_ratio = poisson_ratio

        # Cross-sectional properties
        self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
        self.Iy = (torch.pi * self.radius ** 4) / 4 
        self.Iz = self.Iy
        self.A = torch.pi * self.radius ** 2
        self.J = (torch.pi * self.radius ** 4) / 2

        # Stiffness components
        self.S_u = self.young_modulus * self.A / self.length
        self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
        self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
        self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
        self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
        self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
        self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
        self.S_Tr = self.shear_modulus * self.J / self.length

        # Section rotations at the two ends
        self.Beta_a = Beta_a
        self.Beta_b = Beta_b

    def get_element_stiffness_matrix(self):
        """Element stiffness matrix."""
        K_element = torch.tensor([
            [self.S_u, 0, 0, 0, 0, 0, -self.S_u, 0, 0, 0, 0, 0],
            [0, self.S_v1a, 0, 0, 0, self.S_theta1a, 0, -self.S_v1a, 0, 0, 0, self.S_theta1a],
            [0, 0, self.S_v2a, 0, -self.S_theta2a, 0, 0, 0, -self.S_v2a, 0, -self.S_theta2a, 0],
            [0, 0, 0, self.S_Tr, 0, 0, 0, 0, 0, -self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2b, 0, 0, 0, self.S_v2b, 0, self.S_theta2c, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1b, 0, -self.S_v1b, 0, 0, 0, self.S_theta1c],
            [-self.S_u, 0, 0, 0, 0, 0, self.S_u, 0, 0, 0, 0, 0],
            [0, -self.S_v1a, 0, 0, 0, -self.S_theta1a, 0, self.S_v1a, 0, 0, 0, -self.S_theta1a],
            [0, 0, -self.S_v2a, 0, self.S_theta2a, 0, 0, 0, self.S_v2a, 0, self.S_theta2a, 0],
            [0, 0, 0, -self.S_Tr, 0, 0, 0, 0, 0, self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2c, 0, 0, 0, self.S_v2b, 0, self.S_theta2b, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1c, 0, -self.S_v1b, 0, 0, 0, self.S_theta1b],
        ], dtype=torch.float32)

        return K_element

    def System_Transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        # print(vector_x,vector_y,vector_z)
        # Calculate alpha and ceta using PyTorch
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)
        # print(alpha)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)

        # Z_axis_b = rotation(V_projection, X_axis, self.Beta_b)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        # Y_axis_b = rotation(Z_axis_b, X_axis, torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        # Z_axis_b = Z_axis_b / torch.norm(Z_axis_b)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)
        # Y_axis_b = Y_axis_b / torch.norm(Y_axis_b)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)
        matrix_T = torch.zeros((12, 12), dtype=torch.float32)
        for i in range(0, 12, 3):
            matrix_T[i:i + 3, i:i + 3] = lambda_matrix
        return matrix_T

    def nodal_transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        # Calculate alpha and ceta using PyTorch
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)

        # Z_axis_b = rotation(V_projection, X_axis, self.Beta_b)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        # Y_axis_b = rotation(Z_axis_b, X_axis, torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        # Z_axis_b = Z_axis_b / torch.norm(Z_axis_b)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)
        # Y_axis_b = Y_axis_b / torch.norm(Y_axis_b)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)

        return lambda_matrix


# In[676]:


def assemble_stiffness_matrix(beams, n_nodes, n_dof_per_node, connectivity):
    """Global stiffness matrix assembly."""
    total_dof = n_nodes * n_dof_per_node  # Total degrees of freedom
    K_global = torch.zeros((total_dof, total_dof), dtype=torch.float32)
    for idx, (i, j) in enumerate(connectivity):
        Matrix_T = beams[idx].System_Transform()  # Get transformation matrix

        K_element = torch.matmul(torch.transpose(Matrix_T, 0, 1),
                                 torch.matmul(beams[idx].get_element_stiffness_matrix(), Matrix_T))

        start_idx = (i - 1) * n_dof_per_node
        end_idx = (j - 1) * n_dof_per_node
        K_global[start_idx:start_idx + 6, start_idx:start_idx + 6] = K_global[start_idx:start_idx + 6,
                                                                     start_idx:start_idx + 6] + K_element[0:6, 0:6]
        K_global[end_idx:end_idx + 6, end_idx:end_idx + 6] = K_global[end_idx:end_idx + 6,
                                                             end_idx:end_idx + 6] + K_element[6:12, 6:12]
        K_global[start_idx:start_idx + 6, end_idx:end_idx + 6] = K_global[start_idx:start_idx + 6,
                                                                 end_idx:end_idx + 6] + K_element[0:6, 6:12]
        K_global[end_idx:end_idx + 6, start_idx:start_idx + 6] = K_global[end_idx:end_idx + 6,
                                                                 start_idx:start_idx + 6] + K_element[6:12, 0:6]

    return K_global


# In[677]:


def Strain_E(node_coords, connectivity, fixed_dof, F):
    # node_coords[:, 2] = 0.0
    # Element Assembly
    beams = []
    for connection in connectivity:
        node_1_coords = node_coords[connection[0] - 1]
        node_2_coords = node_coords[connection[1] - 1]
        beam = Beam(node_coordinates=torch.stack([node_1_coords, node_2_coords]),
                    R=D_radius, young_modulus=D_young_modulus,
                    shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                    Beta_b=cross_section_angle_b)
        beams.append(beam)
    # Stiffness renewal
    K_global = assemble_stiffness_matrix(beams, n_nodes=len(node_coords), n_dof_per_node=6, connectivity=connectivity)
    K_global[fixed_dof, :] = K_global[fixed_dof, :] - K_global[fixed_dof, :]
    K_global[:, fixed_dof] = K_global[:, fixed_dof] - K_global[:, fixed_dof]
    K_global[fixed_dof, fixed_dof] = 1e5
    rank_K = torch.linalg.matrix_rank(K_global)

    if rank_K < K_global.shape[0]:
        print("Warning: The stiffness matrix is not of full rank")
    else:
        displacements = torch.linalg.solve(K_global, F)

    # Compute strain energy
    strain_energy_list = []
    Local_d = torch.zeros(len(connectivity), 12, dtype=torch.float32)
    for n, (i, j) in enumerate(connectivity):
        matrix_T = beams[n].System_Transform()
        Tep_displacements = torch.cat(
            [displacements[6 * (i - 1):6 * (i - 1) + 6], displacements[6 * (j - 1):6 * (j - 1) + 6]], dim=0)
        Local_d_n = torch.matmul(Tep_displacements, matrix_T.T)
        Local_d[n, :] = Local_d_n.clone()
        K_g = torch.matmul(torch.transpose(matrix_T, 0, 1),
                           torch.matmul(beams[n].get_element_stiffness_matrix(), matrix_T))

        strain_energy_list.append(torch.matmul(Local_d_n, torch.matmul(K_g, Local_d_n.reshape(-1, 1))))

    Strain_energy = torch.stack(strain_energy_list)

    return Strain_energy, Local_d, displacements, beams


# In[678]:


# Element creating
#################  input below:
############################################################################################################## input
# initial coordinates

####### BCs
fixed_dof = []
for node in Fixed_nodes:
    fixed_dof.extend([(node - 1) * 6 + i for i in range(6)])
# print(fixed_dof)
####### Gradient descent
step = 0.001
epochs = 800
# Obj_coords = 15
####### Plotting
steps = 20  # steps for tracing deformation shape
###################################################################################################################################################
###################################################################################################################################################


# In[679]:

# Optimized Variables
## initial variables
Idx_q1 = [3, 4, 5, 8, 9, 10]
Idx_q2 = [1, 6, 11, 2, 7, 12]
Idx_q1 = [i - 1 for i in Idx_q1] 
Idx_q2 = [i - 1 for i in Idx_q2] 
q = torch.rand(2, requires_grad=True)
## Optimization
torch.autograd.set_detect_anomaly(True)
# Optimizer setting
optimizer = optim.Adam([q], lr=step)
# Initilizing
# New_Coordinates = torch.zeros(n_nodes * 3, dtype=torch.float32)
# Loss_his = []
Disp_his = []
patience = 5
count = 0

# Loop start
for iteration in range(epochs + 1):
    print('ite',iteration)
    # Forwards
    q_vec = torch.zeros(n_elements, requires_grad=True).clone()
    q_vec[Idx_q1] = q[0] 
    q_vec[Idx_q2] = q[1]
    Q = torch.diag(q_vec) * 1 / r  # scaling
    new_node_coords = FDM(Q)
    if iteration == 0:
        print(new_node_coords)
    N_coords = new_node_coords.clone()
    Strain_energy, _, displacements, _ = Strain_E(N_coords, connectivity, fixed_dof, F)
    idx = 6 * torch.arange(n_nodes) + 2
    Ave_Disp = abs(torch.sum(displacements[idx] / len(Free_nodes)))
    Disp_his.append(Ave_Disp.item())
    if iteration > 0:  
        previous_Ave_Disp = Disp_his[iteration - 1]  
        change = abs(Ave_Disp - previous_Ave_Disp) / previous_Ave_Disp  
        if change < 1/1000:
            count += 1
        else:
            count = 0 
        if count >= patience:
            print(f"Early stopping at iteration {iteration}: Ave_Disp change < 1% for {patience} consecutive iterations.")
            break 
    N_coords = N_coords.reshape(-1)
    New_Coordinates = torch.zeros(n_nodes * 3, dtype=torch.float32)
    for n in range(n_nodes):
        New_Coordinates[3*n : 3*n+3] = N_coords[3*n : 3*n+3] + displacements[6*n : 6*n+3]
    New_Coordinates = New_Coordinates.view(n_nodes, 3).clone()
#     AVE = Average_height(Free_nodes, New_Coordinates)
#     print("Average height",AVE)
#     # loss
#     Loss = torch.norm(AVE - Obj_coords)
#     Loss_his.append(Loss.item())
    # Backwards
    optimizer.zero_grad()
    # print(q.grad)
    Ave_Disp.backward(retain_graph=True)

    # Grad
    gradients = q.grad
    print('Grad',gradients)
    frob_norm = torch.norm(gradients)
    optimizer.step()
    
    # print iteration
    if iteration % 5 == 0:
        print(f"Iteration {iteration}: Normalized Gradient = {frob_norm}, Adaptive learning rate = {step}")
print("Optimization completed.")
print(q)
# print("coordinates:",node_coords)

#############################################################################################################
## Visualization
# print(Coordinates)
# displacements = Strain_E(node_coords, connectivity, fixed_dof, F)[2]
# print("displacements:", displacements)
print("Deformed:", New_Coordinates)

x_orig = node_coords[:, 0].detach().numpy()
y_orig = node_coords[:, 1].detach().numpy()
z_orig = node_coords[:, 2].detach().numpy()

x_def = New_Coordinates[:, 0].detach().numpy()
y_def = New_Coordinates[:, 1].detach().numpy()
z_def = New_Coordinates[:, 2].detach().numpy()


fig = go.Figure()


for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_orig[i-1], x_orig[j-1]],
        y=[y_orig[i-1], y_orig[j-1]],
        z=[z_orig[i-1], z_orig[j-1]],
        mode='lines',
        line=dict(color='blue', width=4),
        name='Original Geometry'
    ))


for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_def[i-1], x_def[j-1]],
        y=[y_def[i-1], y_def[j-1]],
        z=[z_def[i-1], z_def[j-1]],
        mode='lines',
        line=dict(color='red', width=4),
        name='Deformed Geometry'
    ))


for node in Free_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_def[node-1]],
        y=[y_def[node-1]],
        z=[z_def[node-1]],
        mode='markers+text',
        marker=dict(size=5, color='green'),
        text=[f'Node {node}'],
        textposition='top center',
        name=f'Free Node {node}'
    ))


fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        aspectmode='data'
    ),
    title='Deformation Comparison: Original vs. Deformed Geometry (FE Analysis)',
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()

########################################################################################################################

### Plot the optimization history
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'red'
ax1.set_xlabel('Iterations')
ax1.set_ylabel('Average Displacement', color=color)
ax1.plot(range(len(Disp_his)), Disp_his, label='Average Displacement', color=color, linewidth=2, linestyle='--')
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True)

lines1, labels1 = ax1.get_legend_handles_labels()
ax1.legend(lines1, labels1, loc='upper right')

plt.title('Loss & Average Displacement vs. Iterations')

plt.tight_layout()
plt.show()
# Out:
# ite 0
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.5721],
#         [3.0000, 6.0000, 0.5721],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.5721],
#         [6.0000, 6.0000, 0.5721],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Grad tensor([0.0021, 0.0021])
# Iteration 0: Normalized Gradient = 0.0029576008673757315, Adaptive learning rate = 0.001
# ite 1
# Grad tensor([0.0021, 0.0021])
# ite 2
# Grad tensor([0.0021, 0.0021])
# ite 3
# Grad tensor([0.0021, 0.0021])
# ite 4
# Grad tensor([0.0021, 0.0021])
# ite 5
# Grad tensor([0.0021, 0.0021])
# Iteration 5: Normalized Gradient = 0.0029423402156680822, Adaptive learning rate = 0.001
# ite 6
# Grad tensor([0.0021, 0.0021])
# ite 7
# Grad tensor([0.0021, 0.0021])
# ite 8
# Grad tensor([0.0021, 0.0021])
# ite 9
# Grad tensor([0.0021, 0.0021])
# ite 10
# Grad tensor([0.0021, 0.0021])
# Iteration 10: Normalized Gradient = 0.002927070017904043, Adaptive learning rate = 0.001
# ite 11
# Grad tensor([0.0021, 0.0021])
# ite 12
# Grad tensor([0.0021, 0.0021])
# ite 13
# Grad tensor([0.0021, 0.0021])
# ite 14
# Grad tensor([0.0021, 0.0021])
# ite 15
# Grad tensor([0.0021, 0.0021])
# Iteration 15: Normalized Gradient = 0.0029117953963577747, Adaptive learning rate = 0.001
# ite 16
# Grad tensor([0.0021, 0.0021])
# ite 17
# Grad tensor([0.0021, 0.0021])
# ite 18
# Grad tensor([0.0021, 0.0021])
# ite 19
# Grad tensor([0.0021, 0.0021])
# ite 20
# Grad tensor([0.0020, 0.0020])
# Iteration 20: Normalized Gradient = 0.002896522171795368, Adaptive learning rate = 0.001
# ite 21
# Grad tensor([0.0020, 0.0020])
# ite 22
# Grad tensor([0.0020, 0.0020])
# ite 23
# Grad tensor([0.0020, 0.0020])
# ite 24
# Grad tensor([0.0020, 0.0020])
# ite 25
# Grad tensor([0.0020, 0.0020])
# Iteration 25: Normalized Gradient = 0.0028812552336603403, Adaptive learning rate = 0.001
# ite 26
# Grad tensor([0.0020, 0.0020])
# ite 27
# Grad tensor([0.0020, 0.0020])
# ite 28
# Grad tensor([0.0020, 0.0020])
# ite 29
# Grad tensor([0.0020, 0.0020])
# ite 30
# Grad tensor([0.0020, 0.0020])
# Iteration 30: Normalized Gradient = 0.0028660022653639317, Adaptive learning rate = 0.001
# ite 31
# Grad tensor([0.0020, 0.0020])
# ite 32
# Grad tensor([0.0020, 0.0020])
# ite 33
# Grad tensor([0.0020, 0.0020])
# ite 34
# Grad tensor([0.0020, 0.0020])
# ite 35
# Grad tensor([0.0020, 0.0020])
# Iteration 35: Normalized Gradient = 0.0028507611714303493, Adaptive learning rate = 0.001
# ite 36
# Grad tensor([0.0020, 0.0020])
# ite 37
# Grad tensor([0.0020, 0.0020])
# ite 38
# Grad tensor([0.0020, 0.0020])
# ite 39
# Grad tensor([0.0020, 0.0020])
# ite 40
# Grad tensor([0.0020, 0.0020])
# Iteration 40: Normalized Gradient = 0.0028355405665934086, Adaptive learning rate = 0.001
# ite 41
# Grad tensor([0.0020, 0.0020])
# ite 42
# Grad tensor([0.0020, 0.0020])
# ite 43
# Grad tensor([0.0020, 0.0020])
# ite 44
# Grad tensor([0.0020, 0.0020])
# ite 45
# Grad tensor([0.0020, 0.0020])
# Iteration 45: Normalized Gradient = 0.0028203383553773165, Adaptive learning rate = 0.001
# ite 46
# Grad tensor([0.0020, 0.0020])
# ite 47
# Grad tensor([0.0020, 0.0020])
# ite 48
# Grad tensor([0.0020, 0.0020])
# ite 49
# Grad tensor([0.0020, 0.0020])
# ite 50
# Grad tensor([0.0020, 0.0020])
# Iteration 50: Normalized Gradient = 0.002805159194394946, Adaptive learning rate = 0.001
# ite 51
# Grad tensor([0.0020, 0.0020])
# ite 52
# Grad tensor([0.0020, 0.0020])
# ite 53
# Grad tensor([0.0020, 0.0020])
# ite 54
# Grad tensor([0.0020, 0.0020])
# ite 55
# Grad tensor([0.0020, 0.0020])
# Iteration 55: Normalized Gradient = 0.0027900002896785736, Adaptive learning rate = 0.001
# ite 56
# Grad tensor([0.0020, 0.0020])
# ite 57
# Grad tensor([0.0020, 0.0020])
# ite 58
# Grad tensor([0.0020, 0.0020])
# ite 59
# Grad tensor([0.0020, 0.0020])
# ite 60
# Grad tensor([0.0020, 0.0020])
# Iteration 60: Normalized Gradient = 0.0027748660650104284, Adaptive learning rate = 0.001
# ite 61
# Grad tensor([0.0020, 0.0020])
# ite 62
# Grad tensor([0.0020, 0.0020])
# ite 63
# Grad tensor([0.0020, 0.0020])
# ite 64
# Grad tensor([0.0020, 0.0020])
# ite 65
# Grad tensor([0.0020, 0.0020])
# Iteration 65: Normalized Gradient = 0.002759756986051798, Adaptive learning rate = 0.001
# ite 66
# Grad tensor([0.0019, 0.0019])
# ite 67
# Grad tensor([0.0019, 0.0019])
# ite 68
# Grad tensor([0.0019, 0.0019])
# ite 69
# Grad tensor([0.0019, 0.0019])
# ite 70
# Grad tensor([0.0019, 0.0019])
# Iteration 70: Normalized Gradient = 0.0027446714229881763, Adaptive learning rate = 0.001
# ite 71
# Grad tensor([0.0019, 0.0019])
# ite 72
# Grad tensor([0.0019, 0.0019])
# ite 73
# Grad tensor([0.0019, 0.0019])
# ite 74
# Grad tensor([0.0019, 0.0019])
# ite 75
# Grad tensor([0.0019, 0.0019])
# Iteration 75: Normalized Gradient = 0.002729613333940506, Adaptive learning rate = 0.001
# ite 76
# Grad tensor([0.0019, 0.0019])
# ite 77
# Grad tensor([0.0019, 0.0019])
# ite 78
# Grad tensor([0.0019, 0.0019])
# ite 79
# Grad tensor([0.0019, 0.0019])
# ite 80
# Grad tensor([0.0019, 0.0019])
# Iteration 80: Normalized Gradient = 0.002714580623432994, Adaptive learning rate = 0.001
# ite 81
# Grad tensor([0.0019, 0.0019])
# ite 82
# Grad tensor([0.0019, 0.0019])
# ite 83
# Grad tensor([0.0019, 0.0019])
# ite 84
# Grad tensor([0.0019, 0.0019])
# ite 85
# Grad tensor([0.0019, 0.0019])
# Iteration 85: Normalized Gradient = 0.002699573989957571, Adaptive learning rate = 0.001
# ite 86
# Grad tensor([0.0019, 0.0019])
# ite 87
# Grad tensor([0.0019, 0.0019])
# ite 88
# Grad tensor([0.0019, 0.0019])
# ite 89
# Grad tensor([0.0019, 0.0019])
# ite 90
# Grad tensor([0.0019, 0.0019])
# Iteration 90: Normalized Gradient = 0.0026845962274819613, Adaptive learning rate = 0.001
# ite 91
# Grad tensor([0.0019, 0.0019])
# ite 92
# Grad tensor([0.0019, 0.0019])
# ite 93
# Grad tensor([0.0019, 0.0019])
# ite 94
# Grad tensor([0.0019, 0.0019])
# ite 95
# Grad tensor([0.0019, 0.0019])
# Iteration 95: Normalized Gradient = 0.0026696447748690844, Adaptive learning rate = 0.001
# ite 96
# Grad tensor([0.0019, 0.0019])
# ite 97
# Grad tensor([0.0019, 0.0019])
# ite 98
# Grad tensor([0.0019, 0.0019])
# ite 99
# Grad tensor([0.0019, 0.0019])
# ite 100
# Grad tensor([0.0019, 0.0019])
# Iteration 100: Normalized Gradient = 0.0026547207962721586, Adaptive learning rate = 0.001
# ite 101
# Grad tensor([0.0019, 0.0019])
# ite 102
# Grad tensor([0.0019, 0.0019])
# ite 103
# Grad tensor([0.0019, 0.0019])
# ite 104
# Grad tensor([0.0019, 0.0019])
# ite 105
# Grad tensor([0.0019, 0.0019])
# Iteration 105: Normalized Gradient = 0.0026398259215056896, Adaptive learning rate = 0.001
# ite 106
# Grad tensor([0.0019, 0.0019])
# ite 107
# Grad tensor([0.0019, 0.0019])
# ite 108
# Grad tensor([0.0019, 0.0019])
# ite 109
# Grad tensor([0.0019, 0.0019])
# ite 110
# Grad tensor([0.0019, 0.0019])
# Iteration 110: Normalized Gradient = 0.0026249587535858154, Adaptive learning rate = 0.001
# ite 111
# Grad tensor([0.0019, 0.0019])
# ite 112
# Grad tensor([0.0019, 0.0019])
# ite 113
# Grad tensor([0.0018, 0.0018])
# ite 114
# Grad tensor([0.0018, 0.0018])
# ite 115
# Grad tensor([0.0018, 0.0018])
# Iteration 115: Normalized Gradient = 0.0026101202238351107, Adaptive learning rate = 0.001
# ite 116
# Grad tensor([0.0018, 0.0018])
# ite 117
# Grad tensor([0.0018, 0.0018])
# ite 118
# Grad tensor([0.0018, 0.0018])
# ite 119
# Grad tensor([0.0018, 0.0018])
# ite 120
# Grad tensor([0.0018, 0.0018])
# Iteration 120: Normalized Gradient = 0.0025953114964067936, Adaptive learning rate = 0.001
# ite 121
# Grad tensor([0.0018, 0.0018])
# ite 122
# Grad tensor([0.0018, 0.0018])
# ite 123
# Grad tensor([0.0018, 0.0018])
# ite 124
# Grad tensor([0.0018, 0.0018])
# ite 125
# Grad tensor([0.0018, 0.0018])
# Iteration 125: Normalized Gradient = 0.002580532804131508, Adaptive learning rate = 0.001
# ite 126
# Grad tensor([0.0018, 0.0018])
# ite 127
# Grad tensor([0.0018, 0.0018])
# ite 128
# Grad tensor([0.0018, 0.0018])
# ite 129
# Grad tensor([0.0018, 0.0018])
# ite 130
# Grad tensor([0.0018, 0.0018])
# Iteration 130: Normalized Gradient = 0.002565784379839897, Adaptive learning rate = 0.001
# ite 131
# Grad tensor([0.0018, 0.0018])
# ite 132
# Grad tensor([0.0018, 0.0018])
# ite 133
# Grad tensor([0.0018, 0.0018])
# ite 134
# Grad tensor([0.0018, 0.0018])
# ite 135
# Grad tensor([0.0018, 0.0018])
# Iteration 135: Normalized Gradient = 0.002551064593717456, Adaptive learning rate = 0.001
# ite 136
# Grad tensor([0.0018, 0.0018])
# ite 137
# Grad tensor([0.0018, 0.0018])
# ite 138
# Grad tensor([0.0018, 0.0018])
# ite 139
# Grad tensor([0.0018, 0.0018])
# ite 140
# Grad tensor([0.0018, 0.0018])
# Iteration 140: Normalized Gradient = 0.0025363792665302753, Adaptive learning rate = 0.001
# ite 141
# Grad tensor([0.0018, 0.0018])
# ite 142
# Grad tensor([0.0018, 0.0018])
# ite 143
# Grad tensor([0.0018, 0.0018])
# ite 144
# Grad tensor([0.0018, 0.0018])
# ite 145
# Grad tensor([0.0018, 0.0018])
# Iteration 145: Normalized Gradient = 0.0025217202492058277, Adaptive learning rate = 0.001
# ite 146
# Grad tensor([0.0018, 0.0018])
# ite 147
# Grad tensor([0.0018, 0.0018])
# ite 148
# Grad tensor([0.0018, 0.0018])
# ite 149
# Grad tensor([0.0018, 0.0018])
# ite 150
# Grad tensor([0.0018, 0.0018])
# Iteration 150: Normalized Gradient = 0.002507095457985997, Adaptive learning rate = 0.001
# ite 151
# Grad tensor([0.0018, 0.0018])
# ite 152
# Grad tensor([0.0018, 0.0018])
# ite 153
# Grad tensor([0.0018, 0.0018])
# ite 154
# Grad tensor([0.0018, 0.0018])
# ite 155
# Grad tensor([0.0018, 0.0018])
# Iteration 155: Normalized Gradient = 0.00249250209890306, Adaptive learning rate = 0.001
# ite 156
# Grad tensor([0.0018, 0.0018])
# ite 157
# Grad tensor([0.0018, 0.0018])
# ite 158
# Grad tensor([0.0018, 0.0018])
# ite 159
# Grad tensor([0.0018, 0.0018])
# ite 160
# Grad tensor([0.0018, 0.0018])
# Iteration 160: Normalized Gradient = 0.0024779399391263723, Adaptive learning rate = 0.001
# ite 161
# Grad tensor([0.0018, 0.0018])
# ite 162
# Grad tensor([0.0017, 0.0017])
# ite 163
# Grad tensor([0.0017, 0.0017])
# ite 164
# Grad tensor([0.0017, 0.0017])
# ite 165
# Grad tensor([0.0017, 0.0017])
# Iteration 165: Normalized Gradient = 0.002463412005454302, Adaptive learning rate = 0.001
# ite 166
# Grad tensor([0.0017, 0.0017])
# ite 167
# Grad tensor([0.0017, 0.0017])
# ite 168
# Grad tensor([0.0017, 0.0017])
# ite 169
# Grad tensor([0.0017, 0.0017])
# ite 170
# Grad tensor([0.0017, 0.0017])
# Iteration 170: Normalized Gradient = 0.0024489157367497683, Adaptive learning rate = 0.001
# ite 171
# Grad tensor([0.0017, 0.0017])
# ite 172
# Grad tensor([0.0017, 0.0017])
# ite 173
# Grad tensor([0.0017, 0.0017])
# ite 174
# Grad tensor([0.0017, 0.0017])
# ite 175
# Grad tensor([0.0017, 0.0017])
# Iteration 175: Normalized Gradient = 0.0024344518315047026, Adaptive learning rate = 0.001
# ite 176
# Grad tensor([0.0017, 0.0017])
# ite 177
# Grad tensor([0.0017, 0.0017])
# ite 178
# Grad tensor([0.0017, 0.0017])
# ite 179
# Grad tensor([0.0017, 0.0017])
# ite 180
# Grad tensor([0.0017, 0.0017])
# Iteration 180: Normalized Gradient = 0.0024200226180255413, Adaptive learning rate = 0.001
# ite 181
# Grad tensor([0.0017, 0.0017])
# ite 182
# Grad tensor([0.0017, 0.0017])
# ite 183
# Grad tensor([0.0017, 0.0017])
# ite 184
# Grad tensor([0.0017, 0.0017])
# ite 185
# Grad tensor([0.0017, 0.0017])
# Iteration 185: Normalized Gradient = 0.002405626466497779, Adaptive learning rate = 0.001
# ite 186
# Grad tensor([0.0017, 0.0017])
# ite 187
# Grad tensor([0.0017, 0.0017])
# ite 188
# Grad tensor([0.0017, 0.0017])
# ite 189
# Grad tensor([0.0017, 0.0017])
# ite 190
# Grad tensor([0.0017, 0.0017])
# Iteration 190: Normalized Gradient = 0.0023912647739052773, Adaptive learning rate = 0.001
# ite 191
# Grad tensor([0.0017, 0.0017])
# ite 192
# Grad tensor([0.0017, 0.0017])
# ite 193
# Grad tensor([0.0017, 0.0017])
# ite 194
# Grad tensor([0.0017, 0.0017])
# ite 195
# Grad tensor([0.0017, 0.0017])
# Iteration 195: Normalized Gradient = 0.0023769368417561054, Adaptive learning rate = 0.001
# ite 196
# Grad tensor([0.0017, 0.0017])
# ite 197
# Grad tensor([0.0017, 0.0017])
# ite 198
# Grad tensor([0.0017, 0.0017])
# ite 199
# Grad tensor([0.0017, 0.0017])
# ite 200
# Grad tensor([0.0017, 0.0017])
# Iteration 200: Normalized Gradient = 0.0023626440670341253, Adaptive learning rate = 0.001
# ite 201
# Grad tensor([0.0017, 0.0017])
# ite 202
# Grad tensor([0.0017, 0.0017])
# ite 203
# Grad tensor([0.0017, 0.0017])
# ite 204
# Grad tensor([0.0017, 0.0017])
# ite 205
# Grad tensor([0.0017, 0.0017])
# Iteration 205: Normalized Gradient = 0.0023483873810619116, Adaptive learning rate = 0.001
# ite 206
# Grad tensor([0.0017, 0.0017])
# ite 207
# Grad tensor([0.0017, 0.0017])
# ite 208
# Grad tensor([0.0017, 0.0017])
# ite 209
# Grad tensor([0.0017, 0.0017])
# ite 210
# Grad tensor([0.0017, 0.0017])
# Iteration 210: Normalized Gradient = 0.0023341658525168896, Adaptive learning rate = 0.001
# ite 211
# Grad tensor([0.0016, 0.0016])
# ite 212
# Grad tensor([0.0016, 0.0016])
# ite 213
# Grad tensor([0.0016, 0.0016])
# ite 214
# Grad tensor([0.0016, 0.0016])
# ite 215
# Grad tensor([0.0016, 0.0016])
# Iteration 215: Normalized Gradient = 0.0023199780844151974, Adaptive learning rate = 0.001
# ite 216
# Grad tensor([0.0016, 0.0016])
# ite 217
# Grad tensor([0.0016, 0.0016])
# ite 218
# Grad tensor([0.0016, 0.0016])
# ite 219
# Grad tensor([0.0016, 0.0016])
# ite 220
# Grad tensor([0.0016, 0.0016])
# Iteration 220: Normalized Gradient = 0.0023058305960148573, Adaptive learning rate = 0.001
# ite 221
# Grad tensor([0.0016, 0.0016])
# ite 222
# Grad tensor([0.0016, 0.0016])
# ite 223
# Grad tensor([0.0016, 0.0016])
# ite 224
# Grad tensor([0.0016, 0.0016])
# ite 225
# Grad tensor([0.0016, 0.0016])
# Iteration 225: Normalized Gradient = 0.002291715005412698, Adaptive learning rate = 0.001
# ite 226
# Grad tensor([0.0016, 0.0016])
# ite 227
# Grad tensor([0.0016, 0.0016])
# ite 228
# Grad tensor([0.0016, 0.0016])
# ite 229
# Grad tensor([0.0016, 0.0016])
# ite 230
# Grad tensor([0.0016, 0.0016])
# Iteration 230: Normalized Gradient = 0.0022776394616812468, Adaptive learning rate = 0.001
# ite 231
# Grad tensor([0.0016, 0.0016])
# ite 232
# Grad tensor([0.0016, 0.0016])
# ite 233
# Grad tensor([0.0016, 0.0016])
# ite 234
# Grad tensor([0.0016, 0.0016])
# ite 235
# Grad tensor([0.0016, 0.0016])
# Iteration 235: Normalized Gradient = 0.0022635983768850565, Adaptive learning rate = 0.001
# ite 236
# Grad tensor([0.0016, 0.0016])
# ite 237
# Grad tensor([0.0016, 0.0016])
# ite 238
# Grad tensor([0.0016, 0.0016])
# ite 239
# Grad tensor([0.0016, 0.0016])
# ite 240
# Grad tensor([0.0016, 0.0016])
# Iteration 240: Normalized Gradient = 0.002249597106128931, Adaptive learning rate = 0.001
# ite 241
# Grad tensor([0.0016, 0.0016])
# ite 242
# Grad tensor([0.0016, 0.0016])
# ite 243
# Grad tensor([0.0016, 0.0016])
# ite 244
# Grad tensor([0.0016, 0.0016])
# ite 245
# Grad tensor([0.0016, 0.0016])
# Iteration 245: Normalized Gradient = 0.0022356316912919283, Adaptive learning rate = 0.001
# ite 246
# Grad tensor([0.0016, 0.0016])
# ite 247
# Grad tensor([0.0016, 0.0016])
# ite 248
# Grad tensor([0.0016, 0.0016])
# ite 249
# Grad tensor([0.0016, 0.0016])
# ite 250
# Grad tensor([0.0016, 0.0016])
# Iteration 250: Normalized Gradient = 0.0022217039950191975, Adaptive learning rate = 0.001
# ite 251
# Grad tensor([0.0016, 0.0016])
# ite 252
# Grad tensor([0.0016, 0.0016])
# ite 253
# Grad tensor([0.0016, 0.0016])
# ite 254
# Grad tensor([0.0016, 0.0016])
# ite 255
# Grad tensor([0.0016, 0.0016])
# Iteration 255: Normalized Gradient = 0.002207816345617175, Adaptive learning rate = 0.001
# ite 256
# Grad tensor([0.0016, 0.0016])
# ite 257
# Grad tensor([0.0016, 0.0016])
# ite 258
# Grad tensor([0.0016, 0.0016])
# ite 259
# Grad tensor([0.0016, 0.0016])
# ite 260
# Grad tensor([0.0016, 0.0016])
# Iteration 260: Normalized Gradient = 0.0021939664147794247, Adaptive learning rate = 0.001
# ite 261
# Grad tensor([0.0015, 0.0015])
# ite 262
# Grad tensor([0.0015, 0.0015])
# ite 263
# Grad tensor([0.0015, 0.0015])
# ite 264
# Grad tensor([0.0015, 0.0015])
# ite 265
# Grad tensor([0.0015, 0.0015])
# Iteration 265: Normalized Gradient = 0.002180156297981739, Adaptive learning rate = 0.001
# ite 266
# Grad tensor([0.0015, 0.0015])
# ite 267
# Grad tensor([0.0015, 0.0015])
# ite 268
# Grad tensor([0.0015, 0.0015])
# ite 269
# Grad tensor([0.0015, 0.0015])
# ite 270
# Grad tensor([0.0015, 0.0015])
# Iteration 270: Normalized Gradient = 0.0021663829684257507, Adaptive learning rate = 0.001
# ite 271
# Grad tensor([0.0015, 0.0015])
# ite 272
# Grad tensor([0.0015, 0.0015])
# ite 273
# Grad tensor([0.0015, 0.0015])
# ite 274
# Grad tensor([0.0015, 0.0015])
# ite 275
# Grad tensor([0.0015, 0.0015])
# Iteration 275: Normalized Gradient = 0.002152651082724333, Adaptive learning rate = 0.001
# ite 276
# Grad tensor([0.0015, 0.0015])
# ite 277
# Grad tensor([0.0015, 0.0015])
# ite 278
# Grad tensor([0.0015, 0.0015])
# ite 279
# Grad tensor([0.0015, 0.0015])
# ite 280
# Grad tensor([0.0015, 0.0015])
# Iteration 280: Normalized Gradient = 0.0021389583125710487, Adaptive learning rate = 0.001
# ite 281
# Grad tensor([0.0015, 0.0015])
# ite 282
# Grad tensor([0.0015, 0.0015])
# ite 283
# Grad tensor([0.0015, 0.0015])
# ite 284
# Grad tensor([0.0015, 0.0015])
# ite 285
# Grad tensor([0.0015, 0.0015])
# Iteration 285: Normalized Gradient = 0.0021253060549497604, Adaptive learning rate = 0.001
# ite 286
# Grad tensor([0.0015, 0.0015])
# ite 287
# Grad tensor([0.0015, 0.0015])
# ite 288
# Grad tensor([0.0015, 0.0015])
# ite 289
# Grad tensor([0.0015, 0.0015])
# ite 290
# Grad tensor([0.0015, 0.0015])
# Iteration 290: Normalized Gradient = 0.002111696172505617, Adaptive learning rate = 0.001
# ite 291
# Grad tensor([0.0015, 0.0015])
# ite 292
# Grad tensor([0.0015, 0.0015])
# ite 293
# Grad tensor([0.0015, 0.0015])
# ite 294
# Grad tensor([0.0015, 0.0015])
# ite 295
# Grad tensor([0.0015, 0.0015])
# Iteration 295: Normalized Gradient = 0.0020981247071176767, Adaptive learning rate = 0.001
# ite 296
# Grad tensor([0.0015, 0.0015])
# ite 297
# Grad tensor([0.0015, 0.0015])
# ite 298
# Grad tensor([0.0015, 0.0015])
# ite 299
# Grad tensor([0.0015, 0.0015])
# ite 300
# Grad tensor([0.0015, 0.0015])
# Iteration 300: Normalized Gradient = 0.0020845960825681686, Adaptive learning rate = 0.001
# ite 301
# Grad tensor([0.0015, 0.0015])
# ite 302
# Grad tensor([0.0015, 0.0015])
# ite 303
# Grad tensor([0.0015, 0.0015])
# ite 304
# Grad tensor([0.0015, 0.0015])
# ite 305
# Grad tensor([0.0015, 0.0015])
# Iteration 305: Normalized Gradient = 0.0020711058750748634, Adaptive learning rate = 0.001
# ite 306
# Grad tensor([0.0015, 0.0015])
# ite 307
# Grad tensor([0.0015, 0.0015])
# ite 308
# Grad tensor([0.0015, 0.0015])
# ite 309
# Grad tensor([0.0015, 0.0015])
# ite 310
# Grad tensor([0.0015, 0.0015])
# Iteration 310: Normalized Gradient = 0.002057659672573209, Adaptive learning rate = 0.001
# ite 311
# Grad tensor([0.0015, 0.0015])
# ite 312
# Grad tensor([0.0015, 0.0015])
# ite 313
# Grad tensor([0.0014, 0.0014])
# ite 314
# Grad tensor([0.0014, 0.0014])
# ite 315
# Grad tensor([0.0014, 0.0014])
# Iteration 315: Normalized Gradient = 0.0020442544482648373, Adaptive learning rate = 0.001
# ite 316
# Grad tensor([0.0014, 0.0014])
# ite 317
# Grad tensor([0.0014, 0.0014])
# ite 318
# Grad tensor([0.0014, 0.0014])
# ite 319
# Grad tensor([0.0014, 0.0014])
# ite 320
# Grad tensor([0.0014, 0.0014])
# Iteration 320: Normalized Gradient = 0.0020308918319642544, Adaptive learning rate = 0.001
# ite 321
# Grad tensor([0.0014, 0.0014])
# ite 322
# Grad tensor([0.0014, 0.0014])
# ite 323
# Grad tensor([0.0014, 0.0014])
# ite 324
# Grad tensor([0.0014, 0.0014])
# ite 325
# Grad tensor([0.0014, 0.0014])
# Iteration 325: Normalized Gradient = 0.00201757182367146, Adaptive learning rate = 0.001
# ite 326
# Grad tensor([0.0014, 0.0014])
# ite 327
# Grad tensor([0.0014, 0.0014])
# ite 328
# Grad tensor([0.0014, 0.0014])
# ite 329
# Grad tensor([0.0014, 0.0014])
# ite 330
# Grad tensor([0.0014, 0.0014])
# Iteration 330: Normalized Gradient = 0.0020042946562170982, Adaptive learning rate = 0.001
# ite 331
# Grad tensor([0.0014, 0.0014])
# ite 332
# Grad tensor([0.0014, 0.0014])
# ite 333
# Grad tensor([0.0014, 0.0014])
# ite 334
# Grad tensor([0.0014, 0.0014])
# ite 335
# Grad tensor([0.0014, 0.0014])
# Iteration 335: Normalized Gradient = 0.001991060096770525, Adaptive learning rate = 0.001
# ite 336
# Grad tensor([0.0014, 0.0014])
# ite 337
# Grad tensor([0.0014, 0.0014])
# ite 338
# Grad tensor([0.0014, 0.0014])
# ite 339
# Grad tensor([0.0014, 0.0014])
# ite 340
# Grad tensor([0.0014, 0.0014])
# Iteration 340: Normalized Gradient = 0.0019778686109930277, Adaptive learning rate = 0.001
# ite 341
# Grad tensor([0.0014, 0.0014])
# ite 342
# Grad tensor([0.0014, 0.0014])
# ite 343
# Grad tensor([0.0014, 0.0014])
# ite 344
# Grad tensor([0.0014, 0.0014])
# ite 345
# Grad tensor([0.0014, 0.0014])
# Iteration 345: Normalized Gradient = 0.001964721130207181, Adaptive learning rate = 0.001
# ite 346
# Grad tensor([0.0014, 0.0014])
# ite 347
# Grad tensor([0.0014, 0.0014])
# ite 348
# Grad tensor([0.0014, 0.0014])
# ite 349
# Grad tensor([0.0014, 0.0014])
# ite 350
# Grad tensor([0.0014, 0.0014])
# Iteration 350: Normalized Gradient = 0.0019516181200742722, Adaptive learning rate = 0.001
# ite 351
# Grad tensor([0.0014, 0.0014])
# ite 352
# Grad tensor([0.0014, 0.0014])
# ite 353
# Grad tensor([0.0014, 0.0014])
# ite 354
# Grad tensor([0.0014, 0.0014])
# ite 355
# Grad tensor([0.0014, 0.0014])
# Iteration 355: Normalized Gradient = 0.0019385586492717266, Adaptive learning rate = 0.001
# ite 356
# Grad tensor([0.0014, 0.0014])
# ite 357
# Grad tensor([0.0014, 0.0014])
# ite 358
# Grad tensor([0.0014, 0.0014])
# ite 359
# Grad tensor([0.0014, 0.0014])
# ite 360
# Grad tensor([0.0014, 0.0014])
# Iteration 360: Normalized Gradient = 0.0019255435327067971, Adaptive learning rate = 0.001
# ite 361
# Grad tensor([0.0014, 0.0014])
# ite 362
# Grad tensor([0.0014, 0.0014])
# ite 363
# Grad tensor([0.0014, 0.0014])
# ite 364
# Grad tensor([0.0014, 0.0014])
# ite 365
# Grad tensor([0.0014, 0.0014])
# Iteration 365: Normalized Gradient = 0.0019125727703794837, Adaptive learning rate = 0.001
# ite 366
# Grad tensor([0.0014, 0.0014])
# ite 367
# Grad tensor([0.0013, 0.0013])
# ite 368
# Grad tensor([0.0013, 0.0013])
# ite 369
# Grad tensor([0.0013, 0.0013])
# ite 370
# Grad tensor([0.0013, 0.0013])
# Iteration 370: Normalized Gradient = 0.0018996477592736483, Adaptive learning rate = 0.001
# ite 371
# Grad tensor([0.0013, 0.0013])
# ite 372
# Grad tensor([0.0013, 0.0013])
# ite 373
# Grad tensor([0.0013, 0.0013])
# ite 374
# Grad tensor([0.0013, 0.0013])
# ite 375
# Grad tensor([0.0013, 0.0013])
# Iteration 375: Normalized Gradient = 0.0018867686158046126, Adaptive learning rate = 0.001
# ite 376
# Grad tensor([0.0013, 0.0013])
# ite 377
# Grad tensor([0.0013, 0.0013])
# ite 378
# Grad tensor([0.0013, 0.0013])
# ite 379
# Grad tensor([0.0013, 0.0013])
# ite 380
# Grad tensor([0.0013, 0.0013])
# Iteration 380: Normalized Gradient = 0.001873931847512722, Adaptive learning rate = 0.001
# ite 381
# Grad tensor([0.0013, 0.0013])
# ite 382
# Grad tensor([0.0013, 0.0013])
# ite 383
# Grad tensor([0.0013, 0.0013])
# ite 384
# Grad tensor([0.0013, 0.0013])
# ite 385
# Grad tensor([0.0013, 0.0013])
# Iteration 385: Normalized Gradient = 0.0018611425766721368, Adaptive learning rate = 0.001
# ite 386
# Grad tensor([0.0013, 0.0013])
# ite 387
# Grad tensor([0.0013, 0.0013])
# ite 388
# Grad tensor([0.0013, 0.0013])
# ite 389
# Grad tensor([0.0013, 0.0013])
# ite 390
# Grad tensor([0.0013, 0.0013])
# Iteration 390: Normalized Gradient = 0.0018483984749764204, Adaptive learning rate = 0.001
# ite 391
# Grad tensor([0.0013, 0.0013])
# ite 392
# Grad tensor([0.0013, 0.0013])
# ite 393
# Grad tensor([0.0013, 0.0013])
# ite 394
# Grad tensor([0.0013, 0.0013])
# ite 395
# Grad tensor([0.0013, 0.0013])
# Iteration 395: Normalized Gradient = 0.001835702103562653, Adaptive learning rate = 0.001
# ite 396
# Grad tensor([0.0013, 0.0013])
# ite 397
# Grad tensor([0.0013, 0.0013])
# ite 398
# Grad tensor([0.0013, 0.0013])
# ite 399
# Grad tensor([0.0013, 0.0013])
# ite 400
# Grad tensor([0.0013, 0.0013])
# Iteration 400: Normalized Gradient = 0.0018230517162010074, Adaptive learning rate = 0.001
# ite 401
# Grad tensor([0.0013, 0.0013])
# ite 402
# Grad tensor([0.0013, 0.0013])
# ite 403
# Grad tensor([0.0013, 0.0013])
# ite 404
# Grad tensor([0.0013, 0.0013])
# ite 405
# Grad tensor([0.0013, 0.0013])
# Iteration 405: Normalized Gradient = 0.001810448244214058, Adaptive learning rate = 0.001
# ite 406
# Grad tensor([0.0013, 0.0013])
# ite 407
# Grad tensor([0.0013, 0.0013])
# ite 408
# Grad tensor([0.0013, 0.0013])
# ite 409
# Grad tensor([0.0013, 0.0013])
# ite 410
# Grad tensor([0.0013, 0.0013])
# Iteration 410: Normalized Gradient = 0.0017978922696784139, Adaptive learning rate = 0.001
# ite 411
# Grad tensor([0.0013, 0.0013])
# ite 412
# Grad tensor([0.0013, 0.0013])
# ite 413
# Grad tensor([0.0013, 0.0013])
# ite 414
# Grad tensor([0.0013, 0.0013])
# ite 415
# Grad tensor([0.0013, 0.0013])
# Iteration 415: Normalized Gradient = 0.0017853823956102133, Adaptive learning rate = 0.001
# ite 416
# Grad tensor([0.0013, 0.0013])
# ite 417
# Grad tensor([0.0013, 0.0013])
# ite 418
# Grad tensor([0.0013, 0.0013])
# ite 419
# Grad tensor([0.0013, 0.0013])
# ite 420
# Grad tensor([0.0013, 0.0013])
# Iteration 420: Normalized Gradient = 0.001772919436916709, Adaptive learning rate = 0.001
# ite 421
# Grad tensor([0.0013, 0.0013])
# ite 422
# Grad tensor([0.0013, 0.0013])
# ite 423
# Grad tensor([0.0012, 0.0012])
# ite 424
# Grad tensor([0.0012, 0.0012])
# ite 425
# Grad tensor([0.0012, 0.0012])
# Iteration 425: Normalized Gradient = 0.0017605057219043374, Adaptive learning rate = 0.001
# ite 426
# Grad tensor([0.0012, 0.0012])
# ite 427
# Grad tensor([0.0012, 0.0012])
# ite 428
# Grad tensor([0.0012, 0.0012])
# ite 429
# Grad tensor([0.0012, 0.0012])
# ite 430
# Grad tensor([0.0012, 0.0012])
# Iteration 430: Normalized Gradient = 0.0017481384566053748, Adaptive learning rate = 0.001
# ite 431
# Grad tensor([0.0012, 0.0012])
# ite 432
# Grad tensor([0.0012, 0.0012])
# ite 433
# Grad tensor([0.0012, 0.0012])
# ite 434
# Grad tensor([0.0012, 0.0012])
# ite 435
# Grad tensor([0.0012, 0.0012])
# Iteration 435: Normalized Gradient = 0.0017358200857415795, Adaptive learning rate = 0.001
# ite 436
# Grad tensor([0.0012, 0.0012])
# ite 437
# Grad tensor([0.0012, 0.0012])
# ite 438
# Grad tensor([0.0012, 0.0012])
# ite 439
# Grad tensor([0.0012, 0.0012])
# ite 440
# Grad tensor([0.0012, 0.0012])
# Iteration 440: Normalized Gradient = 0.0017235497944056988, Adaptive learning rate = 0.001
# ite 441
# Grad tensor([0.0012, 0.0012])
# ite 442
# Grad tensor([0.0012, 0.0012])
# ite 443
# Grad tensor([0.0012, 0.0012])
# ite 444
# Grad tensor([0.0012, 0.0012])
# ite 445
# Grad tensor([0.0012, 0.0012])
# Iteration 445: Normalized Gradient = 0.001711327931843698, Adaptive learning rate = 0.001
# ite 446
# Grad tensor([0.0012, 0.0012])
# ite 447
# Grad tensor([0.0012, 0.0012])
# ite 448
# Grad tensor([0.0012, 0.0012])
# ite 449
# Grad tensor([0.0012, 0.0012])
# ite 450
# Grad tensor([0.0012, 0.0012])
# Iteration 450: Normalized Gradient = 0.001699155429378152, Adaptive learning rate = 0.001
# ite 451
# Grad tensor([0.0012, 0.0012])
# ite 452
# Grad tensor([0.0012, 0.0012])
# ite 453
# Grad tensor([0.0012, 0.0012])
# ite 454
# Grad tensor([0.0012, 0.0012])
# ite 455
# Grad tensor([0.0012, 0.0012])
# Iteration 455: Normalized Gradient = 0.0016870322870090604, Adaptive learning rate = 0.001
# ite 456
# Grad tensor([0.0012, 0.0012])
# ite 457
# Grad tensor([0.0012, 0.0012])
# ite 458
# Grad tensor([0.0012, 0.0012])
# ite 459
# Grad tensor([0.0012, 0.0012])
# ite 460
# Grad tensor([0.0012, 0.0012])
# Iteration 460: Normalized Gradient = 0.0016749593196436763, Adaptive learning rate = 0.001
# ite 461
# Grad tensor([0.0012, 0.0012])
# ite 462
# Grad tensor([0.0012, 0.0012])
# ite 463
# Grad tensor([0.0012, 0.0012])
# ite 464
# Grad tensor([0.0012, 0.0012])
# ite 465
# Grad tensor([0.0012, 0.0012])
# Iteration 465: Normalized Gradient = 0.001662934897467494, Adaptive learning rate = 0.001
# ite 466
# Grad tensor([0.0012, 0.0012])
# ite 467
# Grad tensor([0.0012, 0.0012])
# ite 468
# Grad tensor([0.0012, 0.0012])
# ite 469
# Grad tensor([0.0012, 0.0012])
# ite 470
# Grad tensor([0.0012, 0.0012])
# Iteration 470: Normalized Gradient = 0.0016509597189724445, Adaptive learning rate = 0.001
# ite 471
# Grad tensor([0.0012, 0.0012])
# ite 472
# Grad tensor([0.0012, 0.0012])
# ite 473
# Grad tensor([0.0012, 0.0012])
# ite 474
# Grad tensor([0.0012, 0.0012])
# ite 475
# Grad tensor([0.0012, 0.0012])
# Iteration 475: Normalized Gradient = 0.0016390349483117461, Adaptive learning rate = 0.001
# ite 476
# Grad tensor([0.0012, 0.0012])
# ite 477
# Grad tensor([0.0012, 0.0012])
# ite 478
# Grad tensor([0.0012, 0.0012])
# ite 479
# Grad tensor([0.0012, 0.0012])
# ite 480
# Grad tensor([0.0012, 0.0012])
# Iteration 480: Normalized Gradient = 0.0016271605854853988, Adaptive learning rate = 0.001
# ite 481
# Grad tensor([0.0011, 0.0011])
# ite 482
# Grad tensor([0.0011, 0.0011])
# ite 483
# Grad tensor([0.0011, 0.0011])
# ite 484
# Grad tensor([0.0011, 0.0011])
# ite 485
# Grad tensor([0.0011, 0.0011])
# Iteration 485: Normalized Gradient = 0.0016153370961546898, Adaptive learning rate = 0.001
# ite 486
# Grad tensor([0.0011, 0.0011])
# ite 487
# Grad tensor([0.0011, 0.0011])
# ite 488
# Grad tensor([0.0011, 0.0011])
# ite 489
# Grad tensor([0.0011, 0.0011])
# ite 490
# Grad tensor([0.0011, 0.0011])
# Iteration 490: Normalized Gradient = 0.0016035629669204354, Adaptive learning rate = 0.001
# ite 491
# Grad tensor([0.0011, 0.0011])
# ite 492
# Grad tensor([0.0011, 0.0011])
# ite 493
# Grad tensor([0.0011, 0.0011])
# ite 494
# Grad tensor([0.0011, 0.0011])
# ite 495
# Grad tensor([0.0011, 0.0011])
# Iteration 495: Normalized Gradient = 0.001591840642504394, Adaptive learning rate = 0.001
# ite 496
# Grad tensor([0.0011, 0.0011])
# ite 497
# Grad tensor([0.0011, 0.0011])
# ite 498
# Grad tensor([0.0011, 0.0011])
# ite 499
# Grad tensor([0.0011, 0.0011])
# ite 500
# Grad tensor([0.0011, 0.0011])
# Iteration 500: Normalized Gradient = 0.0015801693079993129, Adaptive learning rate = 0.001
# ite 501
# Grad tensor([0.0011, 0.0011])
# ite 502
# Grad tensor([0.0011, 0.0011])
# ite 503
# Grad tensor([0.0011, 0.0011])
# ite 504
# Grad tensor([0.0011, 0.0011])
# ite 505
# Grad tensor([0.0011, 0.0011])
# Iteration 505: Normalized Gradient = 0.0015685483813285828, Adaptive learning rate = 0.001
# ite 506
# Grad tensor([0.0011, 0.0011])
# ite 507
# Grad tensor([0.0011, 0.0011])
# ite 508
# Grad tensor([0.0011, 0.0011])
# ite 509
# Grad tensor([0.0011, 0.0011])
# ite 510
# Grad tensor([0.0011, 0.0011])
# Iteration 510: Normalized Gradient = 0.0015569792594760656, Adaptive learning rate = 0.001
# ite 511
# Grad tensor([0.0011, 0.0011])
# ite 512
# Grad tensor([0.0011, 0.0011])
# ite 513
# Grad tensor([0.0011, 0.0011])
# ite 514
# Grad tensor([0.0011, 0.0011])
# ite 515
# Grad tensor([0.0011, 0.0011])
# Iteration 515: Normalized Gradient = 0.0015454617096111178, Adaptive learning rate = 0.001
# ite 516
# Grad tensor([0.0011, 0.0011])
# ite 517
# Grad tensor([0.0011, 0.0011])
# ite 518
# Grad tensor([0.0011, 0.0011])
# ite 519
# Grad tensor([0.0011, 0.0011])
# ite 520
# Grad tensor([0.0011, 0.0011])
# Iteration 520: Normalized Gradient = 0.0015339970123022795, Adaptive learning rate = 0.001
# ite 521
# Grad tensor([0.0011, 0.0011])
# ite 522
# Grad tensor([0.0011, 0.0011])
# ite 523
# Grad tensor([0.0011, 0.0011])
# ite 524
# Grad tensor([0.0011, 0.0011])
# ite 525
# Grad tensor([0.0011, 0.0011])
# Iteration 525: Normalized Gradient = 0.0015225833049044013, Adaptive learning rate = 0.001
# ite 526
# Grad tensor([0.0011, 0.0011])
# ite 527
# Grad tensor([0.0011, 0.0011])
# ite 528
# Grad tensor([0.0011, 0.0011])
# ite 529
# Grad tensor([0.0011, 0.0011])
# ite 530
# Grad tensor([0.0011, 0.0011])
# Iteration 530: Normalized Gradient = 0.0015112218679860234, Adaptive learning rate = 0.001
# ite 531
# Grad tensor([0.0011, 0.0011])
# ite 532
# Grad tensor([0.0011, 0.0011])
# ite 533
# Grad tensor([0.0011, 0.0011])
# ite 534
# Grad tensor([0.0011, 0.0011])
# ite 535
# Grad tensor([0.0011, 0.0011])
# Iteration 535: Normalized Gradient = 0.0014999130507931113, Adaptive learning rate = 0.001
# ite 536
# Grad tensor([0.0011, 0.0011])
# ite 537
# Grad tensor([0.0011, 0.0011])
# ite 538
# Grad tensor([0.0011, 0.0011])
# ite 539
# Grad tensor([0.0011, 0.0011])
# ite 540
# Grad tensor([0.0011, 0.0011])
# Iteration 540: Normalized Gradient = 0.0014886572025716305, Adaptive learning rate = 0.001
# ite 541
# Grad tensor([0.0011, 0.0011])
# ite 542
# Grad tensor([0.0010, 0.0010])
# ite 543
# Grad tensor([0.0010, 0.0010])
# ite 544
# Grad tensor([0.0010, 0.0010])
# ite 545
# Grad tensor([0.0010, 0.0010])
# Iteration 545: Normalized Gradient = 0.0014774547889828682, Adaptive learning rate = 0.001
# ite 546
# Grad tensor([0.0010, 0.0010])
# ite 547
# Grad tensor([0.0010, 0.0010])
# ite 548
# Grad tensor([0.0010, 0.0010])
# ite 549
# Grad tensor([0.0010, 0.0010])
# ite 550
# Grad tensor([0.0010, 0.0010])
# Iteration 550: Normalized Gradient = 0.0014663038309663534, Adaptive learning rate = 0.001
# ite 551
# Grad tensor([0.0010, 0.0010])
# ite 552
# Grad tensor([0.0010, 0.0010])
# ite 553
# Grad tensor([0.0010, 0.0010])
# ite 554
# Grad tensor([0.0010, 0.0010])
# ite 555
# Grad tensor([0.0010, 0.0010])
# Iteration 555: Normalized Gradient = 0.0014552067732438445, Adaptive learning rate = 0.001
# ite 556
# Grad tensor([0.0010, 0.0010])
# ite 557
# Grad tensor([0.0010, 0.0010])
# ite 558
# Grad tensor([0.0010, 0.0010])
# ite 559
# Grad tensor([0.0010, 0.0010])
# ite 560
# Grad tensor([0.0010, 0.0010])
# Iteration 560: Normalized Gradient = 0.0014441624516621232, Adaptive learning rate = 0.001
# ite 561
# Grad tensor([0.0010, 0.0010])
# ite 562
# Grad tensor([0.0010, 0.0010])
# ite 563
# Grad tensor([0.0010, 0.0010])
# ite 564
# Grad tensor([0.0010, 0.0010])
# ite 565
# Grad tensor([0.0010, 0.0010])
# Iteration 565: Normalized Gradient = 0.0014331720303744078, Adaptive learning rate = 0.001
# ite 566
# Grad tensor([0.0010, 0.0010])
# ite 567
# Grad tensor([0.0010, 0.0010])
# ite 568
# Grad tensor([0.0010, 0.0010])
# ite 569
# Grad tensor([0.0010, 0.0010])
# ite 570
# Grad tensor([0.0010, 0.0010])
# Iteration 570: Normalized Gradient = 0.0014222355093806982, Adaptive learning rate = 0.001
# ite 571
# Grad tensor([0.0010, 0.0010])
# ite 572
# Grad tensor([0.0010, 0.0010])
# ite 573
# Grad tensor([0.0010, 0.0010])
# ite 574
# Grad tensor([0.0010, 0.0010])
# ite 575
# Grad tensor([0.0010, 0.0010])
# Iteration 575: Normalized Gradient = 0.0014113528886809945, Adaptive learning rate = 0.001
# ite 576
# Grad tensor([0.0010, 0.0010])
# ite 577
# Grad tensor([0.0010, 0.0010])
# ite 578
# Grad tensor([0.0010, 0.0010])
# ite 579
# Grad tensor([0.0010, 0.0010])
# ite 580
# Grad tensor([0.0010, 0.0010])
# Iteration 580: Normalized Gradient = 0.0014005238190293312, Adaptive learning rate = 0.001
# ite 581
# Grad tensor([0.0010, 0.0010])
# ite 582
# Grad tensor([0.0010, 0.0010])
# ite 583
# Grad tensor([0.0010, 0.0010])
# ite 584
# Grad tensor([0.0010, 0.0010])
# ite 585
# Grad tensor([0.0010, 0.0010])
# Iteration 585: Normalized Gradient = 0.001389748533256352, Adaptive learning rate = 0.001
# ite 586
# Grad tensor([0.0010, 0.0010])
# ite 587
# Grad tensor([0.0010, 0.0010])
# ite 588
# Grad tensor([0.0010, 0.0010])
# ite 589
# Grad tensor([0.0010, 0.0010])
# ite 590
# Grad tensor([0.0010, 0.0010])
# Iteration 590: Normalized Gradient = 0.0013790292432531714, Adaptive learning rate = 0.001
# ite 591
# Grad tensor([0.0010, 0.0010])
# ite 592
# Grad tensor([0.0010, 0.0010])
# ite 593
# Grad tensor([0.0010, 0.0010])
# ite 594
# Grad tensor([0.0010, 0.0010])
# ite 595
# Grad tensor([0.0010, 0.0010])
# Iteration 595: Normalized Gradient = 0.0013683635042980313, Adaptive learning rate = 0.001
# ite 596
# Grad tensor([0.0010, 0.0010])
# ite 597
# Grad tensor([0.0010, 0.0010])
# ite 598
# Grad tensor([0.0010, 0.0010])
# ite 599
# Grad tensor([0.0010, 0.0010])
# ite 600
# Grad tensor([0.0010, 0.0010])
# Iteration 600: Normalized Gradient = 0.0013577525969594717, Adaptive learning rate = 0.001
# ite 601
# Grad tensor([0.0010, 0.0010])
# ite 602
# Grad tensor([0.0010, 0.0010])
# ite 603
# Grad tensor([0.0010, 0.0010])
# ite 604
# Grad tensor([0.0010, 0.0010])
# ite 605
# Grad tensor([0.0010, 0.0010])
# Iteration 605: Normalized Gradient = 0.0013471958227455616, Adaptive learning rate = 0.001
# ite 606
# Grad tensor([0.0010, 0.0010])
# ite 607
# Grad tensor([0.0009, 0.0009])
# ite 608
# Grad tensor([0.0009, 0.0009])
# ite 609
# Grad tensor([0.0009, 0.0009])
# ite 610
# Grad tensor([0.0009, 0.0009])
# Iteration 610: Normalized Gradient = 0.0013366950443014503, Adaptive learning rate = 0.001
# ite 611
# Grad tensor([0.0009, 0.0009])
# ite 612
# Grad tensor([0.0009, 0.0009])
# ite 613
# Grad tensor([0.0009, 0.0009])
# ite 614
# Grad tensor([0.0009, 0.0009])
# ite 615
# Grad tensor([0.0009, 0.0009])
# Iteration 615: Normalized Gradient = 0.001326248049736023, Adaptive learning rate = 0.001
# ite 616
# Grad tensor([0.0009, 0.0009])
# ite 617
# Grad tensor([0.0009, 0.0009])
# ite 618
# Grad tensor([0.0009, 0.0009])
# ite 619
# Grad tensor([0.0009, 0.0009])
# ite 620
# Grad tensor([0.0009, 0.0009])
# Iteration 620: Normalized Gradient = 0.0013158574001863599, Adaptive learning rate = 0.001
# ite 621
# Grad tensor([0.0009, 0.0009])
# ite 622
# Grad tensor([0.0009, 0.0009])
# ite 623
# Grad tensor([0.0009, 0.0009])
# ite 624
# Grad tensor([0.0009, 0.0009])
# ite 625
# Grad tensor([0.0009, 0.0009])
# Iteration 625: Normalized Gradient = 0.0013055219314992428, Adaptive learning rate = 0.001
# ite 626
# Grad tensor([0.0009, 0.0009])
# ite 627
# Grad tensor([0.0009, 0.0009])
# ite 628
# Grad tensor([0.0009, 0.0009])
# ite 629
# Grad tensor([0.0009, 0.0009])
# ite 630
# Grad tensor([0.0009, 0.0009])
# Iteration 630: Normalized Gradient = 0.0012952423421666026, Adaptive learning rate = 0.001
# ite 631
# Grad tensor([0.0009, 0.0009])
# ite 632
# Grad tensor([0.0009, 0.0009])
# ite 633
# Grad tensor([0.0009, 0.0009])
# ite 634
# Grad tensor([0.0009, 0.0009])
# ite 635
# Grad tensor([0.0009, 0.0009])
# Iteration 635: Normalized Gradient = 0.0012850186321884394, Adaptive learning rate = 0.001
# ite 636
# Grad tensor([0.0009, 0.0009])
# ite 637
# Grad tensor([0.0009, 0.0009])
# ite 638
# Grad tensor([0.0009, 0.0009])
# ite 639
# Grad tensor([0.0009, 0.0009])
# ite 640
# Grad tensor([0.0009, 0.0009])
# Iteration 640: Normalized Gradient = 0.0012748491717502475, Adaptive learning rate = 0.001
# ite 641
# Grad tensor([0.0009, 0.0009])
# ite 642
# Grad tensor([0.0009, 0.0009])
# ite 643
# Grad tensor([0.0009, 0.0009])
# ite 644
# Grad tensor([0.0009, 0.0009])
# ite 645
# Grad tensor([0.0009, 0.0009])
# Iteration 645: Normalized Gradient = 0.00126473733689636, Adaptive learning rate = 0.001
# ite 646
# Grad tensor([0.0009, 0.0009])
# ite 647
# Grad tensor([0.0009, 0.0009])
# ite 648
# Grad tensor([0.0009, 0.0009])
# ite 649
# Grad tensor([0.0009, 0.0009])
# ite 650
# Grad tensor([0.0009, 0.0009])
# Iteration 650: Normalized Gradient = 0.001254681614227593, Adaptive learning rate = 0.001
# ite 651
# Grad tensor([0.0009, 0.0009])
# ite 652
# Grad tensor([0.0009, 0.0009])
# ite 653
# Grad tensor([0.0009, 0.0009])
# ite 654
# Grad tensor([0.0009, 0.0009])
# ite 655
# Grad tensor([0.0009, 0.0009])
# Iteration 655: Normalized Gradient = 0.0012446811888366938, Adaptive learning rate = 0.001
# ite 656
# Grad tensor([0.0009, 0.0009])
# ite 657
# Grad tensor([0.0009, 0.0009])
# ite 658
# Grad tensor([0.0009, 0.0009])
# ite 659
# Grad tensor([0.0009, 0.0009])
# ite 660
# Grad tensor([0.0009, 0.0009])
# Iteration 660: Normalized Gradient = 0.0012347373412922025, Adaptive learning rate = 0.001
# ite 661
# Grad tensor([0.0009, 0.0009])
# ite 662
# Grad tensor([0.0009, 0.0009])
# ite 663
# Grad tensor([0.0009, 0.0009])
# ite 664
# Grad tensor([0.0009, 0.0009])
# ite 665
# Grad tensor([0.0009, 0.0009])
# Iteration 665: Normalized Gradient = 0.0012248504208400846, Adaptive learning rate = 0.001
# ite 666
# Grad tensor([0.0009, 0.0009])
# ite 667
# Grad tensor([0.0009, 0.0009])
# ite 668
# Grad tensor([0.0009, 0.0009])
# ite 669
# Grad tensor([0.0009, 0.0009])
# ite 670
# Grad tensor([0.0009, 0.0009])
# Iteration 670: Normalized Gradient = 0.0012150199618190527, Adaptive learning rate = 0.001
# ite 671
# Grad tensor([0.0009, 0.0009])
# ite 672
# Grad tensor([0.0009, 0.0009])
# ite 673
# Grad tensor([0.0009, 0.0009])
# ite 674
# Grad tensor([0.0009, 0.0009])
# ite 675
# Grad tensor([0.0009, 0.0009])
# Iteration 675: Normalized Gradient = 0.001205245964229107, Adaptive learning rate = 0.001
# ite 676
# Grad tensor([0.0009, 0.0009])
# ite 677
# Grad tensor([0.0008, 0.0008])
# ite 678
# Grad tensor([0.0008, 0.0008])
# ite 679
# Grad tensor([0.0008, 0.0008])
# ite 680
# Grad tensor([0.0008, 0.0008])
# Iteration 680: Normalized Gradient = 0.0011955294758081436, Adaptive learning rate = 0.001
# ite 681
# Grad tensor([0.0008, 0.0008])
# ite 682
# Grad tensor([0.0008, 0.0008])
# ite 683
# Grad tensor([0.0008, 0.0008])
# ite 684
# Grad tensor([0.0008, 0.0008])
# ite 685
# Grad tensor([0.0008, 0.0008])
# Iteration 685: Normalized Gradient = 0.001185869099572301, Adaptive learning rate = 0.001
# ite 686
# Grad tensor([0.0008, 0.0008])
# ite 687
# Grad tensor([0.0008, 0.0008])
# ite 688
# Grad tensor([0.0008, 0.0008])
# ite 689
# Grad tensor([0.0008, 0.0008])
# ite 690
# Grad tensor([0.0008, 0.0008])
# Iteration 690: Normalized Gradient = 0.0011762661160901189, Adaptive learning rate = 0.001
# ite 691
# Grad tensor([0.0008, 0.0008])
# ite 692
# Grad tensor([0.0008, 0.0008])
# ite 693
# Grad tensor([0.0008, 0.0008])
# ite 694
# Grad tensor([0.0008, 0.0008])
# ite 695
# Grad tensor([0.0008, 0.0008])
# Iteration 695: Normalized Gradient = 0.001166720176115632, Adaptive learning rate = 0.001
# ite 696
# Grad tensor([0.0008, 0.0008])
# ite 697
# Grad tensor([0.0008, 0.0008])
# ite 698
# Grad tensor([0.0008, 0.0008])
# ite 699
# Grad tensor([0.0008, 0.0008])
# ite 700
# Grad tensor([0.0008, 0.0008])
# Iteration 700: Normalized Gradient = 0.0011572319781407714, Adaptive learning rate = 0.001
# ite 701
# Grad tensor([0.0008, 0.0008])
# ite 702
# Grad tensor([0.0008, 0.0008])
# ite 703
# Grad tensor([0.0008, 0.0008])
# ite 704
# Grad tensor([0.0008, 0.0008])
# ite 705
# Grad tensor([0.0008, 0.0008])
# Iteration 705: Normalized Gradient = 0.001147800823673606, Adaptive learning rate = 0.001
# ite 706
# Grad tensor([0.0008, 0.0008])
# ite 707
# Grad tensor([0.0008, 0.0008])
# ite 708
# Grad tensor([0.0008, 0.0008])
# ite 709
# Grad tensor([0.0008, 0.0008])
# ite 710
# Grad tensor([0.0008, 0.0008])
# Iteration 710: Normalized Gradient = 0.0011384285753592849, Adaptive learning rate = 0.001
# ite 711
# Grad tensor([0.0008, 0.0008])
# ite 712
# Grad tensor([0.0008, 0.0008])
# ite 713
# Grad tensor([0.0008, 0.0008])
# ite 714
# Grad tensor([0.0008, 0.0008])
# ite 715
# Grad tensor([0.0008, 0.0008])
# Iteration 715: Normalized Gradient = 0.001129112089984119, Adaptive learning rate = 0.001
# ite 716
# Grad tensor([0.0008, 0.0008])
# ite 717
# Grad tensor([0.0008, 0.0008])
# ite 718
# Grad tensor([0.0008, 0.0008])
# ite 719
# Grad tensor([0.0008, 0.0008])
# ite 720
# Grad tensor([0.0008, 0.0008])
# Iteration 720: Normalized Gradient = 0.0011198542779311538, Adaptive learning rate = 0.001
# ite 721
# Grad tensor([0.0008, 0.0008])
# ite 722
# Grad tensor([0.0008, 0.0008])
# ite 723
# Grad tensor([0.0008, 0.0008])
# ite 724
# Grad tensor([0.0008, 0.0008])
# ite 725
# Grad tensor([0.0008, 0.0008])
# Iteration 725: Normalized Gradient = 0.0011106536258012056, Adaptive learning rate = 0.001
# ite 726
# Grad tensor([0.0008, 0.0008])
# ite 727
# Grad tensor([0.0008, 0.0008])
# ite 728
# Grad tensor([0.0008, 0.0008])
# ite 729
# Grad tensor([0.0008, 0.0008])
# ite 730
# Grad tensor([0.0008, 0.0008])
# Iteration 730: Normalized Gradient = 0.0011015115305781364, Adaptive learning rate = 0.001
# ite 731
# Grad tensor([0.0008, 0.0008])
# ite 732
# Grad tensor([0.0008, 0.0008])
# ite 733
# Grad tensor([0.0008, 0.0008])
# ite 734
# Grad tensor([0.0008, 0.0008])
# ite 735
# Grad tensor([0.0008, 0.0008])
# Iteration 735: Normalized Gradient = 0.0010924271773546934, Adaptive learning rate = 0.001
# ite 736
# Grad tensor([0.0008, 0.0008])
# ite 737
# Grad tensor([0.0008, 0.0008])
# ite 738
# Grad tensor([0.0008, 0.0008])
# ite 739
# Grad tensor([0.0008, 0.0008])
# ite 740
# Grad tensor([0.0008, 0.0008])
# Iteration 740: Normalized Gradient = 0.0010834004497155547, Adaptive learning rate = 0.001
# ite 741
# Grad tensor([0.0008, 0.0008])
# ite 742
# Grad tensor([0.0008, 0.0008])
# ite 743
# Grad tensor([0.0008, 0.0008])
# ite 744
# Grad tensor([0.0008, 0.0008])
# ite 745
# Grad tensor([0.0008, 0.0008])
# Iteration 745: Normalized Gradient = 0.001074432977475226, Adaptive learning rate = 0.001
# ite 746
# Grad tensor([0.0008, 0.0008])
# ite 747
# Grad tensor([0.0008, 0.0008])
# ite 748
# Grad tensor([0.0008, 0.0008])
# ite 749
# Grad tensor([0.0008, 0.0008])
# ite 750
# Grad tensor([0.0008, 0.0008])
# Iteration 750: Normalized Gradient = 0.0010655231308192015, Adaptive learning rate = 0.001
# ite 751
# Grad tensor([0.0008, 0.0008])
# ite 752
# Grad tensor([0.0008, 0.0008])
# ite 753
# Grad tensor([0.0007, 0.0007])
# ite 754
# Grad tensor([0.0007, 0.0007])
# ite 755
# Grad tensor([0.0007, 0.0007])
# Iteration 755: Normalized Gradient = 0.001056671142578125, Adaptive learning rate = 0.001
# ite 756
# Grad tensor([0.0007, 0.0007])
# ite 757
# Grad tensor([0.0007, 0.0007])
# ite 758
# Grad tensor([0.0007, 0.0007])
# ite 759
# Grad tensor([0.0007, 0.0007])
# ite 760
# Grad tensor([0.0007, 0.0007])
# Iteration 760: Normalized Gradient = 0.0010478782933205366, Adaptive learning rate = 0.001
# ite 761
# Grad tensor([0.0007, 0.0007])
# ite 762
# Grad tensor([0.0007, 0.0007])
# ite 763
# Grad tensor([0.0007, 0.0007])
# ite 764
# Grad tensor([0.0007, 0.0007])
# ite 765
# Grad tensor([0.0007, 0.0007])
# Iteration 765: Normalized Gradient = 0.0010391436517238617, Adaptive learning rate = 0.001
# ite 766
# Grad tensor([0.0007, 0.0007])
# ite 767
# Grad tensor([0.0007, 0.0007])
# ite 768
# Grad tensor([0.0007, 0.0007])
# ite 769
# Grad tensor([0.0007, 0.0007])
# ite 770
# Grad tensor([0.0007, 0.0007])
# Iteration 770: Normalized Gradient = 0.0010304676834493876, Adaptive learning rate = 0.001
# ite 771
# Grad tensor([0.0007, 0.0007])
# ite 772
# Grad tensor([0.0007, 0.0007])
# ite 773
# Grad tensor([0.0007, 0.0007])
# ite 774
# Grad tensor([0.0007, 0.0007])
# ite 775
# Grad tensor([0.0007, 0.0007])
# Iteration 775: Normalized Gradient = 0.0010218499228358269, Adaptive learning rate = 0.001
# ite 776
# Grad tensor([0.0007, 0.0007])
# ite 777
# Grad tensor([0.0007, 0.0007])
# ite 778
# Grad tensor([0.0007, 0.0007])
# ite 779
# Grad tensor([0.0007, 0.0007])
# ite 780
# Grad tensor([0.0007, 0.0007])
# Iteration 780: Normalized Gradient = 0.0010132910683751106, Adaptive learning rate = 0.001
# ite 781
# Grad tensor([0.0007, 0.0007])
# ite 782
# Grad tensor([0.0007, 0.0007])
# ite 783
# Grad tensor([0.0007, 0.0007])
# ite 784
# Grad tensor([0.0007, 0.0007])
# ite 785
# Grad tensor([0.0007, 0.0007])
# Iteration 785: Normalized Gradient = 0.0010047908872365952, Adaptive learning rate = 0.001
# ite 786
# Grad tensor([0.0007, 0.0007])
# ite 787
# Grad tensor([0.0007, 0.0007])
# ite 788
# Grad tensor([0.0007, 0.0007])
# ite 789
# Grad tensor([0.0007, 0.0007])
# ite 790
# Grad tensor([0.0007, 0.0007])
# Iteration 790: Normalized Gradient = 0.0009963494958356023, Adaptive learning rate = 0.001
# ite 791
# Grad tensor([0.0007, 0.0007])
# ite 792
# Grad tensor([0.0007, 0.0007])
# ite 793
# Grad tensor([0.0007, 0.0007])
# ite 794
# Grad tensor([0.0007, 0.0007])
# ite 795
# Grad tensor([0.0007, 0.0007])
# Iteration 795: Normalized Gradient = 0.0009879666613414884, Adaptive learning rate = 0.001
# ite 796
# Grad tensor([0.0007, 0.0007])
# ite 797
# Grad tensor([0.0007, 0.0007])
# ite 798
# Grad tensor([0.0007, 0.0007])
# ite 799
# Grad tensor([0.0007, 0.0007])
# ite 800
# Grad tensor([0.0007, 0.0007])
# Iteration 800: Normalized Gradient = 0.0009796430822461843, Adaptive learning rate = 0.001
# Optimization completed.
# tensor([0.2606, 0.2369], requires_grad=True)
# Deformed: tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 2.0060],
#         [3.0000, 6.0000, 2.0060],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 2.0060],
#         [6.0000, 6.0000, 2.0060],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CloneBackward0>)
# <div>                            <div id="5c76dd7d-7494-450a-abff-5251bcbe0427" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c76dd7d-7494-450a-abff-5251bcbe0427")) {                    Plotly.newPlot(                        "5c76dd7d-7494-450a-abff-5251bcbe0427",                        [{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[0.0,3.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[0.0,3.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,3.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,3.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,3.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[6.0,6.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[6.0,6.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[6.0,6.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[9.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[9.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[0.0,2.9999656677246094],"y":[3.0,2.9999654293060303],"z":[0.0,2.006047010421753],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[0.0,2.999967098236084],"y":[6.0,6.000033378601074],"z":[0.0,2.006044387817383],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[3.0,2.9999656677246094],"y":[0.0,2.9999654293060303],"z":[0.0,2.006047010421753],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[2.999967098236084,2.9999656677246094],"y":[6.000033378601074,2.9999654293060303],"z":[2.006044387817383,2.006047010421753],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[3.0,2.999967098236084],"y":[9.0,6.000033378601074],"z":[0.0,2.006044387817383],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[2.9999656677246094,6.000033378601074],"y":[2.9999654293060303,2.999966859817505],"z":[2.006047010421753,2.00604510307312],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[2.999967098236084,6.000034809112549],"y":[6.000033378601074,6.000035285949707],"z":[2.006044387817383,2.006046772003174],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[6.0,6.000033378601074],"y":[0.0,2.999966859817505],"z":[0.0,2.00604510307312],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[6.000034809112549,6.000033378601074],"y":[6.000035285949707,2.999966859817505],"z":[2.006046772003174,2.00604510307312],"type":"scatter3d"},{"line": ...

# %%
#### Sanity Check

# %%
###### With none-FE FDM coordinates match -- with 2 qs

import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import plotly.graph_objects as go

# q.grad.zero_()


# In[663]:


######################## explanation
## "The example model is based on a 5-nodes grid shell strcuture
##  which has a crossing projection in the x-y plane"
##  The FE part would be based on the Euler-bernoulli beam theory


# In[664]:


## Initial Geom
# Initial Coords:
node_coords = torch.tensor(
    [[0.0, 3.0, 0.0], [0.0, 6.0, 0.0], [3.0, 0.0, 0.0], [3.0, 3.0, 0.0], [3.0, 6.0, 0.0], [3.0, 9.0, 0.0],
     [6.0, 0.0, 0.0], [6.0, 3.0, 0.0], [6.0, 6.0, 0.0] ,[6.0, 9.0, 0.0], [9.0, 3.0 ,0.0], [9.0, 6.0, 0.0]],
    dtype=torch.float32, requires_grad=True, )
connectivity = connectivity = [[1, 4], [2, 5], [3, 4], [5, 4], [6, 5], [4, 8],[5, 9], [7, 8], [9, 8],[10, 9],[12, 9],[11, 8]]
n_dof_per_node = 6  # Degrees of freedom per node
total_dof = n_dof_per_node * len(node_coords)
Fixed_nodes = [1, 2, 3, 6, 7, 10, 11, 12]
Free_nodes = []
n_elements = len(connectivity)
n_nodes = len(node_coords)
for i in range(1, n_nodes + 1):
    if i not in Fixed_nodes:
        Free_nodes.append(i)
idx_CF = [node - 1 for node in Fixed_nodes]
idx_CN = [i for i in range(n_nodes) if i not in idx_CF]

# In[665]:


## Force condition
####### Force condition -> need for modification
## +0 to x direction ; +1 to y direction ; +2 to Z direction
## +3 Bending around the z axis ; +4 bending around y axis ; +5 Twisting
# implement upwards loading of 50 kN at every free nodes
F = torch.zeros(total_dof, dtype=torch.float32)
f_n = Free_nodes
f_type = [2, 2, 2, 2]  # The force type
F_value = torch.tensor([50.0, 50.0, 50.0, 50.0]) * 1000  # The force value/direction
r = 1 / torch.max(F_value)
# print(r)
F_sign = torch.sign(F_value)
for idx, i in enumerate(f_n):
    F[6 * (i - 1) + f_type[idx]] = F_value[idx]  # unit: KN / KN*m

px = torch.zeros(len(f_n), 1, dtype=torch.float32)
py = torch.zeros(len(f_n), 1, dtype=torch.float32)
pz = torch.zeros(len(f_n), 1, dtype=torch.float32)

for i in range(len(f_n)):
    if f_type[idx] == 0:
        px[i] = F_value[i]
    elif f_type[idx] == 1:
        py[i] = F_value[i]
    elif f_type[idx] == 2:
        pz[i] = F_value[i]


## Obtaining Matrix D
# Assembly the nodal-branch matrix:
C = torch.zeros(n_elements, n_nodes, dtype=torch.float32)
for n, (i, j) in enumerate(connectivity):
    C[n, i - 1] = 1
    C[n, j - 1] = -1
CF = C[:, idx_CF]
CN = C[:, idx_CN]


# Assembly D
def FDM (Q,CN=CN, CF=CF, px=px, py=py, pz=pz,Fixed_nodes=Fixed_nodes, Free_nodes=Free_nodes,node_coords=node_coords) :
    Dn = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CN))
    DF = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CF))
    ## Coordinates solution
    # separate the coordinates:
    fixed_idces = [node - 1 for node in Fixed_nodes]
    xF = node_coords[fixed_idces, 0].unsqueeze(1)
    yF = node_coords[fixed_idces, 1].unsqueeze(1)
    zF = node_coords[fixed_idces, 2].unsqueeze(1)
    xN = torch.matmul(torch.inverse(Dn), (px - torch.matmul(DF, xF)))
    yN = torch.matmul(torch.inverse(Dn), (py - torch.matmul(DF, yF)))
    zN = torch.matmul(torch.inverse(Dn), (pz - torch.matmul(DF, zF)))
    ## Coordinates renewal: 
    new_node_coords = node_coords.clone()
    for idx, node in enumerate(Free_nodes):
        node_idx = node - 1
        new_node_coords[node_idx, 0] = xN[idx]
        new_node_coords[node_idx, 1] = yN[idx]
        new_node_coords[node_idx, 2] = zN[idx]

    return new_node_coords

# In[670]:

## Check point: FDM completed
# if q.grad is not None:
#     q.grad.zero_()
# loss = torch.sum(new_node_coords[:, 2])
# loss.backward()
# print("Gradient of q:")
# print(q.grad)



# Element creating
#################  input below:
############################################################################################################## input
# initial coordinates

####### BCs
fixed_dof = []
for node in Fixed_nodes:
    fixed_dof.extend([(node - 1) * 6 + i for i in range(6)])
# print(fixed_dof)
####### Gradient descent
step = 0.001
epochs = 500

####### Plotting
steps = 20  # steps for tracing deformation shape
###################################################################################################################################################
###################################################################################################################################################


### Defining the OBJ:
Obj_coords = torch.tensor([1.5, 1.5, 1.5, 1.5])
def Loss(Free_nodes, new_node_coords, Obj_coords):
    n_free_nodes = len(Free_nodes)
    Free_nodes = torch.tensor(Free_nodes)
    y_pred = new_node_coords[(Free_nodes - 1), 2]  
    y_true = Obj_coords 
    error = torch.abs(y_true - y_pred)
    loss = torch.mean(error)
    return loss

# In[679]:

# Optimized Variables
## initial variables
Idx_q1 = [3, 4, 5, 8, 9, 10]
Idx_q2 = [1, 6, 11, 2, 7, 12]
Idx_q1 = [i - 1 for i in Idx_q1] 
Idx_q2 = [i - 1 for i in Idx_q2] 
q = torch.rand(2, requires_grad=True)
## Optimization
torch.autograd.set_detect_anomaly(True)
# Optimizer setting
optimizer = optim.Adam([q], lr=step)
# Loop start
Loss_his = []
for iteration in range(epochs + 1):
    print(iteration)
    # Forwards
    q_vec = torch.zeros(n_elements, requires_grad=True).clone()
    q_vec[Idx_q1] = q[0] 
    q_vec[Idx_q2] = q[1]
    Q = torch.diag(q_vec) * 1 / r  # scaling
    new_node_coords = FDM(Q)
    # loss
    Loss_value = Loss(Free_nodes, new_node_coords, Obj_coords)
    Loss_his.append(Loss_value.item())
    # Backwards
    optimizer.zero_grad()
    # print(q.grad)
    Loss_value.backward(retain_graph=True)

    # Grad
    gradients = q.grad
    frob_norm = torch.norm(gradients)
#     print(gradients)
    optimizer.step()
    print(new_node_coords)
    # print iteration
    if iteration % 5 == 0:
        print(f"Iteration {iteration}: Normalized Gradient = {frob_norm}, Adaptive learning rate = {step}")
print("Optimization completed.")
print(q)
# print("coordinates:",node_coords)

#############################################################################################################
# Coordinates assembly:
x_orig = node_coords[:, 0].detach().numpy()
y_orig = node_coords[:, 1].detach().numpy()
z_orig = node_coords[:, 2].detach().numpy()

x_def = new_node_coords[:, 0].detach().numpy()
y_def = new_node_coords[:, 1].detach().numpy()
z_def = new_node_coords[:, 2].detach().numpy()

fig = go.Figure()

for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_orig[i-1], x_orig[j-1]],
        y=[y_orig[i-1], y_orig[j-1]],
        z=[z_orig[i-1], z_orig[j-1]],
        mode='lines',
        line=dict(color='blue', width=4),
        name='XY-projection(original)'
    ))

for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_def[i-1], x_def[j-1]],
        y=[y_def[i-1], y_def[j-1]],
        z=[z_def[i-1], z_def[j-1]],
        mode='lines',
        line=dict(color='red', width=4),
        name='FDM Solution'
    ))

for node in Free_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_def[node-1]],
        y=[y_def[node-1]],
        z=[z_def[node-1]],
        mode='markers+text',
        marker=dict(size=5, color='green'),
        text=[f'Node {node}'],
        textposition='top center',
        name=f'Free Node {node}'
    ))

fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        aspectmode='data'
    ),
    title='Deformation Comparison: Original vs. Deformed Geometry',
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()

##### Loss history
plt.figure()
plt.plot(range(epochs + 1), Loss_his, label='Loss History', color='blue', linewidth=2)
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Optimization Loss vs. Iterations')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 0
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8428],
#         [3.0000, 6.0000, 0.8428],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8428],
#         [6.0000, 6.0000, 0.8428],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 0: Normalized Gradient = 1.0045517683029175, Adaptive learning rate = 0.001
# 1
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8442],
#         [3.0000, 6.0000, 0.8442],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8442],
#         [6.0000, 6.0000, 0.8442],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 2
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8457],
#         [3.0000, 6.0000, 0.8457],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8457],
#         [6.0000, 6.0000, 0.8457],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 3
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8471],
#         [3.0000, 6.0000, 0.8471],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8471],
#         [6.0000, 6.0000, 0.8471],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 4
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8485],
#         [3.0000, 6.0000, 0.8485],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8485],
#         [6.0000, 6.0000, 0.8485],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 5
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8500],
#         [3.0000, 6.0000, 0.8500],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8500],
#         [6.0000, 6.0000, 0.8500],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 5: Normalized Gradient = 1.0217063426971436, Adaptive learning rate = 0.001
# 6
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8514],
#         [3.0000, 6.0000, 0.8514],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8514],
#         [6.0000, 6.0000, 0.8514],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 7
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8529],
#         [3.0000, 6.0000, 0.8529],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8529],
#         [6.0000, 6.0000, 0.8529],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 8
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8543],
#         [3.0000, 6.0000, 0.8543],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8543],
#         [6.0000, 6.0000, 0.8543],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 9
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8558],
#         [3.0000, 6.0000, 0.8558],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8558],
#         [6.0000, 6.0000, 0.8558],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 10
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8573],
#         [3.0000, 6.0000, 0.8573],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8573],
#         [6.0000, 6.0000, 0.8573],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 10: Normalized Gradient = 1.0393322706222534, Adaptive learning rate = 0.001
# 11
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8588],
#         [3.0000, 6.0000, 0.8588],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8588],
#         [6.0000, 6.0000, 0.8588],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 12
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8602],
#         [3.0000, 6.0000, 0.8602],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8602],
#         [6.0000, 6.0000, 0.8602],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 13
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8617],
#         [3.0000, 6.0000, 0.8617],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8617],
#         [6.0000, 6.0000, 0.8617],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 14
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8632],
#         [3.0000, 6.0000, 0.8632],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8632],
#         [6.0000, 6.0000, 0.8632],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 15
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8647],
#         [3.0000, 6.0000, 0.8647],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8647],
#         [6.0000, 6.0000, 0.8647],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 15: Normalized Gradient = 1.057471752166748, Adaptive learning rate = 0.001
# 16
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8662],
#         [3.0000, 6.0000, 0.8662],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8662],
#         [6.0000, 6.0000, 0.8662],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 17
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8677],
#         [3.0000, 6.0000, 0.8677],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8677],
#         [6.0000, 6.0000, 0.8677],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 18
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8693],
#         [3.0000, 6.0000, 0.8693],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8693],
#         [6.0000, 6.0000, 0.8693],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 19
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8708],
#         [3.0000, 6.0000, 0.8708],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8708],
#         [6.0000, 6.0000, 0.8708],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 20
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8723],
#         [3.0000, 6.0000, 0.8723],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8723],
#         [6.0000, 6.0000, 0.8723],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 20: Normalized Gradient = 1.0761692523956299, Adaptive learning rate = 0.001
# 21
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8739],
#         [3.0000, 6.0000, 0.8739],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8739],
#         [6.0000, 6.0000, 0.8739],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 22
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8754],
#         [3.0000, 6.0000, 0.8754],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8754],
#         [6.0000, 6.0000, 0.8754],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 23
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8770],
#         [3.0000, 6.0000, 0.8770],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8770],
#         [6.0000, 6.0000, 0.8770],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 24
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8785],
#         [3.0000, 6.0000, 0.8785],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8785],
#         [6.0000, 6.0000, 0.8785],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 25
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8801],
#         [3.0000, 6.0000, 0.8801],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8801],
#         [6.0000, 6.0000, 0.8801],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 25: Normalized Gradient = 1.0954694747924805, Adaptive learning rate = 0.001
# 26
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8817],
#         [3.0000, 6.0000, 0.8817],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8817],
#         [6.0000, 6.0000, 0.8817],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 27
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8833],
#         [3.0000, 6.0000, 0.8833],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8833],
#         [6.0000, 6.0000, 0.8833],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 28
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8849],
#         [3.0000, 6.0000, 0.8849],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8849],
#         [6.0000, 6.0000, 0.8849],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 29
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8865],
#         [3.0000, 6.0000, 0.8865],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8865],
#         [6.0000, 6.0000, 0.8865],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 30
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8881],
#         [3.0000, 6.0000, 0.8881],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8881],
#         [6.0000, 6.0000, 0.8881],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 30: Normalized Gradient = 1.115417242050171, Adaptive learning rate = 0.001
# 31
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8897],
#         [3.0000, 6.0000, 0.8897],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8897],
#         [6.0000, 6.0000, 0.8897],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 32
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8913],
#         [3.0000, 6.0000, 0.8913],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8913],
#         [6.0000, 6.0000, 0.8913],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 33
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8930],
#         [3.0000, 6.0000, 0.8930],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8930],
#         [6.0000, 6.0000, 0.8930],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 34
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8946],
#         [3.0000, 6.0000, 0.8946],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8946],
#         [6.0000, 6.0000, 0.8946],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 35
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8963],
#         [3.0000, 6.0000, 0.8963],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8963],
#         [6.0000, 6.0000, 0.8963],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 35: Normalized Gradient = 1.1360580921173096, Adaptive learning rate = 0.001
# 36
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8979],
#         [3.0000, 6.0000, 0.8979],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8979],
#         [6.0000, 6.0000, 0.8979],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 37
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.8996],
#         [3.0000, 6.0000, 0.8996],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.8996],
#         [6.0000, 6.0000, 0.8996],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 38
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9013],
#         [3.0000, 6.0000, 0.9013],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9013],
#         [6.0000, 6.0000, 0.9013],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 39
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9030],
#         [3.0000, 6.0000, 0.9030],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9030],
#         [6.0000, 6.0000, 0.9030],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 40
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9047],
#         [3.0000, 6.0000, 0.9047],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9047],
#         [6.0000, 6.0000, 0.9047],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 40: Normalized Gradient = 1.1574382781982422, Adaptive learning rate = 0.001
# 41
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9064],
#         [3.0000, 6.0000, 0.9064],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9064],
#         [6.0000, 6.0000, 0.9064],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 42
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9081],
#         [3.0000, 6.0000, 0.9081],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9081],
#         [6.0000, 6.0000, 0.9081],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 43
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9098],
#         [3.0000, 6.0000, 0.9098],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9098],
#         [6.0000, 6.0000, 0.9098],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 44
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9116],
#         [3.0000, 6.0000, 0.9116],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9116],
#         [6.0000, 6.0000, 0.9116],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 45
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9133],
#         [3.0000, 6.0000, 0.9133],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9133],
#         [6.0000, 6.0000, 0.9133],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 45: Normalized Gradient = 1.1796045303344727, Adaptive learning rate = 0.001
# 46
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9150],
#         [3.0000, 6.0000, 0.9150],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9150],
#         [6.0000, 6.0000, 0.9150],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 47
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9168],
#         [3.0000, 6.0000, 0.9168],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9168],
#         [6.0000, 6.0000, 0.9168],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 48
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9186],
#         [3.0000, 6.0000, 0.9186],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9186],
#         [6.0000, 6.0000, 0.9186],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 49
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9204],
#         [3.0000, 6.0000, 0.9204],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9204],
#         [6.0000, 6.0000, 0.9204],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 50
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9222],
#         [3.0000, 6.0000, 0.9222],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9222],
#         [6.0000, 6.0000, 0.9222],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 50: Normalized Gradient = 1.202606201171875, Adaptive learning rate = 0.001
# 51
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9240],
#         [3.0000, 6.0000, 0.9240],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9240],
#         [6.0000, 6.0000, 0.9240],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 52
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9258],
#         [3.0000, 6.0000, 0.9258],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9258],
#         [6.0000, 6.0000, 0.9258],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 53
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9276],
#         [3.0000, 6.0000, 0.9276],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9276],
#         [6.0000, 6.0000, 0.9276],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 54
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9294],
#         [3.0000, 6.0000, 0.9294],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9294],
#         [6.0000, 6.0000, 0.9294],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 55
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9313],
#         [3.0000, 6.0000, 0.9313],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9313],
#         [6.0000, 6.0000, 0.9313],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 55: Normalized Gradient = 1.2264946699142456, Adaptive learning rate = 0.001
# 56
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9331],
#         [3.0000, 6.0000, 0.9331],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9331],
#         [6.0000, 6.0000, 0.9331],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 57
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9350],
#         [3.0000, 6.0000, 0.9350],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9350],
#         [6.0000, 6.0000, 0.9350],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 58
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9369],
#         [3.0000, 6.0000, 0.9369],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9369],
#         [6.0000, 6.0000, 0.9369],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 59
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9388],
#         [3.0000, 6.0000, 0.9388],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9388],
#         [6.0000, 6.0000, 0.9388],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 60
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9406],
#         [3.0000, 6.0000, 0.9406],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9406],
#         [6.0000, 6.0000, 0.9406],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 60: Normalized Gradient = 1.2513233423233032, Adaptive learning rate = 0.001
# 61
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9426],
#         [3.0000, 6.0000, 0.9426],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9426],
#         [6.0000, 6.0000, 0.9426],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 62
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9445],
#         [3.0000, 6.0000, 0.9445],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9445],
#         [6.0000, 6.0000, 0.9445],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 63
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9464],
#         [3.0000, 6.0000, 0.9464],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9464],
#         [6.0000, 6.0000, 0.9464],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 64
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9484],
#         [3.0000, 6.0000, 0.9484],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9484],
#         [6.0000, 6.0000, 0.9484],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 65
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9503],
#         [3.0000, 6.0000, 0.9503],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9503],
#         [6.0000, 6.0000, 0.9503],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 65: Normalized Gradient = 1.2771505117416382, Adaptive learning rate = 0.001
# 66
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9523],
#         [3.0000, 6.0000, 0.9523],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9523],
#         [6.0000, 6.0000, 0.9523],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 67
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9543],
#         [3.0000, 6.0000, 0.9543],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9543],
#         [6.0000, 6.0000, 0.9543],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 68
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9562],
#         [3.0000, 6.0000, 0.9562],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9562],
#         [6.0000, 6.0000, 0.9562],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 69
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9582],
#         [3.0000, 6.0000, 0.9582],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9582],
#         [6.0000, 6.0000, 0.9582],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 70
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9603],
#         [3.0000, 6.0000, 0.9603],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9603],
#         [6.0000, 6.0000, 0.9603],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 70: Normalized Gradient = 1.3040368556976318, Adaptive learning rate = 0.001
# 71
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9623],
#         [3.0000, 6.0000, 0.9623],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9623],
#         [6.0000, 6.0000, 0.9623],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 72
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9643],
#         [3.0000, 6.0000, 0.9643],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9643],
#         [6.0000, 6.0000, 0.9643],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 73
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9664],
#         [3.0000, 6.0000, 0.9664],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9664],
#         [6.0000, 6.0000, 0.9664],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 74
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9684],
#         [3.0000, 6.0000, 0.9684],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9684],
#         [6.0000, 6.0000, 0.9684],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 75
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9705],
#         [3.0000, 6.0000, 0.9705],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9705],
#         [6.0000, 6.0000, 0.9705],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 75: Normalized Gradient = 1.332048773765564, Adaptive learning rate = 0.001
# 76
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9726],
#         [3.0000, 6.0000, 0.9726],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9726],
#         [6.0000, 6.0000, 0.9726],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 77
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9747],
#         [3.0000, 6.0000, 0.9747],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9747],
#         [6.0000, 6.0000, 0.9747],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 78
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9768],
#         [3.0000, 6.0000, 0.9768],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9768],
#         [6.0000, 6.0000, 0.9768],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 79
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9790],
#         [3.0000, 6.0000, 0.9790],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9790],
#         [6.0000, 6.0000, 0.9790],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 80
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9811],
#         [3.0000, 6.0000, 0.9811],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9811],
#         [6.0000, 6.0000, 0.9811],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 80: Normalized Gradient = 1.3612582683563232, Adaptive learning rate = 0.001
# 81
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9833],
#         [3.0000, 6.0000, 0.9833],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9833],
#         [6.0000, 6.0000, 0.9833],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 82
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9854],
#         [3.0000, 6.0000, 0.9854],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9854],
#         [6.0000, 6.0000, 0.9854],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 83
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9876],
#         [3.0000, 6.0000, 0.9876],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9876],
#         [6.0000, 6.0000, 0.9876],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 84
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9898],
#         [3.0000, 6.0000, 0.9898],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9898],
#         [6.0000, 6.0000, 0.9898],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 85
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9920],
#         [3.0000, 6.0000, 0.9920],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9920],
#         [6.0000, 6.0000, 0.9920],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 85: Normalized Gradient = 1.391741394996643, Adaptive learning rate = 0.001
# 86
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9943],
#         [3.0000, 6.0000, 0.9943],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9943],
#         [6.0000, 6.0000, 0.9943],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 87
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9965],
#         [3.0000, 6.0000, 0.9965],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9965],
#         [6.0000, 6.0000, 0.9965],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 88
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 0.9987],
#         [3.0000, 6.0000, 0.9987],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 0.9987],
#         [6.0000, 6.0000, 0.9987],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 89
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0010],
#         [3.0000, 6.0000, 1.0010],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0010],
#         [6.0000, 6.0000, 1.0010],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 90
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0033],
#         [3.0000, 6.0000, 1.0033],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0033],
#         [6.0000, 6.0000, 1.0033],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 90: Normalized Gradient = 1.4235820770263672, Adaptive learning rate = 0.001
# 91
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0056],
#         [3.0000, 6.0000, 1.0056],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0056],
#         [6.0000, 6.0000, 1.0056],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 92
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0079],
#         [3.0000, 6.0000, 1.0079],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0079],
#         [6.0000, 6.0000, 1.0079],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 93
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0103],
#         [3.0000, 6.0000, 1.0103],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0103],
#         [6.0000, 6.0000, 1.0103],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 94
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0126],
#         [3.0000, 6.0000, 1.0126],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0126],
#         [6.0000, 6.0000, 1.0126],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 95
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0150],
#         [3.0000, 6.0000, 1.0150],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0150],
#         [6.0000, 6.0000, 1.0150],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 95: Normalized Gradient = 1.4568719863891602, Adaptive learning rate = 0.001
# 96
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0173],
#         [3.0000, 6.0000, 1.0173],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0173],
#         [6.0000, 6.0000, 1.0173],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 97
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0197],
#         [3.0000, 6.0000, 1.0197],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0197],
#         [6.0000, 6.0000, 1.0197],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 98
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0222],
#         [3.0000, 6.0000, 1.0222],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0222],
#         [6.0000, 6.0000, 1.0222],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 99
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0246],
#         [3.0000, 6.0000, 1.0246],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0246],
#         [6.0000, 6.0000, 1.0246],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 100
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0270],
#         [3.0000, 6.0000, 1.0270],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0270],
#         [6.0000, 6.0000, 1.0270],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 100: Normalized Gradient = 1.491709589958191, Adaptive learning rate = 0.001
# 101
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0295],
#         [3.0000, 6.0000, 1.0295],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0295],
#         [6.0000, 6.0000, 1.0295],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 102
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0320],
#         [3.0000, 6.0000, 1.0320],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0320],
#         [6.0000, 6.0000, 1.0320],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 103
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0345],
#         [3.0000, 6.0000, 1.0345],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0345],
#         [6.0000, 6.0000, 1.0345],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 104
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0370],
#         [3.0000, 6.0000, 1.0370],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0370],
#         [6.0000, 6.0000, 1.0370],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 105
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.0395],
#         [3.0000, 6.0000, 1.0395],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.0395],
#         [6.0000, 6.0000, 1.0395],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 105: Normalized Gradient = 1.528202772140503, Adaptive learning rate = 0.001
# 106
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
# ...
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 475
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5000],
#         [3.0000, 6.0000, 1.5000],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5000],
#         [6.0000, 6.0000, 1.5000],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 475: Normalized Gradient = 3.1817727088928223, Adaptive learning rate = 0.001
# 476
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5000],
#         [3.0000, 6.0000, 1.5000],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5000],
#         [6.0000, 6.0000, 1.5000],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 477
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5005],
#         [3.0000, 6.0000, 1.5005],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5005],
#         [6.0000, 6.0000, 1.5005],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 478
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5005],
#         [3.0000, 6.0000, 1.5005],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5005],
#         [6.0000, 6.0000, 1.5005],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 479
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5000],
#         [3.0000, 6.0000, 1.5000],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5000],
#         [6.0000, 6.0000, 1.5000],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 480
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5000],
#         [3.0000, 6.0000, 1.5000],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5000],
#         [6.0000, 6.0000, 1.5000],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 480: Normalized Gradient = 3.1820359230041504, Adaptive learning rate = 0.001
# 481
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4995],
#         [3.0000, 6.0000, 1.4995],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4995],
#         [6.0000, 6.0000, 1.4995],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 482
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4996],
#         [3.0000, 6.0000, 1.4996],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4996],
#         [6.0000, 6.0000, 1.4996],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 483
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5002],
#         [3.0000, 6.0000, 1.5002],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5002],
#         [6.0000, 6.0000, 1.5002],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 484
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5002],
#         [3.0000, 6.0000, 1.5002],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5002],
#         [6.0000, 6.0000, 1.5002],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 485
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4997],
#         [3.0000, 6.0000, 1.4997],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4997],
#         [6.0000, 6.0000, 1.4997],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 485: Normalized Gradient = 3.180680513381958, Adaptive learning rate = 0.001
# 486
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4998],
#         [3.0000, 6.0000, 1.4998],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4998],
#         [6.0000, 6.0000, 1.4998],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 487
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5003],
#         [3.0000, 6.0000, 1.5003],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5003],
#         [6.0000, 6.0000, 1.5003],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 488
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5003],
#         [3.0000, 6.0000, 1.5003],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5003],
#         [6.0000, 6.0000, 1.5003],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 489
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4998],
#         [3.0000, 6.0000, 1.4998],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4998],
#         [6.0000, 6.0000, 1.4998],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 490
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4999],
#         [3.0000, 6.0000, 1.4999],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4999],
#         [6.0000, 6.0000, 1.4999],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 490: Normalized Gradient = 3.1813573837280273, Adaptive learning rate = 0.001
# 491
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5004],
#         [3.0000, 6.0000, 1.5004],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5004],
#         [6.0000, 6.0000, 1.5004],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 492
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5004],
#         [3.0000, 6.0000, 1.5004],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5004],
#         [6.0000, 6.0000, 1.5004],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 493
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4999],
#         [3.0000, 6.0000, 1.4999],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4999],
#         [6.0000, 6.0000, 1.4999],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 494
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4999],
#         [3.0000, 6.0000, 1.4999],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4999],
#         [6.0000, 6.0000, 1.4999],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 495
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5005],
#         [3.0000, 6.0000, 1.5005],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5005],
#         [6.0000, 6.0000, 1.5005],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 495: Normalized Gradient = 3.1839826107025146, Adaptive learning rate = 0.001
# 496
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5005],
#         [3.0000, 6.0000, 1.5005],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5005],
#         [6.0000, 6.0000, 1.5005],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 497
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.4999],
#         [3.0000, 6.0000, 1.4999],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.4999],
#         [6.0000, 6.0000, 1.4999],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 498
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5000],
#         [3.0000, 6.0000, 1.5000],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5000],
#         [6.0000, 6.0000, 1.5000],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 499
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5005],
#         [3.0000, 6.0000, 1.5005],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5005],
#         [6.0000, 6.0000, 1.5005],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# 500
# tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.0000, 3.0000, 1.5005],
#         [3.0000, 6.0000, 1.5005],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [6.0000, 3.0000, 1.5005],
#         [6.0000, 6.0000, 1.5005],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CopySlices>)
# Iteration 500: Normalized Gradient = 3.18402361869812, Adaptive learning rate = 0.001
# Optimization completed.
# tensor([ 0.7335, -0.0668], requires_grad=True)
# <div>                            <div id="d71192d6-ce75-493b-852a-f8d93236437f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d71192d6-ce75-493b-852a-f8d93236437f")) {                    Plotly.newPlot(                        "d71192d6-ce75-493b-852a-f8d93236437f",                        [{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[0.0,3.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[0.0,3.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,3.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,3.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,3.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[6.0,6.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[6.0,6.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[6.0,6.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[9.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[9.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[0.0,3.000000238418579],"y":[3.0,3.0],"z":[0.0,1.5004818439483643],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[0.0,3.0],"y":[6.0,6.0],"z":[0.0,1.5004817247390747],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.0,3.000000238418579],"y":[0.0,3.0],"z":[0.0,1.5004818439483643],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.0,3.000000238418579],"y":[6.0,3.0],"z":[1.5004817247390747,1.5004818439483643],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.0,3.0],"y":[9.0,6.0],"z":[0.0,1.5004817247390747],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.000000238418579,5.999998092651367],"y":[3.0,2.9999988079071045],"z":[1.5004818439483643,1.5004812479019165],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.0,5.999998092651367],"y":[6.0,5.999998569488525],"z":[1.5004817247390747,1.5004812479019165],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[6.0,5.999998092651367],"y":[0.0,2.9999988079071045],"z":[0.0,1.5004812479019165],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[5.999998092651367,5.999998092651367],"y":[5.999998569488525,2.9999988079071045],"z":[1.5004812479019165,1.5004812479019165],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[6.0,5.999998092651367],"y":[9.0,5.999998569488525],"z":[0.0,1. ...
