# %%
###### With none-FE FDM coordinates match -- with individual qs

import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import plotly.graph_objects as go

# q.grad.zero_()


# In[663]:


######################## explanation
## "The example model is based on a 5-nodes grid shell strcuture
##  which has a crossing projection in the x-y plane"
##  The FE part would be based on the Euler-bernoulli beam theory


# In[664]:


## Initial Geom
# Initial Coords:
node_coords = torch.tensor(
    [[0.0, 3.0, 0.0], [0.0, 6.0, 0.0], [3.0, 0.0, 0.0], [3.0, 3.0, 0.0], [3.0, 6.0, 0.0], [3.0, 9.0, 0.0],
     [6.0, 0.0, 0.0], [6.0, 3.0, 0.0], [6.0, 6.0, 0.0] ,[6.0, 9.0, 0.0], [9.0, 3.0 ,0.0], [9.0, 6.0, 0.0]],
    dtype=torch.float32, requires_grad=True, )
connectivity = [[1, 4], [2, 5], [3, 4], [5, 4], [6, 5], [4, 8],[5, 9], [7, 8], [9, 8],[10, 9],[12, 9],[11, 8]]
n_dof_per_node = 6  # Degrees of freedom per node
total_dof = n_dof_per_node * len(node_coords)
Fixed_nodes = [1, 2, 3, 6, 7, 10, 11, 12]
Free_nodes = []
n_elements = len(connectivity)
n_nodes = len(node_coords)
for i in range(1, n_nodes + 1):
    if i not in Fixed_nodes:
        Free_nodes.append(i)
idx_CF = [node - 1 for node in Fixed_nodes]
idx_CN = [i for i in range(n_nodes) if i not in idx_CF]

# In[665]:


## Force condition
####### Force condition -> need for modification
## +0 to x direction ; +1 to y direction ; +2 to Z direction
## +3 Bending around the z axis ; +4 bending around y axis ; +5 Twisting
# implement upwards loading of 50 kN at every free nodes
F = torch.zeros(total_dof, dtype=torch.float32)
f_n = Free_nodes
f_type = [2, 2, 2, 2]  # The force type
F_value = torch.tensor([50.0, 50.0, 50.0, 50.0]) * 1000  # The force value/direction
r = 1 / torch.max(F_value)
# print(r)
F_sign = torch.sign(F_value)
for idx, i in enumerate(f_n):
    F[6 * (i - 1) + f_type[idx]] = F_value[idx]  # unit: KN / KN*m

px = torch.zeros(len(f_n), 1, dtype=torch.float32)
py = torch.zeros(len(f_n), 1, dtype=torch.float32)
pz = torch.zeros(len(f_n), 1, dtype=torch.float32)

for i in range(len(f_n)):
    if f_type[idx] == 0:
        px[i] = F_value[i]
    elif f_type[idx] == 1:
        py[i] = F_value[i]
    elif f_type[idx] == 2:
        pz[i] = F_value[i]


## Obtaining Matrix D
# Assembly the nodal-branch matrix:
C = torch.zeros(n_elements, n_nodes, dtype=torch.float32)
for n, (i, j) in enumerate(connectivity):
    C[n, i - 1] = 1
    C[n, j - 1] = -1
CF = C[:, idx_CF]
CN = C[:, idx_CN]


# Assembly D
def FDM (Q,CN=CN, CF=CF, px=px, py=py, pz=pz,Fixed_nodes=Fixed_nodes, Free_nodes=Free_nodes,node_coords=node_coords) :
    Dn = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CN))
    DF = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CF))
    ## Coordinates solution
    # separate the coordinates:
    fixed_idces = [node - 1 for node in Fixed_nodes]
    xF = node_coords[fixed_idces, 0].unsqueeze(1)
    yF = node_coords[fixed_idces, 1].unsqueeze(1)
    zF = node_coords[fixed_idces, 2].unsqueeze(1)
    xN = torch.matmul(torch.inverse(Dn), (px - torch.matmul(DF, xF)))
    yN = torch.matmul(torch.inverse(Dn), (py - torch.matmul(DF, yF)))
    zN = torch.matmul(torch.inverse(Dn), (pz - torch.matmul(DF, zF)))
    ## Coordinates renewal: 
    new_node_coords = node_coords.clone()
    for idx, node in enumerate(Free_nodes):
        node_idx = node - 1
        new_node_coords[node_idx, 0] = xN[idx]
        new_node_coords[node_idx, 1] = yN[idx]
        new_node_coords[node_idx, 2] = zN[idx]

    return new_node_coords

# In[670]:

## Check point: FDM completed
# if q.grad is not None:
#     q.grad.zero_()
# loss = torch.sum(new_node_coords[:, 2])
# loss.backward()
# print("Gradient of q:")
# print(q.grad)



# Element creating
#################  input below:
############################################################################################################## input
# initial coordinates

####### BCs
fixed_dof = []
for node in Fixed_nodes:
    fixed_dof.extend([(node - 1) * 6 + i for i in range(6)])
# print(fixed_dof)
####### Gradient descent
step = 0.001
epochs = 1000

####### Plotting
steps = 20  # steps for tracing deformation shape
###################################################################################################################################################
###################################################################################################################################################


### Defining the OBJ:
Obj_coords = torch.tensor([1.5, 1.5, 1.5, 1.5])
def Loss(Free_nodes, new_node_coords, Obj_coords):
    n_free_nodes = len(Free_nodes)
    Free_nodes = torch.tensor(Free_nodes)
    y_pred = new_node_coords[(Free_nodes - 1), 2]  
    y_true = Obj_coords 
    error = torch.abs(y_true - y_pred)
    loss = torch.mean(error)
    return loss

# In[679]:

# Optimized Variables
## initial variables
q = torch.rand(12, requires_grad=True)
## Optimization
torch.autograd.set_detect_anomaly(True)
# Optimizer setting
optimizer = optim.Adam([q], lr=step)
# Loop start
Loss_his = []
for iteration in range(epochs + 1):
#     print(iteration)
    # Forwards
    Q = torch.diag(q) * 1 / r  # scaling
    new_node_coords = FDM(Q)
    # loss
    Loss_value = Loss(Free_nodes, new_node_coords, Obj_coords)
    print(Loss_value)
    Loss_his.append(Loss_value.item())
    # Backwards
    optimizer.zero_grad()
    # print(q.grad)
    Loss_value.backward(retain_graph=True)

    # Grad
    gradients = q.grad
    frob_norm = torch.norm(gradients)
#     print(gradients)
    optimizer.step()
    
    # print iteration
    if iteration % 5 == 0:
        print(f"Iteration {iteration}: Normalized Gradient = {frob_norm}, Adaptive learning rate = {step}")
print("Optimization completed.")
print(q)
# print("coordinates:",node_coords)

#############################################################################################################
x_orig = node_coords[:, 0].detach().numpy()
y_orig = node_coords[:, 1].detach().numpy()
z_orig = node_coords[:, 2].detach().numpy()

x_def = new_node_coords[:, 0].detach().numpy()
y_def = new_node_coords[:, 1].detach().numpy()
z_def = new_node_coords[:, 2].detach().numpy()

fig = go.Figure()



for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_orig[i-1], x_orig[j-1]],
        y=[y_orig[i-1], y_orig[j-1]],
        z=[z_orig[i-1], z_orig[j-1]],
        mode='lines',
        line=dict(color='blue', width=4),
        name='XY-projection(original)'
    ))

for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_def[i-1], x_def[j-1]],
        y=[y_def[i-1], y_def[j-1]],
        z=[z_def[i-1], z_def[j-1]],
        mode='lines',
        line=dict(color='red', width=4),
        name='FDM Solution'
    ))

for node in Free_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_def[node-1]],
        y=[y_def[node-1]],
        z=[z_def[node-1]],
        mode='markers+text',
        marker=dict(size=5, color='green'),
        text=[f'Node {node}'],
        textposition='top center',
        name=f'Free Node {node}'
    ))

fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        aspectmode='data'
    ),
    title='Deformation Comparison: Original vs. Deformed Geometry',
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()

##### Loss history
plt.figure()
plt.plot(range(epochs + 1), Loss_his, label='Loss History', color='blue', linewidth=2)
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Optimization Loss vs. Iterations')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# tensor(0.3666, grad_fn=<MeanBackward0>)
# Iteration 0: Normalized Gradient = 1.6775617599487305, Adaptive learning rate = 0.001
# tensor(0.3620, grad_fn=<MeanBackward0>)
# tensor(0.3575, grad_fn=<MeanBackward0>)
# tensor(0.3530, grad_fn=<MeanBackward0>)
# tensor(0.3486, grad_fn=<MeanBackward0>)
# tensor(0.3442, grad_fn=<MeanBackward0>)
# Iteration 5: Normalized Gradient = 1.6136761903762817, Adaptive learning rate = 0.001
# tensor(0.3398, grad_fn=<MeanBackward0>)
# tensor(0.3355, grad_fn=<MeanBackward0>)
# tensor(0.3312, grad_fn=<MeanBackward0>)
# tensor(0.3270, grad_fn=<MeanBackward0>)
# tensor(0.3228, grad_fn=<MeanBackward0>)
# Iteration 10: Normalized Gradient = 1.5536082983016968, Adaptive learning rate = 0.001
# tensor(0.3186, grad_fn=<MeanBackward0>)
# tensor(0.3144, grad_fn=<MeanBackward0>)
# tensor(0.3103, grad_fn=<MeanBackward0>)
# tensor(0.3063, grad_fn=<MeanBackward0>)
# tensor(0.3023, grad_fn=<MeanBackward0>)
# Iteration 15: Normalized Gradient = 1.4972306489944458, Adaptive learning rate = 0.001
# tensor(0.2983, grad_fn=<MeanBackward0>)
# tensor(0.2943, grad_fn=<MeanBackward0>)
# tensor(0.2904, grad_fn=<MeanBackward0>)
# tensor(0.2865, grad_fn=<MeanBackward0>)
# tensor(0.2827, grad_fn=<MeanBackward0>)
# Iteration 20: Normalized Gradient = 1.4443843364715576, Adaptive learning rate = 0.001
# tensor(0.2789, grad_fn=<MeanBackward0>)
# tensor(0.2751, grad_fn=<MeanBackward0>)
# tensor(0.2714, grad_fn=<MeanBackward0>)
# tensor(0.2677, grad_fn=<MeanBackward0>)
# tensor(0.2640, grad_fn=<MeanBackward0>)
# Iteration 25: Normalized Gradient = 1.3948805332183838, Adaptive learning rate = 0.001
# tensor(0.2604, grad_fn=<MeanBackward0>)
ensor(0.0036, grad_fn=<MeanBackward0>)
# tensor(0.0034, grad_fn=<MeanBackward0>)
# tensor(0.0031, grad_fn=<MeanBackward0>)
# tensor(0.0030, grad_fn=<MeanBackward0>)
# tensor(0.0028, grad_fn=<MeanBackward0>)
# Iteration 725: Normalized Gradient = 0.8710798025131226, Adaptive learning rate = 0.001
# tensor(0.0025, grad_fn=<MeanBackward0>)
# tensor(0.0023, grad_fn=<MeanBackward0>)
# tensor(0.0021, grad_fn=<MeanBackward0>)
# tensor(0.0021, grad_fn=<MeanBackward0>)
# tensor(0.0018, grad_fn=<MeanBackward0>)
# Iteration 730: Normalized Gradient = 0.8701657652854919, Adaptive learning rate = 0.001
# tensor(0.0015, grad_fn=<MeanBackward0>)
# tensor(0.0013, grad_fn=<MeanBackward0>)
# tensor(0.0012, grad_fn=<MeanBackward0>)
# tensor(0.0009, grad_fn=<MeanBackward0>)
# tensor(0.0007, grad_fn=<MeanBackward0>)
# Iteration 735: Normalized Gradient = 0.26781392097473145, Adaptive learning rate = 0.001
# tensor(0.0007, grad_fn=<MeanBackward0>)
# tensor(0.0006, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# Iteration 740: Normalized Gradient = 0.4388461112976074, Adaptive learning rate = 0.001
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0007, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# Iteration 745: Normalized Gradient = 0.8669106364250183, Adaptive learning rate = 0.001
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0006, grad_fn=<MeanBackward0>)
# tensor(0.0008, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0007, grad_fn=<MeanBackward0>)
# Iteration 750: Normalized Gradient = 0.8576902747154236, Adaptive learning rate = 0.001
# tensor(0.0007, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0010, grad_fn=<MeanBackward0>)
# tensor(0.0010, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# Iteration 755: Normalized Gradient = 0.8584985136985779, Adaptive learning rate = 0.001
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 760: Normalized Gradient = 0.8671067953109741, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# Iteration 765: Normalized Gradient = 1.590284824371338, Adaptive learning rate = 0.001
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# Iteration 770: Normalized Gradient = 0.26756665110588074, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# Iteration 775: Normalized Gradient = 1.5903422832489014, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# Iteration 780: Normalized Gradient = 0.8585681915283203, Adaptive learning rate = 0.001
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0006, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 785: Normalized Gradient = 1.5917999744415283, Adaptive learning rate = 0.001
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# Iteration 790: Normalized Gradient = 1.5904858112335205, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 795: Normalized Gradient = 1.5901235342025757, Adaptive learning rate = 0.001
# tensor(8.3387e-05, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 800: Normalized Gradient = 1.5918315649032593, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# Iteration 805: Normalized Gradient = 1.5905327796936035, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 810: Normalized Gradient = 1.5901398658752441, Adaptive learning rate = 0.001
# tensor(8.0734e-05, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# Iteration 815: Normalized Gradient = 0.8589879274368286, Adaptive learning rate = 0.001
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0007, grad_fn=<MeanBackward0>)
# tensor(0.0007, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# Iteration 820: Normalized Gradient = 0.885655403137207, Adaptive learning rate = 0.001
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0006, grad_fn=<MeanBackward0>)
# Iteration 825: Normalized Gradient = 1.589762568473816, Adaptive learning rate = 0.001
# tensor(0.0006, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0006, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 830: Normalized Gradient = 1.590073585510254, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(9.8675e-05, grad_fn=<MeanBackward0>)
# tensor(7.1019e-05, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 835: Normalized Gradient = 1.5900769233703613, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# Iteration 840: Normalized Gradient = 0.8589699268341064, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# Iteration 845: Normalized Gradient = 1.5904414653778076, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# Iteration 850: Normalized Gradient = 0.8858736157417297, Adaptive learning rate = 0.001
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(9.3132e-05, grad_fn=<MeanBackward0>)
# Iteration 855: Normalized Gradient = 0.4385330379009247, Adaptive learning rate = 0.001
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# Iteration 860: Normalized Gradient = 0.4385598301887512, Adaptive learning rate = 0.001
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# Iteration 865: Normalized Gradient = 1.5907286405563354, Adaptive learning rate = 0.001
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# Iteration 870: Normalized Gradient = 0.4478587508201599, Adaptive learning rate = 0.001
# tensor(9.5487e-05, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# Iteration 875: Normalized Gradient = 0.44776415824890137, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 880: Normalized Gradient = 1.5901156663894653, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# Iteration 885: Normalized Gradient = 1.5914243459701538, Adaptive learning rate = 0.001
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(4.5151e-05, grad_fn=<MeanBackward0>)
# tensor(8.5443e-05, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# Iteration 890: Normalized Gradient = 1.5906894207000732, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# Iteration 895: Normalized Gradient = 0.8854677677154541, Adaptive learning rate = 0.001
# tensor(8.0138e-05, grad_fn=<MeanBackward0>)
# tensor(5.7369e-05, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# Iteration 900: Normalized Gradient = 0.8848063945770264, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(9.2536e-05, grad_fn=<MeanBackward0>)
# Iteration 905: Normalized Gradient = 0.8854031562805176, Adaptive learning rate = 0.001
# tensor(9.5218e-05, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0006, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 910: Normalized Gradient = 1.5902204513549805, Adaptive learning rate = 0.001
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0006, grad_fn=<MeanBackward0>)
# tensor(0.0006, grad_fn=<MeanBackward0>)
# Iteration 915: Normalized Gradient = 1.5898139476776123, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0007, grad_fn=<MeanBackward0>)
# tensor(0.0007, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# Iteration 920: Normalized Gradient = 1.5912175178527832, Adaptive learning rate = 0.001
# tensor(7.7367e-05, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(5.2840e-05, grad_fn=<MeanBackward0>)
# tensor(0.0007, grad_fn=<MeanBackward0>)
# tensor(0.0006, grad_fn=<MeanBackward0>)
# Iteration 925: Normalized Gradient = 1.5922390222549438, Adaptive learning rate = 0.001
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# Iteration 930: Normalized Gradient = 1.5899913311004639, Adaptive learning rate = 0.001
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0006, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 935: Normalized Gradient = 1.5901968479156494, Adaptive learning rate = 0.001
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# Iteration 940: Normalized Gradient = 0.4474199116230011, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0006, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# Iteration 945: Normalized Gradient = 1.5921388864517212, Adaptive learning rate = 0.001
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0007, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 950: Normalized Gradient = 0.8859860897064209, Adaptive learning rate = 0.001
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(8.0138e-05, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# Iteration 955: Normalized Gradient = 1.5915323495864868, Adaptive learning rate = 0.001
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(6.5476e-05, grad_fn=<MeanBackward0>)
# Iteration 960: Normalized Gradient = 0.8675156235694885, Adaptive learning rate = 0.001
# tensor(9.9391e-05, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 965: Normalized Gradient = 1.5900474786758423, Adaptive learning rate = 0.001
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 970: Normalized Gradient = 1.5900403261184692, Adaptive learning rate = 0.001
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0006, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# Iteration 975: Normalized Gradient = 1.590089201927185, Adaptive learning rate = 0.001
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# Iteration 980: Normalized Gradient = 0.4383609890937805, Adaptive learning rate = 0.001
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0001, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# Iteration 985: Normalized Gradient = 1.5920096635818481, Adaptive learning rate = 0.001
# tensor(0.0004, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0008, grad_fn=<MeanBackward0>)
# Iteration 990: Normalized Gradient = 1.5927306413650513, Adaptive learning rate = 0.001
# tensor(0.0007, grad_fn=<MeanBackward0>)
# tensor(0.0002, grad_fn=<MeanBackward0>)
# tensor(0.0006, grad_fn=<MeanBackward0>)
# tensor(0.0003, grad_fn=<MeanBackward0>)
# tensor(0.0008, grad_fn=<MeanBackward0>)
# Iteration 995: Normalized Gradient = 1.592686414718628, Adaptive learning rate = 0.001
# tensor(0.0010, grad_fn=<MeanBackward0>)
# tensor(0.0005, grad_fn=<MeanBackward0>)
# tensor(0.0007, grad_fn=<MeanBackward0>)
# tensor(0.0011, grad_fn=<MeanBackward0>)
# tensor(0.0007, grad_fn=<MeanBackward0>)
# Iteration 1000: Normalized Gradient = 1.58955979347229, Adaptive learning rate = 0.001
# Optimization completed.
# tensor([0.2579, 0.4258, 0.4089, 0.7385, 0.2407, 1.1563, 0.6333, 0.4245, 1.0446,
#         0.1864, 0.4796, 0.2420], requires_grad=True)
# <div>                            <div id="cb398ce3-cf99-41bb-8bfe-019505fe6554" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb398ce3-cf99-41bb-8bfe-019505fe6554")) {                    Plotly.newPlot(                        "cb398ce3-cf99-41bb-8bfe-019505fe6554",                        [{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[0.0,3.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[0.0,3.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,3.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,3.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,3.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[3.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[6.0,6.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[6.0,6.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[6.0,6.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[9.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"XY-projection(original)","x":[9.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[0.0,3.8485374450683594],"y":[3.0,3.2066400051116943],"z":[0.0,1.4991443157196045],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[0.0,3.4869110584259033],"y":[6.0,4.951540946960449],"z":[0.0,1.499330997467041],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.0,3.8485374450683594],"y":[0.0,3.2066400051116943],"z":[0.0,1.4991443157196045],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.4869110584259033,3.8485374450683594],"y":[4.951540946960449,3.2066400051116943],"z":[1.499330997467041,1.4991443157196045],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.0,3.4869110584259033],"y":[9.0,4.951540946960449],"z":[0.0,1.499330997467041],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.8485374450683594,5.238856315612793],"y":[3.2066400051116943,3.2730560302734375],"z":[1.4991443157196045,1.4993155002593994],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[3.4869110584259033,5.596187591552734],"y":[4.951540946960449,4.740756511688232],"z":[1.499330997467041,1.4995111227035522],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[6.0,5.238856315612793],"y":[0.0,3.2730560302734375],"z":[0.0,1.4993155002593994],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"FDM Solution","x":[5.596187591552734,5.238856315612793],"y":[4.740756511688232,3.2730560302734375],"z":[1.4995111227035522,1. ...

# %%
### Deflected shape matching -- with individual qs
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import plotly.graph_objects as go

# q.grad.zero_()


# In[663]:


######################## explanation
## "The example model is based on a 5-nodes grid shell strcuture
##  which has a crossing projection in the x-y plane"
##  The FE part would be based on the Euler-bernoulli beam theory


# In[664]:


## Initial Geom
# Initial Coords:
node_coords = torch.tensor(
    [[0.0, 3.0, 0.0], [0.0, 6.0, 0.0], [3.0, 0.0, 0.0], [3.0, 3.0, 0.0], [3.0, 6.0, 0.0], [3.0, 9.0, 0.0],
     [6.0, 0.0, 0.0], [6.0, 3.0, 0.0], [6.0, 6.0, 0.0] ,[6.0, 9.0, 0.0], [9.0, 3.0 ,0.0], [9.0, 6.0, 0.0]],
    dtype=torch.float32, requires_grad=True, )
connectivity = [[1, 4], [2, 5], [3, 4], [5, 4], [6, 5], [4, 8],[5, 9], [7, 8], [9, 8],[10, 9],[12, 9],[11, 8]]
n_dof_per_node = 6  # Degrees of freedom per node
total_dof = n_dof_per_node * len(node_coords)
Fixed_nodes = [1, 2, 3, 6, 7, 10, 11, 12]
Free_nodes = []
n_elements = len(connectivity)
n_nodes = len(node_coords)
for i in range(1, n_nodes + 1):
    if i not in Fixed_nodes:
        Free_nodes.append(i)
idx_CF = [node - 1 for node in Fixed_nodes]
idx_CN = [i for i in range(n_nodes) if i not in idx_CF]


## Force condition
####### Force condition -> need for modification
## +0 to x direction ; +1 to y direction ; +2 to Z direction
## +3 Bending around the z axis ; +4 bending around y axis ; +5 Twisting
# implement upwards loading of 50 kN at every free nodes
F = torch.zeros(total_dof, dtype=torch.float32)
f_n = Free_nodes
f_type = [2, 2, 2, 2]  # The force type
F_value = torch.tensor([50.0, 50.0, 50.0, 50.0]) * 1000  # The force value/direction
r = 1 / torch.max(F_value)
# print(r)
F_sign = torch.sign(F_value)
for idx, i in enumerate(f_n):
    F[6 * (i - 1) + f_type[idx]] = F_value[idx]  # unit: KN / KN*m

px = torch.zeros(len(f_n), 1, dtype=torch.float32)
py = torch.zeros(len(f_n), 1, dtype=torch.float32)
pz = torch.zeros(len(f_n), 1, dtype=torch.float32)

for i in range(len(f_n)):
    if f_type[idx] == 0:
        px[i] = F_value[i]
    elif f_type[idx] == 1:
        py[i] = F_value[i]
    elif f_type[idx] == 2:
        pz[i] = F_value[i]


## Obtaining Matrix D
# Assembly the nodal-branch matrix:
C = torch.zeros(n_elements, n_nodes, dtype=torch.float32)
for n, (i, j) in enumerate(connectivity):
    C[n, i - 1] = 1
    C[n, j - 1] = -1
CF = C[:, idx_CF]
CN = C[:, idx_CN]


# Assembly D
def FDM (Q,CN=CN, CF=CF, px=px, py=py, pz=pz,Fixed_nodes=Fixed_nodes, Free_nodes=Free_nodes,node_coords=node_coords) :
    Dn = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CN))
    DF = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CF))
    ## Coordinates solution
    # separate the coordinates:
    fixed_idces = [node - 1 for node in Fixed_nodes]
    xF = node_coords[fixed_idces, 0].unsqueeze(1)
    yF = node_coords[fixed_idces, 1].unsqueeze(1)
    zF = node_coords[fixed_idces, 2].unsqueeze(1)
    xN = torch.matmul(torch.inverse(Dn), (px - torch.matmul(DF, xF)))
    yN = torch.matmul(torch.inverse(Dn), (py - torch.matmul(DF, yF)))
    zN = torch.matmul(torch.inverse(Dn), (pz - torch.matmul(DF, zF)))
    ## Coordinates renewal: 
    new_node_coords = node_coords.clone()
    for idx, node in enumerate(Free_nodes):
        node_idx = node - 1
        new_node_coords[node_idx, 0] = xN[idx]
        new_node_coords[node_idx, 1] = yN[idx]
        new_node_coords[node_idx, 2] = zN[idx]

    return new_node_coords

# In[670]:


## Check point: FDM completed
# if q.grad is not None:
#     q.grad.zero_()
# loss = torch.sum(new_node_coords[:, 2])
# loss.backward()
# print("Gradient of q:")
# print(q.grad)


############ Now comes to FE part:
#### Default values (in meters, Pascals, etc.)
## For rectangular sections
# D_width = 0.1
# D_height = 0.2
# D_young_modulus = 210e9  # Young's modulus in Pascals
# D_shear_modulus = 81e9  # Shear modulus in Pascals
# D_poisson_ratio = 0.3
# cross_section_angle_a = 0  # Cross-section angle at node 1 (anti-clockwise)
# cross_section_angle_b = 0  # Cross-section angle at node 2 (anti-clockwise)
# a_small_number = 1e-10

D_radius = 0.05
D_young_modulus = 210e9  # Young's modulus in Pascals
D_shear_modulus = 81e9  # Shear modulus in Pascals
D_poisson_ratio = 0.3
cross_section_angle_a = 0  # Cross-section angle at node 1 (anti-clockwise)
cross_section_angle_b = 0  # Cross-section angle at node 2 (anti-clockwise)
a_small_number = 1e-10


# In[673]:


def rotation(v, k, theta):
    """Rotation of vector v around axis k by angle theta."""
    k = k / torch.norm(k)  # Normalize k
    cross_product = torch.cross(k, v)
    dot_product = torch.dot(k, v)

    # Ensure theta is a tensor
    theta = torch.tensor(theta, dtype=torch.float32) if not isinstance(theta, torch.Tensor) else theta

    v_rotated = v * torch.cos(theta) + cross_product * torch.sin(theta) + k * dot_product * (1 - torch.cos(theta))
    return v_rotated


# In[674]:


###### Element Creating (euler beam)
# For rectangular sections
# class Beam:
#     def __init__(self, node_coordinates, width=D_width, height=D_height, young_modulus=D_young_modulus,
#                  shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
#                  Beta_b=cross_section_angle_b):
#         self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

#         # Material and geometry
#         self.width = width
#         self.height = height
#         self.young_modulus = young_modulus
#         self.shear_modulus = shear_modulus
#         self.poisson_ratio = poisson_ratio

#         # Cross-sectional properties
#         self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
#         self.Iy = (self.width * self.height ** 3) / 12
#         self.Iz = (self.width ** 3 * self.height) / 12
#         self.A = self.width * self.height
#         self.J = (self.width * self.height ** 3) / 3

#         # Stiffness components
#         self.S_u = self.young_modulus * self.A / self.length
#         self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
#         self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
#         self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
#         self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
#         self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
#         self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
#         self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
#         self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
#         self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
#         self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
#         self.S_Tr = self.shear_modulus * self.J / self.length

#         # Section rotations at the two ends
#         self.Beta_a = Beta_a
#         self.Beta_b = Beta_b


# In[675]:


# For circular sections
class Beam:
    def __init__(self, node_coordinates, R=D_radius, young_modulus=D_young_modulus,
                 shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                 Beta_b=cross_section_angle_b):
        self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

        # Material and geometry
        self.radius = R
        self.young_modulus = young_modulus
        self.shear_modulus = shear_modulus
        self.poisson_ratio = poisson_ratio

        # Cross-sectional properties
        self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
        self.Iy = (torch.pi * self.radius ** 4) / 4 
        self.Iz = self.Iy
        self.A = torch.pi * self.radius ** 2
        self.J = (torch.pi * self.radius ** 4) / 2

        # Stiffness components
        self.S_u = self.young_modulus * self.A / self.length
        self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
        self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
        self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
        self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
        self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
        self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
        self.S_Tr = self.shear_modulus * self.J / self.length

        # Section rotations at the two ends
        self.Beta_a = Beta_a
        self.Beta_b = Beta_b

    def get_element_stiffness_matrix(self):
        """Element stiffness matrix."""
        K_element = torch.tensor([
            [self.S_u, 0, 0, 0, 0, 0, -self.S_u, 0, 0, 0, 0, 0],
            [0, self.S_v1a, 0, 0, 0, self.S_theta1a, 0, -self.S_v1a, 0, 0, 0, self.S_theta1a],
            [0, 0, self.S_v2a, 0, -self.S_theta2a, 0, 0, 0, -self.S_v2a, 0, -self.S_theta2a, 0],
            [0, 0, 0, self.S_Tr, 0, 0, 0, 0, 0, -self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2b, 0, 0, 0, self.S_v2b, 0, self.S_theta2c, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1b, 0, -self.S_v1b, 0, 0, 0, self.S_theta1c],
            [-self.S_u, 0, 0, 0, 0, 0, self.S_u, 0, 0, 0, 0, 0],
            [0, -self.S_v1a, 0, 0, 0, -self.S_theta1a, 0, self.S_v1a, 0, 0, 0, -self.S_theta1a],
            [0, 0, -self.S_v2a, 0, self.S_theta2a, 0, 0, 0, self.S_v2a, 0, self.S_theta2a, 0],
            [0, 0, 0, -self.S_Tr, 0, 0, 0, 0, 0, self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2c, 0, 0, 0, self.S_v2b, 0, self.S_theta2b, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1c, 0, -self.S_v1b, 0, 0, 0, self.S_theta1b],
        ], dtype=torch.float32)

        return K_element

    def System_Transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        # print(vector_x,vector_y,vector_z)
        # Calculate alpha and ceta using PyTorch
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)
        # print(alpha)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)

        # Z_axis_b = rotation(V_projection, X_axis, self.Beta_b)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        # Y_axis_b = rotation(Z_axis_b, X_axis, torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        # Z_axis_b = Z_axis_b / torch.norm(Z_axis_b)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)
        # Y_axis_b = Y_axis_b / torch.norm(Y_axis_b)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)
        matrix_T = torch.zeros((12, 12), dtype=torch.float32)
        for i in range(0, 12, 3):
            matrix_T[i:i + 3, i:i + 3] = lambda_matrix
        return matrix_T

    def nodal_transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        # Calculate alpha and ceta using PyTorch
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)

        # Z_axis_b = rotation(V_projection, X_axis, self.Beta_b)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        # Y_axis_b = rotation(Z_axis_b, X_axis, torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        # Z_axis_b = Z_axis_b / torch.norm(Z_axis_b)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)
        # Y_axis_b = Y_axis_b / torch.norm(Y_axis_b)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)

        return lambda_matrix


# In[676]:


def assemble_stiffness_matrix(beams, n_nodes, n_dof_per_node, connectivity):
    """Global stiffness matrix assembly."""
    total_dof = n_nodes * n_dof_per_node  # Total degrees of freedom
    K_global = torch.zeros((total_dof, total_dof), dtype=torch.float32)
    for idx, (i, j) in enumerate(connectivity):
        Matrix_T = beams[idx].System_Transform()  # Get transformation matrix

        K_element = torch.matmul(torch.transpose(Matrix_T, 0, 1),
                                 torch.matmul(beams[idx].get_element_stiffness_matrix(), Matrix_T))

        start_idx = (i - 1) * n_dof_per_node
        end_idx = (j - 1) * n_dof_per_node
        K_global[start_idx:start_idx + 6, start_idx:start_idx + 6] = K_global[start_idx:start_idx + 6,
                                                                     start_idx:start_idx + 6] + K_element[0:6, 0:6]
        K_global[end_idx:end_idx + 6, end_idx:end_idx + 6] = K_global[end_idx:end_idx + 6,
                                                             end_idx:end_idx + 6] + K_element[6:12, 6:12]
        K_global[start_idx:start_idx + 6, end_idx:end_idx + 6] = K_global[start_idx:start_idx + 6,
                                                                 end_idx:end_idx + 6] + K_element[0:6, 6:12]
        K_global[end_idx:end_idx + 6, start_idx:start_idx + 6] = K_global[end_idx:end_idx + 6,
                                                                 start_idx:start_idx + 6] + K_element[6:12, 0:6]

    return K_global


# In[677]:


def Strain_E(node_coords, connectivity, fixed_dof, F):
    # node_coords[:, 2] = 0.0
    # Element Assembly
    beams = []
    for connection in connectivity:
        node_1_coords = node_coords[connection[0] - 1]
        node_2_coords = node_coords[connection[1] - 1]
        beam = Beam(node_coordinates=torch.stack([node_1_coords, node_2_coords]),
                    R=D_radius, young_modulus=D_young_modulus,
                    shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                    Beta_b=cross_section_angle_b)
        beams.append(beam)
    # Stiffness renewal
    K_global = assemble_stiffness_matrix(beams, n_nodes=len(node_coords), n_dof_per_node=6, connectivity=connectivity)
    K_global[fixed_dof, :] = K_global[fixed_dof, :] - K_global[fixed_dof, :]
    K_global[:, fixed_dof] = K_global[:, fixed_dof] - K_global[:, fixed_dof]
    K_global[fixed_dof, fixed_dof] = 1e5
    rank_K = torch.linalg.matrix_rank(K_global)

    if rank_K < K_global.shape[0]:
        print("Warning: The stiffness matrix is not of full rank")
    else:
        displacements = torch.linalg.solve(K_global, F)

    # Compute strain energy
    strain_energy_list = []
    Local_d = torch.zeros(len(connectivity), 12, dtype=torch.float32)
    for n, (i, j) in enumerate(connectivity):
        matrix_T = beams[n].System_Transform()
        Tep_displacements = torch.cat(
            [displacements[6 * (i - 1):6 * (i - 1) + 6], displacements[6 * (j - 1):6 * (j - 1) + 6]], dim=0)
        Local_d_n = torch.matmul(Tep_displacements, matrix_T.T)
        Local_d[n, :] = Local_d_n.clone()
        K_g = torch.matmul(torch.transpose(matrix_T, 0, 1),
                           torch.matmul(beams[n].get_element_stiffness_matrix(), matrix_T))

        strain_energy_list.append(torch.matmul(Local_d_n, torch.matmul(K_g, Local_d_n.reshape(-1, 1))))

    Strain_energy = torch.stack(strain_energy_list)

    return Strain_energy, Local_d, displacements, beams


# In[678]:


# Element creating
#################  input below:
############################################################################################################## input
# initial coordinates

####### BCs
fixed_dof = []
for node in Fixed_nodes:
    fixed_dof.extend([(node - 1) * 6 + i for i in range(6)])
####### Gradient descent
step = 0.001
epochs = 1000
Obj_coords = 3
####### Plotting
steps = 20  # steps for tracing deformation shape
###################################################################################################################################################
###################################################################################################################################################

### Defining the OBJ:
Obj_coords = torch.tensor([1.5, 1.5, 1.5, 1.5])
def Loss(Free_nodes, new_node_coords, Obj_coords):
    n_free_nodes = len(Free_nodes)
    Free_nodes = torch.tensor(Free_nodes)
    y_pred = new_node_coords[(Free_nodes - 1), 2]  
    y_true = Obj_coords 
    error = torch.abs(y_true - y_pred)
    loss = torch.mean(error)
    return loss
# In[679]:

# Optimized Variables
## initial variables
q = torch.rand(12, requires_grad=True)
## Optimization
torch.autograd.set_detect_anomaly(True)
# Optimizer setting
optimizer = optim.Adam([q], lr=step)
# Initilizing
# New_Coordinates = torch.zeros(n_nodes * 3, dtype=torch.float32)
Loss_his = []
Disp_his = []
# Loop start
for iteration in range(epochs + 1):
    print('ite',iteration)
    # Forwards
    Q = torch.diag(q) * 1 / r  # scaling
    new_node_coords = FDM(Q)
    N_coords = new_node_coords.clone()
    Strain_energy, _, displacements, _ = Strain_E(N_coords, connectivity, fixed_dof, F)
    idx = 6 * torch.arange(n_nodes) + 2
    Ave_Disp = abs(torch.sum(displacements[idx] / len(Free_nodes)))
    Disp_his.append(Ave_Disp.item())
    N_coords = N_coords.reshape(-1)
    New_Coordinates = torch.zeros(n_nodes * 3, dtype=torch.float32)
    for n in range(n_nodes):
        New_Coordinates[3*n : 3*n+3] = N_coords[3*n : 3*n+3] + displacements[6*n : 6*n+3]
    New_Coordinates = New_Coordinates.view(n_nodes, 3).clone()
    # loss
    Loss_value = Loss(Free_nodes, New_Coordinates, Obj_coords)
    Loss_his.append(Loss_value.item())
    # Backwards
    optimizer.zero_grad()
    # print(q.grad)
    Loss_value.backward(retain_graph=True)

    # Grad
    gradients = q.grad
    print('Grad',gradients)
    frob_norm = torch.norm(gradients)
    optimizer.step()
    
    # print iteration
    if iteration % 5 == 0:
        print(f"Iteration {iteration}: Normalized Gradient = {frob_norm}, Adaptive learning rate = {step}")
print("Optimization completed.")
print(q)
# print("coordinates:",node_coords)

#############################################################################################################
## Visualization
# print(Coordinates)
# displacements = Strain_E(node_coords, connectivity, fixed_dof, F)[2]
# print("displacements:", displacements)
print("Deformed:", New_Coordinates)

x_orig = node_coords[:, 0].detach().numpy()
y_orig = node_coords[:, 1].detach().numpy()
z_orig = node_coords[:, 2].detach().numpy()

x_def = New_Coordinates[:, 0].detach().numpy()
y_def = New_Coordinates[:, 1].detach().numpy()
z_def = New_Coordinates[:, 2].detach().numpy()


fig = go.Figure()


for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_orig[i-1], x_orig[j-1]],
        y=[y_orig[i-1], y_orig[j-1]],
        z=[z_orig[i-1], z_orig[j-1]],
        mode='lines',
        line=dict(color='blue', width=4),
        name='Original Geometry'
    ))


for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_def[i-1], x_def[j-1]],
        y=[y_def[i-1], y_def[j-1]],
        z=[z_def[i-1], z_def[j-1]],
        mode='lines',
        line=dict(color='red', width=4),
        name='Deformed Geometry'
    ))


for node in Free_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_def[node-1]],
        y=[y_def[node-1]],
        z=[z_def[node-1]],
        mode='markers+text',
        marker=dict(size=5, color='green'),
        text=[f'Node {node}'],
        textposition='top center',
        name=f'Free Node {node}'
    ))


fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        aspectmode='data'
    ),
    title='Deformation Comparison: Original vs. Deformed Geometry (FE Analysis)',
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()

########################################################################################################################

### Plot the optimization history
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'blue'
ax1.set_xlabel('Iterations')
ax1.set_ylabel('Loss', color=color)
ax1.plot(range(epochs + 1), Loss_his, label='Loss History', color=color, linewidth=2)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True)

ax2 = ax1.twinx()
color = 'red'
ax2.set_ylabel('Average Displacement', color=color)
ax2.plot(range(epochs + 1), Disp_his, label='Average Displacement', color=color, linewidth=2, linestyle='--')
ax2.tick_params(axis='y', labelcolor=color)

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

plt.title('Loss & Average Displacement vs. Iterations')

plt.tight_layout()
plt.show()
# Out:
# ite 0
# Grad tensor([ 2.8731e-01,  2.9408e-01,  2.8738e-01, -2.1869e-04,  2.9398e-01,
#          1.5911e-03,  4.1456e-03,  3.3409e-01,  8.7850e-04,  3.7200e-01,
#          3.7192e-01,  3.3421e-01])
# Iteration 0: Normalized Gradient = 0.9154662489891052, Adaptive learning rate = 0.001
# ite 1
# Grad tensor([ 2.8854e-01,  2.9532e-01,  2.8862e-01, -2.1860e-04,  2.9522e-01,
#          1.6103e-03,  4.1974e-03,  3.3568e-01,  8.8805e-04,  3.7385e-01,
#          3.7377e-01,  3.3580e-01])
# ite 2
# Grad tensor([ 2.8978e-01,  2.9657e-01,  2.8985e-01, -2.1839e-04,  2.9647e-01,
#          1.6298e-03,  4.2500e-03,  3.3728e-01,  8.9763e-04,  3.7572e-01,
#          3.7564e-01,  3.3740e-01])
# ite 3
# Grad tensor([ 2.9103e-01,  2.9782e-01,  2.9110e-01, -2.1814e-04,  2.9772e-01,
#          1.6496e-03,  4.3033e-03,  3.3890e-01,  9.0731e-04,  3.7760e-01,
#          3.7752e-01,  3.3901e-01])
# ite 4
# Grad tensor([ 2.9228e-01,  2.9908e-01,  2.9236e-01, -2.1787e-04,  2.9898e-01,
#          1.6698e-03,  4.3575e-03,  3.4053e-01,  9.1709e-04,  3.7950e-01,
#          3.7942e-01,  3.4064e-01])
# ite 5
# Grad tensor([ 2.9355e-01,  3.0035e-01,  2.9362e-01, -2.1773e-04,  3.0025e-01,
#          1.6900e-03,  4.4123e-03,  3.4217e-01,  9.2700e-04,  3.8142e-01,
#          3.8133e-01,  3.4228e-01])
# Iteration 5: Normalized Gradient = 0.9369603991508484, Adaptive learning rate = 0.001
# ite 6
# Grad tensor([ 2.9482e-01,  3.0163e-01,  2.9489e-01, -2.1748e-04,  3.0153e-01,
#          1.7107e-03,  4.4680e-03,  3.4382e-01,  9.3701e-04,  3.8335e-01,
#          3.8326e-01,  3.4393e-01])
# ite 7
# Grad tensor([ 2.9610e-01,  3.0292e-01,  2.9618e-01, -2.1721e-04,  3.0282e-01,
#          1.7318e-03,  4.5246e-03,  3.4548e-01,  9.4724e-04,  3.8529e-01,
#          3.8520e-01,  3.4560e-01])
# ite 8
# Grad tensor([ 2.9740e-01,  3.0422e-01,  2.9747e-01, -2.1705e-04,  3.0411e-01,
#          1.7530e-03,  4.5820e-03,  3.4716e-01,  9.5749e-04,  3.8725e-01,
#          3.8716e-01,  3.4728e-01])
# ite 9
# Grad tensor([ 2.9870e-01,  3.0552e-01,  2.9876e-01, -2.1678e-04,  3.0542e-01,
#          1.7747e-03,  4.6403e-03,  3.4886e-01,  9.6788e-04,  3.8923e-01,
#          3.8914e-01,  3.4897e-01])
# ite 10
# Grad tensor([ 3.0000e-01,  3.0684e-01,  3.0007e-01, -2.1657e-04,  3.0673e-01,
#          1.7966e-03,  4.6995e-03,  3.5056e-01,  9.7839e-04,  3.9123e-01,
#          3.9113e-01,  3.5068e-01])
# Iteration 10: Normalized Gradient = 0.9592790603637695, Adaptive learning rate = 0.001
# ite 11
# Grad tensor([ 3.0132e-01,  3.0816e-01,  3.0139e-01, -2.1639e-04,  3.0805e-01,
#          1.8189e-03,  4.7597e-03,  3.5228e-01,  9.8908e-04,  3.9324e-01,
#          3.9314e-01,  3.5240e-01])
# ite 12
# Grad tensor([ 3.0265e-01,  3.0949e-01,  3.0272e-01, -2.1616e-04,  3.0939e-01,
#          1.8416e-03,  4.8208e-03,  3.5402e-01,  9.9990e-04,  3.9527e-01,
#          3.9517e-01,  3.5414e-01])
# ite 13
# Grad tensor([ 3.0399e-01,  3.1083e-01,  3.0406e-01, -2.1591e-04,  3.1073e-01,
#          1.8647e-03,  4.8828e-03,  3.5577e-01,  1.0107e-03,  3.9732e-01,
#          3.9721e-01,  3.5589e-01])
# ite 14
# Grad tensor([ 3.0534e-01,  3.1219e-01,  3.0540e-01, -2.1575e-04,  3.1208e-01,
#          1.8881e-03,  4.9459e-03,  3.5754e-01,  1.0218e-03,  3.9939e-01,
#          3.9928e-01,  3.5765e-01])
# ite 15
# Grad tensor([ 3.0670e-01,  3.1355e-01,  3.0676e-01, -2.1553e-04,  3.1344e-01,
#          1.9119e-03,  5.0101e-03,  3.5932e-01,  1.0330e-03,  4.0147e-01,
#          4.0136e-01,  3.5943e-01])
# Iteration 15: Normalized Gradient = 0.9825116991996765, Adaptive learning rate = 0.001
# ite 16
# Grad tensor([ 3.0807e-01,  3.1492e-01,  3.0813e-01, -2.1525e-04,  3.1481e-01,
#          1.9362e-03,  5.0754e-03,  3.6111e-01,  1.0444e-03,  4.0358e-01,
#          4.0347e-01,  3.6123e-01])
# ite 17
# Grad tensor([ 3.0945e-01,  3.1630e-01,  3.0951e-01, -2.1512e-04,  3.1619e-01,
#          1.9608e-03,  5.1417e-03,  3.6293e-01,  1.0560e-03,  4.0571e-01,
#          4.0559e-01,  3.6305e-01])
# ite 18
# Grad tensor([ 3.1084e-01,  3.1769e-01,  3.1090e-01, -2.1478e-04,  3.1758e-01,
#          1.9859e-03,  5.2093e-03,  3.6476e-01,  1.0677e-03,  4.0785e-01,
#          4.0774e-01,  3.6488e-01])
# ite 19
# Grad tensor([ 3.1224e-01,  3.1910e-01,  3.1230e-01, -2.1462e-04,  3.1899e-01,
#          2.0113e-03,  5.2780e-03,  3.6660e-01,  1.0795e-03,  4.1002e-01,
#          4.0990e-01,  3.6672e-01])
# ite 20
# Grad tensor([ 3.1365e-01,  3.2051e-01,  3.1371e-01, -2.1446e-04,  3.2040e-01,
#          2.0372e-03,  5.3479e-03,  3.6847e-01,  1.0916e-03,  4.1221e-01,
#          4.1208e-01,  3.6859e-01])
# Iteration 20: Normalized Gradient = 1.0067534446716309, Adaptive learning rate = 0.001
# ite 21
# Grad tensor([ 3.1507e-01,  3.2193e-01,  3.1513e-01, -2.1416e-04,  3.2182e-01,
#          2.0636e-03,  5.4189e-03,  3.7035e-01,  1.1037e-03,  4.1441e-01,
#          4.1429e-01,  3.7047e-01])
# ite 22
# Grad tensor([ 3.1651e-01,  3.2337e-01,  3.1656e-01, -2.1398e-04,  3.2326e-01,
#          2.0905e-03,  5.4914e-03,  3.7225e-01,  1.1162e-03,  4.1665e-01,
#          4.1652e-01,  3.7237e-01])
# ite 23
# Grad tensor([ 3.1795e-01,  3.2481e-01,  3.1801e-01, -2.1380e-04,  3.2470e-01,
#          2.1178e-03,  5.5650e-03,  3.7416e-01,  1.1286e-03,  4.1890e-01,
#          4.1877e-01,  3.7428e-01])
# ite 24
# Grad tensor([ 3.1941e-01,  3.2627e-01,  3.1947e-01, -2.1355e-04,  3.2616e-01,
#          2.1457e-03,  5.6401e-03,  3.7610e-01,  1.1414e-03,  4.2117e-01,
#          4.2104e-01,  3.7622e-01])
# ite 25
# Grad tensor([ 3.2088e-01,  3.2774e-01,  3.2093e-01, -2.1328e-04,  3.2763e-01,
#          2.1741e-03,  5.7165e-03,  3.7805e-01,  1.1542e-03,  4.2347e-01,
#          4.2334e-01,  3.7817e-01])
# Iteration 25: Normalized Gradient = 1.032105803489685, Adaptive learning rate = 0.001
# ite 26
# Grad tensor([ 3.2236e-01,  3.2922e-01,  3.2242e-01, -2.1307e-04,  3.2911e-01,
#          2.2031e-03,  5.7944e-03,  3.8002e-01,  1.1674e-03,  4.2580e-01,
#          4.2566e-01,  3.8015e-01])
# ite 27
# Grad tensor([ 3.2386e-01,  3.3072e-01,  3.2391e-01, -2.1294e-04,  3.3060e-01,
#          2.2324e-03,  5.8736e-03,  3.8202e-01,  1.1806e-03,  4.2814e-01,
#          4.2800e-01,  3.8214e-01])
# ite 28
# Grad tensor([ 3.2536e-01,  3.3222e-01,  3.2542e-01, -2.1262e-04,  3.3211e-01,
#          2.2625e-03,  5.9546e-03,  3.8403e-01,  1.1941e-03,  4.3051e-01,
#          4.3037e-01,  3.8415e-01])
# ite 29
# Grad tensor([ 3.2688e-01,  3.3374e-01,  3.2693e-01, -2.1248e-04,  3.3363e-01,
#          2.2932e-03,  6.0369e-03,  3.8606e-01,  1.2079e-03,  4.3291e-01,
#          4.3277e-01,  3.8619e-01])
# ite 30
# Grad tensor([ 3.2842e-01,  3.3527e-01,  3.2847e-01, -2.1228e-04,  3.3516e-01,
#          2.3243e-03,  6.1209e-03,  3.8812e-01,  1.2219e-03,  4.3533e-01,
#          4.3519e-01,  3.8824e-01])
# Iteration 30: Normalized Gradient = 1.058674931526184, Adaptive learning rate = 0.001
# ite 31
# Grad tensor([ 3.2996e-01,  3.3681e-01,  3.3001e-01, -2.1207e-04,  3.3670e-01,
#          2.3561e-03,  6.2065e-03,  3.9019e-01,  1.2360e-03,  4.3778e-01,
#          4.3763e-01,  3.9031e-01])
# ite 32
# Grad tensor([ 3.3152e-01,  3.3837e-01,  3.3157e-01, -2.1184e-04,  3.3825e-01,
#          2.3885e-03,  6.2937e-03,  3.9229e-01,  1.2503e-03,  4.4025e-01,
#          4.4010e-01,  3.9241e-01])
# ite 33
# Grad tensor([ 3.3310e-01,  3.3994e-01,  3.3314e-01, -2.1162e-04,  3.3982e-01,
#          2.4216e-03,  6.3828e-03,  3.9441e-01,  1.2649e-03,  4.4276e-01,
#          4.4260e-01,  3.9453e-01])
# ite 34
# Grad tensor([ 3.3468e-01,  3.4152e-01,  3.3473e-01, -2.1141e-04,  3.4140e-01,
#          2.4553e-03,  6.4736e-03,  3.9655e-01,  1.2798e-03,  4.4528e-01,
#          4.4513e-01,  3.9667e-01])
# ite 35
# Grad tensor([ 3.3628e-01,  3.4311e-01,  3.3633e-01, -2.1128e-04,  3.4300e-01,
#          2.4898e-03,  6.5662e-03,  3.9871e-01,  1.2948e-03,  4.4784e-01,
#          4.4768e-01,  3.9883e-01])
# Iteration 35: Normalized Gradient = 1.0865763425827026, Adaptive learning rate = 0.001
# ite 36
# Grad tensor([ 3.3790e-01,  3.4472e-01,  3.3794e-01, -2.1098e-04,  3.4460e-01,
#          2.5249e-03,  6.6607e-03,  4.0090e-01,  1.3102e-03,  4.5043e-01,
#          4.5027e-01,  4.0102e-01])
# ite 37
# Grad tensor([ 3.3953e-01,  3.4634e-01,  3.3957e-01, -2.1082e-04,  3.4623e-01,
#          2.5608e-03,  6.7572e-03,  4.0311e-01,  1.3257e-03,  4.5304e-01,
#          4.5288e-01,  4.0323e-01])
# ite 38
# Grad tensor([ 3.4117e-01,  3.4798e-01,  3.4121e-01, -2.1062e-04,  3.4786e-01,
#          2.5974e-03,  6.8557e-03,  4.0534e-01,  1.3416e-03,  4.5569e-01,
#          4.5552e-01,  4.0546e-01])
# ite 39
# Grad tensor([ 3.4283e-01,  3.4963e-01,  3.4287e-01, -2.1043e-04,  3.4951e-01,
#          2.6348e-03,  6.9562e-03,  4.0760e-01,  1.3576e-03,  4.5836e-01,
#          4.5819e-01,  4.0772e-01])
# ite 40
# Grad tensor([ 3.4450e-01,  3.5129e-01,  3.4454e-01, -2.1023e-04,  3.5118e-01,
#          2.6730e-03,  7.0588e-03,  4.0988e-01,  1.3741e-03,  4.6107e-01,
#          4.6089e-01,  4.1001e-01])
# Iteration 40: Normalized Gradient = 1.1159300804138184, Adaptive learning rate = 0.001
# ite 41
# Grad tensor([ 3.4619e-01,  3.5297e-01,  3.4623e-01, -2.1012e-04,  3.5285e-01,
#          2.7120e-03,  7.1636e-03,  4.1219e-01,  1.3908e-03,  4.6380e-01,
#          4.6363e-01,  4.1231e-01])
# ite 42
# Grad tensor([ 3.4790e-01,  3.5467e-01,  3.4794e-01, -2.0984e-04,  3.5455e-01,
#          2.7519e-03,  7.2706e-03,  4.1452e-01,  1.4077e-03,  4.6657e-01,
#          4.6640e-01,  4.1465e-01])
# ite 43
# Grad tensor([ 3.4962e-01,  3.5638e-01,  3.4966e-01, -2.0968e-04,  3.5626e-01,
#          2.7925e-03,  7.3800e-03,  4.1688e-01,  1.4249e-03,  4.6938e-01,
#          4.6919e-01,  4.1701e-01])
# ite 44
# Grad tensor([ 3.5136e-01,  3.5810e-01,  3.5139e-01, -2.0950e-04,  3.5798e-01,
#          2.8342e-03,  7.4918e-03,  4.1927e-01,  1.4425e-03,  4.7221e-01,
#          4.7203e-01,  4.1940e-01])
# ite 45
# Grad tensor([ 3.5311e-01,  3.5984e-01,  3.5314e-01, -2.0934e-04,  3.5972e-01,
#          2.8767e-03,  7.6058e-03,  4.2168e-01,  1.4602e-03,  4.7508e-01,
#          4.7489e-01,  4.2181e-01])
# Iteration 45: Normalized Gradient = 1.14686918258667, Adaptive learning rate = 0.001
# ite 46
# Grad tensor([ 3.5488e-01,  3.6159e-01,  3.5491e-01, -2.0912e-04,  3.6147e-01,
#          2.9201e-03,  7.7226e-03,  4.2412e-01,  1.4786e-03,  4.7798e-01,
#          4.7779e-01,  4.2425e-01])
# ite 47
# Grad tensor([ 3.5666e-01,  3.6336e-01,  3.5669e-01, -2.0898e-04,  3.6324e-01,
#          2.9646e-03,  7.8418e-03,  4.2659e-01,  1.4970e-03,  4.8092e-01,
#          4.8073e-01,  4.2672e-01])
# ite 48
# Grad tensor([ 3.5846e-01,  3.6515e-01,  3.5850e-01, -2.0882e-04,  3.6503e-01,
#          3.0100e-03,  7.9639e-03,  4.2909e-01,  1.5158e-03,  4.8390e-01,
#          4.8370e-01,  4.2922e-01])
# ite 49
# Grad tensor([ 3.6028e-01,  3.6695e-01,  3.6031e-01, -2.0862e-04,  3.6683e-01,
#          3.0566e-03,  8.0885e-03,  4.3162e-01,  1.5350e-03,  4.8691e-01,
#          4.8671e-01,  4.3175e-01])
# ite 50
# Grad tensor([ 3.6212e-01,  3.6877e-01,  3.6215e-01, -2.0850e-04,  3.6865e-01,
#          3.1041e-03,  8.2161e-03,  4.3418e-01,  1.5545e-03,  4.8996e-01,
#          4.8976e-01,  4.3431e-01])
# Iteration 50: Normalized Gradient = 1.1795363426208496, Adaptive learning rate = 0.001
# ite 51
# Grad tensor([ 3.6397e-01,  3.7060e-01,  3.6400e-01, -2.0830e-04,  3.7048e-01,
#          3.1528e-03,  8.3466e-03,  4.3677e-01,  1.5745e-03,  4.9305e-01,
#          4.9284e-01,  4.3690e-01])
# ite 52
# Grad tensor([ 3.6585e-01,  3.7245e-01,  3.6587e-01, -2.0816e-04,  3.7233e-01,
#          3.2027e-03,  8.4801e-03,  4.3938e-01,  1.5947e-03,  4.9617e-01,
#          4.9596e-01,  4.3952e-01])
# ite 53
# Grad tensor([ 3.6774e-01,  3.7432e-01,  3.6776e-01, -2.0800e-04,  3.7420e-01,
#          3.2536e-03,  8.6167e-03,  4.4204e-01,  1.6154e-03,  4.9934e-01,
#          4.9912e-01,  4.4217e-01])
# ite 54
# Grad tensor([ 3.6964e-01,  3.7621e-01,  3.6967e-01, -2.0784e-04,  3.7608e-01,
#          3.3058e-03,  8.7566e-03,  4.4472e-01,  1.6365e-03,  5.0254e-01,
#          5.0233e-01,  4.4485e-01])
# ite 55
# Grad tensor([ 3.7157e-01,  3.7811e-01,  3.7160e-01, -2.0773e-04,  3.7799e-01,
#          3.3593e-03,  8.8997e-03,  4.4743e-01,  1.6578e-03,  5.0579e-01,
#          5.0557e-01,  4.4756e-01])
# Iteration 55: Normalized Gradient = 1.2140899896621704, Adaptive learning rate = 0.001
# ite 56
# Grad tensor([ 3.7352e-01,  3.8003e-01,  3.7354e-01, -2.0757e-04,  3.7990e-01,
#          3.4141e-03,  9.0463e-03,  4.5018e-01,  1.6797e-03,  5.0908e-01,
#          5.0886e-01,  4.5031e-01])
# ite 57
# Grad tensor([ 3.7548e-01,  3.8197e-01,  3.7550e-01, -2.0741e-04,  3.8184e-01,
#          3.4701e-03,  9.1963e-03,  4.5296e-01,  1.7019e-03,  5.1241e-01,
#          5.1218e-01,  4.5310e-01])
# ite 58
# Grad tensor([ 3.7747e-01,  3.8392e-01,  3.7749e-01, -2.0734e-04,  3.8380e-01,
#          3.5276e-03,  9.3501e-03,  4.5578e-01,  1.7247e-03,  5.1579e-01,
#          5.1556e-01,  4.5591e-01])
# ite 59
# Grad tensor([ 3.7947e-01,  3.8590e-01,  3.7949e-01, -2.0716e-04,  3.8577e-01,
#          3.5865e-03,  9.5076e-03,  4.5863e-01,  1.7479e-03,  5.1921e-01,
#          5.1897e-01,  4.5877e-01])
# ite 60
# Grad tensor([ 3.8149e-01,  3.8789e-01,  3.8151e-01, -2.0705e-04,  3.8776e-01,
#          3.6468e-03,  9.6692e-03,  4.6152e-01,  1.7715e-03,  5.2267e-01,
#          5.2243e-01,  4.6166e-01])
# Iteration 60: Normalized Gradient = 1.250706434249878, Adaptive learning rate = 0.001
# ite 61
# Grad tensor([ 3.8354e-01,  3.8990e-01,  3.8355e-01, -2.0696e-04,  3.8977e-01,
#          3.7088e-03,  9.8344e-03,  4.6445e-01,  1.7956e-03,  5.2618e-01,
#          5.2594e-01,  4.6458e-01])
# ite 62
# Grad tensor([ 3.8560e-01,  3.9193e-01,  3.8562e-01, -2.0691e-04,  3.9180e-01,
#          3.7722e-03,  1.0004e-02,  4.6741e-01,  1.8202e-03,  5.2974e-01,
#          5.2950e-01,  4.6754e-01])
# ite 63
# Grad tensor([ 3.8768e-01,  3.9398e-01,  3.8770e-01, -2.0673e-04,  3.9385e-01,
#          3.8374e-03,  1.0178e-02,  4.7041e-01,  1.8452e-03,  5.3335e-01,
#          5.3310e-01,  4.7055e-01])
# ite 64
# Grad tensor([ 3.8979e-01,  3.9605e-01,  3.8980e-01, -2.0659e-04,  3.9592e-01,
#          3.9041e-03,  1.0356e-02,  4.7345e-01,  1.8709e-03,  5.3701e-01,
#          5.3676e-01,  4.7359e-01])
# ite 65
# Grad tensor([ 3.9192e-01,  3.9813e-01,  3.9193e-01, -2.0655e-04,  3.9800e-01,
#          3.9726e-03,  1.0539e-02,  4.7653e-01,  1.8969e-03,  5.4072e-01,
#          5.4046e-01,  4.7667e-01])
# Iteration 65: Normalized Gradient = 1.2895814180374146, Adaptive learning rate = 0.001
# ite 66
# Grad tensor([ 3.9407e-01,  4.0024e-01,  3.9408e-01, -2.0641e-04,  4.0011e-01,
#          4.0431e-03,  1.0727e-02,  4.7965e-01,  1.9237e-03,  5.4448e-01,
#          5.4422e-01,  4.7979e-01])
# ite 67
# Grad tensor([ 3.9624e-01,  4.0237e-01,  3.9625e-01, -2.0636e-04,  4.0224e-01,
#          4.1152e-03,  1.0919e-02,  4.8281e-01,  1.9510e-03,  5.4829e-01,
#          5.4803e-01,  4.8295e-01])
# ite 68
# Grad tensor([ 3.9843e-01,  4.0452e-01,  3.9844e-01, -2.0627e-04,  4.0438e-01,
#          4.1894e-03,  1.1116e-02,  4.8602e-01,  1.9787e-03,  5.5216e-01,
#          5.5189e-01,  4.8615e-01])
# ite 69
# Grad tensor([ 4.0064e-01,  4.0668e-01,  4.0065e-01, -2.0618e-04,  4.0655e-01,
#          4.2656e-03,  1.1319e-02,  4.8926e-01,  2.0072e-03,  5.5608e-01,
#          5.5580e-01,  4.8940e-01])
# ite 70
# Grad tensor([ 4.0288e-01,  4.0887e-01,  4.0289e-01, -2.0609e-04,  4.0874e-01,
#          4.3438e-03,  1.1527e-02,  4.9255e-01,  2.0362e-03,  5.6005e-01,
#          5.5978e-01,  4.9269e-01])
# Iteration 70: Normalized Gradient = 1.330938696861267, Adaptive learning rate = 0.001
# ite 71
# Grad tensor([ 3.5757e-01,  3.6331e-01,  3.5762e-01, -6.5552e-05,  3.6326e-01,
#         -1.8627e-02, -8.3405e-02,  2.0386e-01, -2.2178e-02, -1.4002e-01,
#         -1.4028e-01,  2.0358e-01])
# ite 72
# Grad tensor([ 3.5955e-01,  3.6532e-01,  3.5959e-01, -6.5324e-05,  3.6528e-01,
#         -1.8790e-02, -8.3912e-02,  2.0481e-01, -2.2257e-02, -1.4039e-01,
#         -1.4066e-01,  2.0452e-01])
# ite 73
# Grad tensor([ 3.6142e-01,  3.6712e-01,  3.6146e-01, -6.5552e-05,  3.6708e-01,
#         -1.7572e-02, -7.5717e-02,  2.1766e-01, -2.0166e-02, -1.2813e-01,
#         -1.2840e-01,  2.1735e-01])
# ite 85
# Grad tensor([ 3.8142e-01,  3.8403e-01,  3.8146e-01, -8.0126e-05,  3.8399e-01,
#         -1.7348e-02, -7.4508e-02,  2.1873e-01, -1.9873e-02, -1.2664e-01,
#         -1.2691e-01,  2.1843e-01])
# Iteration 85: Normalized Gradient = 0.8484491109848022, Adaptive learning rate = 0.001
# ite 86
# Grad tensor([ 3.8305e-01,  3.8536e-01,  3.8309e-01, -8.2150e-05,  3.8532e-01,
#         -1.7116e-02, -7.3269e-02,  2.1980e-01, -1.9572e-02, -1.2513e-01,
#         -1.2541e-01,  2.1949e-01])
# ite 87
# Grad tensor([ 3.8468e-01,  3.8669e-01,  3.8473e-01, -8.4492e-05,  3.8665e-01,
#         -1.6877e-02, -7.2004e-02,  2.2087e-01, -1.9265e-02, -1.2362e-01,
#         -1.2390e-01,  2.2056e-01])
# ite 88
# Grad tensor([ 3.8633e-01,  3.8803e-01,  3.8638e-01, -8.6584e-05,  3.8800e-01,
#         -1.6632e-02, -7.0720e-02,  2.2193e-01, -1.8952e-02, -1.2210e-01,
#         -1.2238e-01,  2.2162e-01])
# ite 89
# Grad tensor([ 3.8799e-01,  3.8939e-01,  3.8803e-01, -8.8994e-05,  3.8935e-01,
#         -1.6383e-02, -6.9420e-02,  2.2299e-01, -1.8635e-02, -1.2058e-01,
#         -1.2086e-01,  2.2268e-01])
# ite 90
# Grad tensor([ 3.8965e-01,  3.9075e-01,  3.8970e-01, -9.1541e-05,  3.9072e-01,
#         -1.6130e-02, -6.8108e-02,  2.2405e-01, -1.8314e-02, -1.1906e-01,
#         -1.1935e-01,  2.2374e-01])
# Iteration 90: Normalized Gradient = 0.8619503974914551, Adaptive learning rate = 0.001
# ite 91
# Grad tensor([ 3.9133e-01,  3.9213e-01,  3.9138e-01, -9.3951e-05,  3.9210e-01,
#         -1.5874e-02, -6.6788e-02,  2.2511e-01, -1.7990e-02, -1.1755e-01,
#         -1.1784e-01,  2.2480e-01])
# ite 92
# Grad tensor([ 3.9303e-01,  3.9353e-01,  3.9308e-01, -9.6543e-05,  3.9350e-01,
#         -1.5615e-02, -6.5462e-02,  2.2617e-01, -1.7665e-02, -1.1604e-01,
#         -1.1633e-01,  2.2586e-01])
# ite 93
# Grad tensor([ 3.9473e-01,  3.9495e-01,  3.9478e-01, -9.9135e-05,  3.9491e-01,
#         -1.5354e-02, -6.4133e-02,  2.2723e-01, -1.7337e-02, -1.1455e-01,
#         -1.1484e-01,  2.2692e-01])
# ite 94
# Grad tensor([ 3.9646e-01,  3.9638e-01,  3.9651e-01, -1.0173e-04,  3.9635e-01,
#         -1.5092e-02, -6.2802e-02,  2.2829e-01, -1.7009e-02, -1.1306e-01,
#         -1.1336e-01,  2.2798e-01])
# ite 95
# Grad tensor([ 3.9820e-01,  3.9783e-01,  3.9825e-01, -1.0450e-04,  3.9780e-01,
#         -1.4828e-02, -6.1473e-02,  2.2935e-01, -1.6680e-02, -1.1159e-01,
#         -1.1188e-01,  2.2904e-01])
# Iteration 95: Normalized Gradient = 0.8763483762741089, Adaptive learning rate = 0.001
# ite 96
# Grad tensor([ 3.9995e-01,  3.9931e-01,  4.0001e-01, -1.0714e-04,  3.9927e-01,
#         -1.4564e-02, -6.0144e-02,  2.3041e-01, -1.6351e-02, -1.1013e-01,
#         -1.1043e-01,  2.3010e-01])
# ite 97
# Grad tensor([ 4.0173e-01,  4.0080e-01,  4.0178e-01, -1.0996e-04,  4.0077e-01,
#         -1.4299e-02, -5.8820e-02,  2.3148e-01, -1.6021e-02, -1.0869e-01,
#         -1.0899e-01,  2.3116e-01])
# ite 98
# Grad tensor([ 4.0352e-01,  4.0232e-01,  4.0357e-01, -1.1278e-04,  4.0228e-01,
#         -1.4035e-02, -5.7499e-02,  2.3254e-01, -1.5692e-02, -1.0726e-01,
#         -1.0756e-01,  2.3222e-01])
# ite 99
# Grad tensor([ 4.0533e-01,  4.0386e-01,  4.0539e-01, -1.1551e-04,  4.0382e-01,
#         -1.3769e-02, -5.6183e-02,  2.3361e-01, -1.5363e-02, -1.0585e-01,
#         -1.0615e-01,  2.3329e-01])
# ite 100
# Grad tensor([ 4.0716e-01,  4.0542e-01,  4.0722e-01, -1.1837e-04,  4.0539e-01,
#         -1.3504e-02, -5.4873e-02,  2.3468e-01, -1.5035e-02, -1.0445e-01,
#         -1.0476e-01,  2.3436e-01])
# Iteration 100: Normalized Gradient = 0.8919709324836731, Adaptive learning rate = 0.001
# ite 101
# Grad tensor([ 4.0901e-01,  4.0701e-01,  4.0907e-01, -1.2101e-04,  4.0697e-01,
#         -1.3240e-02, -5.3569e-02,  2.3575e-01, -1.4708e-02, -1.0307e-01,
#         -1.0338e-01,  2.3543e-01])
# ite 102
# Grad tensor([ 4.1089e-01,  4.0862e-01,  4.1094e-01, -1.2383e-04,  4.0858e-01,
#         -1.2975e-02, -5.2271e-02,  2.3683e-01, -1.4381e-02, -1.0171e-01,
#         -1.0202e-01,  2.3651e-01])
# ite 103
# Grad tensor([ 4.1278e-01,  4.1025e-01,  4.1284e-01, -1.2665e-04,  4.1022e-01,
#         -1.2711e-02, -5.0980e-02,  2.3791e-01, -1.4056e-02, -1.0037e-01,
#         -1.0067e-01,  2.3759e-01])
# ite 104
# Grad tensor([ 4.1469e-01,  4.1192e-01,  4.1475e-01, -1.2933e-04,  4.1188e-01,
#         -1.2447e-02, -4.9696e-02,  2.3900e-01, -1.3731e-02, -9.9041e-02,
#         -9.9348e-02,  2.3867e-01])
# ite 105
# Grad tensor([ 4.1663e-01,  4.1360e-01,  4.1669e-01, -1.3206e-04,  4.1357e-01,
#         -1.2184e-02, -4.8419e-02,  2.4009e-01, -1.3408e-02, -9.7731e-02,
#         -9.8040e-02,  2.3976e-01])
# Iteration 105: Normalized Gradient = 0.909000813961029, Adaptive learning rate = 0.001
# ite 106
# Grad tensor([ 4.1859e-01,  4.1532e-01,  4.1865e-01, -1.3479e-04,  4.1529e-01,
#         -1.1921e-02, -4.7149e-02,  2.4118e-01, -1.3085e-02, -9.6438e-02,
#         -9.6748e-02,  2.4086e-01])
# ite 107
# Grad tensor([ 4.2057e-01,  4.1706e-01,  4.2063e-01, -1.3742e-04,  4.1703e-01,
#         -1.1659e-02, -4.5886e-02,  2.4228e-01, -1.2764e-02, -9.5163e-02,
#         -9.5473e-02,  2.4196e-01])
# ite 108
# Grad tensor([ 4.2258e-01,  4.1883e-01,  4.2264e-01, -1.3997e-04,  4.1880e-01,
#         -1.1397e-02, -4.4630e-02,  2.4339e-01, -1.2444e-02, -9.3905e-02,
#         -9.4216e-02,  2.4306e-01])
# ite 109
# Grad tensor([ 4.2461e-01,  4.2063e-01,  4.2467e-01, -1.4261e-04,  4.2060e-01,
#         -1.1136e-02, -4.3380e-02,  2.4450e-01, -1.2125e-02, -9.2663e-02,
#         -9.2975e-02,  2.4417e-01])
# ite 110
# Grad tensor([ 4.2667e-01,  4.2246e-01,  4.2673e-01, -1.4506e-04,  4.2242e-01,
#         -1.0874e-02, -4.2137e-02,  2.4562e-01, -1.1807e-02, -9.1438e-02,
#         -9.1750e-02,  2.4529e-01])
# Iteration 110: Normalized Gradient = 0.927558183670044, Adaptive learning rate = 0.001
# ite 111
# Grad tensor([ 3.0547e-01,  3.5762e-01,  3.0529e-01,  2.1234e-04,  3.5732e-01,
#         -3.5046e-02, -5.9214e-02, -3.6296e-01, -1.2889e-03, -4.1770e-01,
#         -4.1747e-01, -3.6321e-01])
# ite 112
# Grad tensor([ 3.0628e-01,  3.5860e-01,  3.0610e-01,  2.1882e-04,  3.5830e-01,
#         -3.3942e-02, -5.7196e-02, -3.6239e-01, -1.2413e-03, -4.1638e-01,
#         -4.1615e-01, -3.6264e-01])
# ite 113
# Grad tensor([ 3.0701e-01,  3.5956e-01,  3.0683e-01,  2.2749e-04,  3.5926e-01,
#         -3.2683e-02, -5.5022e-02, -3.6154e-01, -1.1980e-03, -4.1483e-01,
#         -4.1461e-01, -3.6179e-01])
# ite 114
# Grad tensor([ 3.0767e-01,  3.6049e-01,  3.0749e-01,  2.3799e-04,  3.6019e-01,
#         -3.1289e-02, -5.2716e-02, -3.6044e-01, -1.1582e-03, -4.1308e-01,
#         -4.1286e-01, -3.6070e-01])
# ite 115
# Grad tensor([ 3.0829e-01,  3.6142e-01,  3.0810e-01,  2.5041e-04,  3.6112e-01,
#         -2.9781e-02, -5.0295e-02, -3.5914e-01, -1.1217e-03, -4.1116e-01,
#         -4.1094e-01, -3.5940e-01])
# Iteration 115: Normalized Gradient = 1.0249333381652832, Adaptive learning rate = 0.001
# ite 116
# Grad tensor([ 3.0886e-01,  3.6233e-01,  3.0868e-01,  2.6444e-04,  3.6204e-01,
#         -2.8174e-02, -4.7779e-02, -3.5766e-01, -1.0879e-03, -4.0910e-01,
#         -4.0889e-01, -3.5792e-01])
# ite 117
# Grad tensor([ 3.0941e-01,  3.6325e-01,  3.0922e-01,  2.8010e-04,  3.6296e-01,
#         -2.6486e-02, -4.5184e-02, -3.5604e-01, -1.0566e-03, -4.0693e-01,
#         -4.0673e-01, -3.5631e-01])
# ite 118
# Grad tensor([ 3.0993e-01,  3.6418e-01,  3.0974e-01,  2.9718e-04,  3.6388e-01,
#         -2.4729e-02, -4.2522e-02, -3.5431e-01, -1.0275e-03, -4.0467e-01,
#         -4.0447e-01, -3.5457e-01])
# ite 119
# Grad tensor([ 3.1045e-01,  3.6512e-01,  3.1025e-01,  3.1575e-04,  3.6482e-01,
#         -2.2915e-02, -3.9806e-02, -3.5247e-01, -1.0004e-03, -4.0234e-01,
#         -4.0214e-01, -3.5274e-01])
# ite 120
# Grad tensor([ 3.1096e-01,  3.6607e-01,  3.1076e-01,  3.3556e-04,  3.6578e-01,
#         -2.1055e-02, -3.7047e-02, -3.5056e-01, -9.7496e-04, -3.9995e-01,
#         -3.9976e-01, -3.5083e-01])
# Iteration 120: Normalized Gradient = 1.0142126083374023, Adaptive learning rate = 0.001
# ite 121
# Grad tensor([ 4.4575e-01,  4.4070e-01,  4.4582e-01, -1.8558e-04,  4.4065e-01,
#         -5.9995e-03, -2.4109e-02,  2.5269e-01, -9.2062e-03, -7.9008e-02,
#         -7.9326e-02,  2.5237e-01])
# ite 122
# Grad tensor([ 4.4737e-01,  4.4235e-01,  4.4744e-01, -1.9008e-04,  4.4230e-01,
#         -5.4666e-03, -2.2292e-02,  2.5303e-01, -9.0202e-03, -7.8021e-02,
#         -7.8340e-02,  2.5272e-01])
# ite 123
# Grad tensor([ 4.4909e-01,  4.4408e-01,  4.4916e-01, -1.9436e-04,  4.4404e-01,
#         -4.9607e-03, -2.0546e-02,  2.5345e-01, -8.8244e-03, -7.7057e-02,
#         -7.7376e-02,  2.5314e-01])
# ite 124
# Grad tensor([ 4.5091e-01,  4.4591e-01,  4.5098e-01, -1.9845e-04,  4.4586e-01,
#         -4.4783e-03, -1.8860e-02,  2.5394e-01, -8.6198e-03, -7.6116e-02,
#         -7.6434e-02,  2.5363e-01])
# ite 125
# Grad tensor([ 4.5281e-01,  4.4781e-01,  4.5289e-01, -2.0223e-04,  4.4776e-01,
#         -4.0165e-03, -1.7228e-02,  2.5449e-01, -8.4072e-03, -7.5196e-02,
#         -7.5514e-02,  2.5417e-01])
# Iteration 125: Normalized Gradient = 0.9758487939834595, Adaptive learning rate = 0.001
# ite 126
# Grad tensor([ 4.5480e-01,  4.4980e-01,  4.5488e-01, -2.0582e-04,  4.4974e-01,
#         -3.5725e-03, -1.5643e-02,  2.5509e-01, -8.1876e-03, -7.4296e-02,
#         -7.4613e-02,  2.5478e-01])
# ite 127
# Grad tensor([ 4.5687e-01,  4.5185e-01,  4.5695e-01, -2.0909e-04,  4.5180e-01,
#         -3.1442e-03, -1.4100e-02,  2.5575e-01, -7.9615e-03, -7.3415e-02,
#         -7.3732e-02,  2.5544e-01])
# ite 128
# Grad tensor([ 0.2694, -0.2926,  0.2696, -0.0075, -0.2926, -0.0013,  0.0029,  0.1785,
#         -0.0084, -0.1847, -0.1843,  0.1781])
# ite 129
# Grad tensor([ 0.1277, -0.3719,  0.1276, -0.0068, -0.3721, -0.0059, -0.0017, -0.4183,
#         -0.0014, -0.4974, -0.4965, -0.4187])
# ite 130
# Grad tensor([ 0.1273, -0.3726,  0.1272, -0.0066, -0.3728, -0.0048, -0.0014, -0.4179,
#         -0.0013, -0.4964, -0.4955, -0.4183])
# Iteration 130: Normalized Gradient = 1.0732487440109253, Adaptive learning rate = 0.001
# ite 131
# Grad tensor([ 0.1268, -0.3728,  0.1267, -0.0064, -0.3730, -0.0038, -0.0011, -0.4174,
#         -0.0013, -0.4952, -0.4943, -0.4177])
# ite 132
# Grad tensor([ 0.2707, -0.2925,  0.2709, -0.0067, -0.2925, -0.0005,  0.0019,  0.1786,
#         -0.0074, -0.1830, -0.1826,  0.1782])
# ite 133
# Grad tensor([ 0.2707, -0.2919,  0.2709, -0.0062, -0.2919, -0.0004,  0.0017,  0.1785,
#         -0.0072, -0.1825, -0.1821,  0.1781])
# ite 134
# Grad tensor([ 2.7071e-01, -2.9107e-01,  2.7094e-01, -5.7140e-03, -2.9105e-01,
#         -1.9088e-04,  1.5129e-03,  1.7846e-01, -6.9026e-03, -1.8196e-01,
#         -1.8153e-01,  1.7807e-01])
# ite 135
# Grad tensor([ 2.7070e-01, -2.9014e-01,  2.7094e-01, -5.1105e-03, -2.9012e-01,
#         -3.8983e-05,  1.3609e-03,  1.7844e-01, -6.6250e-03, -1.8141e-01,
#         -1.8098e-01,  1.7805e-01])
# Iteration 135: Normalized Gradient = 0.6665763854980469, Adaptive learning rate = 0.001
# ite 136
# Grad tensor([-4.1666e-01, -4.9105e-01, -4.1635e-01, -2.0823e-04, -4.9076e-01,
#         -8.3742e-04,  1.7424e-03,  3.1937e-02, -5.3882e-03, -2.7364e-01,
#         -2.7381e-01,  3.1715e-02])
# ite 137
# Grad tensor([-4.1741e-01, -4.9074e-01, -4.1710e-01, -1.2783e-04, -4.9045e-01,
#         -1.3702e-03,  1.5563e-03,  3.1757e-02, -5.1464e-03, -2.7314e-01,
#         -2.7331e-01,  3.1533e-02])
# ite 138
# Grad tensor([-4.1782e-01, -4.9014e-01, -4.1752e-01, -5.3205e-05, -4.8984e-01,
#         -1.7675e-03,  1.4220e-03,  3.1632e-02, -4.9080e-03, -2.7256e-01,
#         -2.7273e-01,  3.1406e-02])
# ite 139
# Grad tensor([-4.1794e-01, -4.8926e-01, -4.1763e-01,  1.5780e-05, -4.8897e-01,
#         -2.0430e-03,  1.3338e-03,  3.1555e-02, -4.6728e-03, -2.7193e-01,
#         -2.7208e-01,  3.1328e-02])
# ite 140
# Grad tensor([-4.1778e-01, -4.8816e-01, -4.1747e-01,  7.9899e-05, -4.8786e-01,
#         -2.2092e-03,  1.2867e-03,  3.1522e-02, -4.4408e-03, -2.7123e-01,
#         -2.7138e-01,  3.1293e-02])
# Iteration 140: Normalized Gradient = 0.98708575963974, Adaptive learning rate = 0.001
# ite 141
# Grad tensor([-4.1737e-01, -4.8684e-01, -4.1707e-01,  1.3974e-04, -4.8654e-01,
#         -2.2773e-03,  1.2763e-03,  3.1527e-02, -4.2117e-03, -2.7049e-01,
#         -2.7064e-01,  3.1296e-02])
# ite 142
# Grad tensor([-4.1675e-01, -4.8534e-01, -4.1646e-01,  1.9545e-04, -4.8504e-01,
#         -2.2581e-03,  1.2981e-03,  3.1567e-02, -3.9856e-03, -2.6970e-01,
#         -2.6985e-01,  3.1334e-02])
# ite 143
# Grad tensor([-4.1594e-01, -4.8369e-01, -4.1565e-01,  2.4770e-04, -4.8338e-01,
#         -2.1611e-03,  1.3483e-03,  3.1638e-02, -3.7622e-03, -2.6888e-01,
#         -2.6902e-01,  3.1402e-02])
# ite 144
# Grad tensor([ 0.2672, -0.2794,  0.2675, -0.0005, -0.2794,  0.0003,  0.0011,  0.1780,
#         -0.0042, -0.1761, -0.1757,  0.1776])
# ite 145
# Grad tensor([ 4.6888e-01,  4.5174e-01,  4.6892e-01, -6.3210e-05,  4.5171e-01,
#          8.0786e-04, -4.0103e-03,  2.5814e-01, -3.6020e-03, -6.4910e-02,
#         -6.5195e-02,  2.5781e-01])
# Iteration 145: Normalized Gradient = 0.994705080986023, Adaptive learning rate = 0.001
# ite 146
# Grad tensor([ 4.6845e-01,  4.5067e-01,  4.6850e-01, -4.9522e-05,  4.5064e-01,
#          7.8248e-04, -4.0649e-03,  2.5809e-01, -3.3522e-03, -6.4678e-02,
#         -6.4962e-02,  2.5775e-01])
# ite 147
# Grad tensor([ 4.6837e-01,  4.4999e-01,  4.6841e-01, -3.6698e-05,  4.4996e-01,
#          7.9008e-04, -4.0006e-03,  2.5815e-01, -3.0994e-03, -6.4419e-02,
#         -6.4701e-02,  2.5782e-01])
# ite 148
# Grad tensor([ 4.6859e-01,  4.4966e-01,  4.6863e-01, -2.4556e-05,  4.4963e-01,
#          8.2680e-04, -3.8304e-03,  2.5832e-01, -2.8439e-03, -6.4136e-02,
#         -6.4416e-02,  2.5799e-01])
# ite 149
# Grad tensor([ 4.6909e-01,  4.4964e-01,  4.6913e-01, -1.3051e-05,  4.4961e-01,
#          8.8962e-04, -3.5664e-03,  2.5859e-01, -2.5857e-03, -6.3831e-02,
#         -6.4109e-02,  2.5825e-01])
# ite 150
# Grad tensor([ 4.6984e-01,  4.4990e-01,  4.6987e-01, -2.3192e-06,  4.4988e-01,
#          9.7577e-04, -3.2182e-03,  2.5894e-01, -2.3248e-03, -6.3508e-02,
#         -6.3784e-02,  2.5860e-01])
# Iteration 150: Normalized Gradient = 0.9941715598106384, Adaptive learning rate = 0.001
# ite 151
# Grad tensor([-0.2116,  0.2474, -0.2115, -0.0014,  0.2477, -0.0018, -0.0026,  0.1124,
#         -0.0017, -0.1548, -0.1556,  0.1122])
# ite 152
# Grad tensor([-0.2117,  0.2475, -0.2116, -0.0016,  0.2478, -0.0019, -0.0023,  0.1126,
#         -0.0015, -0.1545, -0.1553,  0.1124])
# ite 153
# Grad tensor([-0.2117,  0.2476, -0.2117, -0.0016,  0.2478, -0.0020, -0.0019,  0.1127,
#         -0.0013, -0.1543, -0.1551,  0.1125])
# ite 154
# Grad tensor([-0.2116,  0.2476, -0.2116, -0.0016,  0.2479, -0.0020, -0.0015,  0.1129,
#         -0.0011, -0.1540, -0.1548,  0.1127])
# ite 155
# Grad tensor([-0.2115,  0.2478, -0.2114, -0.0015,  0.2481, -0.0021, -0.0011,  0.1130,
#         -0.0009, -0.1538, -0.1545,  0.1128])
# Iteration 155: Normalized Gradient = 0.5342032313346863, Adaptive learning rate = 0.001
# ite 156
# Grad tensor([-4.1768e-01, -4.8080e-01, -4.1741e-01,  5.7607e-04, -4.8048e-01,
#         -2.8472e-03, -6.4347e-06,  3.1738e-02, -7.9165e-04, -2.6335e-01,
#         -2.6344e-01,  3.1483e-02])
# ite 157
# Grad tensor([-3.2489e-01, -3.7183e-01, -3.2468e-01,  3.9279e-04, -3.7153e-01,
#         -4.0873e-03, -6.0413e-04,  3.2976e-01, -5.6593e-05,  3.6032e-01,
#          3.6026e-01,  3.3005e-01])
# ite 158
# Grad tensor([-3.2468e-01, -3.7182e-01, -3.2446e-01,  3.8256e-04, -3.7152e-01,
#         -3.7486e-03, -8.3110e-04,  3.2995e-01, -7.5352e-05,  3.6008e-01,
#          3.6002e-01,  3.3023e-01])
# ite 159
# Grad tensor([-3.2432e-01, -3.7163e-01, -3.2410e-01,  3.7528e-04, -3.7133e-01,
#         -3.2215e-03, -7.4656e-04,  3.3026e-01, -9.1427e-05,  3.6004e-01,
#          3.5998e-01,  3.3055e-01])
# ite 160
# Grad tensor([-3.2384e-01, -3.7128e-01, -3.2362e-01,  3.7057e-04, -3.7098e-01,
#         -2.5248e-03, -3.8231e-04,  3.3071e-01, -1.0516e-04,  3.6018e-01,
#          3.6012e-01,  3.3100e-01])
# Iteration 160: Normalized Gradient = 0.9815425276756287, Adaptive learning rate = 0.001
# ite 161
# Grad tensor([-4.1601e-01, -4.7993e-01, -4.1574e-01,  5.2364e-04, -4.7960e-01,
#         -1.1070e-03,  7.4942e-05,  3.1934e-02,  6.3437e-06, -2.6269e-01,
#         -2.6278e-01,  3.1671e-02])
# ite 162
# Grad tensor([-3.5795e-01,  1.6475e-01, -3.5814e-01, -1.3075e-03,  1.6478e-01,
#          2.6539e-04, -1.1285e-03, -4.8064e-01,  6.7166e-05, -4.5271e-01,
#         -4.5315e-01, -4.8079e-01])
# ite 163
# Grad tensor([-3.5729e-01,  1.6450e-01, -3.5748e-01, -1.1920e-03,  1.6453e-01,
#          1.3226e-04, -1.4391e-03, -4.8082e-01,  5.7071e-05, -4.5257e-01,
#         -4.5301e-01, -4.8097e-01])
# ite 164
# Grad tensor([ 4.1341e-01,  4.7776e-01,  4.1315e-01, -4.8371e-04,  4.7743e-01,
#         -3.5552e-04, -4.1014e-04, -3.2214e-02, -3.2808e-04,  2.6208e-01,
#          2.6217e-01, -3.1947e-02])
# ite 165
# Grad tensor([ 4.1281e-01,  4.7747e-01,  4.1255e-01, -4.5775e-04,  4.7714e-01,
#         -6.1746e-04, -4.0675e-04, -3.2261e-02, -3.8920e-04,  2.6189e-01,
#          2.6198e-01, -3.1993e-02])
# Iteration 165: Normalized Gradient = 0.9672256708145142, Adaptive learning rate = 0.001
# ite 166
# Grad tensor([ 4.1251e-01,  4.7751e-01,  4.1225e-01, -4.3178e-04,  4.7718e-01,
#         -7.7612e-04, -3.7269e-04, -3.2256e-02, -4.2501e-04,  2.6183e-01,
#          2.6192e-01, -3.1988e-02])
# ite 167
# Grad tensor([ 4.1248e-01,  4.7785e-01,  4.1222e-01, -4.0554e-04,  4.7752e-01,
#         -8.4265e-04, -3.1109e-04, -3.2204e-02, -4.3822e-04,  2.6189e-01,
#          2.6197e-01, -3.1935e-02])
# ite 168
# Grad tensor([ 4.1270e-01,  4.7846e-01,  4.1244e-01, -3.7926e-04,  4.7813e-01,
#         -8.2650e-04, -2.2469e-04, -3.2109e-02, -4.3071e-04,  2.6205e-01,
#          2.6213e-01, -3.1841e-02])
# ite 169
# Grad tensor([ 3.2060e-01,  3.7009e-01,  3.2039e-01, -2.4140e-04,  3.6979e-01,
#         -1.0214e-03, -3.6794e-04, -3.3200e-01,  1.5609e-04, -3.6025e-01,
#         -3.6018e-01, -3.3229e-01])
# ite 170
# Grad tensor([ 1.1450e-01, -3.5651e-01,  1.1451e-01, -2.9077e-04, -3.5680e-01,
#         -5.3687e-04,  7.5763e-04, -4.1451e-01,  2.1892e-04, -4.7032e-01,
#         -4.6959e-01, -4.1485e-01])
# Iteration 170: Normalized Gradient = 1.0326067209243774, Adaptive learning rate = 0.001
# ite 171
# Grad tensor([-5.6291e-01, -5.6372e-01, -5.6288e-01,  1.6903e-04, -5.6368e-01,
#          1.2983e-04,  3.4443e-04, -5.6342e-01,  1.0814e-04, -5.6229e-01,
#         -5.6206e-01, -5.6362e-01])
# ite 172
# Grad tensor([-4.7015e-01, -4.5432e-01, -4.7018e-01,  7.1350e-05, -4.5430e-01,
#          1.9804e-05, -7.1173e-04, -2.6328e-01, -4.0975e-04,  6.0059e-02,
#          6.0309e-02, -2.6292e-01])
# ite 173
# Grad tensor([-3.2131e-01, -3.7149e-01, -3.2109e-01,  1.9256e-04, -3.7119e-01,
#         -5.2814e-04, -1.8734e-03,  3.3049e-01, -1.4907e-04,  3.5890e-01,
#          3.5884e-01,  3.3078e-01])
# ite 174
# Grad tensor([ 3.5516e-01, -1.6437e-01,  3.5535e-01, -5.9149e-04, -1.6440e-01,
#         -2.2681e-04, -1.2581e-03,  4.7874e-01, -5.2432e-05,  4.5049e-01,
#          4.5092e-01,  4.7889e-01])
# ite 175
# Grad tensor([ 3.5501e-01, -1.6421e-01,  3.5520e-01, -5.4274e-04, -1.6423e-01,
#         -2.2085e-04, -1.1138e-03,  4.7862e-01, -5.4979e-05,  4.5047e-01,
#          4.5091e-01,  4.7878e-01])
# Iteration 175: Normalized Gradient = 1.0819824934005737, Adaptive learning rate = 0.001
# ite 176
# Grad tensor([ 3.5506e-01, -1.6398e-01,  3.5525e-01, -3.9331e-04, -1.6401e-01,
#         -2.0007e-04, -7.9558e-04,  4.7887e-01, -5.6525e-05,  4.5078e-01,
#          4.5121e-01,  4.7902e-01])
# ite 177
# Grad tensor([ 3.5529e-01, -1.6371e-01,  3.5548e-01, -1.5348e-04, -1.6374e-01,
#         -1.6605e-04, -3.2169e-04,  4.7943e-01, -5.7344e-05,  4.5137e-01,
#          4.5181e-01,  4.7959e-01])
# ite 178
# Grad tensor([-5.6287e-01, -5.6258e-01, -5.6285e-01,  1.6935e-04, -5.6254e-01,
#          1.2997e-04,  3.4529e-04, -5.6297e-01,  1.0864e-04, -5.6238e-01,
#         -5.6215e-01, -5.6317e-01])
# ite 179
# Grad tensor([-3.5575e-01,  1.6308e-01, -3.5594e-01, -4.4984e-04,  1.6311e-01,
#          8.2082e-05, -8.2637e-04, -4.8061e-01,  5.7798e-05, -4.5258e-01,
#         -4.5302e-01, -4.8077e-01])
# ite 180
# Grad tensor([-3.5560e-01,  1.6284e-01, -3.5579e-01, -5.9877e-04,  1.6287e-01,
#          6.3119e-05, -1.1192e-03, -4.8056e-01,  5.8571e-05, -4.5258e-01,
#         -4.5301e-01, -4.8071e-01])
# Iteration 180: Normalized Gradient = 1.0854229927062988, Adaptive learning rate = 0.001
# ite 181
# Grad tensor([ 3.2060e-01,  3.6911e-01,  3.2039e-01, -3.0402e-04,  3.6880e-01,
#         -2.8213e-04, -9.7252e-04, -3.3107e-01,  1.3665e-04, -3.5996e-01,
#         -3.5990e-01, -3.3136e-01])
# ite 182
# Grad tensor([ 5.6183e-01,  5.6052e-01,  5.6180e-01, -1.6880e-04,  5.6048e-01,
#         -1.3010e-04, -3.4529e-04,  5.6209e-01, -1.0873e-04,  5.6166e-01,
#          5.6142e-01,  5.6229e-01])
# ite 183
# Grad tensor([ 5.6209e-01,  5.6076e-01,  5.6206e-01, -1.6853e-04,  5.6072e-01,
#         -1.3015e-04, -3.4529e-04,  5.6206e-01, -1.0868e-04,  5.6165e-01,
#          5.6141e-01,  5.6226e-01])
# ite 184
# Grad tensor([-3.5544e-01,  1.6252e-01, -3.5563e-01, -6.6116e-04,  1.6255e-01,
#          1.5923e-04, -7.8621e-04, -4.7992e-01,  6.1664e-05, -4.5210e-01,
#         -4.5254e-01, -4.8008e-01])
# ite 185
# Grad tensor([-5.6326e-01, -5.6209e-01, -5.6323e-01,  1.6844e-04, -5.6205e-01,
#          1.2988e-04,  3.4515e-04, -5.6265e-01,  1.0864e-04, -5.6228e-01,
#         -5.6204e-01, -5.6285e-01])
# Iteration 185: Normalized Gradient = 1.5911483764648438, Adaptive learning rate = 0.001
# ite 186
# Grad tensor([-3.2126e-01, -3.6994e-01, -3.2105e-01,  2.8926e-04, -3.6963e-01,
#         -6.2673e-04, -1.5771e-04,  3.3043e-01, -1.3322e-04,  3.5941e-01,
#          3.5935e-01,  3.3072e-01])
# ite 187
# Grad tensor([-1.1343e-01,  3.5462e-01, -1.1344e-01, -3.1214e-04,  3.5491e-01,
#         -4.9031e-04, -7.4449e-04,  4.1295e-01, -1.7567e-04,  4.6936e-01,
#          4.6862e-01,  4.1329e-01])
# ite 188
# Grad tensor([-3.2096e-01, -3.6984e-01, -3.2074e-01,  2.7135e-04, -3.6954e-01,
#         -4.0372e-04, -8.7630e-05,  3.3040e-01, -1.2976e-04,  3.5944e-01,
#          3.5938e-01,  3.3069e-01])
# ite 189
# Grad tensor([ 3.2068e-01,  3.6969e-01,  3.2047e-01, -2.6221e-04,  3.6939e-01,
#          2.5329e-05, -2.5743e-04, -3.3063e-01,  1.2740e-04, -3.5973e-01,
#         -3.5967e-01, -3.3093e-01])
# ite 190
# Grad tensor([ 1.1302e-01, -3.5467e-01,  1.1302e-01,  8.8221e-06, -3.5496e-01,
#         -6.8349e-05,  6.7400e-04, -4.1345e-01,  1.6421e-04, -4.7003e-01,
#         -4.6930e-01, -4.1378e-01])
# Iteration 190: Normalized Gradient = 1.0298864841461182, Adaptive learning rate = 0.001
# ite 191
# Grad tensor([ 3.2049e-01,  3.6963e-01,  3.2027e-01, -2.5004e-04,  3.6932e-01,
#         -6.8530e-05, -2.4106e-04, -3.3054e-01,  1.2515e-04, -3.5967e-01,
#         -3.5961e-01, -3.3083e-01])
# ite 192
# Grad tensor([ 5.6193e-01,  5.6192e-01,  5.6190e-01, -1.6871e-04,  5.6188e-01,
#         -1.3019e-04, -3.4474e-04,  5.6177e-01, -1.0873e-04,  5.6174e-01,
#          5.6151e-01,  5.6196e-01])
# ite 193
# Grad tensor([-3.2082e-01, -3.7006e-01, -3.2061e-01,  2.4347e-04, -3.6976e-01,
#         -3.8081e-04, -3.5443e-04,  3.3024e-01, -1.2528e-04,  3.5937e-01,
#          3.5931e-01,  3.3053e-01])
# ite 194
# Grad tensor([-5.6272e-01, -5.6278e-01, -5.6269e-01,  1.6844e-04, -5.6274e-01,
#          1.2997e-04,  3.4429e-04, -5.6224e-01,  1.0868e-04, -5.6222e-01,
#         -5.6199e-01, -5.6244e-01])
# ite 195
# Grad tensor([-3.2080e-01, -3.7006e-01, -3.2059e-01,  2.4199e-04, -3.6976e-01,
#         -3.4270e-04, -3.1050e-04,  3.3027e-01, -1.2433e-04,  3.5943e-01,
#          3.5936e-01,  3.3056e-01])
# Iteration 195: Normalized Gradient = 0.9777671694755554, Adaptive learning rate = 0.001
# ite 196
# Grad tensor([ 3.5431e-01, -1.6219e-01,  3.5451e-01,  6.6393e-06, -1.6222e-01,
#         -1.3847e-04,  3.5548e-04,  4.7923e-01, -7.2487e-05,  4.5183e-01,
#          4.5227e-01,  4.7939e-01])
# ite 197
# Grad tensor([ 3.2040e-01,  3.6947e-01,  3.2019e-01, -2.5423e-04,  3.6916e-01,
#         -1.5289e-04, -4.5029e-04, -3.3057e-01,  1.2305e-04, -3.5977e-01,
#         -3.5971e-01, -3.3086e-01])
# ite 198
# Grad tensor([ 3.2041e-01,  3.6937e-01,  3.2020e-01, -2.6207e-04,  3.6907e-01,
#         -1.8849e-04, -6.0004e-04, -3.3064e-01,  1.2324e-04, -3.5986e-01,
#         -3.5979e-01, -3.3094e-01])
# ite 199
# Grad tensor([ 3.2056e-01,  3.6946e-01,  3.2035e-01, -2.6710e-04,  3.6915e-01,
#         -9.7771e-06, -4.5898e-04, -3.3055e-01,  1.2394e-04, -3.5976e-01,
#         -3.5969e-01, -3.3084e-01])
# ite 200
# Grad tensor([-4.1385e-01, -4.7921e-01, -4.1358e-01,  3.8926e-04, -4.7888e-01,
#         -2.0846e-04,  2.4443e-05,  3.1118e-02,  8.8812e-05, -2.6267e-01,
#         -2.6276e-01,  3.0852e-02])
# Iteration 200: Normalized Gradient = 0.9701755046844482, Adaptive learning rate = 0.001
# ite 201
# Grad tensor([-3.2090e-01, -3.6970e-01, -3.2069e-01,  2.7401e-04, -3.6940e-01,
#         -5.8603e-04, -2.0032e-04,  3.3007e-01, -1.2794e-04,  3.5918e-01,
#          3.5912e-01,  3.3036e-01])
# ite 202
# Grad tensor([-1.1287e-01,  3.5411e-01, -1.1288e-01, -2.7862e-04,  3.5441e-01,
#         -4.8067e-04, -7.4374e-04,  4.1271e-01, -1.7235e-04,  4.6913e-01,
#          4.6840e-01,  4.1305e-01])
# ite 203
# Grad tensor([-1.1281e-01,  3.5412e-01, -1.1281e-01, -2.5725e-04,  3.5442e-01,
#         -3.5452e-04, -7.2544e-04,  4.1288e-01, -1.7421e-04,  4.6928e-01,
#          4.6855e-01,  4.1322e-01])
# ite 204
# Grad tensor([-3.5454e-01,  1.6188e-01, -3.5473e-01, -2.6707e-04,  1.6191e-01,
#          1.4038e-04, -4.9513e-04, -4.7957e-01,  6.5302e-05, -4.5195e-01,
#         -4.5239e-01, -4.7973e-01])
# ite 205
# Grad tensor([ 1.1257e-01, -3.5444e-01,  1.1257e-01, -6.4119e-06, -3.5474e-01,
#         -2.8240e-05,  7.0493e-04, -4.1339e-01,  1.7326e-04, -4.6983e-01,
#         -4.6909e-01, -4.1373e-01])
# Iteration 205: Normalized Gradient = 1.0293993949890137, Adaptive learning rate = 0.001
# ite 206
# Grad tensor([ 2.0544e-01, -2.4487e-01,  2.0539e-01, -2.0204e-04, -2.4519e-01,
#         -6.0277e-05,  6.9572e-04, -1.1401e-01, -1.0341e-04,  1.5237e-01,
#          1.5312e-01, -1.1378e-01])
# ite 207
# Grad tensor([ 5.6180e-01,  5.6193e-01,  5.6177e-01, -1.6848e-04,  5.6188e-01,
#         -1.3015e-04, -3.4461e-04,  5.6201e-01, -1.0873e-04,  5.6180e-01,
#          5.6157e-01,  5.6221e-01])
# ite 208
# Grad tensor([ 1.1246e-01, -3.5445e-01,  1.1246e-01, -9.9908e-05, -3.5474e-01,
#         -5.8662e-06,  7.2669e-04, -4.1326e-01,  1.7035e-04, -4.6972e-01,
#         -4.6898e-01, -4.1359e-01])
# ite 209
# Grad tensor([ 1.1249e-01, -3.5443e-01,  1.1249e-01, -3.0150e-05, -3.5472e-01,
#          1.2574e-04,  7.3858e-04, -4.1319e-01,  1.7058e-04, -4.6965e-01,
#         -4.6891e-01, -4.1352e-01])
# ite 210
# Grad tensor([-3.2071e-01, -3.6969e-01, -3.2049e-01,  2.6102e-04, -3.6938e-01,
#         -4.3015e-04, -2.6653e-04,  3.3005e-01, -1.3008e-04,  3.5912e-01,
#          3.5906e-01,  3.3034e-01])
# Iteration 210: Normalized Gradient = 0.9770483374595642, Adaptive learning rate = 0.001
# ite 211
# Grad tensor([-1.1259e-01,  3.5396e-01, -1.1260e-01, -2.4074e-04,  3.5425e-01,
#         -4.0573e-04, -7.3851e-04,  4.1274e-01, -1.7321e-04,  4.6914e-01,
#          4.6840e-01,  4.1307e-01])
# ite 212
# Grad tensor([-1.1256e-01,  3.5388e-01, -1.1257e-01, -2.9354e-04,  3.5418e-01,
#         -3.2655e-04, -7.0640e-04,  4.1288e-01, -1.7230e-04,  4.6931e-01,
#          4.6858e-01,  4.1322e-01])
# ite 213
# Grad tensor([-3.5442e-01,  1.6154e-01, -3.5462e-01, -3.8108e-04,  1.6157e-01,
#          1.4395e-04, -6.6320e-04, -4.7955e-01,  6.7439e-05, -4.5204e-01,
#         -4.5248e-01, -4.7971e-01])
# ite 214
# Grad tensor([-3.5427e-01,  1.6155e-01, -3.5446e-01, -2.5479e-04,  1.6158e-01,
#          1.1714e-04, -6.8108e-04, -4.7960e-01,  6.9031e-05, -4.5214e-01,
#         -4.5258e-01, -4.7976e-01])
# ite 215
# Grad tensor([ 3.2030e-01,  3.6947e-01,  3.2009e-01, -2.4586e-04,  3.6917e-01,
#         -4.3792e-05, -1.7126e-04, -3.3028e-01,  1.2481e-04, -3.5947e-01,
#         -3.5941e-01, -3.3057e-01])
# Iteration 215: Normalized Gradient = 0.9770389795303345, Adaptive learning rate = 0.001
# ite 216
# Grad tensor([ 3.5370e-01, -1.6172e-01,  3.5389e-01, -1.7571e-04, -1.6176e-01,
#         -1.3770e-04,  1.4293e-04,  4.7887e-01, -7.2396e-05,  4.5154e-01,
#          4.5198e-01,  4.7903e-01])
# ite 217
# Grad tensor([ 3.5367e-01, -1.6176e-01,  3.5387e-01, -2.6553e-04, -1.6179e-01,
#         -1.5195e-04, -1.9327e-05,  4.7881e-01, -7.3123e-05,  4.5150e-01,
#          4.5193e-01,  4.7896e-01])
# ite 218
# Grad tensor([ 2.6083e-01, -2.7141e-01,  2.6107e-01, -1.4138e-04, -2.7142e-01,
#         -5.2637e-05,  3.2283e-04,  1.8002e-01,  1.1282e-04, -1.7027e-01,
#         -1.6985e-01,  1.7961e-01])
# ite 219
# Grad tensor([-5.6261e-01, -5.6294e-01, -5.6258e-01,  1.6794e-04, -5.6290e-01,
#          1.3024e-04,  3.4388e-04, -5.6238e-01,  1.0859e-04, -5.6234e-01,
#         -5.6211e-01, -5.6258e-01])
# ite 220
# Grad tensor([-4.1365e-01, -4.7948e-01, -4.1339e-01,  3.4988e-04, -4.7915e-01,
#         -1.2365e-04, -7.7375e-05,  3.1021e-02,  1.1369e-04, -2.6269e-01,
#         -2.6278e-01,  3.0755e-02])
# Iteration 220: Normalized Gradient = 0.9702842235565186, Adaptive learning rate = 0.001
# ite 221
# Grad tensor([ 5.6200e-01,  5.6186e-01,  5.6197e-01, -1.6807e-04,  5.6181e-01,
#         -1.3019e-04, -3.4470e-04,  5.6188e-01, -1.0868e-04,  5.6161e-01,
#          5.6138e-01,  5.6208e-01])
# ite 222
# Grad tensor([ 5.6211e-01,  5.6173e-01,  5.6208e-01, -1.6794e-04,  5.6169e-01,
#         -1.3024e-04, -3.4470e-04,  5.6214e-01, -1.0859e-04,  5.6173e-01,
#          5.6150e-01,  5.6233e-01])
# ite 223
# Grad tensor([-5.6273e-01, -5.6212e-01, -5.6270e-01,  1.6780e-04, -5.6208e-01,
#          1.3001e-04,  3.4465e-04, -5.6289e-01,  1.0841e-04, -5.6235e-01,
#         -5.6212e-01, -5.6309e-01])
# ite 224
# Grad tensor([-3.5422e-01,  1.6114e-01, -3.5442e-01, -3.9436e-04,  1.6118e-01,
#          9.8157e-05, -6.3487e-04, -4.7999e-01,  5.5570e-05, -4.5211e-01,
#         -4.5255e-01, -4.8015e-01])
# ite 225
# Grad tensor([-3.5405e-01,  1.6111e-01, -3.5425e-01, -3.6971e-04,  1.6115e-01,
#          9.9840e-05, -5.5511e-04, -4.7979e-01,  5.3615e-05, -4.5186e-01,
#         -4.5229e-01, -4.7994e-01])
# Iteration 225: Normalized Gradient = 1.0826166868209839, Adaptive learning rate = 0.001
# ite 226
# Grad tensor([ 4.1330e-01,  4.7861e-01,  4.1304e-01, -3.8349e-04,  4.7828e-01,
#         -3.9427e-05,  1.3938e-05, -3.1159e-02, -2.8519e-04,  2.6231e-01,
#          2.6239e-01, -3.0890e-02])
# ite 227
# Grad tensor([ 5.6195e-01,  5.6177e-01,  5.6192e-01, -1.6780e-04,  5.6173e-01,
#         -1.3033e-04, -3.4465e-04,  5.6178e-01, -1.0850e-04,  5.6102e-01,
#          5.6079e-01,  5.6197e-01])
# ite 228
# Grad tensor([ 3.5370e-01, -1.6130e-01,  3.5390e-01,  3.9563e-06, -1.6134e-01,
#         -1.7985e-04, -2.7967e-04,  4.7898e-01, -5.3478e-05,  4.5106e-01,
#          4.5150e-01,  4.7913e-01])
# ite 229
# Grad tensor([-4.6987e-01, -4.5338e-01, -4.6989e-01,  5.7844e-05, -4.5337e-01,
#         -3.9131e-05, -2.7562e-04, -2.6332e-01, -3.1407e-04,  5.9741e-02,
#          5.9990e-02, -2.6296e-01])
# ite 230
# Grad tensor([-4.7003e-01, -4.5354e-01, -4.7005e-01,  5.7935e-05, -4.5353e-01,
# ...
#         -1.3283e-04, -3.3774e-04,  5.6214e-01, -1.0750e-04,  5.6192e-01,
#          5.6168e-01,  5.6233e-01])
# ite 948
# Grad tensor([-5.6242e-01, -5.6215e-01, -5.6238e-01,  1.5284e-04, -5.6211e-01,
#          1.3265e-04,  3.3747e-04, -5.6250e-01,  1.0741e-04, -5.6240e-01,
#         -5.6216e-01, -5.6270e-01])
# ite 949
# Grad tensor([ 9.3186e-02, -3.3809e-01,  9.3208e-02,  3.1423e-05, -3.3846e-01,
#         -1.1232e-05,  6.7814e-04, -4.1249e-01,  1.6548e-04, -4.6760e-01,
#         -4.6684e-01, -4.1281e-01])
# ite 950
# Grad tensor([ 4.6668e-01,  4.5091e-01,  4.6668e-01, -5.3615e-05,  4.5091e-01,
#         -9.3496e-05, -5.2969e-04,  2.6424e-01,  8.8767e-05, -5.7825e-02,
#         -5.8062e-02,  2.6386e-01])
# Iteration 950: Normalized Gradient = 0.9941686987876892, Adaptive learning rate = 0.001
# ite 951
# Grad tensor([ 5.6199e-01,  5.6159e-01,  5.6194e-01, -1.5298e-04,  5.6155e-01,
#         -1.3265e-04, -3.3760e-04,  5.6187e-01, -1.0746e-04,  5.6190e-01,
#          5.6165e-01,  5.6207e-01])
# ite 952
# Grad tensor([-4.1286e-01, -4.7512e-01, -4.1258e-01,  3.4302e-04, -4.7475e-01,
#         -1.2978e-04,  5.7071e-05,  2.7657e-02,  8.5424e-05, -2.6407e-01,
#         -2.6413e-01,  2.7370e-02])
# ite 953
# Grad tensor([-5.6265e-01, -5.6205e-01, -5.6260e-01,  1.5289e-04, -5.6202e-01,
#          1.3274e-04,  3.3760e-04, -5.6232e-01,  1.0750e-04, -5.6224e-01,
#         -5.6199e-01, -5.6251e-01])
# ite 954
# Grad tensor([ 5.6236e-01,  5.6167e-01,  5.6231e-01, -1.5284e-04,  5.6163e-01,
#         -1.3270e-04, -3.3779e-04,  5.6201e-01, -1.0746e-04,  5.6187e-01,
#          5.6163e-01,  5.6221e-01])
# ite 955
# Grad tensor([-9.3283e-02,  3.3787e-01, -9.3306e-02, -2.3983e-04,  3.3824e-01,
#         -2.3465e-04, -7.0143e-04,  4.1226e-01, -1.7526e-04,  4.6721e-01,
#          4.6646e-01,  4.1257e-01])
# Iteration 955: Normalized Gradient = 1.0109453201293945, Adaptive learning rate = 0.001
# ite 956
# Grad tensor([-5.6278e-01, -5.6205e-01, -5.6273e-01,  1.5270e-04, -5.6201e-01,
#          1.3274e-04,  3.3756e-04, -5.6260e-01,  1.0737e-04, -5.6236e-01,
#         -5.6212e-01, -5.6280e-01])
# ite 957
# Grad tensor([-3.3830e-01,  1.4029e-01, -3.3851e-01, -3.0072e-04,  1.4037e-01,
#          1.2324e-04, -6.0759e-04, -4.7571e-01,  6.1527e-05, -4.5076e-01,
#         -4.5121e-01, -4.7588e-01])
# ite 958
# Grad tensor([ 5.6214e-01,  5.6167e-01,  5.6209e-01, -1.5284e-04,  5.6163e-01,
#         -1.3265e-04, -3.3770e-04,  5.6218e-01, -1.0737e-04,  5.6191e-01,
#          5.6167e-01,  5.6238e-01])
# ite 959
# Grad tensor([ 4.1261e-01,  4.7503e-01,  4.1233e-01, -3.3206e-04,  4.7466e-01,
#         -2.3692e-05, -4.2428e-05, -2.7701e-02, -1.5743e-04,  2.6396e-01,
#          2.6402e-01, -2.7413e-02])
# ite 960
# Grad tensor([-5.6255e-01, -5.6245e-01, -5.6250e-01,  1.5270e-04, -5.6242e-01,
#          1.3270e-04,  3.3738e-04, -5.6250e-01,  1.0746e-04, -5.6226e-01,
#         -5.6202e-01, -5.6270e-01])
# Iteration 960: Normalized Gradient = 1.5907782316207886, Adaptive learning rate = 0.001
# ite 961
# Grad tensor([-5.6241e-01, -5.6250e-01, -5.6237e-01,  1.5280e-04, -5.6246e-01,
#          1.3270e-04,  3.3733e-04, -5.6225e-01,  1.0741e-04, -5.6206e-01,
#         -5.6182e-01, -5.6245e-01])
# ite 962
# Grad tensor([ 3.3765e-01, -1.4039e-01,  3.3786e-01, -9.7634e-05, -1.4047e-01,
#         -1.5325e-04,  4.6293e-05,  4.7486e-01, -6.4074e-05,  4.5003e-01,
#          4.5048e-01,  4.7503e-01])
# ite 963
# Grad tensor([ 5.6156e-01,  5.6180e-01,  5.6151e-01, -1.5270e-04,  5.6177e-01,
#         -1.3274e-04, -3.3738e-04,  5.6132e-01, -1.0755e-04,  5.6120e-01,
#          5.6096e-01,  5.6152e-01])
# ite 964
# Grad tensor([ 5.6173e-01,  5.6196e-01,  5.6169e-01, -1.5266e-04,  5.6192e-01,
#         -1.3288e-04, -3.3729e-04,  5.6150e-01, -1.0755e-04,  5.6140e-01,
#          5.6116e-01,  5.6170e-01])
# ite 965
# Grad tensor([ 3.3785e-01, -1.4032e-01,  3.3806e-01, -7.8080e-05, -1.4039e-01,
#         -1.5013e-04,  1.1696e-04,  4.7524e-01, -6.5484e-05,  4.5046e-01,
#          4.5091e-01,  4.7541e-01])
# Iteration 965: Normalized Gradient = 1.0610935688018799, Adaptive learning rate = 0.001
# ite 966
# Grad tensor([-5.6308e-01, -5.6311e-01, -5.6303e-01,  1.5252e-04, -5.6307e-01,
#          1.3265e-04,  3.3701e-04, -5.6295e-01,  1.0737e-04, -5.6287e-01,
#         -5.6263e-01, -5.6315e-01])
# ite 967
# Grad tensor([-5.6331e-01, -5.6319e-01, -5.6327e-01,  1.5270e-04, -5.6315e-01,
#          1.3260e-04,  3.3697e-04, -5.6328e-01,  1.0723e-04, -5.6320e-01,
#         -5.6296e-01, -5.6348e-01])
# ite 968
# Grad tensor([-5.6308e-01, -5.6282e-01, -5.6304e-01,  1.5275e-04, -5.6278e-01,
#          1.3260e-04,  3.3715e-04, -5.6314e-01,  1.0727e-04, -5.6307e-01,
#         -5.6283e-01, -5.6334e-01])
# ite 969
# Grad tensor([-5.6244e-01, -5.6205e-01, -5.6239e-01,  1.5275e-04, -5.6202e-01,
#          1.3274e-04,  3.3724e-04, -5.6258e-01,  1.0732e-04, -5.6252e-01,
#         -5.6228e-01, -5.6278e-01])
# ite 970
# Grad tensor([ 5.6142e-01,  5.6094e-01,  5.6137e-01, -1.5275e-04,  5.6090e-01,
#         -1.3283e-04, -3.3765e-04,  5.6165e-01, -1.0746e-04,  5.6160e-01,
#          5.6135e-01,  5.6185e-01])
# Iteration 970: Normalized Gradient = 1.5878344774246216, Adaptive learning rate = 0.001
# ite 971
# Grad tensor([ 5.6094e-01,  5.6036e-01,  5.6090e-01, -1.5284e-04,  5.6032e-01,
#         -1.3297e-04, -3.3770e-04,  5.6124e-01, -1.0750e-04,  5.6119e-01,
#          5.6095e-01,  5.6144e-01])
# ite 972
# Grad tensor([ 5.6095e-01,  5.6028e-01,  5.6090e-01, -1.5284e-04,  5.6024e-01,
#         -1.3283e-04, -3.3770e-04,  5.6130e-01, -1.0764e-04,  5.6126e-01,
#          5.6102e-01,  5.6150e-01])
# ite 973
# Grad tensor([ 5.6139e-01,  5.6063e-01,  5.6134e-01, -1.5270e-04,  5.6059e-01,
#         -1.3274e-04, -3.3738e-04,  5.6179e-01, -1.0741e-04,  5.6175e-01,
#          5.6151e-01,  5.6199e-01])
# ite 974
# Grad tensor([ 3.1720e-01,  3.6377e-01,  3.1697e-01, -2.5623e-04,  3.6343e-01,
#         -1.8899e-04, -8.0190e-04, -3.2579e-01,  1.2583e-04, -3.5618e-01,
#         -3.5612e-01, -3.2608e-01])
# ite 975
# Grad tensor([-5.6312e-01, -5.6223e-01, -5.6307e-01,  1.5248e-04, -5.6219e-01,
#          1.3270e-04,  3.3692e-04, -5.6330e-01,  1.0727e-04, -5.6324e-01,
#         -5.6300e-01, -5.6350e-01])
# Iteration 975: Normalized Gradient = 1.5922808647155762, Adaptive learning rate = 0.001
# ite 976
# Grad tensor([-5.6348e-01, -5.6257e-01, -5.6344e-01,  1.5239e-04, -5.6253e-01,
#          1.3265e-04,  3.3697e-04, -5.6344e-01,  1.0718e-04, -5.6336e-01,
#         -5.6312e-01, -5.6364e-01])
# ite 977
# Grad tensor([-5.6338e-01, -5.6243e-01, -5.6333e-01,  1.5234e-04, -5.6239e-01,
#          1.3256e-04,  3.3733e-04, -5.6313e-01,  1.0732e-04, -5.6304e-01,
#         -5.6280e-01, -5.6333e-01])
# ite 978
# Grad tensor([-3.3813e-01,  1.3979e-01, -3.3833e-01, -4.1882e-04,  1.3986e-01,
#          1.7274e-04, -6.2578e-04, -4.7552e-01,  6.4892e-05, -4.5077e-01,
#         -4.5122e-01, -4.7569e-01])
# ite 979
# Grad tensor([ 5.6215e-01,  5.6134e-01,  5.6210e-01, -1.5243e-04,  5.6130e-01,
#         -1.3274e-04, -3.3774e-04,  5.6148e-01, -1.0755e-04,  5.6138e-01,
#          5.6114e-01,  5.6167e-01])
# ite 980
# Grad tensor([ 5.6196e-01,  5.6128e-01,  5.6192e-01, -1.5239e-04,  5.6124e-01,
#         -1.3260e-04, -3.3760e-04,  5.6105e-01, -1.0750e-04,  5.6096e-01,
#          5.6072e-01,  5.6125e-01])
# Iteration 980: Normalized Gradient = 1.5875955820083618, Adaptive learning rate = 0.001
# ite 981
# Grad tensor([ 5.6223e-01,  5.6166e-01,  5.6219e-01, -1.5234e-04,  5.6162e-01,
#         -1.3229e-04, -3.3738e-04,  5.6111e-01, -1.0741e-04,  5.6101e-01,
#          5.6077e-01,  5.6130e-01])
# ite 982
# Grad tensor([-3.1783e-01, -3.6457e-01, -3.1759e-01,  2.3999e-04, -3.6424e-01,
#         -8.2227e-04, -5.9940e-04,  3.2494e-01, -1.2747e-04,  3.5526e-01,
#          3.5520e-01,  3.2523e-01])
# ite 983
# Grad tensor([-4.1355e-01, -4.7580e-01, -4.1327e-01,  3.3779e-04, -4.7544e-01,
#         -4.8244e-04, -1.3697e-04,  2.7494e-02,  1.0566e-04, -2.6412e-01,
#         -2.6418e-01,  2.7207e-02])
# ite 984
# Grad tensor([-5.6352e-01, -5.6310e-01, -5.6347e-01,  1.5225e-04, -5.6307e-01,
#          1.3224e-04,  3.3683e-04, -5.6257e-01,  1.0737e-04, -5.6244e-01,
#         -5.6220e-01, -5.6276e-01])
# ite 985
# Grad tensor([-5.6321e-01, -5.6281e-01, -5.6316e-01,  1.5239e-04, -5.6277e-01,
#          1.3251e-04,  3.3701e-04, -5.6250e-01,  1.0737e-04, -5.6234e-01,
#         -5.6210e-01, -5.6270e-01])
# Iteration 985: Normalized Gradient = 1.591557264328003, Adaptive learning rate = 0.001
# ite 986
# Grad tensor([-3.1744e-01, -3.6426e-01, -3.1721e-01,  2.3610e-04, -3.6393e-01,
#         -3.4365e-04, -1.8226e-04,  3.2521e-01, -1.2978e-04,  3.5549e-01,
#          3.5543e-01,  3.2551e-01])
# ite 987
# Grad tensor([ 5.6171e-01,  5.6132e-01,  5.6167e-01, -1.5248e-04,  5.6128e-01,
#         -1.3283e-04, -3.3760e-04,  5.6171e-01, -1.0741e-04,  5.6152e-01,
#          5.6128e-01,  5.6191e-01])
# ite 988
# Grad tensor([ 5.6144e-01,  5.6103e-01,  5.6140e-01, -1.5257e-04,  5.6099e-01,
#         -1.3274e-04, -3.3747e-04,  5.6188e-01, -1.0741e-04,  5.6168e-01,
#          5.6144e-01,  5.6208e-01])
# ite 989
# Grad tensor([ 3.1678e-01,  3.6356e-01,  3.1654e-01, -2.3908e-04,  3.6322e-01,
#         -4.0886e-04, -6.8167e-04, -3.2561e-01,  1.3044e-04, -3.5587e-01,
#         -3.5581e-01, -3.2590e-01])
# ite 990
# Grad tensor([ 3.1689e-01,  3.6371e-01,  3.1666e-01, -2.3836e-04,  3.6338e-01,
#         -4.4288e-04, -6.9399e-04, -3.2577e-01,  1.3115e-04, -3.5604e-01,
#         -3.5598e-01, -3.2606e-01])
# Iteration 990: Normalized Gradient = 0.9648533463478088, Adaptive learning rate = 0.001
# ite 991
# Grad tensor([-5.6237e-01, -5.6199e-01, -5.6233e-01,  1.5248e-04, -5.6195e-01,
#          1.3251e-04,  3.3710e-04, -5.6302e-01,  1.0727e-04, -5.6274e-01,
#         -5.6250e-01, -5.6322e-01])
# ite 992
# Grad tensor([ 9.2479e-02, -3.3763e-01,  9.2502e-02,  7.1486e-05, -3.3800e-01,
#         -1.2242e-04,  6.7264e-04, -4.1264e-01,  1.8040e-04, -4.6750e-01,
#         -4.6675e-01, -4.1296e-01])
# ite 993
# Grad tensor([ 4.1250e-01,  4.7475e-01,  4.1222e-01, -3.3810e-04,  4.7439e-01,
#         -1.7553e-05, -4.5225e-05, -2.7559e-02, -1.8310e-04,  2.6398e-01,
#          2.6404e-01, -2.7270e-02])
# ite 994
# Grad tensor([ 5.6235e-01,  5.6189e-01,  5.6230e-01, -1.5234e-04,  5.6185e-01,
#         -1.3270e-04, -3.3747e-04,  5.6191e-01, -1.0737e-04,  5.6153e-01,
#          5.6129e-01,  5.6211e-01])
# ite 995
# Grad tensor([-3.1755e-01, -3.6438e-01, -3.1732e-01,  2.4088e-04, -3.6404e-01,
#         -5.7521e-04, -4.9222e-04,  3.2500e-01, -1.3520e-04,  3.5521e-01,
#          3.5515e-01,  3.2529e-01])
# Iteration 995: Normalized Gradient = 0.9646652936935425, Adaptive learning rate = 0.001
# ite 996
# Grad tensor([-4.6770e-01, -4.5172e-01, -4.6770e-01,  5.0068e-05, -4.5172e-01,
#         -1.0775e-04, -5.1023e-05, -2.6462e-01, -2.0689e-04,  5.7492e-02,
#          5.7728e-02, -2.6424e-01])
# ite 997
# Grad tensor([-5.6334e-01, -5.6271e-01, -5.6329e-01,  1.5216e-04, -5.6267e-01,
#          1.3220e-04,  3.3692e-04, -5.6235e-01,  1.0741e-04, -5.6208e-01,
#         -5.6184e-01, -5.6255e-01])
# ite 998
# Grad tensor([-3.1749e-01, -3.6421e-01, -3.1726e-01,  2.4829e-04, -3.6388e-01,
#         -6.1009e-04, -2.9686e-04,  3.2492e-01, -1.2994e-04,  3.5527e-01,
#          3.5521e-01,  3.2521e-01])
# ite 999
# Grad tensor([-9.2493e-02,  3.3733e-01, -9.2516e-02, -2.3060e-04,  3.3770e-01,
#         -3.6130e-04, -7.2293e-04,  4.1179e-01, -1.6994e-04,  4.6682e-01,
#          4.6607e-01,  4.1211e-01])
# ite 1000
# Grad tensor([ 5.6205e-01,  5.6135e-01,  5.6200e-01, -1.5229e-04,  5.6132e-01,
#         -1.3274e-04, -3.3724e-04,  5.6188e-01, -1.0741e-04,  5.6190e-01,
#          5.6166e-01,  5.6208e-01])
# Iteration 1000: Normalized Gradient = 1.5889561176300049, Adaptive learning rate = 0.001
# Optimization completed.
# tensor([0.1282, 0.5112, 0.5385, 0.3954, 0.1563, 0.2841, 0.1575, 0.6294, 0.7941,
#         0.0145, 0.6520, 0.0371], requires_grad=True)
# Deformed: tensor([[0.0000, 3.0000, 0.0000],
#         [0.0000, 6.0000, 0.0000],
#         [3.0000, 0.0000, 0.0000],
#         [3.1315, 2.2118, 1.4996],
#         [2.2809, 4.9123, 1.4992],
#         [3.0000, 9.0000, 0.0000],
#         [6.0000, 0.0000, 0.0000],
#         [5.9776, 2.2907, 1.4996],
#         [6.8359, 4.1020, 1.4998],
#         [6.0000, 9.0000, 0.0000],
#         [9.0000, 3.0000, 0.0000],
#         [9.0000, 6.0000, 0.0000]], grad_fn=<CloneBackward0>)
# <div>                            <div id="e67f6aa5-1d11-430a-ae5d-164f5e4f85aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e67f6aa5-1d11-430a-ae5d-164f5e4f85aa")) {                    Plotly.newPlot(                        "e67f6aa5-1d11-430a-ae5d-164f5e4f85aa",                        [{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[0.0,3.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[0.0,3.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,3.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,3.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,3.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[3.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[6.0,6.0],"y":[0.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[6.0,6.0],"y":[6.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[6.0,6.0],"y":[9.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[9.0,6.0],"y":[6.0,6.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"blue","width":4},"mode":"lines","name":"Original Geometry","x":[9.0,6.0],"y":[3.0,3.0],"z":[0.0,0.0],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[0.0,3.1315293312072754],"y":[3.0,2.2118468284606934],"z":[0.0,1.4995766878128052],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[0.0,2.280864953994751],"y":[6.0,4.912261009216309],"z":[0.0,1.4991859197616577],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[3.0,3.1315293312072754],"y":[0.0,2.2118468284606934],"z":[0.0,1.4995766878128052],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[2.280864953994751,3.1315293312072754],"y":[4.912261009216309,2.2118468284606934],"z":[1.4991859197616577,1.4995766878128052],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[3.0,2.280864953994751],"y":[9.0,4.912261009216309],"z":[0.0,1.4991859197616577],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[3.1315293312072754,5.9775800704956055],"y":[2.2118468284606934,2.2907180786132812],"z":[1.4995766878128052,1.4995845556259155],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[2.280864953994751,6.835934638977051],"y":[4.912261009216309,4.10202169418335],"z":[1.4991859197616577,1.4998254776000977],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[6.0,5.9775800704956055],"y":[0.0,2.2907180786132812],"z":[0.0,1.4995845556259155],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Deformed Geometry","x":[6.835934638977051,5.9775800704956055],"y":[4.10202169418335,2.2907180786132812],"z":[1.4998254776000977,1.4995845556259155],"type":" ...

# %%
### Displacement Controll -- with individual qs
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import plotly.graph_objects as go

# q.grad.zero_()


# In[663]:


######################## explanation
## "The example model is based on a 5-nodes grid shell strcuture
##  which has a crossing projection in the x-y plane"
##  The FE part would be based on the Euler-bernoulli beam theory


# In[664]:


## Initial Geom
# Initial Coords:
node_coords = torch.tensor(
    [[0.0, 3.0, 0.0], [0.0, 6.0, 0.0], [3.0, 0.0, 0.0], [3.0, 3.0, 0.0], [3.0, 6.0, 0.0], [3.0, 9.0, 0.0],
     [6.0, 0.0, 0.0], [6.0, 3.0, 0.0], [6.0, 6.0, 0.0] ,[6.0, 9.0, 0.0], [9.0, 3.0 ,0.0], [9.0, 6.0, 0.0]],
    dtype=torch.float32, requires_grad=True, )
connectivity = [[1, 4], [2, 5], [3, 4], [5, 4], [6, 5], [4, 8],[5, 9], [7, 8], [9, 8],[10, 9],[12, 9],[11, 8]]
n_dof_per_node = 6  # Degrees of freedom per node
total_dof = n_dof_per_node * len(node_coords)
Fixed_nodes = [1, 2, 3, 6, 7, 10, 11, 12]
Free_nodes = []
n_elements = len(connectivity)
n_nodes = len(node_coords)
for i in range(1, n_nodes + 1):
    if i not in Fixed_nodes:
        Free_nodes.append(i)
idx_CF = [node - 1 for node in Fixed_nodes]
idx_CN = [i for i in range(n_nodes) if i not in idx_CF]


## Force condition
####### Force condition -> need for modification
## +0 to x direction ; +1 to y direction ; +2 to Z direction
## +3 Bending around the z axis ; +4 bending around y axis ; +5 Twisting
# implement upwards loading of 50 kN at every free nodes
F = torch.zeros(total_dof, dtype=torch.float32)
f_n = Free_nodes
f_type = [2, 2, 2, 2]  # The force type
F_value = torch.tensor([50.0, 50.0, 50.0, 50.0]) * 1000  # The force value/direction
r = 1 / torch.max(F_value)
# print(r)
F_sign = torch.sign(F_value)
for idx, i in enumerate(f_n):
    F[6 * (i - 1) + f_type[idx]] = F_value[idx]  # unit: KN / KN*m

px = torch.zeros(len(f_n), 1, dtype=torch.float32)
py = torch.zeros(len(f_n), 1, dtype=torch.float32)
pz = torch.zeros(len(f_n), 1, dtype=torch.float32)

for i in range(len(f_n)):
    if f_type[idx] == 0:
        px[i] = F_value[i]
    elif f_type[idx] == 1:
        py[i] = F_value[i]
    elif f_type[idx] == 2:
        pz[i] = F_value[i]


## Obtaining Matrix D
# Assembly the nodal-branch matrix:
C = torch.zeros(n_elements, n_nodes, dtype=torch.float32)
for n, (i, j) in enumerate(connectivity):
    C[n, i - 1] = 1
    C[n, j - 1] = -1
CF = C[:, idx_CF]
CN = C[:, idx_CN]


# Assembly D
def FDM (Q,CN=CN, CF=CF, px=px, py=py, pz=pz,Fixed_nodes=Fixed_nodes, Free_nodes=Free_nodes,node_coords=node_coords) :
    Dn = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CN))
    DF = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CF))
    ## Coordinates solution
    # separate the coordinates:
    fixed_idces = [node - 1 for node in Fixed_nodes]
    xF = node_coords[fixed_idces, 0].unsqueeze(1)
    yF = node_coords[fixed_idces, 1].unsqueeze(1)
    zF = node_coords[fixed_idces, 2].unsqueeze(1)
    xN = torch.matmul(torch.inverse(Dn), (px - torch.matmul(DF, xF)))
    yN = torch.matmul(torch.inverse(Dn), (py - torch.matmul(DF, yF)))
    zN = torch.matmul(torch.inverse(Dn), (pz - torch.matmul(DF, zF)))
    ## Coordinates renewal: 
    new_node_coords = node_coords.clone()
    for idx, node in enumerate(Free_nodes):
        node_idx = node - 1
        new_node_coords[node_idx, 0] = xN[idx]
        new_node_coords[node_idx, 1] = yN[idx]
        new_node_coords[node_idx, 2] = zN[idx]

    return new_node_coords

# In[670]:


## Check point: FDM completed
# if q.grad is not None:
#     q.grad.zero_()
# loss = torch.sum(new_node_coords[:, 2])
# loss.backward()
# print("Gradient of q:")
# print(q.grad)


############ Now comes to FE part:
#### Default values (in meters, Pascals, etc.)
## For rectangular sections
# D_width = 0.1
# D_height = 0.2
# D_young_modulus = 210e9  # Young's modulus in Pascals
# D_shear_modulus = 81e9  # Shear modulus in Pascals
# D_poisson_ratio = 0.3
# cross_section_angle_a = 0  # Cross-section angle at node 1 (anti-clockwise)
# cross_section_angle_b = 0  # Cross-section angle at node 2 (anti-clockwise)
# a_small_number = 1e-10

D_radius = 0.05
D_young_modulus = 210e9  # Young's modulus in Pascals
D_shear_modulus = 81e9  # Shear modulus in Pascals
D_poisson_ratio = 0.3
cross_section_angle_a = 0  # Cross-section angle at node 1 (anti-clockwise)
cross_section_angle_b = 0  # Cross-section angle at node 2 (anti-clockwise)
a_small_number = 1e-10


# In[673]:


def rotation(v, k, theta):
    """Rotation of vector v around axis k by angle theta."""
    k = k / torch.norm(k)  # Normalize k
    cross_product = torch.cross(k, v)
    dot_product = torch.dot(k, v)

    # Ensure theta is a tensor
    theta = torch.tensor(theta, dtype=torch.float32) if not isinstance(theta, torch.Tensor) else theta

    v_rotated = v * torch.cos(theta) + cross_product * torch.sin(theta) + k * dot_product * (1 - torch.cos(theta))
    return v_rotated


# In[674]:


###### Element Creating (euler beam)
# For rectangular sections
# class Beam:
#     def __init__(self, node_coordinates, width=D_width, height=D_height, young_modulus=D_young_modulus,
#                  shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
#                  Beta_b=cross_section_angle_b):
#         self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

#         # Material and geometry
#         self.width = width
#         self.height = height
#         self.young_modulus = young_modulus
#         self.shear_modulus = shear_modulus
#         self.poisson_ratio = poisson_ratio

#         # Cross-sectional properties
#         self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
#         self.Iy = (self.width * self.height ** 3) / 12
#         self.Iz = (self.width ** 3 * self.height) / 12
#         self.A = self.width * self.height
#         self.J = (self.width * self.height ** 3) / 3

#         # Stiffness components
#         self.S_u = self.young_modulus * self.A / self.length
#         self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
#         self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
#         self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
#         self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
#         self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
#         self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
#         self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
#         self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
#         self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
#         self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
#         self.S_Tr = self.shear_modulus * self.J / self.length

#         # Section rotations at the two ends
#         self.Beta_a = Beta_a
#         self.Beta_b = Beta_b


# In[675]:


# For circular sections
class Beam:
    def __init__(self, node_coordinates, R=D_radius, young_modulus=D_young_modulus,
                 shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                 Beta_b=cross_section_angle_b):
        self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

        # Material and geometry
        self.radius = R
        self.young_modulus = young_modulus
        self.shear_modulus = shear_modulus
        self.poisson_ratio = poisson_ratio

        # Cross-sectional properties
        self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
        self.Iy = (torch.pi * self.radius ** 4) / 4 
        self.Iz = self.Iy
        self.A = torch.pi * self.radius ** 2
        self.J = (torch.pi * self.radius ** 4) / 2

        # Stiffness components
        self.S_u = self.young_modulus * self.A / self.length
        self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
        self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
        self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
        self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
        self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
        self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
        self.S_Tr = self.shear_modulus * self.J / self.length

        # Section rotations at the two ends
        self.Beta_a = Beta_a
        self.Beta_b = Beta_b

    def get_element_stiffness_matrix(self):
        """Element stiffness matrix."""
        K_element = torch.tensor([
            [self.S_u, 0, 0, 0, 0, 0, -self.S_u, 0, 0, 0, 0, 0],
            [0, self.S_v1a, 0, 0, 0, self.S_theta1a, 0, -self.S_v1a, 0, 0, 0, self.S_theta1a],
            [0, 0, self.S_v2a, 0, -self.S_theta2a, 0, 0, 0, -self.S_v2a, 0, -self.S_theta2a, 0],
            [0, 0, 0, self.S_Tr, 0, 0, 0, 0, 0, -self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2b, 0, 0, 0, self.S_v2b, 0, self.S_theta2c, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1b, 0, -self.S_v1b, 0, 0, 0, self.S_theta1c],
            [-self.S_u, 0, 0, 0, 0, 0, self.S_u, 0, 0, 0, 0, 0],
            [0, -self.S_v1a, 0, 0, 0, -self.S_theta1a, 0, self.S_v1a, 0, 0, 0, -self.S_theta1a],
            [0, 0, -self.S_v2a, 0, self.S_theta2a, 0, 0, 0, self.S_v2a, 0, self.S_theta2a, 0],
            [0, 0, 0, -self.S_Tr, 0, 0, 0, 0, 0, self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2c, 0, 0, 0, self.S_v2b, 0, self.S_theta2b, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1c, 0, -self.S_v1b, 0, 0, 0, self.S_theta1b],
        ], dtype=torch.float32)

        return K_element

    def System_Transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        # print(vector_x,vector_y,vector_z)
        # Calculate alpha and ceta using PyTorch
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)
        # print(alpha)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)

        # Z_axis_b = rotation(V_projection, X_axis, self.Beta_b)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        # Y_axis_b = rotation(Z_axis_b, X_axis, torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        # Z_axis_b = Z_axis_b / torch.norm(Z_axis_b)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)
        # Y_axis_b = Y_axis_b / torch.norm(Y_axis_b)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)
        matrix_T = torch.zeros((12, 12), dtype=torch.float32)
        for i in range(0, 12, 3):
            matrix_T[i:i + 3, i:i + 3] = lambda_matrix
        return matrix_T

    def nodal_transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        # Calculate alpha and ceta using PyTorch
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)

        # Z_axis_b = rotation(V_projection, X_axis, self.Beta_b)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        # Y_axis_b = rotation(Z_axis_b, X_axis, torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        # Z_axis_b = Z_axis_b / torch.norm(Z_axis_b)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)
        # Y_axis_b = Y_axis_b / torch.norm(Y_axis_b)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)

        return lambda_matrix


# In[676]:


def assemble_stiffness_matrix(beams, n_nodes, n_dof_per_node, connectivity):
    """Global stiffness matrix assembly."""
    total_dof = n_nodes * n_dof_per_node  # Total degrees of freedom
    K_global = torch.zeros((total_dof, total_dof), dtype=torch.float32)
    for idx, (i, j) in enumerate(connectivity):
        Matrix_T = beams[idx].System_Transform()  # Get transformation matrix

        K_element = torch.matmul(torch.transpose(Matrix_T, 0, 1),
                                 torch.matmul(beams[idx].get_element_stiffness_matrix(), Matrix_T))

        start_idx = (i - 1) * n_dof_per_node
        end_idx = (j - 1) * n_dof_per_node
        K_global[start_idx:start_idx + 6, start_idx:start_idx + 6] = K_global[start_idx:start_idx + 6,
                                                                     start_idx:start_idx + 6] + K_element[0:6, 0:6]
        K_global[end_idx:end_idx + 6, end_idx:end_idx + 6] = K_global[end_idx:end_idx + 6,
                                                             end_idx:end_idx + 6] + K_element[6:12, 6:12]
        K_global[start_idx:start_idx + 6, end_idx:end_idx + 6] = K_global[start_idx:start_idx + 6,
                                                                 end_idx:end_idx + 6] + K_element[0:6, 6:12]
        K_global[end_idx:end_idx + 6, start_idx:start_idx + 6] = K_global[end_idx:end_idx + 6,
                                                                 start_idx:start_idx + 6] + K_element[6:12, 0:6]

    return K_global


# In[677]:


def Strain_E(node_coords, connectivity, fixed_dof, F):
    # node_coords[:, 2] = 0.0
    # Element Assembly
    beams = []
    for connection in connectivity:
        node_1_coords = node_coords[connection[0] - 1]
        node_2_coords = node_coords[connection[1] - 1]
        beam = Beam(node_coordinates=torch.stack([node_1_coords, node_2_coords]),
                    R=D_radius, young_modulus=D_young_modulus,
                    shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                    Beta_b=cross_section_angle_b)
        beams.append(beam)
    # Stiffness renewal
    K_global = assemble_stiffness_matrix(beams, n_nodes=len(node_coords), n_dof_per_node=6, connectivity=connectivity)
    K_global[fixed_dof, :] = K_global[fixed_dof, :] - K_global[fixed_dof, :]
    K_global[:, fixed_dof] = K_global[:, fixed_dof] - K_global[:, fixed_dof]
    K_global[fixed_dof, fixed_dof] = 1e5
    rank_K = torch.linalg.matrix_rank(K_global)

    if rank_K < K_global.shape[0]:
        print("Warning: The stiffness matrix is not of full rank")
    else:
        displacements = torch.linalg.solve(K_global, F)

    # Compute strain energy
    strain_energy_list = []
    Local_d = torch.zeros(len(connectivity), 12, dtype=torch.float32)
    for n, (i, j) in enumerate(connectivity):
        matrix_T = beams[n].System_Transform()
        Tep_displacements = torch.cat(
            [displacements[6 * (i - 1):6 * (i - 1) + 6], displacements[6 * (j - 1):6 * (j - 1) + 6]], dim=0)
        Local_d_n = torch.matmul(Tep_displacements, matrix_T.T)
        Local_d[n, :] = Local_d_n.clone()
        K_g = torch.matmul(torch.transpose(matrix_T, 0, 1),
                           torch.matmul(beams[n].get_element_stiffness_matrix(), matrix_T))

        strain_energy_list.append(torch.matmul(Local_d_n, torch.matmul(K_g, Local_d_n.reshape(-1, 1))))

    Strain_energy = torch.stack(strain_energy_list)

    return Strain_energy, Local_d, displacements, beams


# In[678]:


# Element creating
#################  input below:
############################################################################################################## input
# initial coordinates

####### BCs
fixed_dof = []
for node in Fixed_nodes:
    fixed_dof.extend([(node - 1) * 6 + i for i in range(6)])
# print(fixed_dof)
####### Gradient descent
step = 0.001
epochs = 1000
####### Plotting
steps = 20  # steps for tracing deformation shape
###################################################################################################################################################
###################################################################################################################################################


# In[679]:

# Optimized Variables
## initial variables
q = torch.rand(12, requires_grad=True)
## Optimization
torch.autograd.set_detect_anomaly(True)
# Optimizer setting
optimizer = optim.Adam([q], lr=step)
# Initilizing
# New_Coordinates = torch.zeros(n_nodes * 3, dtype=torch.float32)
# Loss_his = []
Disp_his = []
patience = 5
count = 0

# Loop start
for iteration in range(epochs + 1):
    print('ite',iteration)
    # Forwards
    Q = torch.diag(q) * 1 / r  # scaling
    new_node_coords = FDM(Q)
    if iteration == 0:
        print(new_node_coords)
    N_coords = new_node_coords.clone()
    Strain_energy, _, displacements, _ = Strain_E(N_coords, connectivity, fixed_dof, F)
    idx = 6 * torch.arange(n_nodes) + 2
    Ave_Disp = abs(torch.sum(displacements[idx] / len(Free_nodes)))
    Disp_his.append(Ave_Disp.item())
    if iteration > 0:  
        previous_Ave_Disp = Disp_his[iteration - 1]  
        change = abs(Ave_Disp - previous_Ave_Disp) / previous_Ave_Disp  
        if change < 1/1000:
            count += 1
        else:
            count = 0 
        if count >= patience:
            print(f"Early stopping at iteration {iteration}: Ave_Disp change < 1% for {patience} consecutive iterations.")
            break 
    N_coords = N_coords.reshape(-1)
    New_Coordinates = torch.zeros(n_nodes * 3, dtype=torch.float32)
    for n in range(n_nodes):
        New_Coordinates[3*n : 3*n+3] = N_coords[3*n : 3*n+3] + displacements[6*n : 6*n+3]
    New_Coordinates = New_Coordinates.view(n_nodes, 3).clone()
    
    # Backwards
    optimizer.zero_grad()
    # print(q.grad)
    Ave_Disp.backward(retain_graph=True)

    # Grad
    gradients = q.grad
    print('Grad',gradients)
    frob_norm = torch.norm(gradients)
    optimizer.step()
    
    # print iteration
    if iteration % 5 == 0:
        print(f"Iteration {iteration}: Normalized Gradient = {frob_norm}, Adaptive learning rate = {step}")
print("Optimization completed.")
print(q)
# print("coordinates:",node_coords)

#############################################################################################################
## Visualization
# print(Coordinates)
# displacements = Strain_E(node_coords, connectivity, fixed_dof, F)[2]
# print("displacements:", displacements)
print("Deformed:", New_Coordinates)

x_orig = node_coords[:, 0].detach().numpy()
y_orig = node_coords[:, 1].detach().numpy()
z_orig = node_coords[:, 2].detach().numpy()

x_def = New_Coordinates[:, 0].detach().numpy()
y_def = New_Coordinates[:, 1].detach().numpy()
z_def = New_Coordinates[:, 2].detach().numpy()


fig = go.Figure()


for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_orig[i-1], x_orig[j-1]],
        y=[y_orig[i-1], y_orig[j-1]],
        z=[z_orig[i-1], z_orig[j-1]],
        mode='lines',
        line=dict(color='blue', width=4),
        name='Original Geometry'
    ))


for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_def[i-1], x_def[j-1]],
        y=[y_def[i-1], y_def[j-1]],
        z=[z_def[i-1], z_def[j-1]],
        mode='lines',
        line=dict(color='red', width=4),
        name='Deformed Geometry'
    ))


for node in Free_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_def[node-1]],
        y=[y_def[node-1]],
        z=[z_def[node-1]],
        mode='markers+text',
        marker=dict(size=5, color='green'),
        text=[f'Node {node}'],
        textposition='top center',
        name=f'Free Node {node}'
    ))


fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        aspectmode='data'
    ),
    title='Deformation Comparison: Original vs. Deformed Geometry (FE Analysis)',
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()

########################################################################################################################

### Plot the optimization history
fig, ax1 = plt.subplots(figsize=(10, 6))

ax1 = ax1.twinx()
color = 'red'
ax1.set_ylabel('Average Displacement', color=color)
ax1.plot(range(len(Disp_his)), Disp_his, label='Average Displacement', color=color, linewidth=2, linestyle='--')
ax1.tick_params(axis='y', labelcolor=color)

lines1, labels1 = ax1.get_legend_handles_labels()
ax1.legend(lines1 , labels1, loc='upper right')

plt.title('Loss & Average Displacement vs. Iterations')

plt.tight_layout()
plt.show()
