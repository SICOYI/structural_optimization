# %%
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import plotly.graph_objects as go
import time
from datetime import timedelta
import json
import os
import psutil
import gc
import math


gc.collect()  
device = torch.device('cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
############ customization
length = 48
width = 48
n1 = 13
n2 = 13
judge = 0

# %%
############### Problem context formulation

def generate_rectangular_grid_sg(length, width, n1, n2=2, judge=0, z=0, height=0):
    x_points = [i * (length / n1) for i in range(n1 + 1)]
    y_points = [j * (width / n2) for j in range(n2, -1, -1)]

    grid_points = []
    for x in x_points:
        for y in y_points:
            if y == width / 2:
                grid_points.append([x, y, height])
            else:
                grid_points.append([x, y, z])

    if judge == 1:
        corners = [
            [x_points[0], y_points[0], z],
            [x_points[0], y_points[-1], z],
            [x_points[-1], y_points[0], z],
            [x_points[-1], y_points[-1], z]
        ]
        grid_points = [point for point in grid_points if point not in corners]

    return grid_points

def plot_grid(grid_points, length, width):
    x = [point[0] for point in grid_points]
    y = [point[1] for point in grid_points]
    z = [point[2] for point in grid_points]

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(x, y, z, c='r', marker='o', s=50, label='Grid Points')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.legend()
    plt.show()

def generate_connectivity_matrix(new_coords):
    indexed_points = {tuple(point): idx + 1 for idx, point in enumerate(new_coords)}
    connectivity = []

    x_values = sorted(set(point[0] for point in new_coords))
    for x in x_values:
        points_on_line = [point for point in new_coords if point[0] == x]
        points_on_line.sort(key=lambda p: p[1], reverse=True) 

        for i in range(len(points_on_line) - 1):
            node1 = indexed_points[tuple(points_on_line[i])]
            node2 = indexed_points[tuple(points_on_line[i + 1])]
            connectivity.append([node1, node2])

    y_values = sorted(set(point[1] for point in new_coords))
    for y in y_values:
        points_on_line = [point for point in new_coords if point[1] == y]
        points_on_line.sort(key=lambda p: p[0])  

        for i in range(len(points_on_line) - 1):
            node1 = indexed_points[tuple(points_on_line[i])]
            node2 = indexed_points[tuple(points_on_line[i + 1])]
            connectivity.append([node1, node2])

    return connectivity

grid_points = generate_rectangular_grid_sg(length, width, n1, n2, judge)
connectivity = generate_connectivity_matrix(grid_points)
plot_grid(grid_points, length, width)


###########################################################################################################################################################
n_dof_per_node = 6  # Degrees of freedom per node
grid_points = torch.tensor(grid_points, device=device, dtype=torch.float32)
total_dof = n_dof_per_node * len(grid_points)

########## Surrounding fixed
x_max = grid_points[:, 0].max()
x_min = grid_points[:, 0].min()
y_max = grid_points[:, 1].max()
y_min = grid_points[:, 1].min()

Fixed_nodes = torch.where(
    #     (grid_points[:, 0] == x_max) | 
    # (grid_points[:, 0] == x_min) |    
    (grid_points[:, 1] == y_max) |  # y = y_max
    (grid_points[:, 1] == y_min)    # y = y_min
)[0]

Fixed_nodes += 1
Free_nodes = []

n_elements = len(connectivity)
n_nodes = len(grid_points)

for i in range(1, n_nodes + 1):
    if i not in Fixed_nodes:
        Free_nodes.append(i)


####### BCs
fixed_dof = []
for node in Fixed_nodes:
    fixed_dof.extend([(node - 1) * 6 + i for i in range(6)])

##########################################################################################################################################################
##########################################################################################################################################################

# %%
rows = n2 + 1
cols = n1 + 1

idx_matrix = [[0 for _ in range(cols)] for _ in range(rows)]

for k in range(rows * cols):
    row = k % rows
    col = k // rows
    idx_matrix[row][col] = k
V_matrix = torch.arange(0, n2 * (n1 + 1)).reshape(n1 + 1, n2).T

start = n2 * (n1 + 1)
H_matrix = torch.arange(start, start + (n2 + 1) * n1)
H_matrix = H_matrix.reshape(n1 + 1 , n2)
H_matrix = H_matrix.flip(0)
print(V_matrix)
print(H_matrix)
# Out:
# tensor([[  0,  13,  26,  39,  52,  65,  78,  91, 104, 117, 130, 143, 156, 169],
#         [  1,  14,  27,  40,  53,  66,  79,  92, 105, 118, 131, 144, 157, 170],
#         [  2,  15,  28,  41,  54,  67,  80,  93, 106, 119, 132, 145, 158, 171],
#         [  3,  16,  29,  42,  55,  68,  81,  94, 107, 120, 133, 146, 159, 172],
#         [  4,  17,  30,  43,  56,  69,  82,  95, 108, 121, 134, 147, 160, 173],
#         [  5,  18,  31,  44,  57,  70,  83,  96, 109, 122, 135, 148, 161, 174],
#         [  6,  19,  32,  45,  58,  71,  84,  97, 110, 123, 136, 149, 162, 175],
#         [  7,  20,  33,  46,  59,  72,  85,  98, 111, 124, 137, 150, 163, 176],
#         [  8,  21,  34,  47,  60,  73,  86,  99, 112, 125, 138, 151, 164, 177],
#         [  9,  22,  35,  48,  61,  74,  87, 100, 113, 126, 139, 152, 165, 178],
#         [ 10,  23,  36,  49,  62,  75,  88, 101, 114, 127, 140, 153, 166, 179],
#         [ 11,  24,  37,  50,  63,  76,  89, 102, 115, 128, 141, 154, 167, 180],
#         [ 12,  25,  38,  51,  64,  77,  90, 103, 116, 129, 142, 155, 168, 181]])
# tensor([[351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363],
#         [338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350],
#         [325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337],
#         [312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324],
#         [299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311],
#         [286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298],
#         [273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285],
#         [260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272],
#         [247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259],
#         [234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246],
#         [221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233],
#         [208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220],
#         [195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207],
#         [182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194]])

# %%
def Symmetry_shaper(q, matrix):

    rows, cols = matrix.shape

    row_odd = rows % 2 == 1
    col_odd = cols % 2 == 1
    
    if row_odd:

        q = torch.cat([q, q.flip(0)[1:,:]], dim=0)
    else:

        q = torch.cat([q, q.flip(0)], dim=0)
    

    if col_odd:

        q = torch.cat([q, q.flip(1)[:,1:]], dim=1)
    else:

        q = torch.cat([q, q.flip(1)], dim=1)
    
    return q

# %%
############################################################# Force condition
def Force_mat(F_value, F_type, total_dof=total_dof, Free_nodes=Free_nodes, judge=0):
    
    F = torch.zeros(total_dof, dtype=torch.float32, device=device)
    
    if judge == 0:
        F_value = torch.tensor([F_value] * len(Free_nodes), device=device) * 1000 # The force value/direction
        F_type = [F_type] * len(Free_nodes)  # The force type
    else:
        F_value = torch.tensor(F_value) * 1000
        F_value = torch.tensor(F_type)
    
    for idx, i in enumerate(Free_nodes):
        F[6 * (i - 1) + F_type[idx]] = F_value[idx]  # unit: KN / KN*m
        
    return F, F_value

# %%
def save_fdm(state_idx, grid_points, new_node_coords, 
            connectivity, Free_nodes, Fixed_nodes, force, SED,
            save_dir="results", max_states=6):
    """
    多状态组合图保存函数
    
    参数:
        state_idx: 状态序号 (0=初始, 1=第cut次, 2=第2*cut次...)
        max_states: 组合图中最多显示的状态数
    """
    os.makedirs(save_dir, exist_ok=True)
    
    # 数据准备
    x_orig = grid_points[:, 0].cpu().detach().numpy()
    y_orig = grid_points[:, 1].cpu().detach().numpy()
    z_orig = grid_points[:, 2].cpu().detach().numpy()
    
    x_fdm = new_node_coords[:, 0].cpu().detach().numpy()
    y_fdm = new_node_coords[:, 1].cpu().detach().numpy()
    z_fdm = new_node_coords[:, 2].cpu().detach().numpy()
    
    # 计算当前高度
    current_height = max(z_fdm)
    
    # 初始化图形容器
    if not hasattr(save_fdm, 'fig'):
        save_fdm.fig = plt.figure(figsize=(24, 16))
        save_fdm.axes = [save_fdm.fig.add_subplot(2, 3, i+1, projection='3d') 
                       for i in range(max_states)]
        plt.subplots_adjust(wspace=0.3, hspace=0.3)
        save_fdm.saved_states = 0
        save_fdm.max_z = 0  # 用于统一z轴尺度
    
    # 检查是否已存满
    if save_fdm.saved_states >= max_states:
        filename = os.path.join(save_dir, f"FDM_States_{max_states}.png")
        save_fdm.fig.savefig(filename, dpi=200, bbox_inches='tight')
        plt.close(save_fdm.fig)
        delattr(save_fdm, 'fig')
        delattr(save_fdm, 'axes')
        delattr(save_fdm, 'saved_states')
        delattr(save_fdm, 'max_z')
        print(f"Saved full states to {filename}")
        return
    
    # 更新最大z值（用于统一坐标尺度）
    if current_height > save_fdm.max_z:
        save_fdm.max_z = current_height
    
    # 获取当前子图并清除旧内容
    ax = save_fdm.axes[save_fdm.saved_states]
    ax.clear()
    
    # ========== 可视化绘制 ==========
    # 1. 绘制原始网格（浅灰色虚线）
    for i, j in connectivity:
        ax.plot([x_orig[i-1], x_orig[j-1]],
                [y_orig[i-1], y_orig[j-1]],
                [z_orig[i-1], z_orig[j-1]], 
                ':', color='#CCCCCC', linewidth=0.8, alpha=0.7)
    
    # 2. 绘制当前状态网格
    color = '#1f77b4' if state_idx == 0 else '#ff7f0e'  # 初始蓝色，迭代橙色
    for i, j in connectivity:
        ax.plot([x_fdm[i-1], x_fdm[j-1]],
                [y_fdm[i-1], y_fdm[j-1]],
                [z_fdm[i-1], z_fdm[j-1]], 
                '-', color=color, linewidth=1.8, alpha=0.9)
    
    # 3. 标记固定节点（黑色实心圆）
    for node in Fixed_nodes:
        ax.scatter(x_fdm[node-1], y_fdm[node-1], z_fdm[node-1],
                  c='black', s=50, marker='o', alpha=0.8)
    
    # 4. 添加高度标注（替换原来的力值标注）
    ax.text(x=0.05, y=0.90, z=save_fdm.max_z*1.05,
           s=f"Height: {current_height:.2f}m\nSE: {SED:.8f} ", 
           transform=ax.transAxes, 
           fontsize=10,
           bbox=dict(facecolor='white', alpha=0.7))
    
    # ========== 子图装饰 ==========
    ax.set_xlabel('X (m)', fontsize=9)
    ax.set_ylabel('Y (m)', fontsize=9)
    ax.set_zlabel('Z (m)', fontsize=9)
    ax.set_title(f"State {state_idx}" if state_idx > 0 else "Initial State", 
                fontsize=11, pad=12)
    ax.set_zlim(0, save_fdm.max_z * 1.1)  # 统一z轴尺度
    ax.view_init(elev=35, azim=45)
    ax.grid(True, linestyle=':', alpha=0.5)
    
    # 更新状态计数器
    save_fdm.saved_states += 1
    
    # 如果是最后一个状态，立即保存
    if save_fdm.saved_states == max_states:
        filename = os.path.join(save_dir, f"FDM_States_{max_states}.png")
        save_fdm.fig.savefig(filename, dpi=200, bbox_inches='tight')
        plt.close(save_fdm.fig)
        delattr(save_fdm, 'fig')
        delattr(save_fdm, 'axes')
        delattr(save_fdm, 'saved_states')
        delattr(save_fdm, 'max_z')
        print(f"Saved full states to {filename}")


def finalize_fdm(save_dir="results", completed=False):
    """
    最终化处理函数
    
    参数:
        save_dir: 保存目录
        completed: 是否完成所有迭代 (True=已完成全部迭代，False=提前终止)
    """
    if not hasattr(save_fdm, 'fig') or save_fdm.saved_states == 0:
        return
    
    # 如果已完成所有迭代，保存当前进度（不强制填满）
    if completed:
        filename = os.path.join(save_dir, 
                              f"FDM_States_completed_{save_fdm.saved_states}.png")
    # 如果是提前终止，保存上一次有效迭代
    else:
        # 回退一个状态，因为最后一次迭代可能不完整
        save_fdm.saved_states = max(0, save_fdm.saved_states - 1)
        filename = os.path.join(save_dir,
                              f"FDM_States_partial_{save_fdm.saved_states+1}.png")
    
    # 保存图像
    save_fdm.fig.savefig(filename, dpi=200, bbox_inches='tight')
    plt.close(save_fdm.fig)
    
    # 打印保存信息
    if completed:
        print(f"Saved completed states ({save_fdm.saved_states}/{len(save_fdm.axes)}) to {filename}")
    else:
        print(f"Saved last valid state ({save_fdm.saved_states+1}) to {filename}")
    
    # 清理属性
    for attr in ['fig', 'axes', 'saved_states', 'max_z']:
        if hasattr(save_fdm, attr):
            delattr(save_fdm, attr)

# %%
####### FDM part 
C = torch.zeros(n_elements, n_nodes, dtype=torch.float32, device=device)
for n, (i, j) in enumerate(connectivity):
    C[n, i - 1] = 1
    C[n, j - 1] = -1
    
px= torch.zeros(len(Free_nodes), 1, dtype=torch.float32, device=device)
py = torch.zeros(len(Free_nodes), 1, dtype=torch.float32, device=device)
pz = torch.zeros(len(Free_nodes), 1, dtype=torch.float32, device=device)


fixed_idces = torch.tensor([node - 1 for node in Fixed_nodes], device=device)
free_node_indices = torch.tensor([node - 1 for node in Free_nodes], device=device)

CF = C[:, fixed_idces]
CN = C[:, free_node_indices]

def FDM(Q, F_value, CN=CN, CF=CF, px=px, py=py, pz=pz, 
        fixed_idces=fixed_idces, free_node_indices=free_node_indices,
        node_coords=grid_points):
    
    pz[:, 0] = F_value
        
    Dn = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CN))
    DF = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CF))
    
    
    xF = node_coords[fixed_idces, 0].unsqueeze(1)
    yF = node_coords[fixed_idces, 1].unsqueeze(1)
    zF = node_coords[fixed_idces, 2].unsqueeze(1)
    
    xN = torch.matmul(torch.inverse(Dn), (px - torch.matmul(DF, xF)))
    yN = torch.matmul(torch.inverse(Dn), (py - torch.matmul(DF, yF)))
    zN = torch.matmul(torch.inverse(Dn), (pz - torch.matmul(DF, zF)))
        
    
    new_node_coords = node_coords.clone()
    new_node_coords[free_node_indices, 0] = xN.squeeze()
    new_node_coords[free_node_indices, 1] = yN.squeeze()
    new_node_coords[free_node_indices, 2] = zN.squeeze()
    
    return new_node_coords

# %%
###### FE part
D_radius = 0.75
D_young_modulus = 10e9 
D_shear_modulus = 0.7e9 
D_poisson_ratio = 0.3
cross_section_angle_a = 0  
cross_section_angle_b = 0  
a_small_number = 1e-10

def rotation(v, k, theta):
    """Rotation of vector v around axis k by angle theta."""
    k = k / torch.norm(k)  # Normalize k
    cross_product = torch.cross(k, v)
    dot_product = torch.dot(k, v)

    # Ensure theta is a tensor
    theta = torch.tensor(theta, dtype=torch.float32, device=device) if not isinstance(theta, torch.Tensor) else theta

    v_rotated = v * torch.cos(theta) + cross_product * torch.sin(theta) + k * dot_product * (1 - torch.cos(theta))
    return v_rotated

class Beam:
    def __init__(self, node_coordinates, R=D_radius, young_modulus=D_young_modulus,
                 shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                 Beta_b=cross_section_angle_b):
        self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

        # Material and geometry
        self.radius = R
        self.young_modulus = young_modulus
        self.shear_modulus = shear_modulus
        self.poisson_ratio = poisson_ratio

        # Cross-sectional properties
        self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
        self.Iy = (torch.pi * self.radius ** 4) / 4 
        self.Iz = self.Iy
        self.A = torch.pi * self.radius ** 2
        self.J = (torch.pi * self.radius ** 4) / 2

        # Stiffness components
        self.S_u = self.young_modulus * self.A / self.length
        self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
        self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
        self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
        self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
        self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
        self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
        self.S_Tr = self.shear_modulus * self.J / self.length

        # Section rotations at the two ends
        self.Beta_a = Beta_a
        self.Beta_b = Beta_b

    def get_element_stiffness_matrix(self):
        """Element stiffness matrix."""
        K_element = torch.tensor([
            [self.S_u, 0, 0, 0, 0, 0, -self.S_u, 0, 0, 0, 0, 0],
            [0, self.S_v1a, 0, 0, 0, self.S_theta1a, 0, -self.S_v1a, 0, 0, 0, self.S_theta1a],
            [0, 0, self.S_v2a, 0, -self.S_theta2a, 0, 0, 0, -self.S_v2a, 0, -self.S_theta2a, 0],
            [0, 0, 0, self.S_Tr, 0, 0, 0, 0, 0, -self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2b, 0, 0, 0, self.S_v2b, 0, self.S_theta2c, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1b, 0, -self.S_v1b, 0, 0, 0, self.S_theta1c],
            [-self.S_u, 0, 0, 0, 0, 0, self.S_u, 0, 0, 0, 0, 0],
            [0, -self.S_v1a, 0, 0, 0, -self.S_theta1a, 0, self.S_v1a, 0, 0, 0, -self.S_theta1a],
            [0, 0, -self.S_v2a, 0, self.S_theta2a, 0, 0, 0, self.S_v2a, 0, self.S_theta2a, 0],
            [0, 0, 0, -self.S_Tr, 0, 0, 0, 0, 0, self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2c, 0, 0, 0, self.S_v2b, 0, self.S_theta2b, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1c, 0, -self.S_v1b, 0, 0, 0, self.S_theta1b],
        ], dtype=torch.float32, device=device)

        return K_element

    def System_Transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)
        matrix_T = torch.zeros((12, 12), dtype=torch.float32, device=device)
        for i in range(0, 12, 3):
            matrix_T[i:i + 3, i:i + 3] = lambda_matrix
        return matrix_T

    def nodal_transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)
        return lambda_matrix


def assemble_stiffness_matrix(beams, n_nodes, n_dof_per_node, connectivity):
    """Global stiffness matrix assembly."""
    total_dof = n_nodes * n_dof_per_node  # Total degrees of freedom
    K_global = torch.zeros((total_dof, total_dof), dtype=torch.float32, device=device)
    
    for idx, (i, j) in enumerate(connectivity):
        Matrix_T = beams[idx].System_Transform()  # Get transformation matrix
        K_element = torch.matmul(torch.transpose(Matrix_T, 0, 1),
                                 torch.matmul(beams[idx].get_element_stiffness_matrix(), Matrix_T))

        start_idx = (i - 1) * n_dof_per_node
        end_idx = (j - 1) * n_dof_per_node
        K_global[start_idx:start_idx + 6, start_idx:start_idx + 6] += K_element[0:6, 0:6]
        K_global[end_idx:end_idx + 6, end_idx:end_idx + 6] += K_element[6:12, 6:12]
        K_global[start_idx:start_idx + 6, end_idx:end_idx + 6] += K_element[0:6, 6:12]
        K_global[end_idx:end_idx + 6, start_idx:start_idx + 6] += K_element[6:12, 0:6]

    return K_global

def robust_solve(K_global, F, fixed_dof, max_attempts=3):
    
    attempts = 0
    while attempts < max_attempts:
        reg = 1e-6 * torch.eye(K_global.shape[0], device=K_global.device)
        reg[fixed_dof, fixed_dof] = 0  
        K_reg = K_global + reg
        try:
            cond_number = torch.linalg.cond(K_reg)
        except torch._C._LinAlgError:
            print("警告：条件数计算失败（矩阵可能奇异），自动设为0")
            cond_number = torch.tensor(0.0, device=K_reg.device)
        try:
            displacements = torch.linalg.solve(
                K_reg.to(torch.float64), 
                F.to(torch.float64)
            )
            sol_type = 0
            return displacements.to(K_global.dtype), sol_type, cond_number
            
        except RuntimeError:
            diag = torch.diag(K_global)
            extreme_mask = (diag > 1e12) & (~torch.isin(torch.arange(len(diag)), torch.tensor(fixed_dof)))  
            K_reg[extreme_mask] = 0
            K_reg[:, extreme_mask] = 0
            K_reg[extreme_mask, extreme_mask] = 1e12  
            
            K_reg[fixed_dof, :] = 0
            K_reg[:, fixed_dof] = 0
            K_reg[fixed_dof, fixed_dof] = 1e10  
            
            try:
                displacements, info = torch.linalg.cg(
                    K_reg.to(torch.float64),
                    F.to(torch.float64),
                    maxiter=5000,
                    atol=1e-6
                )
                if info > 0:
                    raise RuntimeError("CG nah nah")
                sol_type = 1
                return displacements.to(K_global.dtype), sol_type, cond_number
                
            except:
                K_pinv = torch.linalg.pinv(K_reg)
                K_pinv[fixed_dof, :] = 0  
                displacements = K_pinv @ F
                print("警告：使用伪逆求解，精度可能降低")
                sol_type = 2
                return displacements, sol_type, cond_number
                
        attempts += 1
    
    raise RuntimeError("无法求解线性系统")


def Strain_E(node_coords, connectivity, fixed_dof, F):
    # Element Assembly
    Beam_lens = []
    beams = []
    for connection in connectivity:
        node_1_coords = node_coords[connection[0] - 1]
        node_2_coords = node_coords[connection[1] - 1]
        beam = Beam(node_coordinates=torch.stack([node_1_coords, node_2_coords]),
                    R=D_radius, young_modulus=D_young_modulus,
                    shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                    Beta_b=cross_section_angle_b)
        beams.append(beam)
        Beam_lens.append(beam.length)
    
    # Stiffness renewal
    K_global = assemble_stiffness_matrix(beams, n_nodes=len(node_coords), n_dof_per_node=6, connectivity=connectivity)
    K_global[fixed_dof, :] = 0
    K_global[:, fixed_dof] = 0
    K_global[fixed_dof, fixed_dof] = 1e10
    displacements, sol_type,cond_number= robust_solve(K_global, F, fixed_dof)

    # Compute strain energy
    strain_energy_list = []
    force_list = []
    ASE_list = []
    V_list = []
    Local_d = torch.zeros(len(connectivity), 12, dtype=torch.float32, device=device)
    for n, (i, j) in enumerate(connectivity):
        matrix_T = beams[n].System_Transform()
        Tep_displacements = torch.cat(
            [displacements[6 * (i - 1):6 * (i - 1) + 6], displacements[6 * (j - 1):6 * (j - 1) + 6]], dim=0)
        Local_d_n = torch.matmul(Tep_displacements, matrix_T.T)
        Local_d[n, :] = Local_d_n.clone()
        K_l = beams[n].get_element_stiffness_matrix()
        strain_energy_list.append(0.5 * torch.matmul(Local_d_n, torch.matmul(K_l, Local_d_n.reshape(-1, 1))))
        force_list.append(torch.matmul(K_l, Local_d_n.reshape(-1, 1)))
        ASE_list.append(0.5 * (Local_d_n[0]-Local_d_n[6]) * beams[n].S_u * (Local_d_n[0]-Local_d_n[6]))  
        V_list.append(beams[n].A * beams[n].length)
    
     
    
    Strain_energy = torch.stack(strain_energy_list)
    forces = torch.stack(force_list)
    ASE = torch.stack(ASE_list)
    lens = torch.stack(Beam_lens)
    # epsilon = Local_d[:, 0] / lens
    # Axial_d = Local_d[:, 0]
    V = torch.stack(V_list)
    SED = Strain_energy / lens 
    R = torch.var(SED)
    
    return Strain_energy, cond_number, sol_type, ASE, lens, R, V

# %%
def optimizer(q, gradients, step):
    
    grads = gradients / (torch.norm(gradients, p=2, dim=1, keepdim=True) + 1e-10)
    
    q.data -= grads * step
    with torch.no_grad():
        q[0] = torch.clamp(q[0], min=4.375, max=6.5)
        q[1] = torch.clamp(q[1], min=0.0)

    return q
    
def check_available_memory():
    """返回当前可用CPU内存（MB）"""
    return psutil.virtual_memory().available / (1024 ** 2)

# %%
############### Formulating :::::
####### Gradient descent
step = 0.01
epochs = 500
# Initilizing
patience = 20
####### Force Condition

_, F_value = Force_mat(- 1, 2)
F_fe_g, _ = Force_mat(-1, 2)
F_fe_t1, _ = Force_mat(1, 0)
F_fe_t2, _ = Force_mat(1, 1)

r = 1 / torch.max(F_value)

# %%
##### INItializaing the Q:
rows, cols = V_matrix.shape

q_rows = math.ceil(rows / 2)
q_cols = math.ceil(cols / 2)
q_v = torch.ones((q_rows, q_cols)) * 5.44 

rows_, cols_ = H_matrix.shape
q_rows_ = math.ceil(rows_ / 2)
q_cols_ = math.ceil(cols_ / 2)
q_h = torch.zeros((q_rows_, q_cols_))

q_cat = torch.cat([q_v.unsqueeze(0), q_h.unsqueeze(0)], dim=0)  # 形状 (2, q_rows, q_cols)
q = q_cat.clone().requires_grad_(True)

# %%
############## Optimization loop

#### Initializing Data storage
os.makedirs("data_records", exist_ok=True)
optimization_data = {
    "metadata": {
        "project": "Structural Optimization",
        "Context": "FDM + FE",
        "device": str(device),
        "parameters": {
            "length": length,
            "width": width,
            "grid_size": f"{n1}x{n2}",
            "epochs": epochs,
            "step_size": step
        }
    },
    "iterations": []
}

####### Loop start
count = 0
n_elem = len(connectivity)
start_time = time.time()
cut = epochs / 5
LS_his = []
start = time.time()
# Loop start
for iteration in range(epochs + 1):
    
    print('ite', iteration)
  
    avail_mem = check_available_memory()
    print(f"Iter {iteration} - Available Memory: {avail_mem:.2f} MB")
    if avail_mem < 1000: 
        print(f"⚠️  Low memory warning: {avail_mem:.2f} MB left!")
    
    # Geometry initialization
    GEO_str = time.time()
    q_v, q_h = q[0], q[1] 
    q_V = Symmetry_shaper(q_v, V_matrix)
    q_H = Symmetry_shaper(q_h, H_matrix)
    q_vec = torch.zeros(n_elements, device=device)
    for i in range(V_matrix.shape[0]): 
        for j in range(V_matrix.shape[1]): 
            index = V_matrix[i, j].item()  
            q_vec[index] = q_V[i, j] 
    for i in range(H_matrix.shape[0]):  
        for j in range(H_matrix.shape[1]):  
            index = H_matrix[i, j].item() 
            q_vec[index] = q_H[i, j]           
    q_vec = q_vec * 1 / r
    Q = torch.diag(q_vec) 
    Geometry_initialization_time = time.time() - GEO_str
    
    ####### FDM time
    FDM_Str = time.time()
    new_node_coords = FDM(Q, F_value)
    FDM_time = time.time() - FDM_Str
   
    
   
    Loss_str = time.time()
    N_coords = new_node_coords.clone()
    _, _, _, _,lengths, _, _ = Strain_E(N_coords, connectivity, fixed_dof, F_fe_g) 
    Loss = torch.matmul(torch.abs(q_vec * lengths ),lengths)
    LS_his.append(Loss.clone().detach().item())
    Loss_time = time.time() - Loss_str


    ####### Early stopping
    ES_str = time.time()
    if iteration > 0:  
        Pre_Total_LS = LS_his[iteration - 1]  
        change = abs(Loss - Pre_Total_LS) / Pre_Total_LS 
        if change < 1/10000000:
            count += 1
        else:
            count = 0 
        if count >= patience:
            print(f"Early stopping at iteration {iteration}: Loss change < 1%% for {patience} consecutive iterations.")
            break 
    ES_time = time.time() - ES_str
    
    
    Back_str = time.time()
    if q.grad is not None:
        q.grad.detach_()
        q.grad.zero_()
       
    Loss.backward(retain_graph=True)
    Back_time = time.time() - Back_str
    
    # Grad
    Parameter_str = time.time()
    gradients = q.grad
    q = optimizer(q, gradients, step)
    Parameter_update = time.time() - Parameter_str
    
    
    ####### Data storage:
    iteration_record = {
    "iteration": iteration,
    "Geometry_initialization_time": Geometry_initialization_time,
    "FDM_time": FDM_time,
    "Loss_time": Loss_time,
    "Back_time ": Back_time ,
    "Parameter_update": Parameter_update,
    }  
    optimization_data["iterations"].append(iteration_record)



    if iteration % 10 == 0:
        torch.cuda.empty_cache() if torch.cuda.is_available() else None
        gc.collect()
            

end_time =  time.time() - start
optimization_data["metadata"].update({
    "Ite_time": end_time,
})

with open(os.path.join("data_records", "FDM_time.json"), 'w') as f:
    json.dump(optimization_data, f, indent=2)
    
print("Optimization completed.")
# Out:
# ite 0
# Iter 0 - Available Memory: 5602.26 MB
# ite 1
# Iter 1 - Available Memory: 5587.39 MB
# ite 2
# Iter 2 - Available Memory: 5579.36 MB
# ite 3
# Iter 3 - Available Memory: 5593.32 MB
# ite 4
# Iter 4 - Available Memory: 5524.11 MB
# ite 5
# Iter 5 - Available Memory: 5442.50 MB
# ite 6
# Iter 6 - Available Memory: 5440.91 MB
# ite 7
# Iter 7 - Available Memory: 5439.08 MB
# ite 8
# Iter 8 - Available Memory: 5426.08 MB
# ite 9
# Iter 9 - Available Memory: 5425.74 MB
# ite 10
# Iter 10 - Available Memory: 5426.56 MB
# ite 11
# Iter 11 - Available Memory: 5418.53 MB
# ite 12
# Iter 12 - Available Memory: 5422.81 MB
# ite 13
# Iter 13 - Available Memory: 5435.02 MB
# ite 14
# Iter 14 - Available Memory: 5453.46 MB
# ite 15
# Iter 15 - Available Memory: 5427.92 MB
# ite 16
# Iter 16 - Available Memory: 5429.99 MB
# ite 17
# Iter 17 - Available Memory: 5410.64 MB
# ite 18
# Iter 18 - Available Memory: 5403.94 MB
# ite 19
# Iter 19 - Available Memory: 5390.25 MB
# ite 20
# Iter 20 - Available Memory: 5423.82 MB
# ite 21
# Iter 21 - Available Memory: 5406.80 MB
# ite 22
# Iter 22 - Available Memory: 5424.98 MB
# ite 23
# Iter 23 - Available Memory: 5594.18 MB
# ite 24
# Iter 24 - Available Memory: 5449.72 MB
# ite 25
# Iter 25 - Available Memory: 5514.89 MB
# ite 26
# Iter 26 - Available Memory: 5537.71 MB
# ite 27
# Iter 27 - Available Memory: 5499.31 MB
# ite 28
# Iter 28 - Available Memory: 5440.38 MB
# ite 29
# Iter 29 - Available Memory: 5437.88 MB
# ite 30
# Iter 30 - Available Memory: 5470.16 MB
# ite 31
# Iter 31 - Available Memory: 5433.07 MB
# 警告：条件数计算失败（矩阵可能奇异），自动设为0
# ite 32
# Iter 32 - Available Memory: 5432.82 MB
# ite 33
# Iter 33 - Available Memory: 5416.70 MB
# ite 34
# Iter 34 - Available Memory: 5388.55 MB
# ite 35
# Iter 35 - Available Memory: 5446.21 MB
# ite 36
# Iter 36 - Available Memory: 5448.11 MB
# ite 37
# Iter 37 - Available Memory: 5426.11 MB
# ite 38
# Iter 38 - Available Memory: 5429.69 MB
# ite 39
# Iter 39 - Available Memory: 5412.01 MB
# ite 40
# Iter 40 - Available Memory: 5418.47 MB
# ite 41
# Iter 41 - Available Memory: 5433.08 MB
# ite 42
# Iter 42 - Available Memory: 5437.41 MB
# ite 43
# Iter 43 - Available Memory: 5438.23 MB
# ite 44
# Iter 44 - Available Memory: 5443.71 MB
# ite 45
# Iter 45 - Available Memory: 5388.47 MB
# ite 46
# Iter 46 - Available Memory: 5883.73 MB
# ite 47
# Iter 47 - Available Memory: 5731.63 MB
# ite 48
# Iter 48 - Available Memory: 5449.42 MB
# ite 49
# Iter 49 - Available Memory: 5442.62 MB
# ite 50
# Iter 50 - Available Memory: 5410.43 MB
# ite 51
# Iter 51 - Available Memory: 5354.79 MB
# ite 52
# Iter 52 - Available Memory: 5358.57 MB
# ite 53
# Iter 53 - Available Memory: 5373.73 MB
# ite 54
# Iter 54 - Available Memory: 5365.67 MB
# ite 55
# Iter 55 - Available Memory: 5422.12 MB
# ite 56
# Iter 56 - Available Memory: 5422.69 MB
# ite 57
# Iter 57 - Available Memory: 5423.16 MB
# ite 58
# Iter 58 - Available Memory: 5422.47 MB
# ite 59
# Iter 59 - Available Memory: 5422.75 MB
# ite 60
# Iter 60 - Available Memory: 5420.18 MB
# ite 61
# Iter 61 - Available Memory: 5416.71 MB
# ite 62
# Iter 62 - Available Memory: 5401.31 MB
# ite 63
# Iter 63 - Available Memory: 5436.27 MB
# ite 64
# Iter 64 - Available Memory: 5470.57 MB
# ite 65
# Iter 65 - Available Memory: 5500.66 MB
# ite 66
# Iter 66 - Available Memory: 5416.61 MB
# ite 67
# Iter 67 - Available Memory: 5494.84 MB
# ite 68
# Iter 68 - Available Memory: 5555.60 MB
# ite 69
# Iter 69 - Available Memory: 5566.90 MB
# ite 70
# Iter 70 - Available Memory: 5565.60 MB
# ite 71
# Iter 71 - Available Memory: 5558.18 MB
# ite 72
# Iter 72 - Available Memory: 5546.71 MB
# ite 73
# Iter 73 - Available Memory: 5537.63 MB
# ite 74
# Iter 74 - Available Memory: 5533.38 MB
# ite 75
# Iter 75 - Available Memory: 5541.24 MB
# ite 76
# Iter 76 - Available Memory: 5536.20 MB
# ite 77
# Iter 77 - Available Memory: 5533.14 MB
# ite 78
# Iter 78 - Available Memory: 5532.29 MB
# ite 79
# Iter 79 - Available Memory: 5530.03 MB
# ite 80
# Iter 80 - Available Memory: 5524.42 MB
# ite 81
# Iter 81 - Available Memory: 5534.87 MB
# ite 82
# Iter 82 - Available Memory: 5534.65 MB
# ite 83
# Iter 83 - Available Memory: 5556.44 MB
# ite 84
# Iter 84 - Available Memory: 5397.40 MB
# ite 85
# Iter 85 - Available Memory: 5378.16 MB
# ite 86
# Iter 86 - Available Memory: 5381.21 MB
# ite 87
# Iter 87 - Available Memory: 5331.14 MB
# ite 88
# Iter 88 - Available Memory: 5278.86 MB
# ite 89
# Iter 89 - Available Memory: 5256.19 MB
# ite 90
# Iter 90 - Available Memory: 5283.10 MB
# ite 91
# Iter 91 - Available Memory: 5305.02 MB
# ite 92
# Iter 92 - Available Memory: 5283.85 MB
# ite 93
# Iter 93 - Available Memory: 5267.04 MB
# ite 94
# Iter 94 - Available Memory: 5305.66 MB
# ite 95
# Iter 95 - Available Memory: 5316.04 MB
# ite 96
# Iter 96 - Available Memory: 5336.52 MB
# ite 97
# Iter 97 - Available Memory: 5338.47 MB
# ite 98
# Iter 98 - Available Memory: 5256.55 MB
# ite 99
# Iter 99 - Available Memory: 5267.48 MB
# ite 100
# Iter 100 - Available Memory: 5278.60 MB
# ite 101
# Iter 101 - Available Memory: 5302.05 MB
# ite 102
# Iter 102 - Available Memory: 5321.20 MB
# ite 103
# Iter 103 - Available Memory: 5343.81 MB
# ite 104
# Iter 104 - Available Memory: 5351.06 MB
# ite 105
# Iter 105 - Available Memory: 5368.08 MB
# ite 106
# Iter 106 - Available Memory: 5407.55 MB
# ite 107
# Iter 107 - Available Memory: 5345.14 MB
# ite 108
# Iter 108 - Available Memory: 5345.11 MB
# ite 109
# Iter 109 - Available Memory: 5353.66 MB
# ite 110
# Iter 110 - Available Memory: 5380.02 MB
# ite 111
# Iter 111 - Available Memory: 5365.54 MB
# ite 112
# Iter 112 - Available Memory: 5355.96 MB
# ite 113
# Iter 113 - Available Memory: 5469.50 MB
# ite 114
# Iter 114 - Available Memory: 5492.65 MB
# ite 115
# Iter 115 - Available Memory: 5481.93 MB
# ite 116
# Iter 116 - Available Memory: 5475.50 MB
# ite 117
# Iter 117 - Available Memory: 5496.51 MB
# ite 118
# Iter 118 - Available Memory: 5561.68 MB
# ite 119
# Iter 119 - Available Memory: 5574.39 MB
# ite 120
# Iter 120 - Available Memory: 5566.97 MB
# ite 121
# Iter 121 - Available Memory: 5543.82 MB
# ite 122
# Iter 122 - Available Memory: 5535.89 MB
# ite 123
# Iter 123 - Available Memory: 5531.81 MB
# ite 124
# Iter 124 - Available Memory: 5450.75 MB
# ite 125
# Iter 125 - Available Memory: 5452.13 MB
# ite 126
# Iter 126 - Available Memory: 5444.26 MB
# ite 127
# Iter 127 - Available Memory: 5402.97 MB
# ite 128
# Iter 128 - Available Memory: 5421.04 MB
# ite 129
# Iter 129 - Available Memory: 5394.45 MB
# ite 130
# Iter 130 - Available Memory: 5391.45 MB
# ite 131
# Iter 131 - Available Memory: 5519.85 MB
# ite 132
# Iter 132 - Available Memory: 5570.33 MB
# ite 133
# Iter 133 - Available Memory: 5557.70 MB
# ite 134
# Iter 134 - Available Memory: 5589.46 MB
# ite 135
# Iter 135 - Available Memory: 5584.00 MB
# ite 136
# Iter 136 - Available Memory: 5584.50 MB
# ite 137
# Iter 137 - Available Memory: 5582.45 MB
# ite 138
# Iter 138 - Available Memory: 5580.59 MB
# ite 139
# Iter 139 - Available Memory: 5592.44 MB
# ite 140
# Iter 140 - Available Memory: 5583.45 MB
# ite 141
# Iter 141 - Available Memory: 5578.30 MB
# ite 142
# Iter 142 - Available Memory: 5577.72 MB
# ite 143
# Iter 143 - Available Memory: 5575.02 MB
# ite 144
# Iter 144 - Available Memory: 5576.30 MB
# ite 145
# Iter 145 - Available Memory: 5581.31 MB
# ite 146
# Iter 146 - Available Memory: 5588.85 MB
# ite 147
# Iter 147 - Available Memory: 5588.34 MB
# ite 148
# Iter 148 - Available Memory: 5602.05 MB
# ite 149
# Iter 149 - Available Memory: 5611.03 MB
# ite 150
# Iter 150 - Available Memory: 5630.29 MB
# ite 151
# Iter 151 - Available Memory: 5632.89 MB
# ite 152
# Iter 152 - Available Memory: 5630.18 MB
# ite 153
# Iter 153 - Available Memory: 5634.31 MB
# ite 154
# Iter 154 - Available Memory: 5562.50 MB
# ite 155
# Iter 155 - Available Memory: 5626.66 MB
# ite 156
# Iter 156 - Available Memory: 5626.02 MB
# ite 157
# Iter 157 - Available Memory: 5654.33 MB
# ite 158
# Iter 158 - Available Memory: 5562.33 MB
# ite 159
# Iter 159 - Available Memory: 5543.46 MB
# ite 160
# Iter 160 - Available Memory: 5523.20 MB
# ite 161
# Iter 161 - Available Memory: 5500.05 MB
# ite 162
# Iter 162 - Available Memory: 5499.41 MB
# ite 163
# Iter 163 - Available Memory: 5517.05 MB
# ite 164
# Iter 164 - Available Memory: 5528.01 MB
# ite 165
# Iter 165 - Available Memory: 5533.43 MB
# ite 166
# Iter 166 - Available Memory: 5571.57 MB
# ite 167
# Iter 167 - Available Memory: 5568.00 MB
# ite 168
# Iter 168 - Available Memory: 5577.48 MB
# ite 169
# Iter 169 - Available Memory: 5589.02 MB
# ite 170
# Iter 170 - Available Memory: 5589.21 MB
# ite 171
# Iter 171 - Available Memory: 5572.74 MB
# ite 172
# Iter 172 - Available Memory: 5549.69 MB
# ite 173
# Iter 173 - Available Memory: 5537.23 MB
# ite 174
# Iter 174 - Available Memory: 5543.46 MB
# ite 175
# Iter 175 - Available Memory: 5546.65 MB
# ite 176
# Iter 176 - Available Memory: 5565.93 MB
# ite 177
# Iter 177 - Available Memory: 5613.68 MB
# ite 178
# Iter 178 - Available Memory: 5614.05 MB
# ite 179
# Iter 179 - Available Memory: 5651.12 MB
# ite 180
# Iter 180 - Available Memory: 5651.04 MB
# ite 181
# Iter 181 - Available Memory: 5653.03 MB
# ite 182
# Iter 182 - Available Memory: 5644.42 MB
# ite 183
# Iter 183 - Available Memory: 5640.73 MB
# ite 184
# Iter 184 - Available Memory: 5648.36 MB
# ite 185
# Iter 185 - Available Memory: 5650.02 MB
# ite 186
# Iter 186 - Available Memory: 5652.82 MB
# ite 187
# Iter 187 - Available Memory: 5658.46 MB
# ite 188
# Iter 188 - Available Memory: 5657.56 MB
# ite 189
# Iter 189 - Available Memory: 5617.32 MB
# ite 190
# Iter 190 - Available Memory: 5612.11 MB
# ite 191
# Iter 191 - Available Memory: 5613.35 MB
# ite 192
# Iter 192 - Available Memory: 5614.06 MB
# ite 193
# Iter 193 - Available Memory: 5608.05 MB
# ite 194
# Iter 194 - Available Memory: 5636.15 MB
# ite 195
# Iter 195 - Available Memory: 5640.93 MB
# ite 196
# Iter 196 - Available Memory: 5631.70 MB
# ite 197
# Iter 197 - Available Memory: 5612.27 MB
# ite 198
# Iter 198 - Available Memory: 5581.01 MB
# ite 199
# Iter 199 - Available Memory: 5578.85 MB
# ite 200
# Iter 200 - Available Memory: 5574.59 MB
# ite 201
# Iter 201 - Available Memory: 5538.84 MB
# ite 202
# Iter 202 - Available Memory: 5516.25 MB
# ite 203
# Iter 203 - Available Memory: 5534.83 MB
# ite 204
# Iter 204 - Available Memory: 5540.96 MB
# ite 205
# Iter 205 - Available Memory: 5560.73 MB
# ite 206
# Iter 206 - Available Memory: 5571.73 MB
# ite 207
# Iter 207 - Available Memory: 5575.84 MB
# ite 208
# Iter 208 - Available Memory: 5564.95 MB
# ite 209
# Iter 209 - Available Memory: 5538.91 MB
# ite 210
# Iter 210 - Available Memory: 5544.87 MB
# ite 211
# Iter 211 - Available Memory: 5527.02 MB
# ite 212
# Iter 212 - Available Memory: 5514.43 MB
# ite 213
# Iter 213 - Available Memory: 5522.49 MB
# ite 214
# Iter 214 - Available Memory: 5520.90 MB
# ite 215
# Iter 215 - Available Memory: 5526.10 MB
# ite 216
# Iter 216 - Available Memory: 5517.33 MB
# ite 217
# Iter 217 - Available Memory: 5517.76 MB
# ite 218
# Iter 218 - Available Memory: 5529.81 MB
# ite 219
# Iter 219 - Available Memory: 5532.44 MB
# ite 220
# Iter 220 - Available Memory: 5529.76 MB
# ite 221
# Iter 221 - Available Memory: 5533.30 MB
# ite 222
# Iter 222 - Available Memory: 5535.74 MB
# ite 223
# Iter 223 - Available Memory: 5521.90 MB
# ite 224
# Iter 224 - Available Memory: 5538.73 MB
# ite 225
# Iter 225 - Available Memory: 5526.31 MB
# ite 226
# Iter 226 - Available Memory: 5508.38 MB
# ite 227
# Iter 227 - Available Memory: 5519.41 MB
# ite 228
# Iter 228 - Available Memory: 5512.71 MB
# ite 229
# Iter 229 - Available Memory: 5519.62 MB
# ite 230
# Iter 230 - Available Memory: 5519.72 MB
# ite 231
# Iter 231 - Available Memory: 5530.02 MB
# ite 232
# Iter 232 - Available Memory: 5537.14 MB
# ite 233
# Iter 233 - Available Memory: 5533.67 MB
# ite 234
# Iter 234 - Available Memory: 5534.29 MB
# ite 235
# Iter 235 - Available Memory: 5534.16 MB
# ite 236
# Iter 236 - Available Memory: 5536.43 MB
# ite 237
# Iter 237 - Available Memory: 5535.12 MB
# ite 238
# Iter 238 - Available Memory: 5529.95 MB
# ite 239
# Iter 239 - Available Memory: 5386.65 MB
# ite 240
# Iter 240 - Available Memory: 5389.46 MB
# ite 241
# Iter 241 - Available Memory: 5393.00 MB
# ite 242
# Iter 242 - Available Memory: 5368.56 MB
# ite 243
# Iter 243 - Available Memory: 5307.26 MB
# ite 244
# Iter 244 - Available Memory: 5315.46 MB
# ite 245
# Iter 245 - Available Memory: 5195.58 MB
# ite 246
# Iter 246 - Available Memory: 5267.46 MB
# ite 247
# Iter 247 - Available Memory: 5264.11 MB
# ite 248
# Iter 248 - Available Memory: 5264.76 MB
# ite 249
# Iter 249 - Available Memory: 5291.71 MB
# ite 250
# Iter 250 - Available Memory: 5281.93 MB
# ite 251
# Iter 251 - Available Memory: 5240.84 MB
# ite 252
# Iter 252 - Available Memory: 5246.56 MB
# ite 253
# Iter 253 - Available Memory: 5224.02 MB
# ite 254
# Iter 254 - Available Memory: 5224.73 MB
# ite 255
# Iter 255 - Available Memory: 5252.27 MB
# ite 256
# Iter 256 - Available Memory: 5230.82 MB
# ite 257
# Iter 257 - Available Memory: 5293.30 MB
# ite 258
# Iter 258 - Available Memory: 5291.94 MB
# ite 259
# Iter 259 - Available Memory: 5285.11 MB
# ite 260
# Iter 260 - Available Memory: 5285.60 MB
# ite 261
# Iter 261 - Available Memory: 5294.70 MB
# ite 262
# Iter 262 - Available Memory: 5304.93 MB
# ite 263
# Iter 263 - Available Memory: 5446.12 MB
# ite 264
# Iter 264 - Available Memory: 5455.69 MB
# ite 265
# Iter 265 - Available Memory: 5507.21 MB
# ite 266
# Iter 266 - Available Memory: 5511.88 MB
# ite 267
# Iter 267 - Available Memory: 5520.02 MB
# ite 268
# Iter 268 - Available Memory: 5518.40 MB
# ite 269
# Iter 269 - Available Memory: 5518.64 MB
# ite 270
# Iter 270 - Available Memory: 5542.66 MB
# ite 271
# Iter 271 - Available Memory: 5546.62 MB
# ite 272
# Iter 272 - Available Memory: 5545.24 MB
# ite 273
# Iter 273 - Available Memory: 5557.85 MB
# ite 274
# Iter 274 - Available Memory: 5558.61 MB
# ite 275
# Iter 275 - Available Memory: 5560.44 MB
# ite 276
# Iter 276 - Available Memory: 5564.53 MB
# ite 277
# Iter 277 - Available Memory: 5562.93 MB
# ite 278
# Iter 278 - Available Memory: 5555.57 MB
# ite 279
# Iter 279 - Available Memory: 5553.42 MB
# ite 280
# Iter 280 - Available Memory: 5553.27 MB
# ite 281
# Iter 281 - Available Memory: 5551.29 MB
# ite 282
# Iter 282 - Available Memory: 5558.54 MB
# ite 283
# Iter 283 - Available Memory: 5556.34 MB
# ite 284
# Iter 284 - Available Memory: 5558.54 MB
# ite 285
# Iter 285 - Available Memory: 5563.68 MB
# ite 286
# Iter 286 - Available Memory: 5563.80 MB
# ite 287
# Iter 287 - Available Memory: 5679.62 MB
# ite 288
# Iter 288 - Available Memory: 5682.02 MB
# ite 289
# Iter 289 - Available Memory: 5674.87 MB
# ite 290
# Iter 290 - Available Memory: 5671.93 MB
# ite 291
# Iter 291 - Available Memory: 5673.43 MB
# ite 292
# Iter 292 - Available Memory: 5672.61 MB
# ite 293
# Iter 293 - Available Memory: 5674.01 MB
# ite 294
# Iter 294 - Available Memory: 5665.52 MB
# ite 295
# Iter 295 - Available Memory: 5664.55 MB
# ite 296
# Iter 296 - Available Memory: 5659.48 MB
# ite 297
# Iter 297 - Available Memory: 5659.75 MB
# ite 298
# Iter 298 - Available Memory: 5659.95 MB
# ite 299
# Iter 299 - Available Memory: 5634.70 MB
# ite 300
# Iter 300 - Available Memory: 5635.03 MB
# ite 301
# Iter 301 - Available Memory: 5622.80 MB
# ite 302
# Iter 302 - Available Memory: 5434.06 MB
# ite 303
# Iter 303 - Available Memory: 5438.57 MB
# ite 304
# Iter 304 - Available Memory: 5353.16 MB
# ite 305
# Iter 305 - Available Memory: 5408.04 MB
# ite 306
# Iter 306 - Available Memory: 5282.60 MB
# ite 307
# Iter 307 - Available Memory: 5284.17 MB
# ite 308
# Iter 308 - Available Memory: 5232.36 MB
# ite 309
# Iter 309 - Available Memory: 5222.39 MB
# ite 310
# Iter 310 - Available Memory: 5231.77 MB
# ite 311
# Iter 311 - Available Memory: 5191.91 MB
# ite 312
# Iter 312 - Available Memory: 5193.29 MB
# ite 313
# Iter 313 - Available Memory: 5315.79 MB
# ite 314
# Iter 314 - Available Memory: 5302.77 MB
# ite 315
# Iter 315 - Available Memory: 5260.82 MB
# ite 316
# Iter 316 - Available Memory: 5173.85 MB
# ite 317
# Iter 317 - Available Memory: 5180.35 MB
# ite 318
# Iter 318 - Available Memory: 5185.00 MB
# ite 319
# Iter 319 - Available Memory: 5183.69 MB
# ite 320
# Iter 320 - Available Memory: 5203.05 MB
# ite 321
# Iter 321 - Available Memory: 5221.32 MB
# ite 322
# Iter 322 - Available Memory: 5235.74 MB
# ite 323
# Iter 323 - Available Memory: 5234.36 MB
# ite 324
# Iter 324 - Available Memory: 5246.85 MB
# ite 325
# Iter 325 - Available Memory: 5300.95 MB
# ite 326
# Iter 326 - Available Memory: 5321.23 MB
# ite 327
# Iter 327 - Available Memory: 5312.64 MB
# ite 328
# Iter 328 - Available Memory: 5300.71 MB
# ite 329
# Iter 329 - Available Memory: 5260.91 MB
# ite 330
# Iter 330 - Available Memory: 5294.49 MB
# ite 331
# Iter 331 - Available Memory: 5292.52 MB
# ite 332
# Iter 332 - Available Memory: 5340.63 MB
# ite 333
# Iter 333 - Available Memory: 5364.10 MB
# ite 334
# Iter 334 - Available Memory: 5371.30 MB
# ite 335
# Iter 335 - Available Memory: 5391.83 MB
# ite 336
# Iter 336 - Available Memory: 5392.79 MB
# ite 337
# Iter 337 - Available Memory: 5377.99 MB
# ite 338
# Iter 338 - Available Memory: 5375.78 MB
# ite 339
# Iter 339 - Available Memory: 5371.44 MB
# ite 340
# Iter 340 - Available Memory: 5379.05 MB
# ite 341
# Iter 341 - Available Memory: 5371.69 MB
# ite 342
# Iter 342 - Available Memory: 5386.56 MB
# ite 343
# Iter 343 - Available Memory: 5383.36 MB
# ite 344
# Iter 344 - Available Memory: 5363.89 MB
# ite 345
# Iter 345 - Available Memory: 5367.81 MB
# ite 346
# Iter 346 - Available Memory: 5343.09 MB
# ite 347
# Iter 347 - Available Memory: 5351.78 MB
# ite 348
# Iter 348 - Available Memory: 5289.95 MB
# ite 349
# Iter 349 - Available Memory: 5224.07 MB
# ite 350
# Iter 350 - Available Memory: 5217.33 MB
# ite 351
# Iter 351 - Available Memory: 5144.74 MB
# ite 352
# Iter 352 - Available Memory: 5228.70 MB
# ite 353
# Iter 353 - Available Memory: 5124.88 MB
# ite 354
# Iter 354 - Available Memory: 5130.18 MB
# ite 355
# Iter 355 - Available Memory: 5140.66 MB
# ite 356
# Iter 356 - Available Memory: 5158.97 MB
# ite 357
# Iter 357 - Available Memory: 5165.39 MB
# ite 358
# Iter 358 - Available Memory: 5327.94 MB
# ite 359
# Iter 359 - Available Memory: 5353.61 MB
# ite 360
# Iter 360 - Available Memory: 5380.38 MB
# ite 361
# Iter 361 - Available Memory: 5411.13 MB
# ite 362
# Iter 362 - Available Memory: 5404.44 MB
# ite 363
# Iter 363 - Available Memory: 5399.22 MB
# ite 364
# Iter 364 - Available Memory: 5408.79 MB
# ite 365
# Iter 365 - Available Memory: 5408.95 MB
# ite 366
# Iter 366 - Available Memory: 5432.41 MB
# ite 367
# Iter 367 - Available Memory: 5424.05 MB
# ite 368
# Iter 368 - Available Memory: 5457.51 MB
# ite 369
# Iter 369 - Available Memory: 5476.62 MB
# ite 370
# Iter 370 - Available Memory: 5494.68 MB
# ite 371
# Iter 371 - Available Memory: 5496.41 MB
# ite 372
# Iter 372 - Available Memory: 5525.86 MB
# ite 373
# Iter 373 - Available Memory: 5513.70 MB
# ite 374
# Iter 374 - Available Memory: 5525.28 MB
# ite 375
# Iter 375 - Available Memory: 5537.43 MB
# ite 376
# Iter 376 - Available Memory: 5538.62 MB
# ite 377
# Iter 377 - Available Memory: 5496.58 MB
# ite 378
# Iter 378 - Available Memory: 5508.34 MB
# ite 379
# Iter 379 - Available Memory: 5538.37 MB
# ite 380
# Iter 380 - Available Memory: 5536.98 MB
# ite 381
# Iter 381 - Available Memory: 5566.31 MB
# ite 382
# Iter 382 - Available Memory: 5565.34 MB
# ite 383
# Iter 383 - Available Memory: 5564.67 MB
# ite 384
# Iter 384 - Available Memory: 5544.59 MB
# ite 385
# Iter 385 - Available Memory: 5542.76 MB
# ite 386
# Iter 386 - Available Memory: 5537.57 MB
# ite 387
# Iter 387 - Available Memory: 5535.54 MB
# ite 388
# Iter 388 - Available Memory: 5520.16 MB
# ite 389
# Iter 389 - Available Memory: 5517.16 MB
# ite 390
# Iter 390 - Available Memory: 5518.30 MB
# ite 391
# Iter 391 - Available Memory: 5515.30 MB
# ite 392
# Iter 392 - Available Memory: 5515.75 MB
# ite 393
# Iter 393 - Available Memory: 5518.96 MB
# ite 394
# Iter 394 - Available Memory: 5524.04 MB
# ite 395
# Iter 395 - Available Memory: 5527.09 MB
# ite 396
# Iter 396 - Available Memory: 5525.83 MB
# ite 397
# Iter 397 - Available Memory: 5556.47 MB
# ite 398
# Iter 398 - Available Memory: 5514.29 MB
# ite 399
# Iter 399 - Available Memory: 5521.18 MB
# ite 400
# Iter 400 - Available Memory: 5530.99 MB
# ite 401
# Iter 401 - Available Memory: 5540.20 MB
# ite 402
# Iter 402 - Available Memory: 5549.54 MB
# ite 403
# Iter 403 - Available Memory: 5560.37 MB
# ite 404
# Iter 404 - Available Memory: 5511.67 MB
# ite 405
# Iter 405 - Available Memory: 5504.35 MB
# ite 406
# Iter 406 - Available Memory: 5484.50 MB
# ite 407
# Iter 407 - Available Memory: 5496.86 MB
# ite 408
# Iter 408 - Available Memory: 5474.82 MB
# ite 409
# Iter 409 - Available Memory: 5487.02 MB
# ite 410
# Iter 410 - Available Memory: 5486.16 MB
# ite 411
# Iter 411 - Available Memory: 5490.06 MB
# ite 412
# Iter 412 - Available Memory: 5504.54 MB
# ite 413
# Iter 413 - Available Memory: 5502.43 MB
# ite 414
# Iter 414 - Available Memory: 5529.57 MB
# ite 415
# Iter 415 - Available Memory: 5514.40 MB
# ite 416
# Iter 416 - Available Memory: 5503.30 MB
# ite 417
# Iter 417 - Available Memory: 5506.53 MB
# ite 418
# Iter 418 - Available Memory: 5523.86 MB
# ite 419
# Iter 419 - Available Memory: 5520.52 MB
# ite 420
# Iter 420 - Available Memory: 5528.60 MB
# ite 421
# Iter 421 - Available Memory: 5526.98 MB
# ite 422
# Iter 422 - Available Memory: 5524.56 MB
# ite 423
# Iter 423 - Available Memory: 5564.61 MB
# ite 424
# Iter 424 - Available Memory: 5553.36 MB
# ite 425
# Iter 425 - Available Memory: 5544.40 MB
# ite 426
# Iter 426 - Available Memory: 5530.98 MB
# ite 427
# Iter 427 - Available Memory: 5535.61 MB
# ite 428
# Iter 428 - Available Memory: 5548.33 MB
# ite 429
# Iter 429 - Available Memory: 5559.37 MB
# ite 430
# Iter 430 - Available Memory: 5561.20 MB
# ite 431
# Iter 431 - Available Memory: 5557.17 MB
# ite 432
# Iter 432 - Available Memory: 5550.78 MB
# ite 433
# Iter 433 - Available Memory: 5553.20 MB
# ite 434
# Iter 434 - Available Memory: 5574.34 MB
# ite 435
# Iter 435 - Available Memory: 5570.75 MB
# ite 436
# Iter 436 - Available Memory: 5568.00 MB
# ite 437
# Iter 437 - Available Memory: 5557.02 MB
# ite 438
# Iter 438 - Available Memory: 5561.15 MB
# ite 439
# Iter 439 - Available Memory: 5558.55 MB
# ite 440
# Iter 440 - Available Memory: 5578.46 MB
# ite 441
# Iter 441 - Available Memory: 5621.52 MB
# ite 442
# Iter 442 - Available Memory: 5621.45 MB
# ite 443
# Iter 443 - Available Memory: 5624.01 MB
# ite 444
# Iter 444 - Available Memory: 5608.45 MB
# ite 445
# Iter 445 - Available Memory: 5597.27 MB
# ite 446
# Iter 446 - Available Memory: 5448.68 MB
# ite 447
# Iter 447 - Available Memory: 5443.66 MB
# ite 448
# Iter 448 - Available Memory: 5449.53 MB
# ite 449
# Iter 449 - Available Memory: 5384.55 MB
# ite 450
# Iter 450 - Available Memory: 5345.82 MB
# ite 451
# Iter 451 - Available Memory: 5359.33 MB
# ite 452
# Iter 452 - Available Memory: 5373.72 MB
# ite 453
# Iter 453 - Available Memory: 5374.18 MB
# ite 454
# Iter 454 - Available Memory: 5377.05 MB
# ite 455
# Iter 455 - Available Memory: 5391.97 MB
# ite 456
# Iter 456 - Available Memory: 5400.25 MB
# ite 457
# Iter 457 - Available Memory: 5395.72 MB
# ite 458
# Iter 458 - Available Memory: 5382.38 MB
# ite 459
# Iter 459 - Available Memory: 5281.36 MB
# ite 460
# Iter 460 - Available Memory: 5353.76 MB
# ite 461
# Iter 461 - Available Memory: 5298.52 MB
# ite 462
# Iter 462 - Available Memory: 5303.79 MB
# ite 463
# Iter 463 - Available Memory: 5227.89 MB
# ite 464
# Iter 464 - Available Memory: 5274.44 MB
# ite 465
# Iter 465 - Available Memory: 5278.48 MB
# ite 466
# Iter 466 - Available Memory: 5274.84 MB
# ite 467
# Iter 467 - Available Memory: 5222.32 MB
# ite 468
# Iter 468 - Available Memory: 5205.39 MB
# ite 469
# Iter 469 - Available Memory: 5220.18 MB
# ite 470
# Iter 470 - Available Memory: 5189.61 MB
# ite 471
# Iter 471 - Available Memory: 5191.09 MB
# ite 472
# Iter 472 - Available Memory: 5230.46 MB
# ite 473
# Iter 473 - Available Memory: 5228.15 MB
# ite 474
# Iter 474 - Available Memory: 5227.68 MB
# ite 475
# Iter 475 - Available Memory: 5259.43 MB
# ite 476
# Iter 476 - Available Memory: 5251.41 MB
# ite 477
# Iter 477 - Available Memory: 5253.76 MB
# ite 478
# Iter 478 - Available Memory: 5243.28 MB
# ite 479
# Iter 479 - Available Memory: 5235.20 MB
# ite 480
# Iter 480 - Available Memory: 5305.49 MB
# ite 481
# Iter 481 - Available Memory: 5310.64 MB
# ite 482
# Iter 482 - Available Memory: 5389.44 MB
# ite 483
# Iter 483 - Available Memory: 5207.34 MB
# ite 484
# Iter 484 - Available Memory: 5211.13 MB
# ite 485
# Iter 485 - Available Memory: 5266.10 MB
# ite 486
# Iter 486 - Available Memory: 5283.91 MB
# ite 487
# Iter 487 - Available Memory: 5302.95 MB
# ite 488
# Iter 488 - Available Memory: 5340.39 MB
# ite 489
# Iter 489 - Available Memory: 5313.70 MB
# ite 490
# Iter 490 - Available Memory: 5258.20 MB
# ite 491
# Iter 491 - Available Memory: 5263.75 MB
# ite 492
# Iter 492 - Available Memory: 5231.98 MB
# ite 493
# Iter 493 - Available Memory: 5220.07 MB
# ite 494
# Iter 494 - Available Memory: 5209.74 MB
# ite 495
# Iter 495 - Available Memory: 5203.86 MB
# ite 496
# Iter 496 - Available Memory: 5208.36 MB
# ite 497
# Iter 497 - Available Memory: 5210.44 MB
# ite 498
# Iter 498 - Available Memory: 5197.91 MB
# ite 499
# Iter 499 - Available Memory: 5150.16 MB
# ite 500
# Iter 500 - Available Memory: 5113.13 MB
# Optimization completed.

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'black'
ax1.set_ylabel('LOss', color=color)
ax1.plot(range(len(LS_his)), LS_his, label='LOss', color=color, linewidth=2, linestyle='--')
ax1.tick_params(axis='y', labelcolor=color)

# Mark specific points
marker_points = [
    0,  # First point
    *range(100, len(LS_his), 100),  # Every 200th point
    len(LS_his)-1  # Last point
]

for point in marker_points:
    ax1.scatter(point, LS_his[point], color='blue', zorder=5)
    ax1.text(point, LS_his[point], 
             f'({LS_his[point]:.4f})',
             ha='right' if point == len(LS_his)-1 else 'left',
             va='bottom',
             bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))

ax1.legend(loc='upper right')
plt.title('Loss vs. Iterations')
plt.tight_layout()
plt.savefig('LS_history.png', dpi=150, bbox_inches='tight')
plt.show()
