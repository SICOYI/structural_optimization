# %%
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import plotly.graph_objects as go
import time
from datetime import timedelta
import json
import os
import psutil
import gc
import math

# 强制进行垃圾回收（释放循环引用等未被引用的对象）
gc.collect()  
# Set device to GPU if available
device = torch.device('cpu')
print(f"Using device: {device}")

# %%
############ customization
length = 48
width = 48
n1 = 13
n2 = 13
judge = 0

# %%
############### Problem context formulation

def generate_rectangular_grid_sg(length, width, n1, n2=2, judge=1, z=0, height=0):
    x_points = [i * (length / n1) for i in range(n1 + 1)]
    y_points = [j * (width / n2) for j in range(n2, -1, -1)]

    grid_points = []
    for x in x_points:
        for y in y_points:
            if y == width / 2:
                grid_points.append([x, y, height])
            else:
                grid_points.append([x, y, z])

    if judge == 1:
        corners = [
            [x_points[0], y_points[0], z],
            [x_points[0], y_points[-1], z],
            [x_points[-1], y_points[0], z],
            [x_points[-1], y_points[-1], z]
        ]
        grid_points = [point for point in grid_points if point not in corners]

    return grid_points

def plot_grid(grid_points, length, width):
    x = [point[0] for point in grid_points]
    y = [point[1] for point in grid_points]
    z = [point[2] for point in grid_points]

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(x, y, z, c='r', marker='o', s=50, label='Grid Points')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.legend()
    plt.show()

def generate_connectivity_matrix(new_coords):
    indexed_points = {tuple(point): idx + 1 for idx, point in enumerate(new_coords)}
    connectivity = []

    x_values = sorted(set(point[0] for point in new_coords))
    for x in x_values:
        points_on_line = [point for point in new_coords if point[0] == x]
        points_on_line.sort(key=lambda p: p[1], reverse=True) 

        for i in range(len(points_on_line) - 1):
            node1 = indexed_points[tuple(points_on_line[i])]
            node2 = indexed_points[tuple(points_on_line[i + 1])]
            connectivity.append([node1, node2])

    y_values = sorted(set(point[1] for point in new_coords))
    for y in y_values:
        points_on_line = [point for point in new_coords if point[1] == y]
        points_on_line.sort(key=lambda p: p[0])  

        for i in range(len(points_on_line) - 1):
            node1 = indexed_points[tuple(points_on_line[i])]
            node2 = indexed_points[tuple(points_on_line[i + 1])]
            connectivity.append([node1, node2])

    return connectivity

grid_points = generate_rectangular_grid_sg(length, width, n1, n2, judge)
connectivity = generate_connectivity_matrix(grid_points)
plot_grid(grid_points, length, width)


###########################################################################################################################################################
n_dof_per_node = 6  # Degrees of freedom per node
grid_points = torch.tensor(grid_points, device=device, dtype=torch.float32)
total_dof = n_dof_per_node * len(grid_points)

########## Surrounding fixed
x_max = grid_points[:, 0].max()
x_min = grid_points[:, 0].min()
y_max = grid_points[:, 1].max()
y_min = grid_points[:, 1].min()

Fixed_nodes = torch.where(
    ((grid_points[:, 0] == x_max) & (grid_points[:, 1] == y_max)) |  # (x_max, y_max)
    ((grid_points[:, 0] == x_max) & (grid_points[:, 1] == y_min)) |  # (x_max, y_min)
    ((grid_points[:, 0] == x_min) & (grid_points[:, 1] == y_max)) |  # (x_min, y_max)
    ((grid_points[:, 0] == x_min) & (grid_points[:, 1] == y_min))    # (x_min, y_min)
)[0]

Fixed_nodes += 1
Free_nodes = []

n_elements = len(connectivity)
n_nodes = len(grid_points)

for i in range(1, n_nodes + 1):
    if i not in Fixed_nodes:
        Free_nodes.append(i)


####### BCs
fixed_dof = []
for node in Fixed_nodes:
    fixed_dof.extend([(node - 1) * 6 + i for i in range(6)])

##########################################################################################################################################################
##########################################################################################################################################################

# %%
rows = n2 + 1
cols = n1 + 1

idx_matrix = [[0 for _ in range(cols)] for _ in range(rows)]

for k in range(rows * cols):
    row = k % rows
    col = k // rows
    idx_matrix[row][col] = k
V_matrix = torch.arange(0, n2 * (n1 + 1)).reshape(n1 + 1, n2).T

start = n2 * (n1 + 1)
H_matrix = torch.arange(start, start + (n2 + 1) * n1)
H_matrix = H_matrix.reshape(n1 + 1 , n2)
H_matrix = H_matrix.flip(0)
print(V_matrix)
print(H_matrix)

# %%
def Symmetry_shaper(q, matrix):

    rows, cols = matrix.shape

    row_odd = rows % 2 == 1
    col_odd = cols % 2 == 1
    
    if row_odd:

        q = torch.cat([q, q.flip(0)[1:,:]], dim=0)
    else:

        q = torch.cat([q, q.flip(0)], dim=0)
    

    if col_odd:

        q = torch.cat([q, q.flip(1)[:,1:]], dim=1)
    else:

        q = torch.cat([q, q.flip(1)], dim=1)
    
    return q

# %%
############################################################# Force condition
def Force_mat(F_value, F_type, total_dof=total_dof, Free_nodes=Free_nodes, judge=0):
    
    F = torch.zeros(total_dof, dtype=torch.float32, device=device)
    
    if judge == 0:
        F_value = torch.tensor([F_value] * len(Free_nodes), device=device) * 1000 # The force value/direction
        F_type = [F_type] * len(Free_nodes)  # The force type
    else:
        F_value = torch.tensor(F_value) * 1000
        F_value = torch.tensor(F_type)
    
    for idx, i in enumerate(Free_nodes):
        F[6 * (i - 1) + F_type[idx]] = F_value[idx]  # unit: KN / KN*m
        
    return F, F_value

# %%
def save_fdm(state_idx, grid_points, new_node_coords, 
            connectivity, Free_nodes, Fixed_nodes, force, SED,
            save_dir="results", max_states=6):
    """
    多状态组合图保存函数
    
    参数:
        state_idx: 状态序号 (0=初始, 1=第cut次, 2=第2*cut次...)
        max_states: 组合图中最多显示的状态数
    """
    os.makedirs(save_dir, exist_ok=True)
    
    # 数据准备
    x_orig = grid_points[:, 0].cpu().detach().numpy()
    y_orig = grid_points[:, 1].cpu().detach().numpy()
    z_orig = grid_points[:, 2].cpu().detach().numpy()
    
    x_fdm = new_node_coords[:, 0].cpu().detach().numpy()
    y_fdm = new_node_coords[:, 1].cpu().detach().numpy()
    z_fdm = new_node_coords[:, 2].cpu().detach().numpy()
    
    # 计算当前高度
    current_height = max(z_fdm)
    
    # 初始化图形容器
    if not hasattr(save_fdm, 'fig'):
        save_fdm.fig = plt.figure(figsize=(24, 16))
        save_fdm.axes = [save_fdm.fig.add_subplot(2, 3, i+1, projection='3d') 
                       for i in range(max_states)]
        plt.subplots_adjust(wspace=0.3, hspace=0.3)
        save_fdm.saved_states = 0
        save_fdm.max_z = 0  # 用于统一z轴尺度
    
    # 检查是否已存满
    if save_fdm.saved_states >= max_states:
        filename = os.path.join(save_dir, f"FDM_States_{max_states}.png")
        save_fdm.fig.savefig(filename, dpi=200, bbox_inches='tight')
        plt.close(save_fdm.fig)
        delattr(save_fdm, 'fig')
        delattr(save_fdm, 'axes')
        delattr(save_fdm, 'saved_states')
        delattr(save_fdm, 'max_z')
        print(f"Saved full states to {filename}")
        return
    
    # 更新最大z值（用于统一坐标尺度）
    if current_height > save_fdm.max_z:
        save_fdm.max_z = current_height
    
    # 获取当前子图并清除旧内容
    ax = save_fdm.axes[save_fdm.saved_states]
    ax.clear()
    
    # ========== 可视化绘制 ==========
    # 1. 绘制原始网格（浅灰色虚线）
    for i, j in connectivity:
        ax.plot([x_orig[i-1], x_orig[j-1]],
                [y_orig[i-1], y_orig[j-1]],
                [z_orig[i-1], z_orig[j-1]], 
                ':', color='#CCCCCC', linewidth=0.8, alpha=0.7)
    
    # 2. 绘制当前状态网格
    color = '#1f77b4' if state_idx == 0 else '#ff7f0e'  # 初始蓝色，迭代橙色
    for i, j in connectivity:
        ax.plot([x_fdm[i-1], x_fdm[j-1]],
                [y_fdm[i-1], y_fdm[j-1]],
                [z_fdm[i-1], z_fdm[j-1]], 
                '-', color=color, linewidth=1.8, alpha=0.9)
    
    # 3. 标记固定节点（黑色实心圆）
    for node in Fixed_nodes:
        ax.scatter(x_fdm[node-1], y_fdm[node-1], z_fdm[node-1],
                  c='black', s=50, marker='o', alpha=0.8)
    
    # 4. 添加高度标注（替换原来的力值标注）
    ax.text(x=0.05, y=0.90, z=save_fdm.max_z*1.05,
           s=f"Height: {current_height:.2f}m\nSE: {SED:.8f} ", 
           transform=ax.transAxes, 
           fontsize=10,
           bbox=dict(facecolor='white', alpha=0.7))
    
    # ========== 子图装饰 ==========
    ax.set_xlabel('X (m)', fontsize=9)
    ax.set_ylabel('Y (m)', fontsize=9)
    ax.set_zlabel('Z (m)', fontsize=9)
    ax.set_title(f"State {state_idx}" if state_idx > 0 else "Initial State", 
                fontsize=11, pad=12)
    ax.set_zlim(0, save_fdm.max_z * 1.1)  # 统一z轴尺度
    ax.view_init(elev=35, azim=45)
    ax.grid(True, linestyle=':', alpha=0.5)
    
    # 更新状态计数器
    save_fdm.saved_states += 1
    
    # 如果是最后一个状态，立即保存
    if save_fdm.saved_states == max_states:
        filename = os.path.join(save_dir, f"FDM_States_{max_states}.png")
        save_fdm.fig.savefig(filename, dpi=200, bbox_inches='tight')
        plt.close(save_fdm.fig)
        delattr(save_fdm, 'fig')
        delattr(save_fdm, 'axes')
        delattr(save_fdm, 'saved_states')
        delattr(save_fdm, 'max_z')
        print(f"Saved full states to {filename}")


def finalize_fdm(save_dir="results", completed=False):
    """
    最终化处理函数
    
    参数:
        save_dir: 保存目录
        completed: 是否完成所有迭代 (True=已完成全部迭代，False=提前终止)
    """
    if not hasattr(save_fdm, 'fig') or save_fdm.saved_states == 0:
        return
    
    # 如果已完成所有迭代，保存当前进度（不强制填满）
    if completed:
        filename = os.path.join(save_dir, 
                              f"FDM_States_completed_{save_fdm.saved_states}.png")
    # 如果是提前终止，保存上一次有效迭代
    else:
        # 回退一个状态，因为最后一次迭代可能不完整
        save_fdm.saved_states = max(0, save_fdm.saved_states - 1)
        filename = os.path.join(save_dir,
                              f"FDM_States_partial_{save_fdm.saved_states+1}.png")
    
    # 保存图像
    save_fdm.fig.savefig(filename, dpi=200, bbox_inches='tight')
    plt.close(save_fdm.fig)
    
    # 打印保存信息
    if completed:
        print(f"Saved completed states ({save_fdm.saved_states}/{len(save_fdm.axes)}) to {filename}")
    else:
        print(f"Saved last valid state ({save_fdm.saved_states+1}) to {filename}")
    
    # 清理属性
    for attr in ['fig', 'axes', 'saved_states', 'max_z']:
        if hasattr(save_fdm, attr):
            delattr(save_fdm, attr)

# %%
####### FDM part 
C = torch.zeros(n_elements, n_nodes, dtype=torch.float32, device=device)
for n, (i, j) in enumerate(connectivity):
    C[n, i - 1] = 1
    C[n, j - 1] = -1
    
px= torch.zeros(len(Free_nodes), 1, dtype=torch.float32, device=device)
py = torch.zeros(len(Free_nodes), 1, dtype=torch.float32, device=device)
pz = torch.zeros(len(Free_nodes), 1, dtype=torch.float32, device=device)


fixed_idces = torch.tensor([node - 1 for node in Fixed_nodes], device=device)
free_node_indices = torch.tensor([node - 1 for node in Free_nodes], device=device)

CF = C[:, fixed_idces]
CN = C[:, free_node_indices]

def FDM(Q, F_value, node_coords, CN=CN, CF=CF, px=px, py=py, pz=pz, 
        fixed_idces=fixed_idces, free_node_indices=free_node_indices,
        ):
    
    pz[:, 0] = F_value
        
    Dn = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CN))
    DF = torch.matmul(torch.transpose(CN, 0, 1), torch.matmul(Q, CF))
    
    
    xF = node_coords[fixed_idces, 0].unsqueeze(1)
    yF = node_coords[fixed_idces, 1].unsqueeze(1)
    zF = node_coords[fixed_idces, 2].unsqueeze(1)
    
    xN = torch.matmul(torch.inverse(Dn), (px - torch.matmul(DF, xF)))
    yN = torch.matmul(torch.inverse(Dn), (py - torch.matmul(DF, yF)))
    zN = torch.matmul(torch.inverse(Dn), (pz - torch.matmul(DF, zF)))
        
    
    new_node_coords = node_coords.clone()
    new_node_coords[free_node_indices, 0] = xN.squeeze()
    new_node_coords[free_node_indices, 1] = yN.squeeze()
    new_node_coords[free_node_indices, 2] = zN.squeeze()
    
    return new_node_coords

# %%
###### FE part
D_radius = 0.75
D_young_modulus = 10e9 
D_shear_modulus = 0.7e9 
D_poisson_ratio = 0.3
cross_section_angle_a = 0  
cross_section_angle_b = 0  
a_small_number = 1e-10

def rotation(v, k, theta):
    """Rotation of vector v around axis k by angle theta."""
    k = k / torch.norm(k)  # Normalize k
    cross_product = torch.cross(k, v)
    dot_product = torch.dot(k, v)

    # Ensure theta is a tensor
    theta = torch.tensor(theta, dtype=torch.float32, device=device) if not isinstance(theta, torch.Tensor) else theta

    v_rotated = v * torch.cos(theta) + cross_product * torch.sin(theta) + k * dot_product * (1 - torch.cos(theta))
    return v_rotated

class Beam:
    def __init__(self, node_coordinates, R=D_radius, young_modulus=D_young_modulus,
                 shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                 Beta_b=cross_section_angle_b):
        self.node_coordinates = node_coordinates  # (2, 3) tensor for node coordinates

        # Material and geometry
        self.radius = R
        self.young_modulus = young_modulus
        self.shear_modulus = shear_modulus
        self.poisson_ratio = poisson_ratio

        # Cross-sectional properties
        self.length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])  # Length of the beam
        self.Iy = (torch.pi * self.radius ** 4) / 4 
        self.Iz = self.Iy
        self.A = torch.pi * self.radius ** 2
        self.J = (torch.pi * self.radius ** 4) / 2

        # Stiffness components
        self.S_u = self.young_modulus * self.A / self.length
        self.S_v1a = 12 * self.young_modulus * self.Iy / (self.length ** 3)
        self.S_v1b = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_v2a = 12 * self.young_modulus * self.Iz / (self.length ** 3)
        self.S_v2b = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta1a = 6 * self.young_modulus * self.Iy / (self.length ** 2)
        self.S_theta1b = 4 * self.young_modulus * self.Iy / self.length
        self.S_theta1c = 2 * self.young_modulus * self.Iy / self.length
        self.S_theta2a = 6 * self.young_modulus * self.Iz / (self.length ** 2)
        self.S_theta2b = 4 * self.young_modulus * self.Iz / self.length
        self.S_theta2c = 2 * self.young_modulus * self.Iz / self.length
        self.S_Tr = self.shear_modulus * self.J / self.length

        # Section rotations at the two ends
        self.Beta_a = Beta_a
        self.Beta_b = Beta_b

    def get_element_stiffness_matrix(self):
        """Element stiffness matrix."""
        K_element = torch.tensor([
            [self.S_u, 0, 0, 0, 0, 0, -self.S_u, 0, 0, 0, 0, 0],
            [0, self.S_v1a, 0, 0, 0, self.S_theta1a, 0, -self.S_v1a, 0, 0, 0, self.S_theta1a],
            [0, 0, self.S_v2a, 0, -self.S_theta2a, 0, 0, 0, -self.S_v2a, 0, -self.S_theta2a, 0],
            [0, 0, 0, self.S_Tr, 0, 0, 0, 0, 0, -self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2b, 0, 0, 0, self.S_v2b, 0, self.S_theta2c, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1b, 0, -self.S_v1b, 0, 0, 0, self.S_theta1c],
            [-self.S_u, 0, 0, 0, 0, 0, self.S_u, 0, 0, 0, 0, 0],
            [0, -self.S_v1a, 0, 0, 0, -self.S_theta1a, 0, self.S_v1a, 0, 0, 0, -self.S_theta1a],
            [0, 0, -self.S_v2a, 0, self.S_theta2a, 0, 0, 0, self.S_v2a, 0, self.S_theta2a, 0],
            [0, 0, 0, -self.S_Tr, 0, 0, 0, 0, 0, self.S_Tr, 0, 0],
            [0, 0, -self.S_v2b, 0, self.S_theta2c, 0, 0, 0, self.S_v2b, 0, self.S_theta2b, 0],
            [0, self.S_v1b, 0, 0, 0, self.S_theta1c, 0, -self.S_v1b, 0, 0, 0, self.S_theta1b],
        ], dtype=torch.float32, device=device)

        return K_element

    def System_Transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)
        matrix_T = torch.zeros((12, 12), dtype=torch.float32, device=device)
        for i in range(0, 12, 3):
            matrix_T[i:i + 3, i:i + 3] = lambda_matrix
        return matrix_T

    def nodal_transform(self):
        """Coordinate transformation matrix."""
        vector_x = self.node_coordinates[1, 0] - self.node_coordinates[0, 0]
        vector_y = self.node_coordinates[1, 1] - self.node_coordinates[0, 1]
        vector_z = self.node_coordinates[1, 2] - self.node_coordinates[0, 2]
        length = torch.norm(self.node_coordinates[1] - self.node_coordinates[0])
        
        z_value = torch.clamp(vector_z / length, min=-1 + 1e-6, max=1 - 1e-6)
        ceta = torch.acos(z_value)
        value = vector_x / torch.sqrt(vector_y ** 2 + vector_x ** 2 + a_small_number)
        value = torch.clamp(value, min=-1 + 1e-6, max=1 - 1e-6)
        alpha = torch.acos(value)

        Projection_Z_x = - vector_z / length * torch.sin(alpha)
        Projection_Z_y = - vector_z / length * torch.cos(alpha)
        Projection_Z_z = torch.cos(torch.pi / 2 - ceta)

        V_projection = torch.stack([Projection_Z_x, Projection_Z_y, Projection_Z_z])
        X_axis = torch.stack([vector_x / length, vector_y / length, vector_z / length])
        Z_axis_a = rotation(V_projection, X_axis, self.Beta_a)
        Y_axis_a = rotation(Z_axis_a, X_axis, -torch.pi / 2)
        Z_axis_a = Z_axis_a / torch.norm(Z_axis_a)
        Y_axis_a = Y_axis_a / torch.norm(Y_axis_a)

        lambda_matrix = torch.stack([X_axis, Y_axis_a, Z_axis_a], dim=0)
        return lambda_matrix


def assemble_stiffness_matrix(beams, n_nodes, n_dof_per_node, connectivity):
    """Global stiffness matrix assembly."""
    total_dof = n_nodes * n_dof_per_node  # Total degrees of freedom
    K_global = torch.zeros((total_dof, total_dof), dtype=torch.float32, device=device)
    
    for idx, (i, j) in enumerate(connectivity):
        Matrix_T = beams[idx].System_Transform()  # Get transformation matrix
        K_element = torch.matmul(torch.transpose(Matrix_T, 0, 1),
                                 torch.matmul(beams[idx].get_element_stiffness_matrix(), Matrix_T))

        start_idx = (i - 1) * n_dof_per_node
        end_idx = (j - 1) * n_dof_per_node
        K_global[start_idx:start_idx + 6, start_idx:start_idx + 6] += K_element[0:6, 0:6]
        K_global[end_idx:end_idx + 6, end_idx:end_idx + 6] += K_element[6:12, 6:12]
        K_global[start_idx:start_idx + 6, end_idx:end_idx + 6] += K_element[0:6, 6:12]
        K_global[end_idx:end_idx + 6, start_idx:start_idx + 6] += K_element[6:12, 0:6]

    return K_global

def robust_solve(K_global, F, fixed_dof, max_attempts=3):
    
    attempts = 0
    while attempts < max_attempts:
        reg = 1e-6 * torch.eye(K_global.shape[0], device=K_global.device)
        reg[fixed_dof, fixed_dof] = 0  
        K_reg = K_global + reg
        
        try:
            displacements = torch.linalg.solve(
                K_reg.to(torch.float64), 
                F.to(torch.float64)
            )
            return displacements.to(K_global.dtype)
            
        except RuntimeError:
            diag = torch.diag(K_global)
            extreme_mask = (diag > 1e12) & (~torch.isin(torch.arange(len(diag)), torch.tensor(fixed_dof)))  
            K_reg[extreme_mask] = 0
            K_reg[:, extreme_mask] = 0
            K_reg[extreme_mask, extreme_mask] = 1e12  
            
            K_reg[fixed_dof, :] = 0
            K_reg[:, fixed_dof] = 0
            K_reg[fixed_dof, fixed_dof] = 1e10  
            
            try:
                displacements, info = torch.linalg.cg(
                    K_reg.to(torch.float64),
                    F.to(torch.float64),
                    maxiter=5000,
                    atol=1e-6
                )
                if info > 0:
                    raise RuntimeError("CG nah nah")
                return displacements.to(K_global.dtype)
                
            except:
                K_pinv = torch.linalg.pinv(K_reg)
                K_pinv[fixed_dof, :] = 0  
                displacements = K_pinv @ F
                print("警告：使用伪逆求解，精度可能降低")
                return displacements
                
        attempts += 1
    
    raise RuntimeError("无法求解线性系统")


def Strain_E(node_coords, connectivity, fixed_dof, F):
    # Element Assembly
    Beam_lens = []
    beams = []
    for connection in connectivity:
        node_1_coords = node_coords[connection[0] - 1]
        node_2_coords = node_coords[connection[1] - 1]
        beam = Beam(node_coordinates=torch.stack([node_1_coords, node_2_coords]),
                    R=D_radius, young_modulus=D_young_modulus,
                    shear_modulus=D_shear_modulus, poisson_ratio=D_poisson_ratio, Beta_a=cross_section_angle_a,
                    Beta_b=cross_section_angle_b)
        beams.append(beam)
        Beam_lens.append(beam.length)
    
    # Stiffness renewal
    K_global = assemble_stiffness_matrix(beams, n_nodes=len(node_coords), n_dof_per_node=6, connectivity=connectivity)
    K_global[fixed_dof, :] = 0
    K_global[:, fixed_dof] = 0
    K_global[fixed_dof, fixed_dof] = 1e10

    displacements = robust_solve(K_global, F, fixed_dof)

    # Compute strain energy
    strain_energy_list = []
    force_list = []
    ASE_list = []
    V_list = []
    Local_d = torch.zeros(len(connectivity), 12, dtype=torch.float32, device=device)
    for n, (i, j) in enumerate(connectivity):
        matrix_T = beams[n].System_Transform()
        Tep_displacements = torch.cat(
            [displacements[6 * (i - 1):6 * (i - 1) + 6], displacements[6 * (j - 1):6 * (j - 1) + 6]], dim=0)
        Local_d_n = torch.matmul(Tep_displacements, matrix_T.T)
        Local_d[n, :] = Local_d_n.clone()
        K_l = beams[n].get_element_stiffness_matrix()
        strain_energy_list.append(0.5 * torch.matmul(Local_d_n, torch.matmul(K_l, Local_d_n.reshape(-1, 1))))
        force_list.append(torch.matmul(K_l, Local_d_n.reshape(-1, 1)))
        ASE_list.append(0.5 * (Local_d_n[0]-Local_d_n[6]) * beams[n].S_u * (Local_d_n[0]-Local_d_n[6]))  
        V_list.append(beams[n].A * beams[n].length)
    
     
    
    Strain_energy = torch.stack(strain_energy_list)
    forces = torch.stack(force_list)
    ASE = torch.stack(ASE_list)
    lens = torch.stack(Beam_lens)
    # epsilon = Local_d[:, 0] / lens
    # Axial_d = Local_d[:, 0]
    V = torch.stack(V_list)
    SED = Strain_energy / lens 
    R = torch.var(SED)
    
    return Strain_energy, forces, displacements, ASE, lens, R, V

# %%
def find_edge_connections(Edge_nodes, connectivity):

    # 将Edge_nodes转换为集合便于快速查找
    Edge_nodes = Edge_nodes + 1
    edge_set = set(Edge_nodes.tolist() if torch.is_tensor(Edge_nodes) else Edge_nodes)
    
    edge_connection_indices = []
    
    for idx, (i, j) in enumerate(connectivity):
        if i in edge_set and j in edge_set:
            edge_connection_indices.append(idx)
    
    return edge_connection_indices

# %%
Edge_nodes = torch.where(
    (grid_points[:, 0] == x_max) |  # x = x_max
    (grid_points[:, 0] == x_min) | # x = x_min
    (grid_points[:, 1] == y_max) |  # y = y_max
    (grid_points[:, 1] == y_min)    # y = y_min
    )[0]




Fxed_nodes = torch.where(
    ((grid_points[:, 0] == x_max) & (grid_points[:, 1] == y_max) | 
    (grid_points[:, 0] == x_min) & (grid_points[:, 1] == y_max) |  
    (grid_points[:, 0] == x_max) & (grid_points[:, 1] == y_min) |  
    (grid_points[:, 0] == x_min) & (grid_points[:, 1] == y_min))   
)[0]

Fxed_nodes += 1
Fre_nodes = []

for i in range(1, n_nodes + 1):
    if i not in Fxed_nodes:
        Fre_nodes.append(i)
        
pz_ini = torch.zeros(len(Fre_nodes), 1, dtype=torch.float32)
px_ini = torch.zeros(len(Fre_nodes), 1, dtype=torch.float32)
py_ini = torch.zeros(len(Fre_nodes), 1, dtype=torch.float32)
F_ini = pz_ini[:, 0]
        
id_Fixed = torch.tensor(Fxed_nodes) - 1
id_Free = torch.tensor(Fre_nodes) - 1 

id_CF = id_Fixed
id_CN = id_Free
F = C[:, id_CF]
N = C[:, id_CN]

edge_indices = find_edge_connections(Edge_nodes, connectivity)


left_fixed = torch.where(grid_points[:, 1] == y_max)[0]  
right_fixed = torch.where(grid_points[:, 1] == y_min)[0] 

span_nodes = torch.cat([left_fixed, right_fixed])

# %%
def optimizer(q, gradients, step):
    
    grads = gradients / (torch.norm(gradients, p=2, dim=1, keepdim=True) + 1e-10)
    
    q.data -= grads * step
    with torch.no_grad():
        q[0] = torch.clamp(q[0], min=4.375, max=6.5)
        q[1] = torch.clamp(q[1], min=0.0)

    return q
    
def check_available_memory():
    """返回当前可用CPU内存（MB）"""
    return psutil.virtual_memory().available / (1024 ** 2)

# %%
############### Formulating :::::
####### Gradient descent
step = 0.3
epochs = 0
# Initilizing
patience = 20
####### Force Condition

_, F_value = Force_mat(- 1, 2)
F_fe_g, _ = Force_mat(-1, 2)
F_fe_l1, _ = Force_mat(1, 0)
F_fe_l2, _ = Force_mat(1, 1)


r = 1 / torch.max(F_value)

# %%
##### INItializaing the Q:
rows, cols = V_matrix.shape

q_rows = math.ceil(rows / 2)
q_cols = math.ceil(cols / 2)
q_v = torch.ones((q_rows, q_cols)) * 5.44 
rows_, cols_ = H_matrix.shape
q_rows_ = math.ceil(rows_ / 2)
q_cols_ = math.ceil(cols_ / 2)
q_h = torch.zeros((q_rows_, q_cols_))

q_cat = torch.cat([q_v.unsqueeze(0), q_h.unsqueeze(0)], dim=0)  # 形状 (2, q_rows, q_cols)
q = q_cat.clone().requires_grad_(True)

# %%
############## Optimization loop

#### Initializing Data storage
os.makedirs("data_records", exist_ok=True)
optimization_data = {
    "metadata": {
        "project": "Structural Optimization",
        "Context": "FDM + FE",
        "device": str(device),
        "parameters": {
            "length": length,
            "width": width,
            "grid_size": f"{n1}x{n2}",
            "epochs": epochs,
            "step_size": step
        }
    },
    "iterations": []
}

####### Loop start
n_elem = len(connectivity)
start_time = time.time()
cut = epochs / 5
LS_his = []
count = 0

# Loop start
for iteration in range(epochs + 1):
    print('ite', iteration)
    
    iter_start = time.time() 
    
    avail_mem = check_available_memory()
    print(f"Iter {iteration} - Available Memory: {avail_mem:.2f} MB")
    if avail_mem < 1000: 
        print(f"⚠️  Low memory warning: {avail_mem:.2f} MB left!")
        
    
    # Forwards
    #### Curved grid
    q_ini =  torch.ones(n_elements)
    q_ini[edge_indices] = torch.tensor([5.0]) 
    Q_ini = torch.diag(q_ini)   
    ini_grid = FDM(Q_ini, F_ini, grid_points, N, F, px_ini, py_ini, pz_ini, id_CF,id_CN)
    
    q_v, q_h = q[0], q[1] 
    q_V = Symmetry_shaper(q_v, V_matrix)
    q_H = Symmetry_shaper(q_h, H_matrix)
    
    q_vec = torch.zeros(n_elements, device=device)
    
    for i in range(V_matrix.shape[0]): 
        for j in range(V_matrix.shape[1]): 
            index = V_matrix[i, j].item()  
            q_vec[index] = q_V[i, j] 
    for i in range(H_matrix.shape[0]):  
        for j in range(H_matrix.shape[1]):  
            index = H_matrix[i, j].item() 
            q_vec[index] = q_H[i, j] 
        
    Q = torch.diag(q_vec) * 1 / r  # scaling
    new_node_coords = FDM(Q, F_value, ini_grid)
    if iteration == 0:
        ini_coords = new_node_coords
    height = max(new_node_coords[:,2])
    
    span =  torch.abs(
    new_node_coords[span_nodes[:10], 1] -  
    new_node_coords[span_nodes[-10:], 1]   
    ).mean()
    
    ####### FDM time
    FDM_time = (time.time() - iter_start) / 60
        
    N_coords = new_node_coords.clone()
    FE_str = time.time()
    Strain_energy_g, forces_g, _, Beam_lens, _, _, V = Strain_E(N_coords, connectivity, fixed_dof, F_fe_g)
    Strain_energy_1, forces_l1, _, _, _, _, _ = Strain_E(N_coords, connectivity, fixed_dof, F_fe_l1)
    Strain_energy_2, forces_l2, _, _, _, _, _ = Strain_E(N_coords, connectivity, fixed_dof, F_fe_l2)
    
    ######## FE time
    FE_time = time.time() - FE_str    
    force = abs(forces_g[:, 0, 0])
    load_path = torch.dot(force , Beam_lens)
    ES_g = torch.sum(Strain_energy_g)
    ES_l1 = torch.sum(Strain_energy_1) 
    ES_l2 = torch.sum(Strain_energy_2) 
    Volume = torch.sum(V)
    Loss = ES_g 
    
    # Loss_his.append(loss.item())
    LS_his.append(Loss.clone().detach().item())
    
    print("Loss:", Loss)
    print('load_path', load_path)
    print('ite height:', height)
        
    # Backwards
    
    Back_str = time.time()
    if q.grad is not None:
        q.grad.detach_()
        q.grad.zero_()
       
    Loss.backward(retain_graph=True)
    Back_time = (time.time() - Back_str) / 60
    
    # Grad
    gradients = q.grad
    frob_norm = torch.norm(gradients)
    q = optimizer(q, gradients, step)
    

    ####### Data storage:
    iteration_record = {
    "iteration": iteration,
    "variables": q.detach().cpu().numpy().tolist(),
    "strain_energy_g": ES_g.item(),
    "strain_energy_l1": ES_l1.item(),
    "strain_energy_l2": ES_l2.item(),
    "Load_path": load_path.item(),
    "Volume": Volume.item(),
    "gradient_norm": torch.norm(gradients).item() if q.grad is not None else 0.0,
               "timing": {
            "FDM_time": FDM_time,
            "FE_time": FE_time,
            "Back_propagation time": Back_time,
        },
    }  
    optimization_data["iterations"].append(iteration_record)

    # if iteration % cut == 0 or iteration == 0:
    #     state_idx = iteration // cut  
    #     save_fdm(state_idx, grid_points, new_node_coords, 
    #             connectivity, Free_nodes, Fixed_nodes, 
    #             force, ES_l1.detach().cpu().item())  #### Note there is strain energy input
    
    # # print iteration
    # if iteration % 5 == 0:
    #     print(f"Iteration {iteration}: Normalized Gradient = {frob_norm}, Adaptive learning rate = {step}")

    # if iteration % 10 == 0:
    #     torch.cuda.empty_cache() if torch.cuda.is_available() else None
    #     gc.collect()
            
    ####### Early stopping
    if iteration > 0:  
        Pre_Total_LS = LS_his[iteration - 1]  
        change = abs(Loss - Pre_Total_LS) / Pre_Total_LS 
        if change < 1/100000:
            count += 1
        else:
            count = 0 
        if count >= patience:
            print(f"Early stopping at iteration {iteration}: Loss change < 1%% for {patience} consecutive iterations.")
            break 
 

finalize_fdm()
total_time = (time.time() - iter_start) / 60
optimization_data["metadata"].update({
    "Ite_time": total_time,
})

with open(os.path.join("data_records", "LC1_data.json"), 'w') as f:
    json.dump(optimization_data, f, indent=2)
    
print("Optimization completed.")
print(q)
# Out:
# Wins_q tensor([5.9529, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2786, 0.3192, 0.2385])
# Wins_grad tensor([-0.0048, -0.0254, -0.0248, -0.0236, -0.0226, -0.0220, -0.0007, -0.0008,
#         -0.0005])
# ite 98
# Iter 98 - Available Memory: 5756.90 MB
# q_ini: tensor(5.9529, grad_fn=<SelectBackward0>)
# span: tensor(19.3558, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2365, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1380, grad_fn=<SumBackward0>)
# load_path tensor(466186.4375, grad_fn=<DotBackward0>)
# R: tensor(2.2596e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([5.9618, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2800, 0.3207, 0.2394])
# Wins_grad tensor([-0.0047, -0.0254, -0.0248, -0.0236, -0.0226, -0.0220, -0.0007, -0.0008,
#         -0.0005])
# ite 99
# Iter 99 - Available Memory: 5762.25 MB
# q_ini: tensor(5.9618, grad_fn=<SelectBackward0>)
# span: tensor(19.3605, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2365, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1380, grad_fn=<SumBackward0>)
# load_path tensor(466360.4375, grad_fn=<DotBackward0>)
# R: tensor(2.2621e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([5.9707, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2813, 0.3222, 0.2403])
# Wins_grad tensor([-0.0047, -0.0254, -0.0248, -0.0236, -0.0227, -0.0220, -0.0007, -0.0008,
#         -0.0005])
# ite 100
# Iter 100 - Available Memory: 5776.33 MB
# q_ini: tensor(5.9707, grad_fn=<SelectBackward0>)
# span: tensor(19.3652, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2365, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1380, grad_fn=<SumBackward0>)
# load_path tensor(466534.1562, grad_fn=<DotBackward0>)
# R: tensor(2.2645e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([5.9796, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2826, 0.3236, 0.2412])
# Wins_grad tensor([-0.0047, -0.0254, -0.0248, -0.0236, -0.0227, -0.0221, -0.0007, -0.0008,
#         -0.0005])
# Iteration 100: Normalized Gradient = 0.053324244916439056, Adaptive learning rate = 0.1
# ite 101
# Iter 101 - Available Memory: 5774.26 MB
# q_ini: tensor(5.9796, grad_fn=<SelectBackward0>)
# span: tensor(19.3698, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2365, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1381, grad_fn=<SumBackward0>)
# load_path tensor(466706.6250, grad_fn=<DotBackward0>)
# R: tensor(2.2669e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([5.9884, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2839, 0.3251, 0.2421])
# Wins_grad tensor([-0.0047, -0.0254, -0.0248, -0.0236, -0.0227, -0.0221, -0.0007, -0.0008,
#         -0.0005])
# ite 102
# Iter 102 - Available Memory: 5785.91 MB
# q_ini: tensor(5.9884, grad_fn=<SelectBackward0>)
# span: tensor(19.3745, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2365, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1381, grad_fn=<SumBackward0>)
# load_path tensor(466878., grad_fn=<DotBackward0>)
# R: tensor(2.2694e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([5.9973, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2852, 0.3266, 0.2430])
# Wins_grad tensor([-0.0047, -0.0254, -0.0248, -0.0236, -0.0227, -0.0221, -0.0007, -0.0008,
#         -0.0005])
# ite 103
# Iter 103 - Available Memory: 5795.43 MB
# q_ini: tensor(5.9973, grad_fn=<SelectBackward0>)
# span: tensor(19.3791, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2365, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1381, grad_fn=<SumBackward0>)
# load_path tensor(467048.6250, grad_fn=<DotBackward0>)
# R: tensor(2.2718e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.0061, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2865, 0.3280, 0.2439])
# Wins_grad tensor([-0.0047, -0.0254, -0.0248, -0.0237, -0.0227, -0.0221, -0.0007, -0.0008,
#         -0.0005])
# ite 104
# Iter 104 - Available Memory: 5793.80 MB
# q_ini: tensor(6.0061, grad_fn=<SelectBackward0>)
# span: tensor(19.3837, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2366, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1382, grad_fn=<SumBackward0>)
# load_path tensor(467218.3125, grad_fn=<DotBackward0>)
# R: tensor(2.2742e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.0148, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2878, 0.3295, 0.2448])
# Wins_grad tensor([-0.0047, -0.0254, -0.0249, -0.0237, -0.0227, -0.0221, -0.0007, -0.0008,
#         -0.0005])
# ite 105
# Iter 105 - Available Memory: 5780.86 MB
# q_ini: tensor(6.0148, grad_fn=<SelectBackward0>)
# span: tensor(19.3883, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2366, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1382, grad_fn=<SumBackward0>)
# load_path tensor(467387.0312, grad_fn=<DotBackward0>)
# R: tensor(2.2766e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.0236, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2890, 0.3309, 0.2456])
# Wins_grad tensor([-0.0047, -0.0254, -0.0249, -0.0237, -0.0227, -0.0221, -0.0007, -0.0008,
#         -0.0005])
# Iteration 105: Normalized Gradient = 0.05341270565986633, Adaptive learning rate = 0.1
# ite 106
# Iter 106 - Available Memory: 5796.15 MB
# q_ini: tensor(6.0236, grad_fn=<SelectBackward0>)
# span: tensor(19.3929, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2366, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1382, grad_fn=<SumBackward0>)
# load_path tensor(467554.8125, grad_fn=<DotBackward0>)
# R: tensor(2.2790e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.0324, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2903, 0.3323, 0.2465])
# Wins_grad tensor([-0.0047, -0.0254, -0.0249, -0.0237, -0.0227, -0.0221, -0.0007, -0.0008,
#         -0.0005])
# ite 107
# Iter 107 - Available Memory: 5785.66 MB
# q_ini: tensor(6.0324, grad_fn=<SelectBackward0>)
# span: tensor(19.3974, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2366, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1382, grad_fn=<SumBackward0>)
# load_path tensor(467720.6875, grad_fn=<DotBackward0>)
# R: tensor(2.2814e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.0411, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2916, 0.3337, 0.2474])
# Wins_grad tensor([-0.0047, -0.0254, -0.0249, -0.0237, -0.0227, -0.0221, -0.0007, -0.0008,
#         -0.0005])
# ite 108
# Iter 108 - Available Memory: 5781.37 MB
# q_ini: tensor(6.0411, grad_fn=<SelectBackward0>)
# span: tensor(19.4020, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2366, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1383, grad_fn=<SumBackward0>)
# load_path tensor(467886.9062, grad_fn=<DotBackward0>)
# R: tensor(2.2838e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.0498, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2929, 0.3352, 0.2482])
# Wins_grad tensor([-0.0047, -0.0254, -0.0249, -0.0237, -0.0228, -0.0222, -0.0007, -0.0008,
#         -0.0005])
# ite 109
# Iter 109 - Available Memory: 5771.92 MB
# q_ini: tensor(6.0498, grad_fn=<SelectBackward0>)
# span: tensor(19.4065, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2366, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1383, grad_fn=<SumBackward0>)
# load_path tensor(468052.0625, grad_fn=<DotBackward0>)
# R: tensor(2.2861e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.0585, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2941, 0.3366, 0.2491])
# Wins_grad tensor([-0.0047, -0.0254, -0.0249, -0.0237, -0.0228, -0.0222, -0.0007, -0.0008,
#         -0.0005])
# ite 110
# Iter 110 - Available Memory: 5776.87 MB
# q_ini: tensor(6.0585, grad_fn=<SelectBackward0>)
# span: tensor(19.4110, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2367, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1383, grad_fn=<SumBackward0>)
# load_path tensor(468216.0625, grad_fn=<DotBackward0>)
# R: tensor(2.2885e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.0672, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2954, 0.3380, 0.2499])
# Wins_grad tensor([-0.0046, -0.0254, -0.0249, -0.0237, -0.0228, -0.0222, -0.0007, -0.0007,
#         -0.0004])
# Iteration 110: Normalized Gradient = 0.05349951982498169, Adaptive learning rate = 0.1
# ite 111
# Iter 111 - Available Memory: 5795.66 MB
# q_ini: tensor(6.0672, grad_fn=<SelectBackward0>)
# span: tensor(19.4154, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2367, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1384, grad_fn=<SumBackward0>)
# load_path tensor(468379.5625, grad_fn=<DotBackward0>)
# R: tensor(2.2909e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.0758, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2967, 0.3393, 0.2507])
# Wins_grad tensor([-0.0046, -0.0254, -0.0249, -0.0237, -0.0228, -0.0222, -0.0007, -0.0007,
#         -0.0004])
# ite 112
# Iter 112 - Available Memory: 5883.86 MB
# q_ini: tensor(6.0758, grad_fn=<SelectBackward0>)
# span: tensor(19.4199, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2367, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1384, grad_fn=<SumBackward0>)
# load_path tensor(468541.4375, grad_fn=<DotBackward0>)
# R: tensor(2.2932e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.0845, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2979, 0.3407, 0.2516])
# Wins_grad tensor([-0.0046, -0.0254, -0.0249, -0.0237, -0.0228, -0.0222, -0.0007, -0.0007,
#         -0.0004])
# ite 113
# Iter 113 - Available Memory: 5859.42 MB
# q_ini: tensor(6.0845, grad_fn=<SelectBackward0>)
# span: tensor(19.4243, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2367, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1384, grad_fn=<SumBackward0>)
# load_path tensor(468703.3750, grad_fn=<DotBackward0>)
# R: tensor(2.2956e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.0931, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.2992, 0.3421, 0.2524])
# Wins_grad tensor([-0.0046, -0.0254, -0.0249, -0.0237, -0.0228, -0.0222, -0.0007, -0.0007,
#         -0.0004])
# ite 114
# Iter 114 - Available Memory: 5855.93 MB
# q_ini: tensor(6.0931, grad_fn=<SelectBackward0>)
# span: tensor(19.4288, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2367, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1385, grad_fn=<SumBackward0>)
# load_path tensor(468863.6875, grad_fn=<DotBackward0>)
# R: tensor(2.2979e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.1017, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3005, 0.3435, 0.2532])
# Wins_grad tensor([-0.0046, -0.0254, -0.0249, -0.0238, -0.0228, -0.0222, -0.0007, -0.0007,
#         -0.0004])
# ite 115
# Iter 115 - Available Memory: 5859.09 MB
# q_ini: tensor(6.1017, grad_fn=<SelectBackward0>)
# span: tensor(19.4332, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2367, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1385, grad_fn=<SumBackward0>)
# load_path tensor(469023.7812, grad_fn=<DotBackward0>)
# R: tensor(2.3002e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.1103, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3017, 0.3448, 0.2540])
# Wins_grad tensor([-0.0046, -0.0254, -0.0249, -0.0238, -0.0228, -0.0222, -0.0007, -0.0007,
#         -0.0004])
# Iteration 115: Normalized Gradient = 0.05358562245965004, Adaptive learning rate = 0.1
# ite 116
# Iter 116 - Available Memory: 5860.70 MB
# q_ini: tensor(6.1103, grad_fn=<SelectBackward0>)
# span: tensor(19.4375, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2368, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1385, grad_fn=<SumBackward0>)
# load_path tensor(469182.8750, grad_fn=<DotBackward0>)
# R: tensor(2.3025e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.1189, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3030, 0.3462, 0.2548])
# Wins_grad tensor([-0.0046, -0.0254, -0.0249, -0.0238, -0.0228, -0.0223, -0.0007, -0.0007,
#         -0.0004])
# ite 117
# Iter 117 - Available Memory: 5904.90 MB
# q_ini: tensor(6.1189, grad_fn=<SelectBackward0>)
# span: tensor(19.4419, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2368, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1386, grad_fn=<SumBackward0>)
# load_path tensor(469340.3750, grad_fn=<DotBackward0>)
# R: tensor(2.3048e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.1274, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3042, 0.3475, 0.2556])
# Wins_grad tensor([-0.0046, -0.0254, -0.0250, -0.0238, -0.0229, -0.0223, -0.0007, -0.0007,
#         -0.0004])
# ite 118
# Iter 118 - Available Memory: 5892.86 MB
# q_ini: tensor(6.1274, grad_fn=<SelectBackward0>)
# span: tensor(19.4463, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2368, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1386, grad_fn=<SumBackward0>)
# load_path tensor(469497.4062, grad_fn=<DotBackward0>)
# R: tensor(2.3071e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.1359, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3054, 0.3488, 0.2564])
# Wins_grad tensor([-0.0046, -0.0254, -0.0250, -0.0238, -0.0229, -0.0223, -0.0007, -0.0007,
#         -0.0004])
# ite 119
# Iter 119 - Available Memory: 5898.51 MB
# q_ini: tensor(6.1359, grad_fn=<SelectBackward0>)
# span: tensor(19.4506, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2368, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1386, grad_fn=<SumBackward0>)
# load_path tensor(469653.7500, grad_fn=<DotBackward0>)
# R: tensor(2.3094e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.1445, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3067, 0.3502, 0.2572])
# Wins_grad tensor([-0.0046, -0.0254, -0.0250, -0.0238, -0.0229, -0.0223, -0.0007, -0.0007,
#         -0.0004])
# ite 120
# Iter 120 - Available Memory: 5855.20 MB
# q_ini: tensor(6.1445, grad_fn=<SelectBackward0>)
# span: tensor(19.4549, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2368, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1386, grad_fn=<SumBackward0>)
# load_path tensor(469810., grad_fn=<DotBackward0>)
# R: tensor(2.3117e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.1530, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3079, 0.3515, 0.2580])
# Wins_grad tensor([-0.0046, -0.0254, -0.0250, -0.0238, -0.0229, -0.0223, -0.0007, -0.0007,
#         -0.0004])
# Iteration 120: Normalized Gradient = 0.053670309484004974, Adaptive learning rate = 0.1
# ite 121
# Iter 121 - Available Memory: 5802.27 MB
# q_ini: tensor(6.1530, grad_fn=<SelectBackward0>)
# span: tensor(19.4592, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2368, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1387, grad_fn=<SumBackward0>)
# load_path tensor(469964.8125, grad_fn=<DotBackward0>)
# R: tensor(2.3140e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.1614, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3091, 0.3528, 0.2588])
# Wins_grad tensor([-0.0046, -0.0254, -0.0250, -0.0238, -0.0229, -0.0223, -0.0007, -0.0007,
#         -0.0004])
# ite 122
# Iter 122 - Available Memory: 5742.66 MB
# q_ini: tensor(6.1614, grad_fn=<SelectBackward0>)
# span: tensor(19.4635, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2368, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1387, grad_fn=<SumBackward0>)
# load_path tensor(470118.7812, grad_fn=<DotBackward0>)
# R: tensor(2.3163e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.1699, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3104, 0.3541, 0.2596])
# Wins_grad tensor([-0.0045, -0.0254, -0.0250, -0.0238, -0.0229, -0.0223, -0.0007, -0.0007,
#         -0.0004])
# ite 123
# Iter 123 - Available Memory: 6041.07 MB
# q_ini: tensor(6.1699, grad_fn=<SelectBackward0>)
# span: tensor(19.4677, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2369, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1387, grad_fn=<SumBackward0>)
# load_path tensor(470271.3125, grad_fn=<DotBackward0>)
# R: tensor(2.3186e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.1784, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3116, 0.3554, 0.2603])
# Wins_grad tensor([-0.0045, -0.0254, -0.0250, -0.0238, -0.0229, -0.0223, -0.0007, -0.0007,
#         -0.0004])
# ite 124
# Iter 124 - Available Memory: 5978.81 MB
# q_ini: tensor(6.1784, grad_fn=<SelectBackward0>)
# span: tensor(19.4720, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2369, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1388, grad_fn=<SumBackward0>)
# load_path tensor(470424., grad_fn=<DotBackward0>)
# R: tensor(2.3208e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.1868, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3128, 0.3567, 0.2611])
# Wins_grad tensor([-0.0045, -0.0254, -0.0250, -0.0239, -0.0229, -0.0224, -0.0007, -0.0007,
#         -0.0004])
# ite 125
# Iter 125 - Available Memory: 5929.75 MB
# q_ini: tensor(6.1868, grad_fn=<SelectBackward0>)
# span: tensor(19.4762, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2369, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1388, grad_fn=<SumBackward0>)
# load_path tensor(470575.6250, grad_fn=<DotBackward0>)
# R: tensor(2.3231e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.1952, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3140, 0.3580, 0.2619])
# Wins_grad tensor([-0.0045, -0.0254, -0.0250, -0.0239, -0.0229, -0.0224, -0.0007, -0.0007,
#         -0.0004])
# Iteration 125: Normalized Gradient = 0.053753823041915894, Adaptive learning rate = 0.1
# ite 126
# Iter 126 - Available Memory: 5906.34 MB
# q_ini: tensor(6.1952, grad_fn=<SelectBackward0>)
# span: tensor(19.4804, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2369, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1388, grad_fn=<SumBackward0>)
# load_path tensor(470727.4375, grad_fn=<DotBackward0>)
# R: tensor(2.3253e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.2036, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3153, 0.3592, 0.2626])
# Wins_grad tensor([-0.0045, -0.0254, -0.0250, -0.0239, -0.0230, -0.0224, -0.0007, -0.0007,
#         -0.0004])
# ite 127
# Iter 127 - Available Memory: 5872.61 MB
# q_ini: tensor(6.2036, grad_fn=<SelectBackward0>)
# span: tensor(19.4846, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2369, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1388, grad_fn=<SumBackward0>)
# load_path tensor(470876.5625, grad_fn=<DotBackward0>)
# R: tensor(2.3276e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.2120, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3165, 0.3605, 0.2634])
# Wins_grad tensor([-0.0045, -0.0254, -0.0250, -0.0239, -0.0230, -0.0224, -0.0007, -0.0007,
#         -0.0004])
# ite 128
# Iter 128 - Available Memory: 5844.98 MB
# q_ini: tensor(6.2120, grad_fn=<SelectBackward0>)
# span: tensor(19.4888, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2369, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1389, grad_fn=<SumBackward0>)
# load_path tensor(471025.7500, grad_fn=<DotBackward0>)
# R: tensor(2.3298e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.2203, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3177, 0.3618, 0.2641])
# Wins_grad tensor([-0.0045, -0.0254, -0.0250, -0.0239, -0.0230, -0.0224, -0.0007, -0.0007,
#         -0.0004])
# ite 129
# Iter 129 - Available Memory: 5839.51 MB
# q_ini: tensor(6.2203, grad_fn=<SelectBackward0>)
# span: tensor(19.4930, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2369, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1389, grad_fn=<SumBackward0>)
# load_path tensor(471174.9688, grad_fn=<DotBackward0>)
# R: tensor(2.3320e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.2287, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3189, 0.3630, 0.2648])
# Wins_grad tensor([-0.0045, -0.0254, -0.0250, -0.0239, -0.0230, -0.0224, -0.0006, -0.0007,
#         -0.0004])
# ite 130
# Iter 130 - Available Memory: 5833.68 MB
# q_ini: tensor(6.2287, grad_fn=<SelectBackward0>)
# span: tensor(19.4972, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2370, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1389, grad_fn=<SumBackward0>)
# load_path tensor(471322.3125, grad_fn=<DotBackward0>)
# R: tensor(2.3343e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4., grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.2370, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3201, 0.3643, 0.2656])
# Wins_grad tensor([-0.0045, -0.0254, -0.0250, -0.0239, -0.0230, -0.0224, -0.0006, -0.0007,
#         -0.0004])
# Iteration 130: Normalized Gradient = 0.0538361631333828, Adaptive learning rate = 0.1
# ite 131
# Iter 131 - Available Memory: 5830.65 MB
# q_ini: tensor(6.2370, grad_fn=<SelectBackward0>)
# span: tensor(19.5013, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2370, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1390, grad_fn=<SumBackward0>)
# load_path tensor(471469.8438, grad_fn=<DotBackward0>)
# R: tensor(2.3365e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.2453, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3213, 0.3655, 0.2663])
# Wins_grad tensor([-0.0045, -0.0254, -0.0251, -0.0239, -0.0230, -0.0224, -0.0006, -0.0007,
#         -0.0004])
# ite 132
# Iter 132 - Available Memory: 5828.78 MB
# q_ini: tensor(6.2453, grad_fn=<SelectBackward0>)
# span: tensor(19.5054, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2370, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1390, grad_fn=<SumBackward0>)
# load_path tensor(471616.4375, grad_fn=<DotBackward0>)
# R: tensor(2.3387e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.2536, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3225, 0.3667, 0.2670])
# Wins_grad tensor([-0.0045, -0.0254, -0.0251, -0.0239, -0.0230, -0.0224, -0.0006, -0.0007,
#         -0.0004])
# ite 133
# Iter 133 - Available Memory: 5824.88 MB
# q_ini: tensor(6.2536, grad_fn=<SelectBackward0>)
# span: tensor(19.5095, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2370, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1390, grad_fn=<SumBackward0>)
# load_path tensor(471761.7500, grad_fn=<DotBackward0>)
# R: tensor(2.3409e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.2619, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3237, 0.3679, 0.2678])
# Wins_grad tensor([-0.0045, -0.0254, -0.0251, -0.0239, -0.0230, -0.0225, -0.0006, -0.0007,
#         -0.0004])
# ite 134
# Iter 134 - Available Memory: 5819.10 MB
# q_ini: tensor(6.2619, grad_fn=<SelectBackward0>)
# span: tensor(19.5136, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2370, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1391, grad_fn=<SumBackward0>)
# load_path tensor(471906.3438, grad_fn=<DotBackward0>)
# R: tensor(2.3431e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.2702, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3249, 0.3692, 0.2685])
# Wins_grad tensor([-0.0045, -0.0254, -0.0251, -0.0239, -0.0230, -0.0225, -0.0006, -0.0007,
#         -0.0004])
# ite 135
# Iter 135 - Available Memory: 5816.98 MB
# q_ini: tensor(6.2702, grad_fn=<SelectBackward0>)
# span: tensor(19.5177, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2370, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1391, grad_fn=<SumBackward0>)
# load_path tensor(472051.1250, grad_fn=<DotBackward0>)
# R: tensor(2.3453e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.2784, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3261, 0.3704, 0.2692])
# Wins_grad tensor([-0.0044, -0.0254, -0.0251, -0.0239, -0.0230, -0.0225, -0.0006, -0.0007,
#         -0.0004])
# Iteration 135: Normalized Gradient = 0.053917646408081055, Adaptive learning rate = 0.1
# ite 136
# Iter 136 - Available Memory: 5826.12 MB
# q_ini: tensor(6.2784, grad_fn=<SelectBackward0>)
# span: tensor(19.5217, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2370, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1391, grad_fn=<SumBackward0>)
# load_path tensor(472194.6250, grad_fn=<DotBackward0>)
# R: tensor(2.3475e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.2867, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3273, 0.3716, 0.2699])
# Wins_grad tensor([-0.0044, -0.0254, -0.0251, -0.0240, -0.0231, -0.0225, -0.0006, -0.0006,
#         -0.0004])
# ite 137
# Iter 137 - Available Memory: 5826.72 MB
# q_ini: tensor(6.2867, grad_fn=<SelectBackward0>)
# span: tensor(19.5258, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2370, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1391, grad_fn=<SumBackward0>)
# load_path tensor(472336.9375, grad_fn=<DotBackward0>)
# R: tensor(2.3496e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.2949, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3284, 0.3728, 0.2706])
# Wins_grad tensor([-0.0044, -0.0254, -0.0251, -0.0240, -0.0231, -0.0225, -0.0006, -0.0006,
#         -0.0004])
# ite 138
# Iter 138 - Available Memory: 5821.64 MB
# q_ini: tensor(6.2949, grad_fn=<SelectBackward0>)
# span: tensor(19.5298, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2371, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1392, grad_fn=<SumBackward0>)
# load_path tensor(472479.4375, grad_fn=<DotBackward0>)
# R: tensor(2.3518e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.3031, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3296, 0.3740, 0.2713])
# Wins_grad tensor([-0.0044, -0.0254, -0.0251, -0.0240, -0.0231, -0.0225, -0.0006, -0.0006,
#         -0.0004])
# ite 139
# Iter 139 - Available Memory: 5806.19 MB
# q_ini: tensor(6.3031, grad_fn=<SelectBackward0>)
# span: tensor(19.5338, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2371, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1392, grad_fn=<SumBackward0>)
# load_path tensor(472620.4375, grad_fn=<DotBackward0>)
# R: tensor(2.3540e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.3113, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3308, 0.3751, 0.2720])
# Wins_grad tensor([-0.0044, -0.0254, -0.0251, -0.0240, -0.0231, -0.0225, -0.0006, -0.0006,
#         -0.0004])
# ite 140
# Iter 140 - Available Memory: 5758.01 MB
# q_ini: tensor(6.3113, grad_fn=<SelectBackward0>)
# span: tensor(19.5378, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2371, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1392, grad_fn=<SumBackward0>)
# load_path tensor(472761.5625, grad_fn=<DotBackward0>)
# R: tensor(2.3561e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.3194, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3320, 0.3763, 0.2727])
# Wins_grad tensor([-0.0044, -0.0254, -0.0251, -0.0240, -0.0231, -0.0225, -0.0006, -0.0006,
#         -0.0004])
# Iteration 140: Normalized Gradient = 0.05399775132536888, Adaptive learning rate = 0.1
# ite 141
# Iter 141 - Available Memory: 5862.23 MB
# q_ini: tensor(6.3194, grad_fn=<SelectBackward0>)
# span: tensor(19.5418, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2371, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1392, grad_fn=<SumBackward0>)
# load_path tensor(472901.7812, grad_fn=<DotBackward0>)
# R: tensor(2.3583e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.3276, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3332, 0.3775, 0.2734])
# Wins_grad tensor([-0.0044, -0.0254, -0.0251, -0.0240, -0.0231, -0.0225, -0.0006, -0.0006,
#         -0.0004])
# ite 142
# Iter 142 - Available Memory: 5802.18 MB
# q_ini: tensor(6.3276, grad_fn=<SelectBackward0>)
# span: tensor(19.5458, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2371, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1393, grad_fn=<SumBackward0>)
# load_path tensor(473041.1875, grad_fn=<DotBackward0>)
# R: tensor(2.3604e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.3357, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3343, 0.3787, 0.2741])
# Wins_grad tensor([-0.0044, -0.0254, -0.0251, -0.0240, -0.0231, -0.0226, -0.0006, -0.0006,
#         -0.0004])
# ite 143
# Iter 143 - Available Memory: 5786.98 MB
# q_ini: tensor(6.3357, grad_fn=<SelectBackward0>)
# span: tensor(19.5497, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2371, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1393, grad_fn=<SumBackward0>)
# load_path tensor(473179.1250, grad_fn=<DotBackward0>)
# R: tensor(2.3625e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.3439, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3355, 0.3798, 0.2747])
# Wins_grad tensor([-0.0044, -0.0255, -0.0251, -0.0240, -0.0231, -0.0226, -0.0006, -0.0006,
#         -0.0004])
# ite 144
# Iter 144 - Available Memory: 5757.70 MB
# q_ini: tensor(6.3439, grad_fn=<SelectBackward0>)
# span: tensor(19.5536, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2371, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1393, grad_fn=<SumBackward0>)
# load_path tensor(473317.5625, grad_fn=<DotBackward0>)
# R: tensor(2.3647e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.3520, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3367, 0.3810, 0.2754])
# Wins_grad tensor([-0.0044, -0.0255, -0.0251, -0.0240, -0.0231, -0.0226, -0.0006, -0.0006,
#         -0.0004])
# ite 145
# Iter 145 - Available Memory: 5735.92 MB
# q_ini: tensor(6.3520, grad_fn=<SelectBackward0>)
# span: tensor(19.5576, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2371, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1394, grad_fn=<SumBackward0>)
# load_path tensor(473455., grad_fn=<DotBackward0>)
# R: tensor(2.3668e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.3601, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3378, 0.3821, 0.2761])
# Wins_grad tensor([-0.0044, -0.0255, -0.0252, -0.0240, -0.0231, -0.0226, -0.0006, -0.0006,
#         -0.0004])
# Iteration 145: Normalized Gradient = 0.05407686159014702, Adaptive learning rate = 0.1
# ite 146
# Iter 146 - Available Memory: 5672.83 MB
# q_ini: tensor(6.3601, grad_fn=<SelectBackward0>)
# span: tensor(19.5615, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2372, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1394, grad_fn=<SumBackward0>)
# load_path tensor(473591.3750, grad_fn=<DotBackward0>)
# R: tensor(2.3689e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.3681, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3390, 0.3832, 0.2767])
# Wins_grad tensor([-0.0044, -0.0255, -0.0252, -0.0240, -0.0232, -0.0226, -0.0006, -0.0006,
#         -0.0004])
# ite 147
# Iter 147 - Available Memory: 5715.60 MB
# q_ini: tensor(6.3681, grad_fn=<SelectBackward0>)
# span: tensor(19.5654, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2372, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1394, grad_fn=<SumBackward0>)
# load_path tensor(473728.0625, grad_fn=<DotBackward0>)
# R: tensor(2.3710e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.3762, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3401, 0.3844, 0.2774])
# Wins_grad tensor([-0.0044, -0.0255, -0.0252, -0.0241, -0.0232, -0.0226, -0.0006, -0.0006,
#         -0.0004])
# ite 148
# Iter 148 - Available Memory: 5667.80 MB
# q_ini: tensor(6.3762, grad_fn=<SelectBackward0>)
# span: tensor(19.5693, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2372, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1394, grad_fn=<SumBackward0>)
# load_path tensor(473863.3438, grad_fn=<DotBackward0>)
# R: tensor(2.3731e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.3842, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3413, 0.3855, 0.2781])
# Wins_grad tensor([-0.0044, -0.0255, -0.0252, -0.0241, -0.0232, -0.0226, -0.0006, -0.0006,
#         -0.0004])
# ite 149
# Iter 149 - Available Memory: 5605.81 MB
# q_ini: tensor(6.3842, grad_fn=<SelectBackward0>)
# span: tensor(19.5731, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2372, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1395, grad_fn=<SumBackward0>)
# load_path tensor(473997.6562, grad_fn=<DotBackward0>)
# R: tensor(2.3752e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.3923, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3424, 0.3866, 0.2787])
# Wins_grad tensor([-0.0043, -0.0255, -0.0252, -0.0241, -0.0232, -0.0226, -0.0006, -0.0006,
#         -0.0004])
# ite 150
# Iter 150 - Available Memory: 5581.10 MB
# q_ini: tensor(6.3923, grad_fn=<SelectBackward0>)
# span: tensor(19.5770, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2372, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1395, grad_fn=<SumBackward0>)
# load_path tensor(474132.1875, grad_fn=<DotBackward0>)
# R: tensor(2.3773e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.4003, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3436, 0.3877, 0.2794])
# Wins_grad tensor([-0.0043, -0.0255, -0.0252, -0.0241, -0.0232, -0.0226, -0.0006, -0.0006,
#         -0.0004])
# Iteration 150: Normalized Gradient = 0.0541548915207386, Adaptive learning rate = 0.1
# ite 151
# Iter 151 - Available Memory: 5531.68 MB
# q_ini: tensor(6.4003, grad_fn=<SelectBackward0>)
# span: tensor(19.5808, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2372, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1395, grad_fn=<SumBackward0>)
# load_path tensor(474265.6250, grad_fn=<DotBackward0>)
# R: tensor(2.3794e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.4083, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3447, 0.3888, 0.2800])
# Wins_grad tensor([-0.0043, -0.0255, -0.0252, -0.0241, -0.0232, -0.0227, -0.0006, -0.0006,
#         -0.0003])
# ite 152
# Iter 152 - Available Memory: 5486.95 MB
# q_ini: tensor(6.4083, grad_fn=<SelectBackward0>)
# span: tensor(19.5846, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2372, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1396, grad_fn=<SumBackward0>)
# load_path tensor(474398.1562, grad_fn=<DotBackward0>)
# R: tensor(2.3815e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.4163, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3459, 0.3900, 0.2806])
# Wins_grad tensor([-0.0043, -0.0255, -0.0252, -0.0241, -0.0232, -0.0227, -0.0006, -0.0006,
#         -0.0003])
# ite 153
# Iter 153 - Available Memory: 5498.66 MB
# q_ini: tensor(6.4163, grad_fn=<SelectBackward0>)
# span: tensor(19.5885, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2372, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1396, grad_fn=<SumBackward0>)
# load_path tensor(474530.3438, grad_fn=<DotBackward0>)
# R: tensor(2.3835e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.4243, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3470, 0.3910, 0.2813])
# Wins_grad tensor([-0.0043, -0.0255, -0.0252, -0.0241, -0.0232, -0.0227, -0.0006, -0.0006,
#         -0.0003])
# ite 154
# Iter 154 - Available Memory: 5478.39 MB
# q_ini: tensor(6.4243, grad_fn=<SelectBackward0>)
# span: tensor(19.5922, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2372, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1396, grad_fn=<SumBackward0>)
# load_path tensor(474661.7500, grad_fn=<DotBackward0>)
# R: tensor(2.3856e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.4322, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3481, 0.3921, 0.2819])
# Wins_grad tensor([-0.0043, -0.0255, -0.0252, -0.0241, -0.0232, -0.0227, -0.0006, -0.0006,
#         -0.0003])
# ite 155
# Iter 155 - Available Memory: 5549.45 MB
# q_ini: tensor(6.4322, grad_fn=<SelectBackward0>)
# span: tensor(19.5960, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2372, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1396, grad_fn=<SumBackward0>)
# load_path tensor(474793.6562, grad_fn=<DotBackward0>)
# R: tensor(2.3877e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.4402, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3493, 0.3932, 0.2825])
# Wins_grad tensor([-0.0043, -0.0255, -0.0252, -0.0241, -0.0232, -0.0227, -0.0006, -0.0006,
#         -0.0003])
# Iteration 155: Normalized Gradient = 0.05423197150230408, Adaptive learning rate = 0.1
# ite 156
# Iter 156 - Available Memory: 5475.42 MB
# q_ini: tensor(6.4402, grad_fn=<SelectBackward0>)
# span: tensor(19.5998, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2373, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1397, grad_fn=<SumBackward0>)
# load_path tensor(474923.3125, grad_fn=<DotBackward0>)
# R: tensor(2.3897e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.4481, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3504, 0.3943, 0.2832])
# Wins_grad tensor([-0.0043, -0.0255, -0.0252, -0.0241, -0.0233, -0.0227, -0.0006, -0.0006,
#         -0.0003])
# ite 157
# Iter 157 - Available Memory: 5397.27 MB
# q_ini: tensor(6.4481, grad_fn=<SelectBackward0>)
# span: tensor(19.6036, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2373, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1397, grad_fn=<SumBackward0>)
# load_path tensor(475053.2500, grad_fn=<DotBackward0>)
# R: tensor(2.3918e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4., grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.4560, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3515, 0.3954, 0.2838])
# Wins_grad tensor([-0.0043, -0.0255, -0.0252, -0.0241, -0.0233, -0.0227, -0.0006, -0.0006,
#         -0.0003])
# ite 158
# Iter 158 - Available Memory: 5395.21 MB
# q_ini: tensor(6.4560, grad_fn=<SelectBackward0>)
# span: tensor(19.6073, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2373, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1397, grad_fn=<SumBackward0>)
# load_path tensor(475182.7188, grad_fn=<DotBackward0>)
# R: tensor(2.3938e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.4639, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3527, 0.3964, 0.2844])
# Wins_grad tensor([-0.0043, -0.0255, -0.0252, -0.0241, -0.0233, -0.0227, -0.0006, -0.0006,
#         -0.0003])
# ite 159
# Iter 159 - Available Memory: 5373.90 MB
# q_ini: tensor(6.4639, grad_fn=<SelectBackward0>)
# span: tensor(19.6110, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2373, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1397, grad_fn=<SumBackward0>)
# load_path tensor(475311.6875, grad_fn=<DotBackward0>)
# R: tensor(2.3958e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.4718, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3538, 0.3975, 0.2850])
# Wins_grad tensor([-0.0043, -0.0255, -0.0252, -0.0242, -0.0233, -0.0227, -0.0006, -0.0006,
#         -0.0003])
# ite 160
# Iter 160 - Available Memory: 5345.71 MB
# q_ini: tensor(6.4718, grad_fn=<SelectBackward0>)
# span: tensor(19.6147, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2373, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1398, grad_fn=<SumBackward0>)
# load_path tensor(475439.7500, grad_fn=<DotBackward0>)
# R: tensor(2.3979e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.4797, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3549, 0.3986, 0.2856])
# Wins_grad tensor([-0.0043, -0.0255, -0.0252, -0.0242, -0.0233, -0.0227, -0.0006, -0.0006,
#         -0.0003])
# Iteration 160: Normalized Gradient = 0.05430779978632927, Adaptive learning rate = 0.1
# ite 161
# Iter 161 - Available Memory: 5347.00 MB
# q_ini: tensor(6.4797, grad_fn=<SelectBackward0>)
# span: tensor(19.6185, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2373, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1398, grad_fn=<SumBackward0>)
# load_path tensor(475567.0625, grad_fn=<DotBackward0>)
# R: tensor(2.3999e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.4875, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3560, 0.3996, 0.2862])
# Wins_grad tensor([-0.0043, -0.0255, -0.0253, -0.0242, -0.0233, -0.0228, -0.0006, -0.0006,
#         -0.0003])
# ite 162
# Iter 162 - Available Memory: 5336.54 MB
# q_ini: tensor(6.4875, grad_fn=<SelectBackward0>)
# span: tensor(19.6221, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2373, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1398, grad_fn=<SumBackward0>)
# load_path tensor(475694., grad_fn=<DotBackward0>)
# R: tensor(2.4019e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.4954, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3572, 0.4006, 0.2868])
# Wins_grad tensor([-0.0043, -0.0255, -0.0253, -0.0242, -0.0233, -0.0228, -0.0006, -0.0006,
#         -0.0003])
# ite 163
# Iter 163 - Available Memory: 5319.98 MB
# q_ini: tensor(6.4954, grad_fn=<SelectBackward0>)
# span: tensor(19.6258, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2373, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1398, grad_fn=<SumBackward0>)
# load_path tensor(475820.0625, grad_fn=<DotBackward0>)
# R: tensor(2.4039e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.5032, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3583, 0.4017, 0.2874])
# Wins_grad tensor([-0.0043, -0.0255, -0.0253, -0.0242, -0.0233, -0.0228, -0.0006, -0.0006,
#         -0.0003])
# ite 164
# Iter 164 - Available Memory: 5341.45 MB
# q_ini: tensor(6.5032, grad_fn=<SelectBackward0>)
# span: tensor(19.6295, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2373, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1399, grad_fn=<SumBackward0>)
# load_path tensor(475945.5000, grad_fn=<DotBackward0>)
# R: tensor(2.4059e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.5110, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3594, 0.4027, 0.2880])
# Wins_grad tensor([-0.0042, -0.0255, -0.0253, -0.0242, -0.0233, -0.0228, -0.0006, -0.0006,
#         -0.0003])
# ite 165
# Iter 165 - Available Memory: 5321.36 MB
# q_ini: tensor(6.5110, grad_fn=<SelectBackward0>)
# span: tensor(19.6332, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2373, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1399, grad_fn=<SumBackward0>)
# load_path tensor(476071.4375, grad_fn=<DotBackward0>)
# R: tensor(2.4079e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.5188, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3605, 0.4037, 0.2886])
# Wins_grad tensor([-0.0042, -0.0255, -0.0253, -0.0242, -0.0233, -0.0228, -0.0006, -0.0006,
#         -0.0003])
# Iteration 165: Normalized Gradient = 0.05438268929719925, Adaptive learning rate = 0.1
# ite 166
# Iter 166 - Available Memory: 5311.07 MB
# q_ini: tensor(6.5188, grad_fn=<SelectBackward0>)
# span: tensor(19.6368, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2374, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1399, grad_fn=<SumBackward0>)
# load_path tensor(476195.6875, grad_fn=<DotBackward0>)
# R: tensor(2.4099e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.5266, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3616, 0.4048, 0.2892])
# Wins_grad tensor([-0.0042, -0.0255, -0.0253, -0.0242, -0.0233, -0.0228, -0.0006, -0.0006,
#         -0.0003])
# ite 167
# Iter 167 - Available Memory: 5314.04 MB
# q_ini: tensor(6.5266, grad_fn=<SelectBackward0>)
# span: tensor(19.6404, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2374, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1399, grad_fn=<SumBackward0>)
# load_path tensor(476320.3125, grad_fn=<DotBackward0>)
# R: tensor(2.4119e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.5344, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3627, 0.4058, 0.2898])
# Wins_grad tensor([-0.0042, -0.0255, -0.0253, -0.0242, -0.0234, -0.0228, -0.0006, -0.0006,
#         -0.0003])
# ite 168
# Iter 168 - Available Memory: 5301.36 MB
# q_ini: tensor(6.5344, grad_fn=<SelectBackward0>)
# span: tensor(19.6440, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2374, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1400, grad_fn=<SumBackward0>)
# load_path tensor(476443.3750, grad_fn=<DotBackward0>)
# R: tensor(2.4139e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.5421, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3638, 0.4068, 0.2904])
# Wins_grad tensor([-0.0042, -0.0255, -0.0253, -0.0242, -0.0234, -0.0228, -0.0006, -0.0005,
#         -0.0003])
# ite 169
# Iter 169 - Available Memory: 5280.76 MB
# q_ini: tensor(6.5421, grad_fn=<SelectBackward0>)
# span: tensor(19.6476, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2374, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1400, grad_fn=<SumBackward0>)
# load_path tensor(476567.1875, grad_fn=<DotBackward0>)
# R: tensor(2.4159e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.5499, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3649, 0.4078, 0.2910])
# Wins_grad tensor([-0.0042, -0.0255, -0.0253, -0.0242, -0.0234, -0.0228, -0.0006, -0.0005,
#         -0.0003])
# ite 170
# Iter 170 - Available Memory: 5271.41 MB
# q_ini: tensor(6.5499, grad_fn=<SelectBackward0>)
# span: tensor(19.6512, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2374, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1400, grad_fn=<SumBackward0>)
# load_path tensor(476688.6875, grad_fn=<DotBackward0>)
# R: tensor(2.4178e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.5576, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3660, 0.4088, 0.2915])
# Wins_grad tensor([-0.0042, -0.0255, -0.0253, -0.0242, -0.0234, -0.0229, -0.0006, -0.0005,
#         -0.0003])
# Iteration 170: Normalized Gradient = 0.05445638671517372, Adaptive learning rate = 0.1
# ite 171
# Iter 171 - Available Memory: 5284.82 MB
# q_ini: tensor(6.5576, grad_fn=<SelectBackward0>)
# span: tensor(19.6548, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2374, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1400, grad_fn=<SumBackward0>)
# load_path tensor(476810.5000, grad_fn=<DotBackward0>)
# R: tensor(2.4198e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.5653, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3671, 0.4098, 0.2921])
# Wins_grad tensor([-0.0042, -0.0255, -0.0253, -0.0243, -0.0234, -0.0229, -0.0006, -0.0005,
#         -0.0003])
# ite 172
# Iter 172 - Available Memory: 5277.39 MB
# q_ini: tensor(6.5653, grad_fn=<SelectBackward0>)
# span: tensor(19.6584, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2374, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1401, grad_fn=<SumBackward0>)
# load_path tensor(476932.3125, grad_fn=<DotBackward0>)
# R: tensor(2.4218e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.5731, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3682, 0.4108, 0.2927])
# Wins_grad tensor([-0.0042, -0.0255, -0.0253, -0.0243, -0.0234, -0.0229, -0.0006, -0.0005,
#         -0.0003])
# ite 173
# Iter 173 - Available Memory: 5260.43 MB
# q_ini: tensor(6.5731, grad_fn=<SelectBackward0>)
# span: tensor(19.6619, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2374, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1401, grad_fn=<SumBackward0>)
# load_path tensor(477053.1562, grad_fn=<DotBackward0>)
# R: tensor(2.4237e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.5807, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3693, 0.4118, 0.2932])
# Wins_grad tensor([-0.0042, -0.0255, -0.0253, -0.0243, -0.0234, -0.0229, -0.0006, -0.0005,
#         -0.0003])
# ite 174
# Iter 174 - Available Memory: 5258.46 MB
# q_ini: tensor(6.5807, grad_fn=<SelectBackward0>)
# span: tensor(19.6655, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2374, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1401, grad_fn=<SumBackward0>)
# load_path tensor(477173.5938, grad_fn=<DotBackward0>)
# R: tensor(2.4257e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.5884, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3704, 0.4127, 0.2938])
# Wins_grad tensor([-0.0042, -0.0255, -0.0253, -0.0243, -0.0234, -0.0229, -0.0006, -0.0005,
#         -0.0003])
# ite 175
# Iter 175 - Available Memory: 5246.90 MB
# q_ini: tensor(6.5884, grad_fn=<SelectBackward0>)
# span: tensor(19.6690, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2374, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1401, grad_fn=<SumBackward0>)
# load_path tensor(477293.2812, grad_fn=<DotBackward0>)
# R: tensor(2.4276e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.5961, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3715, 0.4137, 0.2944])
# Wins_grad tensor([-0.0042, -0.0255, -0.0253, -0.0243, -0.0234, -0.0229, -0.0006, -0.0005,
#         -0.0003])
# Iteration 175: Normalized Gradient = 0.05452948063611984, Adaptive learning rate = 0.1
# ite 176
# Iter 176 - Available Memory: 5230.57 MB
# q_ini: tensor(6.5961, grad_fn=<SelectBackward0>)
# span: tensor(19.6725, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2374, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1402, grad_fn=<SumBackward0>)
# load_path tensor(477412.5625, grad_fn=<DotBackward0>)
# R: tensor(2.4295e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([6.6037, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.3725, 0.4147, 0.2949])
# Wins_grad tensor([-0.0042, -0.0255, -0.0253, -0.0243, -0.0234, -0.0229, -0.0006, -0.0005,
#         -0.0003])
# ite 177
# Iter 177 - Available Memory: 5217.13 MB
# ...
# R: tensor(2.8314e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.4763, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6292, 0.5594, 0.3796])
# Wins_grad tensor([-3.0104e-03, -2.6003e-02, -2.6549e-02, -2.5911e-02, -2.5275e-02,
#         -2.4886e-02, -4.0264e-04, -1.0534e-04, -7.7815e-05])
# ite 477
# Iter 477 - Available Memory: 5520.66 MB
# q_ini: tensor(8.4763, grad_fn=<SelectBackward0>)
# span: tensor(20.3905, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1454, grad_fn=<SumBackward0>)
# load_path tensor(499527.6250, grad_fn=<DotBackward0>)
# R: tensor(2.8324e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.4815, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6299, 0.5596, 0.3797])
# Wins_grad tensor([-3.0079e-03, -2.6005e-02, -2.6552e-02, -2.5915e-02, -2.5279e-02,
#         -2.4890e-02, -4.0229e-04, -1.0461e-04, -7.7530e-05])
# ite 478
# Iter 478 - Available Memory: 5482.25 MB
# q_ini: tensor(8.4815, grad_fn=<SelectBackward0>)
# span: tensor(20.3922, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1454, grad_fn=<SumBackward0>)
# load_path tensor(499573.3750, grad_fn=<DotBackward0>)
# R: tensor(2.8333e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.4867, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6306, 0.5598, 0.3798])
# Wins_grad tensor([-3.0054e-03, -2.6006e-02, -2.6555e-02, -2.5918e-02, -2.5283e-02,
#         -2.4895e-02, -4.0189e-04, -1.0393e-04, -7.7241e-05])
# ite 479
# Iter 479 - Available Memory: 5471.02 MB
# q_ini: tensor(8.4867, grad_fn=<SelectBackward0>)
# span: tensor(20.3938, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1454, grad_fn=<SumBackward0>)
# load_path tensor(499619.5938, grad_fn=<DotBackward0>)
# R: tensor(2.8342e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.4919, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6313, 0.5600, 0.3800])
# Wins_grad tensor([-3.0029e-03, -2.6008e-02, -2.6557e-02, -2.5922e-02, -2.5288e-02,
#         -2.4900e-02, -4.0155e-04, -1.0325e-04, -7.6970e-05])
# ite 480
# Iter 480 - Available Memory: 5460.45 MB
# q_ini: tensor(8.4919, grad_fn=<SelectBackward0>)
# span: tensor(20.3955, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1454, grad_fn=<SumBackward0>)
# load_path tensor(499665., grad_fn=<DotBackward0>)
# R: tensor(2.8351e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.4971, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6320, 0.5602, 0.3801])
# Wins_grad tensor([-3.0003e-03, -2.6009e-02, -2.6560e-02, -2.5926e-02, -2.5292e-02,
#         -2.4904e-02, -4.0116e-04, -1.0260e-04, -7.6672e-05])
# Iteration 480: Normalized Gradient = 0.05764657258987427, Adaptive learning rate = 0.1
# ite 481
# Iter 481 - Available Memory: 5505.46 MB
# q_ini: tensor(8.4971, grad_fn=<SelectBackward0>)
# span: tensor(20.3971, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1455, grad_fn=<SumBackward0>)
# load_path tensor(499710.3750, grad_fn=<DotBackward0>)
# R: tensor(2.8360e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5023, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6327, 0.5603, 0.3802])
# Wins_grad tensor([-2.9979e-03, -2.6011e-02, -2.6563e-02, -2.5929e-02, -2.5296e-02,
#         -2.4909e-02, -4.0076e-04, -1.0184e-04, -7.6435e-05])
# ite 482
# Iter 482 - Available Memory: 5477.33 MB
# q_ini: tensor(8.5023, grad_fn=<SelectBackward0>)
# span: tensor(20.3988, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1455, grad_fn=<SumBackward0>)
# load_path tensor(499755.2812, grad_fn=<DotBackward0>)
# R: tensor(2.8370e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5075, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6334, 0.5605, 0.3804])
# Wins_grad tensor([-2.9954e-03, -2.6012e-02, -2.6565e-02, -2.5933e-02, -2.5300e-02,
#         -2.4913e-02, -4.0042e-04, -1.0122e-04, -7.6165e-05])
# ite 483
# Iter 483 - Available Memory: 5445.99 MB
# q_ini: tensor(8.5075, grad_fn=<SelectBackward0>)
# span: tensor(20.4004, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1455, grad_fn=<SumBackward0>)
# load_path tensor(499800.9375, grad_fn=<DotBackward0>)
# R: tensor(2.8379e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5127, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6341, 0.5607, 0.3805])
# Wins_grad tensor([-2.9929e-03, -2.6014e-02, -2.6568e-02, -2.5937e-02, -2.5304e-02,
#         -2.4918e-02, -4.0005e-04, -1.0049e-04, -7.5876e-05])
# ite 484
# Iter 484 - Available Memory: 5444.13 MB
# q_ini: tensor(8.5127, grad_fn=<SelectBackward0>)
# span: tensor(20.4021, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1455, grad_fn=<SumBackward0>)
# load_path tensor(499846.6562, grad_fn=<DotBackward0>)
# R: tensor(2.8388e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5179, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6348, 0.5609, 0.3806])
# Wins_grad tensor([-2.9904e-03, -2.6015e-02, -2.6571e-02, -2.5941e-02, -2.5309e-02,
#         -2.4922e-02, -3.9966e-04, -9.9842e-05, -7.5641e-05])
# ite 485
# Iter 485 - Available Memory: 5432.53 MB
# q_ini: tensor(8.5179, grad_fn=<SelectBackward0>)
# span: tensor(20.4037, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1455, grad_fn=<SumBackward0>)
# load_path tensor(499891.3125, grad_fn=<DotBackward0>)
# R: tensor(2.8397e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5231, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6355, 0.5610, 0.3808])
# Wins_grad tensor([-2.9879e-03, -2.6017e-02, -2.6573e-02, -2.5944e-02, -2.5313e-02,
#         -2.4926e-02, -3.9924e-04, -9.9198e-05, -7.5342e-05])
# Iteration 485: Normalized Gradient = 0.057682737708091736, Adaptive learning rate = 0.1
# ite 486
# Iter 486 - Available Memory: 5419.37 MB
# q_ini: tensor(8.5231, grad_fn=<SelectBackward0>)
# span: tensor(20.4053, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1455, grad_fn=<SumBackward0>)
# load_path tensor(499935.8438, grad_fn=<DotBackward0>)
# R: tensor(2.8406e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5282, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6362, 0.5612, 0.3809])
# Wins_grad tensor([-2.9854e-03, -2.6018e-02, -2.6576e-02, -2.5948e-02, -2.5317e-02,
#         -2.4931e-02, -3.9887e-04, -9.8509e-05, -7.5083e-05])
# ite 487
# Iter 487 - Available Memory: 5393.14 MB
# q_ini: tensor(8.5282, grad_fn=<SelectBackward0>)
# span: tensor(20.4070, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1455, grad_fn=<SumBackward0>)
# load_path tensor(499980.7500, grad_fn=<DotBackward0>)
# R: tensor(2.8415e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5334, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6369, 0.5614, 0.3810])
# Wins_grad tensor([-2.9830e-03, -2.6020e-02, -2.6579e-02, -2.5952e-02, -2.5321e-02,
#         -2.4935e-02, -3.9850e-04, -9.7829e-05, -7.4802e-05])
# ite 488
# Iter 488 - Available Memory: 5377.51 MB
# q_ini: tensor(8.5334, grad_fn=<SelectBackward0>)
# span: tensor(20.4086, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1455, grad_fn=<SumBackward0>)
# load_path tensor(500026.2500, grad_fn=<DotBackward0>)
# R: tensor(2.8424e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5386, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6375, 0.5615, 0.3811])
# Wins_grad tensor([-2.9805e-03, -2.6021e-02, -2.6581e-02, -2.5955e-02, -2.5325e-02,
#         -2.4940e-02, -3.9815e-04, -9.7188e-05, -7.4558e-05])
# ite 489
# Iter 489 - Available Memory: 5351.24 MB
# q_ini: tensor(8.5386, grad_fn=<SelectBackward0>)
# span: tensor(20.4102, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1455, grad_fn=<SumBackward0>)
# load_path tensor(500070.6562, grad_fn=<DotBackward0>)
# R: tensor(2.8433e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5437, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6382, 0.5617, 0.3813])
# Wins_grad tensor([-2.9780e-03, -2.6023e-02, -2.6584e-02, -2.5959e-02, -2.5330e-02,
#         -2.4944e-02, -3.9778e-04, -9.6522e-05, -7.4293e-05])
# ite 490
# Iter 490 - Available Memory: 5294.85 MB
# q_ini: tensor(8.5437, grad_fn=<SelectBackward0>)
# span: tensor(20.4118, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1456, grad_fn=<SumBackward0>)
# load_path tensor(500115.0625, grad_fn=<DotBackward0>)
# R: tensor(2.8442e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5489, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6389, 0.5619, 0.3814])
# Wins_grad tensor([-2.9756e-03, -2.6024e-02, -2.6587e-02, -2.5963e-02, -2.5334e-02,
#         -2.4948e-02, -3.9733e-04, -9.5840e-05, -7.4009e-05])
# Iteration 490: Normalized Gradient = 0.05771825090050697, Adaptive learning rate = 0.1
# ite 491
# Iter 491 - Available Memory: 5344.18 MB
# q_ini: tensor(8.5489, grad_fn=<SelectBackward0>)
# span: tensor(20.4135, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1456, grad_fn=<SumBackward0>)
# load_path tensor(500159.0625, grad_fn=<DotBackward0>)
# R: tensor(2.8451e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5540, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6396, 0.5620, 0.3815])
# Wins_grad tensor([-2.9731e-03, -2.6026e-02, -2.6589e-02, -2.5966e-02, -2.5338e-02,
#         -2.4953e-02, -3.9698e-04, -9.5161e-05, -7.3758e-05])
# ite 492
# Iter 492 - Available Memory: 5297.78 MB
# q_ini: tensor(8.5540, grad_fn=<SelectBackward0>)
# span: tensor(20.4151, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1456, grad_fn=<SumBackward0>)
# load_path tensor(500203.5625, grad_fn=<DotBackward0>)
# R: tensor(2.8460e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5592, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6403, 0.5622, 0.3817])
# Wins_grad tensor([-2.9707e-03, -2.6027e-02, -2.6592e-02, -2.5970e-02, -2.5342e-02,
#         -2.4957e-02, -3.9660e-04, -9.4565e-05, -7.3509e-05])
# ite 493
# Iter 493 - Available Memory: 5266.04 MB
# q_ini: tensor(8.5592, grad_fn=<SelectBackward0>)
# span: tensor(20.4167, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1456, grad_fn=<SumBackward0>)
# load_path tensor(500247.7188, grad_fn=<DotBackward0>)
# R: tensor(2.8469e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5643, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6410, 0.5624, 0.3818])
# Wins_grad tensor([-2.9682e-03, -2.6029e-02, -2.6594e-02, -2.5973e-02, -2.5346e-02,
#         -2.4961e-02, -3.9631e-04, -9.3859e-05, -7.3232e-05])
# ite 494
# Iter 494 - Available Memory: 5264.09 MB
# q_ini: tensor(8.5643, grad_fn=<SelectBackward0>)
# span: tensor(20.4183, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1456, grad_fn=<SumBackward0>)
# load_path tensor(500292., grad_fn=<DotBackward0>)
# R: tensor(2.8478e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5695, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6417, 0.5625, 0.3819])
# Wins_grad tensor([-2.9658e-03, -2.6030e-02, -2.6597e-02, -2.5977e-02, -2.5350e-02,
#         -2.4966e-02, -3.9589e-04, -9.3248e-05, -7.3021e-05])
# ite 495
# Iter 495 - Available Memory: 5261.15 MB
# q_ini: tensor(8.5695, grad_fn=<SelectBackward0>)
# span: tensor(20.4199, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1456, grad_fn=<SumBackward0>)
# load_path tensor(500335.8125, grad_fn=<DotBackward0>)
# R: tensor(2.8487e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5746, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6424, 0.5627, 0.3820])
# Wins_grad tensor([-2.9634e-03, -2.6032e-02, -2.6600e-02, -2.5981e-02, -2.5354e-02,
#         -2.4970e-02, -3.9549e-04, -9.2570e-05, -7.2730e-05])
# Iteration 495: Normalized Gradient = 0.05775361508131027, Adaptive learning rate = 0.1
# ite 496
# Iter 496 - Available Memory: 5174.82 MB
# q_ini: tensor(8.5746, grad_fn=<SelectBackward0>)
# span: tensor(20.4215, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1456, grad_fn=<SumBackward0>)
# load_path tensor(500379.4688, grad_fn=<DotBackward0>)
# R: tensor(2.8496e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5797, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6430, 0.5629, 0.3822])
# Wins_grad tensor([-2.9610e-03, -2.6033e-02, -2.6602e-02, -2.5984e-02, -2.5358e-02,
#         -2.4975e-02, -3.9520e-04, -9.1980e-05, -7.2503e-05])
# ite 497
# Iter 497 - Available Memory: 5177.22 MB
# q_ini: tensor(8.5797, grad_fn=<SelectBackward0>)
# span: tensor(20.4231, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1456, grad_fn=<SumBackward0>)
# load_path tensor(500423.1250, grad_fn=<DotBackward0>)
# R: tensor(2.8504e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5848, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6437, 0.5630, 0.3823])
# Wins_grad tensor([-2.9585e-03, -2.6034e-02, -2.6605e-02, -2.5988e-02, -2.5362e-02,
#         -2.4979e-02, -3.9480e-04, -9.1350e-05, -7.2238e-05])
# ite 498
# Iter 498 - Available Memory: 5151.35 MB
# q_ini: tensor(8.5848, grad_fn=<SelectBackward0>)
# span: tensor(20.4247, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1457, grad_fn=<SumBackward0>)
# load_path tensor(500466.9688, grad_fn=<DotBackward0>)
# R: tensor(2.8513e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5900, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6444, 0.5632, 0.3824])
# Wins_grad tensor([-2.9561e-03, -2.6036e-02, -2.6607e-02, -2.5991e-02, -2.5366e-02,
#         -2.4983e-02, -3.9439e-04, -9.0682e-05, -7.1987e-05])
# ite 499
# Iter 499 - Available Memory: 5146.97 MB
# q_ini: tensor(8.5900, grad_fn=<SelectBackward0>)
# span: tensor(20.4263, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1457, grad_fn=<SumBackward0>)
# load_path tensor(500510.8125, grad_fn=<DotBackward0>)
# R: tensor(2.8522e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.5951, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6451, 0.5633, 0.3825])
# Wins_grad tensor([-2.9537e-03, -2.6038e-02, -2.6610e-02, -2.5995e-02, -2.5371e-02,
#         -2.4988e-02, -3.9406e-04, -9.0061e-05, -7.1772e-05])
# ite 500
# Iter 500 - Available Memory: 5143.62 MB
# q_ini: tensor(8.5951, grad_fn=<SelectBackward0>)
# span: tensor(20.4279, grad_fn=<MeanBackward0>)
# Ratio tensor(0.2381, grad_fn=<DivBackward0>)
# Estrain: tensor(0.1457, grad_fn=<SumBackward0>)
# load_path tensor(500553.7812, grad_fn=<DotBackward0>)
# R: tensor(2.8531e-07, grad_fn=<VarBackward0>)
# ite height: tensor(4.0000, grad_fn=<UnbindBackward0>)
# Wins_q tensor([8.6002, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6458, 0.5635, 0.3827])
# Wins_grad tensor([-2.9513e-03, -2.6039e-02, -2.6613e-02, -2.5998e-02, -2.5374e-02,
#         -2.4992e-02, -3.9367e-04, -8.9346e-05, -7.1475e-05])
# Saved full states to results/FDM_States_6.png
# Iteration 500: Normalized Gradient = 0.05778839811682701, Adaptive learning rate = 0.1
# Optimization completed.
# tensor([8.6002, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 0.6458, 0.5635, 0.3827],
#        requires_grad=True)
# Estrain: tensor(0.1457, grad_fn=<SumBackward0>)
# Height 4.0000005

# %%
########################

# %%
#######################

# %%
##### Visual
#############################################################################################################
## Visualization 1
x_orig = grid_points[:, 0].cpu().detach().numpy()
y_orig = grid_points[:, 1].cpu().detach().numpy()
z_orig = grid_points[:, 2].cpu().detach().numpy()

new_coords = new_node_coords
x_fdm = new_coords[:, 0].cpu().detach().numpy()
y_fdm = new_coords[:, 1].cpu().detach().numpy()
z_fdm = new_coords[:, 2].cpu().detach().numpy()

Max_height = max(z_fdm)
fig = go.Figure()

force_np = force.cpu().detach().numpy()
abs_forces = np.abs(force_np)
abs_forces = np.round(abs_forces)

ratio = [0.01, 0.3, 0.7, 0.9]  
max_force = np.max(abs_forces)  
thresholds = np.array(ratio) * max_force  
width_levels = np.digitize(abs_forces, thresholds) 
line_widths = [1, 3, 5, 7, 9] 
# line_widths = [1, 1, 1, 1, 1] 

# First clear all existing traces (optional, depends on your needs)
fig.data = []

for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_orig[i-1], x_orig[j-1]],
        y=[y_orig[i-1], y_orig[j-1]],
        z=[z_orig[i-1], z_orig[j-1]],
        mode='lines',
        line=dict(
            color='blue',
            width=1
        ),
        opacity=0.1,  # 修改 opacity 为数值（0.0~1.0），而不是字符串
        name='Grid',
        showlegend=False
    ))

# Add FDM solution traces with width based on force magnitude
for idx, connection in enumerate(connectivity):
    i, j = connection
    width_level = width_levels[idx]  # digitize returns 1-based index
    current_width = line_widths[width_level]
    
    fig.add_trace(go.Scatter3d(
        x=[x_fdm[i-1], x_fdm[j-1]],
        y=[y_fdm[i-1], y_fdm[j-1]],
        z=[z_fdm[i-1], z_fdm[j-1]],
        mode='lines',
        line=dict(color='black', width=current_width),
        name=f'FDM solution (Level {width_level+1})',
        showlegend=False
    ))
    

arrow_scale = 3.0  # Adjust this to change arrow size
for node in Free_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_fdm[node-1], x_fdm[node-1]],
        y=[y_fdm[node-1], y_fdm[node-1]+ arrow_scale],
        z=[z_fdm[node-1], z_fdm[node-1]],
        mode='lines',
        line=dict(
            color='red',
            width=1  # Arrow shaft width
        ),
        name=f'Load at Node {node}',
        showlegend=False
    ))
    # Add arrow head
    fig.add_trace(go.Cone(
        x=[x_fdm[node-1]],
        y=[y_fdm[node-1]+ arrow_scale],
        z=[z_fdm[node-1]],
        u=[0],
        v=[0.1],
        w=[0],
        sizemode="absolute",
        sizeref=0.4,
        anchor="tip",
        colorscale=[[0, 'red'], [1, 'red']],
        showscale=False
    ))


# Add fixed nodes
for node in Fixed_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_fdm[node-1]],
        y=[y_fdm[node-1]],
        z=[z_fdm[node-1]],
        mode='markers+text',
        marker=dict(size=5, color='black'),
        name=f'Fixed Node {node}',
        showlegend=False
    ))

    # 白点配置
    
node_marker_config = {
    'size': 3,          
    'color': 'white',   
    'opacity': 1,       
    'line': {           
        'width': 4,     
        'color': 'black' 
    }
}

# 然后在使用时：
# 将Fixed_nodes从Tensor转换为list
if torch.is_tensor(Fixed_nodes):
    Fixed_nodes_list = Fixed_nodes.cpu().tolist()
else:
    Fixed_nodes_list = list(Fixed_nodes)
    
all_nodes = list(set(Fixed_nodes_list + Free_nodes)) 
for node in all_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_fdm[node-1]],
        y=[y_fdm[node-1]],
        z=[z_fdm[node-1]],
        mode='markers',
        marker=node_marker_config,
        name=f'Node {node}',
        showlegend=False
    ))

    
         
force_traces = []
for idx, connection in enumerate(connectivity):
    i, j = connection
    mid_x = (x_fdm[i-1] + x_fdm[j-1]) / 2
    mid_y = (y_fdm[i-1] + y_fdm[j-1]) / 2
    mid_z = (z_fdm[i-1] + z_fdm[j-1]) / 2
    trace = go.Scatter3d(
        x=[mid_x],
        y=[mid_y],
        z=[mid_z],
        mode='markers+text',
        marker=dict(size=1, color='green'),
        text=[f"{force_np[idx]:.0f}"],
        textposition='top center',
        textfont=dict(size=8),
        name=f'Force {idx+1}',
        visible=True
    )
    force_traces.append(trace)
    fig.add_trace(trace)
fig.update_layout(
    updatemenus=[
        dict(
            type="buttons",
            direction="right",
            x=0.1,
            y=1.1,
            buttons=[
                dict(
                    label="✅ Show forces",
                    method="update",
                    args=[{"visible": [True] * len(fig.data)}],
                ),
                dict(
                    label="❌ Hide forces",
                    method="update",
                    args=[{"visible": [True] * (len(fig.data) - len(force_traces)) + [False] * len(force_traces)}],
                )
            ]
        )
    ],
    scene=dict(
        xaxis=dict(
            showbackground=False,
            showgrid=False,
            showline=False,
            showticklabels=False,
            title=''
        ),
        yaxis=dict(
            showbackground=False,
            showgrid=False,
            showline=False,
            showticklabels=False,
            title=''
        ),
        zaxis=dict(
            showbackground=False,
            showgrid=False,
            showline=False,
            showticklabels=False,
            
            title=''
        ),
        aspectmode='data'
    ),
    title='OPT',
    annotations=[
        dict(
            x=0.05,  # X position (0-1, left to right)
            y=0.95,  # Y position (0-1, bottom to top)
            xref="paper",
            yref="paper",
            # text=f"Strain energy= {Total_ES:.4f}, Volume = {Volume:.4f}, Max_height = {Max_height:.4f}, Load_path  = {load_path :.4f} ",
            showarrow=False,
            font=dict(
                size=14,
                color="black"
            ),
            bgcolor="white",
            bordercolor="black",
            borderwidth=1,
            borderpad=4
        )
    ]
)
fig.show()

fig.write_html("E_strain Opt(Z).html")

# print(f"Strain energy= {Total_ES:.4f}, Volume = {Volume:.4f}, Max_height = {Max_height:.4f}, Load_path  = {load_path :.4f} ")

# %%
##### Visual
#############################################################################################################
## Visualization 1
x_orig = grid_points[:, 0].cpu().detach().numpy()
y_orig = grid_points[:, 1].cpu().detach().numpy()
z_orig = grid_points[:, 2].cpu().detach().numpy()

new_coords = new_node_coords
x_fdm = new_coords[:, 0].cpu().detach().numpy()
y_fdm = new_coords[:, 1].cpu().detach().numpy()
z_fdm = new_coords[:, 2].cpu().detach().numpy()

Max_height = max(z_fdm)
fig = go.Figure()

force_np = force.cpu().detach().numpy()
abs_forces = np.abs(force_np)
abs_forces = np.round(abs_forces)

ratio = [0.01, 0.3, 0.7, 0.9]  
max_force = np.max(abs_forces)  
thresholds = np.array(ratio) * max_force  
width_levels = np.digitize(abs_forces, thresholds) 
line_widths = [1, 3, 5, 7, 9] 
# line_widths = [1, 1, 1, 1, 1]

# First clear all existing traces (optional, depends on your needs)
fig.data = []

for connection in connectivity:
    i, j = connection
    fig.add_trace(go.Scatter3d(
        x=[x_orig[i-1], x_orig[j-1]],
        y=[y_orig[i-1], y_orig[j-1]],
        z=[z_orig[i-1], z_orig[j-1]],
        mode='lines',
        line=dict(
            color='blue',
            width=1
        ),
        opacity=0.1,  # 修改 opacity 为数值（0.0~1.0），而不是字符串
        name='Grid',
        showlegend=False
    ))

# Add FDM solution traces with width based on force magnitude
for idx, connection in enumerate(connectivity):
    i, j = connection
    width_level = width_levels[idx]  # digitize returns 1-based index
    current_width = line_widths[width_level]
    
    fig.add_trace(go.Scatter3d(
        x=[x_fdm[i-1], x_fdm[j-1]],
        y=[y_fdm[i-1], y_fdm[j-1]],
        z=[z_fdm[i-1], z_fdm[j-1]],
        mode='lines',
        line=dict(color='firebrick', width=current_width),
        name=f'FDM solution (Level {width_level+1})',
        showlegend=False
    ))
    

# arrow_scale = 1.2  # Adjust this to change arrow size
# for node in Free_nodes:
#     fig.add_trace(go.Scatter3d(
#         x=[x_fdm[node-1], x_fdm[node-1]],
#         y=[y_fdm[node-1], y_fdm[node-1]+ arrow_scale],
#         z=[z_fdm[node-1], z_fdm[node-1]],
#         mode='lines',
#         line=dict(
#             color='red',
#             width=1  # Arrow shaft width
#         ),
#         name=f'Load at Node {node}',
#         showlegend=False
#     ))
#     # Add arrow head
#     fig.add_trace(go.Cone(
#         x=[x_fdm[node-1]],
#         y=[y_fdm[node-1]+ arrow_scale],
#         z=[z_fdm[node-1]],
#         u=[0],
#         v=[0.1],
#         w=[0],
#         sizemode="absolute",
#         sizeref=0.4,
#         anchor="tip",
#         colorscale=[[0, 'red'], [1, 'red']],
#         showscale=False
#     ))


# Add fixed nodes
for node in Fixed_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_fdm[node-1]],
        y=[y_fdm[node-1]],
        z=[z_fdm[node-1]],
        mode='markers+text',
        marker=dict(size=5, color='black'),
        name=f'Fixed Node {node}',
        showlegend=False
    ))

    # 白点配置
    
node_marker_config = {
    'size': 3,          
    'color': 'white',   
    'opacity': 1,       
    'line': {           
        'width': 4,     
        'color': 'black' 
    }
}

# 然后在使用时：
# 将Fixed_nodes从Tensor转换为list
if torch.is_tensor(Fixed_nodes):
    Fixed_nodes_list = Fixed_nodes.cpu().tolist()
else:
    Fixed_nodes_list = list(Fixed_nodes)
    
all_nodes = list(set(Fixed_nodes_list + Free_nodes)) 
for node in all_nodes:
    fig.add_trace(go.Scatter3d(
        x=[x_fdm[node-1]],
        y=[y_fdm[node-1]],
        z=[z_fdm[node-1]],
        mode='markers',
        marker=node_marker_config,
        name=f'Node {node}',
        showlegend=False
    ))

    
         
force_traces = []
for idx, connection in enumerate(connectivity):
    i, j = connection
    mid_x = (x_fdm[i-1] + x_fdm[j-1]) / 2
    mid_y = (y_fdm[i-1] + y_fdm[j-1]) / 2
    mid_z = (z_fdm[i-1] + z_fdm[j-1]) / 2
    trace = go.Scatter3d(
        x=[mid_x],
        y=[mid_y],
        z=[mid_z],
        mode='markers+text',
        marker=dict(size=1, color='green'),
        text=[f"{force_np[idx]:.0f}"],
        textposition='top center',
        textfont=dict(size=8),
        name=f'Force {idx+1}',
        visible=True
    )
    force_traces.append(trace)
    fig.add_trace(trace)
fig.update_layout(
    updatemenus=[
        dict(
            type="buttons",
            direction="right",
            x=0.1,
            y=1.1,
            buttons=[
                dict(
                    label="✅ Show forces",
                    method="update",
                    args=[{"visible": [True] * len(fig.data)}],
                ),
                dict(
                    label="❌ Hide forces",
                    method="update",
                    args=[{"visible": [True] * (len(fig.data) - len(force_traces)) + [False] * len(force_traces)}],
                )
            ]
        )
    ],
    scene=dict(
        xaxis=dict(
            showbackground=False,
            showgrid=False,
            showline=False,
            showticklabels=False,
            title=''
        ),
        yaxis=dict(
            showbackground=False,
            showgrid=False,
            showline=False,
            showticklabels=False,
            title=''
        ),
        zaxis=dict(
            showbackground=False,
            showgrid=False,
            showline=False,
            showticklabels=False,
            
            title=''
        ),
        aspectmode='data'
    ),
    title='OPT',
    annotations=[
        dict(
            x=0.05,  # X position (0-1, left to right)
            y=0.95,  # Y position (0-1, bottom to top)
            xref="paper",
            yref="paper",
            text=f"Strain energy= {Total_ES:.4f}, Volume = {Volume:.4f}, Max_height = {Max_height:.4f}, Load_path  = {load_path :.4f} ",
            showarrow=False,
            font=dict(
                size=14,
                color="black"
            ),
            bgcolor="white",
            bordercolor="black",
            borderwidth=1,
            borderpad=4
        )
    ]
)
fig.show()

fig.write_html("FE_a.html")

# %%
############## Optimization loop

#### Initializing Data storage
os.makedirs("data_records", exist_ok=True)
optimization_data = {
    "metadata": {
        "project": "Structural Optimization",
        "Context": "FDM + FE",
        "device": str(device),
        "parameters": {
            "length": length,
            "width": width,
            "grid_size": f"{n1}x{n2}",
            "epochs": epochs,
            "step_size": step
        }
    },
    "iterations": []
}

####### Loop start
n_elem = len(connectivity)
start_time = time.time()
epochs = 0
cut = epochs / 5
ES_his = []
LP_his = []
LS_his = []
count = 0

# Loop start
for iteration in range(epochs + 1):
    print('ite', iteration)
    
    iter_start = time.time() 
    
    avail_mem = check_available_memory()
    print(f"Iter {iteration} - Available Memory: {avail_mem:.2f} MB")
    if avail_mem < 1000: 
        print(f"⚠️  Low memory warning: {avail_mem:.2f} MB left!")
        
    
    # Forwards
    #### Curved grid
    q_ini =  torch.ones(n_elements)
    q_ini[edge_indices] = torch.tensor([5.0]) 
    Q_ini = torch.diag(q_ini)   
    ini_grid = FDM(Q_ini, F_ini, grid_points, N, F, px_ini, py_ini, pz_ini, id_CF,id_CN)
    
    q_v, q_h = q[0], q[1] 
    q_V = Symmetry_shaper(q_v, V_matrix)
    q_H = Symmetry_shaper(q_h, H_matrix)
    
    q_vec = torch.zeros(n_elements, device=device)
    
    for i in range(V_matrix.shape[0]): 
        for j in range(V_matrix.shape[1]): 
            index = V_matrix[i, j].item()  
            q_vec[index] = q_V[i, j] 
    for i in range(H_matrix.shape[0]):  
        for j in range(H_matrix.shape[1]):  
            index = H_matrix[i, j].item() 
            q_vec[index] = q_H[i, j] 
        
    Q = torch.diag(q_vec) * 1 / r  # scaling
    new_node_coords = FDM(Q, F_value, ini_grid)
    height = max(new_node_coords[:,2])
    
    span =  torch.abs(
    new_node_coords[span_nodes[:10], 1] -  
    new_node_coords[span_nodes[-10:], 1]   
    ).mean()
    
    ####### FDM time
    FDM_time = (time.time() - iter_start) / 60
        
    N_coords = new_node_coords.clone()
    FE_str = time.time()
    Strain_energy, forces, displacements, ASE, Beam_lens, R, V = Strain_E(N_coords, connectivity, fixed_dof, F_fe)
    
    ######## FE time
    FE_time = (time.time() - FE_str) / 60       
    force = abs(forces[:, 0, 0])
    load_path = torch.dot(force , Beam_lens)

    Total_ES = torch.sum(Strain_energy) 
    Axial_rate = torch.sum(ASE) / Total_ES

    Volume = torch.sum(V)
    Loss = Total_ES / span

    print('span:',span)
 

    LP_his.append(load_path.item()) 
    ES_his.append(Total_ES.item())
    LS_his.append(Loss.clone().detach().item())
    
    print("Estrain:", Total_ES)
    print('ite height:', height)

    ############################ Deformation
    N_coords = N_coords.reshape(-1)
    New_Coordinates = torch.zeros(n_nodes * 3, dtype=torch.float32, device=device)
    for n in range(n_nodes):
        New_Coordinates[3*n : 3*n+3] = N_coords[3*n : 3*n+3] + displacements[6*n : 6*n+3]
    New_Coordinates = New_Coordinates.view(n_nodes, 3).clone()
        
    # Backwards
    
    Back_str = time.time()
    if q.grad is not None:
        q.grad.detach_()
        q.grad.zero_()
       
    Total_ES.backward(retain_graph=True)
    Back_time = (time.time() - Back_str) / 60
    
    # Grad
    gradients = q.grad
    frob_norm = torch.norm(gradients)
    q = optimizer(q, gradients, step)
    
    Wins_q = q.cpu().clone().detach()   
    print('Wins_q', Wins_q)    
    print('Wins_grad', gradients) 

    ####### Data storage:
    iteration_record = {
    "iteration": iteration,
    "variables": q.detach().cpu().numpy().tolist(),
    "strain_energy": Total_ES.item(),
    "Load_path": load_path.item(),
    "Axial SE ratio": Axial_rate.item(),
    "Volume": Volume.item(),
    "R": R.item(),
    "gradient_norm": torch.norm(gradients).item() if q.grad is not None else 0.0,
               "timing": {
            "FDM_time": FDM_time,
            "FE_time": FE_time,
            "Back_propagation time": Back_time,
        },
    }  
    optimization_data["iterations"].append(iteration_record)

    # if iteration % cut == 0 or iteration == 0:
    #     state_idx = iteration // cut  
    #     save_fdm(state_idx, grid_points, new_node_coords, 
    #             connectivity, Free_nodes, Fixed_nodes, 
    #             force, Total_ES.detach().cpu().item())
    
    # print iteration
    if iteration % 5 == 0:
        print(f"Iteration {iteration}: Normalized Gradient = {frob_norm}, Adaptive learning rate = {step}")

    if iteration % 10 == 0:
        torch.cuda.empty_cache() if torch.cuda.is_available() else None
        gc.collect()
            
    # ######## Early stopping
    # if iteration > 0:  
    #     Pre_Total_ES = ES_his[iteration - 1]  
    #     change = abs(Total_ES - Pre_Total_ES) / Pre_Total_ES 
    #     if change < 1/100000:
    #         count += 1
    #     else:
    #         count = 0 
    #     if count >= patience:
    #         print(f"Early stopping at iteration {iteration}: Total_ES change < 1%% for {patience} consecutive iterations.")
    #         break 
            

finalize_fdm()
total_time = (time.time() - iter_start) / 60
optimization_data["metadata"].update({
    "Ite_time": total_time,
})

with open(os.path.join("data_records", "FULL_data.json"), 'w') as f:
    json.dump(optimization_data, f, indent=2)
    
print("Optimization completed.")
print(q)
print("Estrain:", Total_ES)
print('Height',max(new_node_coords[:, 2].cpu().detach().numpy()))
